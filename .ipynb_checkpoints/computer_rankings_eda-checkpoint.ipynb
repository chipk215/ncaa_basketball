# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import learning_curve
from IPython.core.debugger import set_trace
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)
# Out:
# Seaborn version:  0.9.0

# %%
summary_data = pd.read_csv('massey_seasons_with_id.csv')
summary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5454 entries, 0 to 5453
# Data columns (total 13 columns):
# SAG          5454 non-null int64
# WLK          5454 non-null float64
# WOL          5454 non-null int64
# Team         5454 non-null object
# RTH          5454 non-null int64
# COL          5454 non-null float64
# POM          5454 non-null float64
# DOL          5454 non-null float64
# RPI          5454 non-null float64
# MOR          5454 non-null int64
# season       5454 non-null int64
# win_pct      5454 non-null float64
# kaggle_id    5454 non-null object
# dtypes: float64(6), int64(5), object(2)
# memory usage: 554.0+ KB

# %%
summary_data.describe()
# Out:
#                SAG          WLK          WOL          RTH          COL  \
# count  5454.000000  5454.000000  5454.000000  5454.000000  5454.000000
# mean    171.387055   171.340484   171.412725   171.364503   171.321782
# std      98.977414    98.926046    98.995735    98.973345    98.887448
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%      86.000000    86.000000    86.000000    86.000000    86.000000
# 50%     171.000000   171.000000   171.000000   171.000000   171.000000
# 75%     257.000000   257.000000   257.000000   257.000000   256.750000
# max     351.000000   351.000000   351.000000   351.000000   351.000000
#
#                POM          DOL          RPI          MOR       season  \
# count  5454.000000  5454.000000  5454.000000  5454.000000  5454.000000
# mean    171.310231   171.341217   171.283645   171.301247  2010.621746
# std      98.906044    98.922645    98.868126    98.914325     4.595077
# min       1.000000     1.000000     1.000000     1.000000  2003.000000
# 25%      86.000000    86.000000    86.000000    86.000000  2007.000000
# 50%     171.000000   171.000000   171.000000   171.000000  2011.000000
# 75%     257.000000   257.000000   256.000000   257.000000  2015.000000
# max     351.000000   351.000000   351.000000   351.000000  2018.000000
#
#            win_pct
# count  5454.000000
# mean      0.513328
# std       0.179117
# min       0.000000
# 25%       0.387097
# 50%       0.515152
# 75%       0.645161
# max       1.000000

# %%
summary_data = summary_data[summary_data['season'] < 2018]
summary_data.describe()['season']
# Out:
# count    5103.000000
# mean     2010.114247
# std         4.308661
# min      2003.000000
# 25%      2006.000000
# 50%      2010.000000
# 75%      2014.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
summary_data[summary_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SAG, WLK, WOL, Team, RTH, COL, POM, DOL, RPI, MOR, season, win_pct, kaggle_id]
# Index: []

# %%
#summary_data[summary_data['season']==2013][['Team','SAG']].sort_values(by=['SAG'])

# %%
tourney_data = pd.read_csv('tournament_results.csv')
tourney_data.drop(columns=['days_from_epoch','day','num_ot','academic_year','win_region','win_alias','lose_region',
                           'lose_alias','lose_code_ncaa','win_school_ncaa','win_code_ncaa','win_name','lose_name',
                           'win_pts','win_kaggle_team_id','lose_school_ncaa','lose_kaggle_team_id','lose_pts'],inplace=True)

tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 9 columns):
# season          2117 non-null int64
# round           2117 non-null int64
# game_date       2117 non-null object
# win_seed        2117 non-null int64
# win_market      2117 non-null object
# win_team_id     2117 non-null object
# lose_seed       2117 non-null int64
# lose_market     2117 non-null object
# lose_team_id    2117 non-null object
# dtypes: int64(4), object(5)
# memory usage: 148.9+ KB

# %%
tourney_data[tourney_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [season, round, game_date, win_seed, win_market, win_team_id, lose_seed, lose_market, lose_team_id]
# Index: []

# %%
tourney_data = tourney_data[tourney_data['season'] >= 2003]
tourney_data.describe()['season']
# Out:
# count     981.000000
# mean     2010.085627
# std         4.325153
# min      2003.000000
# 25%      2006.000000
# 50%      2010.000000
# 75%      2014.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
tourney_data['game_result'] = 1
tourney_data.game_result = tourney_data.game_result.astype(int)
tourney_data.rename(columns={"win_seed":"team_seed","win_market":"team","win_team_id":"team_id"}, inplace=True)
tourney_data.rename(columns={"lose_seed":"opp_team_seed","lose_market":"opp_team","lose_team_id":"opp_team_id"}, inplace=True)
tourney_data['start_season'] = tourney_data['season'] -1
tourney_data
# Out:
#       season  round   game_date  team_seed                   team  \
# 10      2013     64  2013-03-22          9                 Temple
# 17      2011     64  2011-03-17          7                 Temple
# 27      2013     64  2013-03-21          5  Virginia Commonwealth
# 29      2012     64  2012-03-15         12  Virginia Commonwealth
# 30      2011      8  2011-03-27         11  Virginia Commonwealth
# 31      2011     16  2011-03-25         11  Virginia Commonwealth
# 32      2007     64  2007-03-15         11  Virginia Commonwealth
# 33      2011     32  2011-03-20         11  Virginia Commonwealth
# 34      2011     64  2011-03-18         11  Virginia Commonwealth
# 35      2011     68  2011-03-16         11  Virginia Commonwealth
# 36      2016     64  2016-03-18         10  Virginia Commonwealth
# 37      2013     64  2013-03-21          8         Colorado State
# 44      2017     64  2017-03-17         11           Rhode Island
# 46      2015     64  2015-03-19          5                   Utah
# 48      2016     64  2016-03-17          3                   Utah
# 49      2015     32  2015-03-21          5                   Utah
# 60      2005     64  2005-03-17          6                   Utah
# 61      2003     64  2003-03-21          9                   Utah
# 62      2005     32  2005-03-19          6                   Utah
# 72      2017     64  2017-03-17          3                 Baylor
# 73      2017     32  2017-03-19          3                 Baylor
# 74      2010     32  2010-03-20          3                 Baylor
# 75      2010     64  2010-03-18          3                 Baylor
# 76      2010     16  2010-03-26          3                 Baylor
# 77      2012     16  2012-03-23          3                 Baylor
# 78      2012     64  2012-03-15          3                 Baylor
# 79      2012     32  2012-03-17          3                 Baylor
# 80      2014     64  2014-03-21          6                 Baylor
# 81      2014     32  2014-03-23          6                 Baylor
# 82      2014     64  2014-03-21         14                 Mercer
# ...      ...    ...         ...        ...                    ...
# 2028    2016     64  2016-03-18          6             Notre Dame
# 2029    2017     64  2017-03-16          5             Notre Dame
# 2030    2015     32  2015-03-21          3             Notre Dame
# 2031    2015     16  2015-03-26          3             Notre Dame
# 2034    2015     64  2015-03-19          3             Notre Dame
# 2036    2003     64  2003-03-20          5             Notre Dame
# 2037    2011     64  2011-03-18          2             Notre Dame
# 2038    2003     32  2003-03-22          5             Notre Dame
# 2045    2013     64  2013-03-22         11              Minnesota
# 2054    2012     64  2012-03-16         15                 Lehigh
# 2057    2005     64  2005-03-18          5           Georgia Tech
# 2064    2010     64  2010-03-19         10           Georgia Tech
# 2072    2004      4  2004-04-03          3           Georgia Tech
# 2073    2004     32  2004-03-21          3           Georgia Tech
# 2074    2004      8  2004-03-28          3           Georgia Tech
# 2075    2004     16  2004-03-26          3           Georgia Tech
# 2076    2004     64  2004-03-19          3           Georgia Tech
# 2079    2004     64  2004-03-19          5               Illinois
# 2081    2004     32  2004-03-21          5               Illinois
# 2082    2013     64  2013-03-22          7               Illinois
# 2084    2005     16  2005-03-24          1               Illinois
# 2085    2005     64  2005-03-17          1               Illinois
# 2087    2005     32  2005-03-19          1               Illinois
# 2088    2005      4  2005-04-02          1               Illinois
# 2089    2005      8  2005-03-26          1               Illinois
# 2102    2003     64  2003-03-20          4               Illinois
# 2103    2006     64  2006-03-16          4               Illinois
# 2104    2011     64  2011-03-18          9               Illinois
# 2105    2005     68  2005-03-15         16                Oakland
# 2115    2003     64  2003-03-20         13                  Tulsa
#
#                                    team_id  opp_team_seed  \
# 10    8598d1b6-106b-4083-a512-2e495729525a              8
# 17    8598d1b6-106b-4083-a512-2e495729525a             10
# 27    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             12
# 29    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5
# 30    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              1
# 31    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             10
# 32    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              6
# 33    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              3
# 34    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              6
# 35    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             11
# 36    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              7
# 37    1a470730-f328-4fb1-8bbf-36a069e4d6b2              9
# 44    7e42bca2-3cd7-4aca-aa46-f190fe5d8eb4              6
# 46    0d037a5d-827a-44dd-8b70-57603d671d5d             12
# 48    0d037a5d-827a-44dd-8b70-57603d671d5d             14
# 49    0d037a5d-827a-44dd-8b70-57603d671d5d              4
# 60    0d037a5d-827a-44dd-8b70-57603d671d5d             11
# 61    0d037a5d-827a-44dd-8b70-57603d671d5d              8
# 62    0d037a5d-827a-44dd-8b70-57603d671d5d              3
# 72    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 73    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 74    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 75    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 76    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             10
# 77    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             10
# 78    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 79    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 80    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 81    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf              3
# 82    a14b0057-8eb5-43d2-a33b-666196da933e              3
# ...                                    ...            ...
# 2028  80962f09-8821-48b6-8cf0-0cf0eea56aa8             11
# 2029  80962f09-8821-48b6-8cf0-0cf0eea56aa8             12
# 2030  80962f09-8821-48b6-8cf0-0cf0eea56aa8              6
# 2031  80962f09-8821-48b6-8cf0-0cf0eea56aa8              7
# 2034  80962f09-8821-48b6-8cf0-0cf0eea56aa8             14
# 2036  80962f09-8821-48b6-8cf0-0cf0eea56aa8             12
# 2037  80962f09-8821-48b6-8cf0-0cf0eea56aa8             15
# 2038  80962f09-8821-48b6-8cf0-0cf0eea56aa8              4
# 2045  fa416692-7e09-4f0a-9bcf-0cf7d5149a14              6
# 2054  508f503f-dc57-4f4c-a01e-4f195e5c05c8              2
# 2057  0f63a6f5-bda7-4fd9-9271-8d33f555ca19             12
# 2064  0f63a6f5-bda7-4fd9-9271-8d33f555ca19              7
# 2072  0f63a6f5-bda7-4fd9-9271-8d33f555ca19              2
# 2073  0f63a6f5-bda7-4fd9-9271-8d33f555ca19              6
# 2074  0f63a6f5-bda7-4fd9-9271-8d33f555ca19              4
# 2075  0f63a6f5-bda7-4fd9-9271-8d33f555ca19             10
# 2076  0f63a6f5-bda7-4fd9-9271-8d33f555ca19             14
# 2079  150148c2-ca8f-414f-8f41-d94a55d4a122             12
# 2089          2004
# 2102          2002
# 2103          2005
# 2104          2010
# 2105          2004
# 2115          2002
#
# [981 rows x 11 columns]

# %%
tourney_data['copy_team'] = tourney_data['team']
tourney_data['copy_team_seed'] = tourney_data['team_seed']
tourney_data['copy_team_id'] = tourney_data['team_id']

#swap the team and opp team data
tourney_data.loc[1::2,'team'] = tourney_data.loc[1::2,'opp_team']
tourney_data.loc[1::2,'opp_team'] = tourney_data.loc[1::2,'copy_team']
tourney_data.loc[1::2,'team_seed'] = tourney_data.loc[1::2,'opp_team_seed']
tourney_data.loc[1::2,'opp_team_seed'] = tourney_data.loc[1::2,'copy_team_seed']
tourney_data.loc[1::2,'team_id'] = tourney_data.loc[1::2,'opp_team_id']
tourney_data.loc[1::2,'opp_team_id'] = tourney_data.loc[1::2,'copy_team_id']

# flip the game result
tourney_data.loc[1::2,'game_result'] = 0

#drop the temporary columns
tourney_data.drop(columns=['copy_team','copy_team_seed','copy_team_id','start_season'],inplace=True)
tourney_data.head()
# Out:
#     season  round   game_date  team_seed                   team  \
# 10    2013     64  2013-03-22          8   North Carolina State
# 17    2011     64  2011-03-17          7                 Temple
# 27    2013     64  2013-03-21         12                  Akron
# 29    2012     64  2012-03-15         12  Virginia Commonwealth
# 30    2011      8  2011-03-27          1                 Kansas
#
#                                  team_id  opp_team_seed  \
# 10  52df1e19-b142-4a76-a439-ad68455d0581              9
# 17  8598d1b6-106b-4083-a512-2e495729525a             10
# 27  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5
# 29  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5
# 30  fae4855b-1b64-4b40-a632-9ed345e1e952             11
#
#                  opp_team                           opp_team_id  game_result
# 10                 Temple  8598d1b6-106b-4083-a512-2e495729525a            0
# 17             Penn State  4aebd148-8119-4875-954c-66779867989b            1
# 27  Virginia Commonwealth  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0
# 29          Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 30  Virginia Commonwealth  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0

# %%
m_tourney_data = tourney_data.merge(summary_data, left_on=['season','team_id'], 
                                right_on=['season', 'kaggle_id'],how='left',suffixes=('','_y'))

m_tourney_data.head()

#m_tourney_data.drop(columns=['season_y','kaggle_id'],inplace=True)
# Out:
#    season  round   game_date  team_seed                   team  \
# 0    2013     64  2013-03-22          8   North Carolina State
# 1    2011     64  2011-03-17          7                 Temple
# 2    2013     64  2013-03-21         12                  Akron
# 3    2012     64  2012-03-15         12  Virginia Commonwealth
# 4    2011      8  2011-03-27          1                 Kansas
#
#                                 team_id  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  SAG   WLK  WOL  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0   25  27.0   36
# 1  4aebd148-8119-4875-954c-66779867989b            1   32  30.0   25
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0   62  55.0   52
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1   50  43.0   32
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0    2   2.0    3
#
#               Team  RTH   COL   POM   DOL   RPI  MOR   win_pct  \
# 0         NC State   28  32.0  35.0  32.0  33.0   24  0.705882
# 1           Temple   32  27.0  38.0  25.0  30.0   45  0.781250
# 2            Akron   59  50.0  54.0  46.0  42.0   60  0.812500
# 3  VA Commonwealth   54  35.0  47.0  33.0  38.0   55  0.823529
# 4           Kansas    2   1.0   3.0   2.0   1.0    3  0.942857
#
#                               kaggle_id
# 0  52df1e19-b142-4a76-a439-ad68455d0581
# 1  8598d1b6-106b-4083-a512-2e495729525a
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952

# %%
#m_tourney_data.head()
m_tourney_data[m_tourney_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [season, round, game_date, team_seed, team, team_id, opp_team_seed, opp_team, opp_team_id, game_result, SAG, WLK, WOL, Team, RTH, COL, POM, DOL, RPI, MOR, win_pct, kaggle_id]
# Index: []

# %%
tourney_data = m_tourney_data.merge(summary_data, left_on=['season','opp_team_id'], 
                                right_on=['season', 'kaggle_id'], how='left',suffixes=('_t','_o'))

# %%
tourney_data.head()
# Out:
#    season  round   game_date  team_seed                   team  \
# 0    2013     64  2013-03-22          8   North Carolina State
# 1    2011     64  2011-03-17          7                 Temple
# 2    2013     64  2013-03-21         12                  Akron
# 3    2012     64  2012-03-15         12  Virginia Commonwealth
# 4    2011      8  2011-03-27          1                 Kansas
#
#                                 team_id  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  SAG_t  WLK_t  WOL_t  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0     25   27.0     36
# 1  4aebd148-8119-4875-954c-66779867989b            1     32   30.0     25
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0     62   55.0     52
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1     50   43.0     32
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0      2    2.0      3
#
#             Team_t  RTH_t  COL_t  POM_t  DOL_t  RPI_t  MOR_t  win_pct_t  \
# 0         NC State     28   32.0   35.0   32.0   33.0     24   0.705882
# 1           Temple     32   27.0   38.0   25.0   30.0     45   0.781250
# 2            Akron     59   50.0   54.0   46.0   42.0     60   0.812500
# 3  VA Commonwealth     54   35.0   47.0   33.0   38.0     55   0.823529
# 4           Kansas      2    1.0    3.0    2.0    1.0      3   0.942857
#
#                             kaggle_id_t  SAG_o  WLK_o  WOL_o           Team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581     55   58.0     35           Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a     45   42.0     43          Penn St
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20     26   19.0     27  VA Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518     10   10.0     16       Wichita St
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952     77   55.0     54  VA Commonwealth
#
#    RTH_o  COL_o  POM_o  DOL_o  RPI_o  MOR_o  win_pct_o  \
# 0     47   40.0   68.0   45.0   41.0     52   0.718750
# 1     37   39.0   39.0   39.0   39.0     27   0.575758
# 2     27   27.0   21.0   31.0   24.0     16   0.764706
# 3     16   11.0   10.0   15.0   12.0     10   0.843750
# 4     74   59.0   84.0   72.0   49.0     80   0.676471
#
#                             kaggle_id_o
# 0  8598d1b6-106b-4083-a512-2e495729525a
# 1  4aebd148-8119-4875-954c-66779867989b
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518

# %%
tourney_data.rename(index=str,columns={'team_seed':'seed_t', 'opp_team_seed':'seed_o'},inplace=True)

# %%
tourney_data.drop(columns=['Team_t','Team_o','kaggle_id_o','kaggle_id_t'],inplace=True)
tourney_data.head()
# Out:
#    season  round   game_date  seed_t                   team  \
# 0    2013     64  2013-03-22       8   North Carolina State
# 1    2011     64  2011-03-17       7                 Temple
# 2    2013     64  2013-03-21      12                  Akron
# 3    2012     64  2012-03-15      12  Virginia Commonwealth
# 4    2011      8  2011-03-27       1                 Kansas
#
#                                 team_id  seed_o               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                             opp_team_id  game_result  SAG_t  WLK_t  WOL_t  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0     25   27.0     36
# 1  4aebd148-8119-4875-954c-66779867989b            1     32   30.0     25
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0     62   55.0     52
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1     50   43.0     32
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0      2    2.0      3
#
#    RTH_t  COL_t  POM_t  DOL_t  RPI_t  MOR_t  win_pct_t  SAG_o  WLK_o  WOL_o  \
# 0     28   32.0   35.0   32.0   33.0     24   0.705882     55   58.0     35
# 1     32   27.0   38.0   25.0   30.0     45   0.781250     45   42.0     43
# 2     59   50.0   54.0   46.0   42.0     60   0.812500     26   19.0     27
# 3     54   35.0   47.0   33.0   38.0     55   0.823529     10   10.0     16
# 4      2    1.0    3.0    2.0    1.0      3   0.942857     77   55.0     54
#
#    RTH_o  COL_o  POM_o  DOL_o  RPI_o  MOR_o  win_pct_o
# 0     47   40.0   68.0   45.0   41.0     52   0.718750
# 1     37   39.0   39.0   39.0   39.0     27   0.575758
# 2     27   27.0   21.0   31.0   24.0     16   0.764706
# 3     16   11.0   10.0   15.0   12.0     10   0.843750
# 4     74   59.0   84.0   72.0   49.0     80   0.676471

# %% [markdown]
# #### SAG Upsets

# %%
# t loses to o and t has higher ranking
upset_cond_1 = (tourney_data['game_result']==0) & (tourney_data['SAG_t'] < tourney_data['SAG_o'] )
# o loses to t and o has higher ranking
upset_cond_2 = (tourney_data['game_result']==1) & (tourney_data['SAG_t'] > tourney_data['SAG_o'] )

sag_upsets = tourney_data[upset_cond_1 | upset_cond_2][['season','round', 'team','opp_team','game_result','SAG_t','SAG_o']]

# %%
sag_upsets.head()
print(sag_upsets.shape)
# Out:
# (280, 7)

# %%
sns.catplot('season', kind='count',aspect=1.5, data=sag_upsets)

# %%
tournament_games = {}
for year in range(2003,2018,1):
    tournament_games[year] = tourney_data[tourney_data['season'] == year].shape[0]

# %%
def compute_percentage(x):
    #print(x)
    game_count = tournament_games[x[0]]
    #set_trace()
    val = 100.0 * len(x)/ game_count
    
    return val

# %%
ratings = ['seed','SAG','WLK','WOL','RTH','COL','POM','DOL','RPI','MOR']
for rating in ratings:
    rating_t = rating + '_t'
    rating_o = rating + '_o'
    upset_cond_1 = (tourney_data['game_result']==0) & (tourney_data[rating_t] < tourney_data[rating_o] )
    upset_cond_2 = (tourney_data['game_result']==1) & (tourney_data[rating_t] > tourney_data[rating_o] )
    upsets = tourney_data[upset_cond_1 | upset_cond_2][['season','round', 'team','opp_team','game_result',rating_t,rating_o ]]
    plot = sns.barplot(x='season', y='season',data=wlk_upsets, orient='v',estimator=lambda x: compute_percentage(x))
    plot.set(xlabel='Season', ylabel=rating +' Upset Percent')
    plot.set_title(rating + " Upsets")
    plot.figure.set_size_inches(8,4)
    plt.show()
    avg_upsets = upsets.shape[0]/upsets['season'].nunique()
    print("Average " + rating + " upsets per tournament season= ",avg_upsets)
# Out:
# Average seed upsets per tournament season=  17.533333333333335
# Average SAG upsets per tournament season=  18.666666666666668
# Average WLK upsets per tournament season=  19.0
# Average WOL upsets per tournament season=  19.266666666666666
# Average RTH upsets per tournament season=  18.933333333333334
# Average COL upsets per tournament season=  19.666666666666668
# Average POM upsets per tournament season=  18.533333333333335
# Average DOL upsets per tournament season=  19.4
# Average RPI upsets per tournament season=  20.066666666666666
# Average MOR upsets per tournament season=  18.8
