# %%
import urllib
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %% [markdown]
# Connect to the local sql express database.

# %%
params = urllib.parse.quote_plus("DRIVER={SQL Server Native Client 11.0};"
                                 "SERVER=DESKTOP-LSOCJD8\SQLEXPRESS;"
                                 "DATABASE=NCAA_Basketball;"
                                 "Trusted_Connection=yes")

engine = create_engine("mssql+pyodbc:///?odbc_connect={}".format(params))
connection = engine.connect()
result = connection.execute("SELECT SYSTEM_USER AS me")
row = result.fetchone()
print(row['me'])
# Out:
# MicrosoftAccount\chipk215@msn.com

# %% [markdown]
# Get games for training.
# This function reads all of the data into memory.

# %%
def get_games_for_training(season, db_connect):
    sql = """
    SELECT  game_id, season, scheduled_date, 
        home_team, market, opp_market, win, 
        points_game, opp_points_game,
        field_goals_pct, 
        offensive_rebounds, 
        free_throws_att,
        free_throws_pct,
        turnovers      
    FROM [NCAA_Basketball].[dbo].[d1_2015]
    WHERE (season = {}) 
     """.format(season)
    
    games_df = pd.read_sql_query(sql, connection)
    return games_df

# %% [markdown]
# Get the team information for the specified season and team name.
# Revisit and only pull data prior to a game date (game date needs to be provided as a parameter)

# %%
def get_games_for_team(season, team, game_date, db_connect):
    if ("'" in team):
        pos = team.find("'")
        team = team[: pos]
        print(team)
        
    sql = """
    SELECT scheduled_date, home_team,market, opp_market, win, 
        points_game, opp_points_game,
        field_goals_pct, 
        offensive_rebounds, 
        free_throws_att,
        free_throws_pct,
        turnovers      
    FROM [NCAA_Basketball].[dbo].[d1_2015]
     WHERE (season = {}) AND (market like  N'{}%') AND scheduled_date < '{}'
     """.format(season, team, game_date.strftime("%Y-%m-%d"))
    
    team_df = pd.read_sql_query(sql, connection)
    return team_df

# %%
# Compute the win percentage for a team.
def compute_win_percentage(team_df):
    return team_df[team_df.win == True].count()['win']/team_df.shape[0]

# %%
def process_game_record(season, game_date, principal_team, opp_team):
    #print("Principal=",principal_team, " Opponent= ", opp_team)
    principal_df = get_games_for_team(season, principal_team, game_date, connection )
    opponent_df =  get_games_for_team(season, opp_team,game_date, connection )
    result = compute_feature_differences(principal_df, opponent_df)
    return result

# %%
def compute_feature_differences(principal_df, opponent_df):
    principal_summary = principal_df.describe()
    opponent_summary = opponent_df.describe()
    diff = principal_summary.loc['mean'] - opponent_summary.loc['mean']
    principal_vs_opponent = diff.to_frame(name="Difference").transpose()
    win_diff = compute_win_percentage(principal_df) -  compute_win_percentage(opponent_df)  
    principal_vs_opponent['win_pct'] = pd.Series(win_diff, index=principal_vs_opponent.index)
    return principal_vs_opponent

# %%
games_df = get_games_for_training(2015, connection)

games_df.info()
#games_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5515 entries, 0 to 5514
# Data columns (total 14 columns):
# game_id               5515 non-null object
# season                5515 non-null int64
# scheduled_date        5515 non-null datetime64[ns]
# home_team             5515 non-null bool
# market                5515 non-null object
# opp_market            5515 non-null object
# win                   5515 non-null bool
# points_game           5515 non-null int64
# opp_points_game       5515 non-null int64
# field_goals_pct       5515 non-null float64
# offensive_rebounds    5515 non-null int64
# free_throws_att       5515 non-null int64
# free_throws_pct       5515 non-null float64
# turnovers             5515 non-null int64
# dtypes: bool(2), datetime64[ns](1), float64(2), int64(6), object(3)
# memory usage: 527.9+ KB

# %%
stats = games_df.apply(lambda x: process_game_record(x.season, x.scheduled_date, x.market, x.opp_market), axis=1)
game_stats_df = stats[0]
for row in range(1,stats.shape[0]):
    game_stats_df = pd.concat([game_stats_df,stats[row]], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [mean] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-e34d0436a3ab> in <module>()
# ----> 1 stats = games_df.apply(lambda x: process_game_record(x.season, x.scheduled_date, x.market, x.opp_market), axis=1)
#       2 game_stats_df = stats[0]
#       3 for row in range(1,stats.shape[0]):
#       4     game_stats_df = pd.concat([game_stats_df,stats[row]], ignore_index=True)
#       5
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# <ipython-input-57-e34d0436a3ab> in <lambda>(x)
# ----> 1 stats = games_df.apply(lambda x: process_game_record(x.season, x.scheduled_date, x.market, x.opp_market), axis=1)
#       2 game_stats_df = stats[0]
#       3 for row in range(1,stats.shape[0]):
#       4     game_stats_df = pd.concat([game_stats_df,stats[row]], ignore_index=True)
#       5
#
# <ipython-input-16-60e42c5bb2f0> in process_game_record(season, game_date, principal_team, opp_team)
#       3     principal_df = get_games_for_team(season, principal_team, game_date, connection )
#       4     opponent_df =  get_games_for_team(season, opp_team,game_date, connection )
# ----> 5     result = compute_feature_differences(principal_df, opponent_df)
#       6     return result
#
# <ipython-input-56-fc44b89e423f> in compute_feature_differences(principal_df, opponent_df)
#       2     principal_summary = principal_df.describe()
#       3     opponent_summary = opponent_df.describe()
# ----> 4     diff = principal_summary.loc['mean'] - opponent_summary.loc['mean']
#       5     principal_vs_opponent = diff.to_frame(name="Difference").transpose()
#       6     win_diff = compute_win_percentage(principal_df) -  compute_win_percentage(opponent_df)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: ('the label [mean] is not in the [index]', 'occurred at index 0')

# %%
game_stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5515 entries, 0 to 5514
# Data columns (total 8 columns):
# points_game           5515 non-null float64
# opp_points_game       5515 non-null float64
# field_goals_pct       5515 non-null float64
# offensive_rebounds    5515 non-null float64
# free_throws_att       5515 non-null float64
# free_throws_pct       5515 non-null float64
# turnovers             5515 non-null float64
# win_pct               5515 non-null float64
# dtypes: float64(8)
# memory usage: 344.8 KB

# %%
# this is the feature dataframe with some convenience columns added

game_stats_df['game_id'] = games_df['game_id']
game_stats_df['market'] = games_df['market']
game_stats_df['opp_market'] = games_df['opp_market']
game_stats_df['game_result'] = games_df['win'].astype(int)
game_stats_df['game_date'] = games_df['scheduled_date']
game_stats_df
# Out:
#       points_game  opp_points_game  field_goals_pct  offensive_rebounds  \
# 0        7.170455        17.136364         0.609091           -6.545455
# 1       -0.181818        -4.216783         4.993007           -1.534965
# 2        6.303030         1.878788        -1.936364            4.939394
# 3        4.452991       -12.427350         4.996581            1.589744
# 4        7.025926         4.755556         2.335185            2.911111
# 5        0.666667        18.000000         0.383333           -2.333333
# 6        3.400000        -2.190909         2.354545            0.609091
# 7       14.000000         1.285714         9.328571           -0.857143
# 8        6.616667         8.716667         9.565000           -7.283333
# 9        4.463636        -7.463636        -2.023636            3.727273
# 10      -6.755556        -5.622222        -0.286667           -1.688889
# 11       2.500000        -7.222222         7.247222           -2.527778
# 12     -12.366667       -23.366667         1.970000           -0.600000
# 13      -3.219048       -13.485714        -6.915238            6.580952
# 14      -2.237762         8.573427         1.150350           -0.951049
# 15       9.466667         1.733333         5.384444           -0.733333
# 16       3.954545         3.393939        -1.822727            0.166667
# 17      12.500000         8.944444         4.866667           -0.638889
# 18       5.203333         6.470000         1.356000           -1.030000
# 19       0.181818        10.000000        -0.745455            4.636364
# 20      -0.926471        -1.735294         1.544118           -1.235294
# 21       6.944444         6.925926         2.331481            1.037037
# 22       3.825000        13.500000         5.820000           -3.675000
# 23      -0.070707         1.353535        -3.365657            4.181818
# 24       4.785714         8.803571         3.171429           -0.535714
# 25     -15.027778        -8.152778        -2.065278           -0.055556
# 26      -1.872727       -18.690909         0.421818            0.472727
# 27      -5.200000        14.600000        -3.620000            2.900000
# 28      -5.900000        10.816667        -2.101667            0.383333
# 29     -14.929293        -2.569024        -6.305051            2.663300
# ...           ...              ...              ...                 ...
# 5485     1.949495        -1.535354         3.192929            1.828283
# 5486   -13.000000         0.125000        -8.591667            1.166667
# 5487   -12.593939        -7.509091        -5.190303           -1.400000
# 5488     5.093182         3.490909         3.959545           -1.802273
# 5489    -9.776316         3.002632        -0.378947           -3.047368
# 5490   -11.357143         0.442857        -9.640000            2.757143
# 5491     4.575000         4.141667         2.447500           -0.850000
# 5492    -4.072222         1.542593        -4.041852            2.337037
# 5493    -2.522727        -5.140909         1.581818           -0.827273
# 5494     7.082143         2.457143         5.195000           -0.782143
# 5495    -0.988889        -5.200000         1.060000           -0.822222
# 5496    11.142857        10.857143         2.157143           -2.428571
# 5497    -4.722222         5.467593        -6.101852            2.037037
# 5498     0.585714         5.000000        -0.862857           -0.500000
# 5499    -0.307692        -3.482517        -1.159441            1.041958
# 5500     8.292308        12.284615         0.960000           -0.315385
# 5501    -4.898990         2.737374         0.964646           -0.050505
# 5502     5.244444         9.444444        -3.027778            0.255556
# 5503   -15.161616       -14.828283        -3.875758            2.919192
# 10              Grand Canyon            0 2015-11-14
# 11               New Orleans            1 2015-11-14
# 12                      UTSA            1 2015-11-14
# 13            Boston College            0 2015-11-14
# 14         Northern Illinois            0 2015-11-14
# 15             Jackson State            1 2015-11-14
# 16                       UAB            1 2015-11-14
# 17                  Stanford            0 2015-11-14
# 18                  Missouri            0 2015-11-14
# 19                Georgetown            1 2015-11-14
# 20                  Arkansas            0 2015-11-14
# 21                    Temple            1 2015-11-14
# 22         Mississippi State            0 2015-11-14
# 23                   Colgate            0 2015-11-14
# 24              Northeastern            0 2015-11-14
# 25                 Princeton            0 2015-11-14
# 26       Fairleigh Dickinson            1 2015-11-14
# 27                   Clemson            0 2015-11-14
# 28       Saint Joseph's (PA)            0 2015-11-14
# 29             North Florida            0 2015-11-14
# ...                      ...          ...        ...
# 5485              Miami (FL)            1 2016-03-24
# 5486              Notre Dame            0 2016-03-25
# 5487                    Duke            1 2016-03-25
# 5488                Virginia            0 2016-03-25
# 5489                  Kansas            0 2016-03-25
# 5490                 Gonzaga            1 2016-03-26
# 5491                  Oregon            1 2016-03-26
# 5492                 Indiana            1 2016-03-26
# 5493                  Kansas            1 2016-03-27
# 5494                Syracuse            0 2016-03-27
# 5495                N.J.I.T.            1 2016-03-27
# 5496            Old Dominion            0 2016-03-28
# 5497              Notre Dame            1 2016-03-28
# 5498               UC Irvine            0 2016-03-28
# 5499        UC Santa Barbara            0 2016-03-28
# 5500              Valparaiso            0 2016-03-29
# 5501          Louisiana Tech            1 2016-03-29
# 5502          Morehead State            0 2016-03-29
# 5503                 Oakland            0 2016-03-29
# 5504               UC Irvine            1 2016-03-29
# 5505                 Oakland            0 2016-03-30
# 5506         San Diego State            1 2016-03-30
# 5507        UC Santa Barbara            1 2016-03-30
# 5508                  Nevada            0 2016-03-31
# 5509                 Oakland            1 2016-03-31
# 5510       George Washington            0 2016-03-31
# 5511                Oklahoma            1 2016-04-02
# 5512                  Nevada            0 2016-04-02
# 5513          North Carolina            0 2016-04-03
# 5514          North Carolina            1 2016-04-05
#
# [5515 rows x 13 columns]

# %%
#game_stats_df.to_csv('D1_2015_Processed_Stats.csv')

# %%
game_record = games_df.loc[0]
game_record
# Out:
# game_id               e302d3cb-bbeb-47fa-9f96-0d85eb176c86
# season                                                2015
# scheduled_date                         2015-11-13 00:00:00
# home_team                                            False
# market                                           Fairfield
# opp_market                                            Yale
# win                                                  False
# points_game                                             57
# opp_points_game                                         70
# field_goals_pct                                         40
# offensive_rebounds                                       4
# free_throws_att                                         13
# free_throws_pct                                       76.9
# turnovers                                               15
# Name: 0, dtype: object

# %%
type(game_record.scheduled_date)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
temp_date = game_record.scheduled_date.date()
type(temp_date)
# Out:
# datetime.date

# %%
temp_date
# Out:
# datetime.date(2015, 11, 13)

# %%
date_string = f'{temp_date:%Y-%m-%d}'
date_string
# Out:
# '2015-11-13'

# %%
s2 = temp_date.strftime("%Y-%m-%d")
s2
# Out:
# '2015-11-13'
