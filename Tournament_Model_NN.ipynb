# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)
# Out:
# Seaborn version:  0.9.0

# %% [markdown]
# #### Power Conference Feature
#
# From EDA we know that a small number of conferences account for 70% of all confernece wins.
#
# If one of the two teams is in a power conference, indicate the advantage that team has for winning the game.

# %%
# Compare the conferences of two teams playing in a game.
# If both teams are in power conference or both teams are not in a power conference return 0.
# If the opponent team is in a power conference and the first team is not in a power conference return -1
# If the first team is a power conference team and opponent is not then return 1.

def conf_compare(team_conf, opp_conf):
    team_top = team_conf in top_tournament_conferences_list
    opp_top = opp_conf in top_tournament_conferences_list
    if team_top == opp_top:
        return 0
    elif team_top :
        return 1
    else:
        return -1

# %%
def join_feature_name_with_importance_value(features, importances):
    """
    Join via a list of tuples, feature names with their importance values
    :param features: data frame whose features are represented by columns used by classifier
    :param importances: feature importance scores assigned by classifier
    :return: sorted list (highest importances first) of feature,importance tuples
    """
    if features.columns.shape[0] != importances.shape[0]:
        return []

    feature_importances = []
    for item in range(features.columns.shape[0]):
        feature_importances.append((features.columns[item], importances[item]))
    feature_importances_sorted = sorted(feature_importances, reverse=True, key=lambda kv: abs(kv[1]))

    return feature_importances_sorted

# %%
def display_important_features_regression(classifier, features):
    importances = classifier.coef_[0]
    #print("Importances: ", importances) 
    feature_importances = join_feature_name_with_importance_value(features, importances)
    print('Coefficient Values')
    for items in feature_importances:
        print(items[0]," ", items[1])

# %%
def get_tournament_record(df, season, round_, team):
    return df[(df['season_t'] == season) & (df['round']== round_) & (df['team']==team)]

# %%
def print_game_info(df, season, round_, team):
    t_rec = get_tournament_record(df, season, round_, team)
    opp_team = t_rec['opp_team'].iloc[0]
    print('\t\t',team,'\t',opp_team)
    print('Seed','\t\t',"%6d"%t_rec['team_seed'].iloc[0],'\t',"%6d"%t_rec['opp_team_seed'].iloc[0])
    print('PPG','\t\t',"%6.2f"%t_rec['pts_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['pts_avg_o'].iloc[0])
    print('Allow PPG','\t',"%6.2f"%t_rec['opp_pts_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['opp_pts_avg_o'].iloc[0])
    print('Poss Avg','\t',"%6.2f"%t_rec['poss_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['poss_avg_o'].iloc[0])
    print('FG %','\t\t',"%6.2f"%(100*t_rec['fg_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['fg_pct_o'].iloc[0]))
    print('Allow FG %','\t',"%6.2f"%(100*t_rec['allow_fg_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['allow_fg_pct_o'].iloc[0]))
    print('Off Rb Avg','\t',"%6.2f"%t_rec['off_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['off_rebs_avg_o'].iloc[0])
    print('Allow Off Rb Avg',"%6.2f"%t_rec['allow_off_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['allow_off_rebs_avg_o'].iloc[0])
    print('Def Rb Avg','\t',"%6.2f"%t_rec['def_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['def_rebs_avg_o'].iloc[0])
    print('Allow Def Rb Avg',"%6.2f"%t_rec['allow_def_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['allow_def_rebs_avg_o'].iloc[0])  
    print('FT ATT Avg','\t',"%6.2f"%t_rec['ft_att_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['ft_att_avg_o'].iloc[0]) 
    print('Allow FT ATT Avg',"%6.2f"%t_rec['allow_ft_att_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['allow_ft_att_avg_o'].iloc[0])
    print('FT %','\t\t',"%6.2f"%(100*t_rec['ft_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['ft_pct_o'].iloc[0]))
    print('Turnover Avg','\t',"%6.2f"%t_rec['to_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['to_avg_o'].iloc[0])
    print('Takeaway Avg','\t',"%6.2f"%t_rec['steal_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['steal_avg_o'].iloc[0])
    print('Win %','\t\t',"%6.2f"%(100*t_rec['win_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['win_pct_o'].iloc[0]))
    print('Off Rating','\t',"%6.2f"%t_rec['off_rating_t'].iloc[0],'\t',"%6.2f"%t_rec['off_rating_o'].iloc[0])
    print('SRS Rating','\t',"%6.2f"%t_rec['SRS_t'].iloc[0],'\t',"%6.2f"%t_rec['SRS_o'].iloc[0])
    #print('SOS Rating','\t',"%6.2f"%t_rec['SOS_t'].iloc[0],'\t',"%6.2f"%t_rec['SOS_o'].iloc[0])
    print('\n\nTop Conference= ', t_rec['top_conf'].iloc[0])
    print('Game Result= ', t_rec['game_result'].iloc[0], ' (One indicates win for ', team,')')
    print('Predicted Result= ', t_rec['predicted_result'].iloc[0])
    print('Predicted Probability= ',"%6.3f"%t_rec['pred_win_prob'].iloc[0])
    return

# %% [markdown]
# #### Read in regular season team statistics from SRCBB https://www.sports-reference.com/cbb/

# %%
#Note season indicates start of season, e.g. 2013 to 2014, the corresponding tournament season is 1 greater than this value
# The tournament season for season 2013 is 2014
summary_data = pd.read_csv('sr_summaries_kaggle_id.csv')
print(summary_data.shape)

#display rows with NaNs
summary_data[summary_data.isnull().any(axis=1)]
# Out:
# (2439, 22)
# Empty DataFrame
# Columns: [season, School, team_id, Games, SRS, SOS, win_pct, pts_avg, opp_pts_avg, fg_pct, allow_fg_pct, ft_pct, allow_ft_att_avg, poss_avg, off_rebs_avg, allow_off_rebs_avg, def_rebs_avg, allow_def_rebs_avg, to_avg, steal_avg, off_rating, ft_att_avg]
# Index: []

# %%
#drop records with NaNs
summary_data.dropna(inplace=True)
print(summary_data.shape)
# Out:
# (2439, 22)

# %% [markdown]
# #### Read table of team names and associated team meta data from the Kaggle data set.
#
# https://console.cloud.google.com/bigquery?project=bigqueryncaa&p=bigquery-public-data&d=ncaa_basketball&page=dataset

# %%
# Read table of team names and associated team meta data
teams = pd.read_csv('D1_teams.csv')
teams.drop(columns=['code_ncaa','school_ncaa','turner_name','league_name','league_alias','conf_alias',
                    'conf_id','division_name','division_alias','division_id',
                    'kaggle_team_id','venue_id'], inplace=True)
teams.info()
teams.set_index('id',inplace=True)
teams.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 2 columns):
# id           351 non-null object
# conf_name    351 non-null object
# dtypes: object(2)
# memory usage: 5.6+ KB
#                                      conf_name
# id
# fe406882-9f22-495e-9df6-ef357a6803c6       Ivy
# ca478771-aa3d-4231-81e0-b70f519134fb       Ivy
# 5c7bf63f-bc39-43c5-9907-73b50b7a6b34       Ivy
# d60357bd-1205-42e9-9092-d986a2843a34       Ivy
# 88ff8c00-958e-4ccf-a21d-77fab9e93692       Ivy

# %% [markdown]
# #### Read in the NCAA Men's Tournament results from the the Kaggle data set.

# %%
tourney_data = pd.read_csv('tournament_results.csv')
tourney_data.drop(columns=['days_from_epoch','day','num_ot','academic_year','win_region','win_alias','lose_region',
                           'lose_alias','lose_code_ncaa','win_school_ncaa','win_code_ncaa','win_name','lose_name',
                           'win_pts','win_kaggle_team_id','lose_school_ncaa','lose_kaggle_team_id','lose_pts'],inplace=True)

tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 9 columns):
# season          2117 non-null int64
# round           2117 non-null int64
# game_date       2117 non-null object
# win_seed        2117 non-null int64
# win_market      2117 non-null object
# win_team_id     2117 non-null object
# lose_seed       2117 non-null int64
# lose_market     2117 non-null object
# lose_team_id    2117 non-null object
# dtypes: int64(4), object(5)
# memory usage: 148.9+ KB

# %% [markdown]
# ### Extract some historical data

# %%
game_data = tourney_data.join(teams, on='win_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'win_kaggle_team_id','conf_name':'win_conf_name'}, inplace=True)
game_data = game_data.join(teams,on='lose_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'lose_kaggle_team_id','conf_name':'lose_conf_name'}, inplace=True)
games_won_conf = game_data.groupby('win_conf_name').size().reset_index(name='count').sort_values(by=['count'], ascending=False)

games_won_conf['percent'] = 100 * games_won_conf['count']/games_won_conf['count'].sum()
games_won_conf['cum_percent'] = games_won_conf['percent'].cumsum()
games_won_conf.head()
# Out:
#      win_conf_name  count    percent  cum_percent
# 3   Atlantic Coast    431  20.358999    20.358999
# 9          Big Ten    313  14.785073    35.144072
# 24    Southeastern    269  12.706660    47.850732
# 5           Big 12    231  10.911667    58.762400
# 22      Pacific 12    197   9.305621    68.068021

# %% [markdown]
# Identify the conferences that have won 70% of all conference games

# %%
top_tournament_conferences_list = games_won_conf[games_won_conf['cum_percent']<= 70]['win_conf_name'].tolist()
top_tournament_conferences_list
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']

# %%
tourney_data.describe()['season']
# Out:
# count    2117.000000
# mean     2001.193198
# std         9.563883
# min      1985.000000
# 25%      1993.000000
# 50%      2001.000000
# 75%      2010.000000
# max      2017.000000
# Name: season, dtype: float64

# %% [markdown]
# Note the tournament data is available for tournament years 1985 through 2017.

# %%
summary_data.describe()['season']
# Out:
# count    2439.000000
# mean     2013.015990
# std         1.997987
# min      2010.000000
# 25%      2011.000000
# 50%      2013.000000
# 75%      2015.000000
# max      2016.000000
# Name: season, dtype: float64

# %% [markdown]
# The summary season data in this set goes back to 2010. If more training data is needed we can go back to earlier seasons.
#
# So the intersection of season summary data with tournament data are regular seasons 2010 through 2016.

# %%
tourney_data = tourney_data[tourney_data['season'] >= 2011]
tourney_data.describe()['season']
# Out:
# count     469.000000
# mean     2014.000000
# std         2.002136
# min      2011.000000
# 25%      2012.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 469 entries, 10 to 2104
# Data columns (total 9 columns):
# season          469 non-null int64
# round           469 non-null int64
# game_date       469 non-null object
# win_seed        469 non-null int64
# win_market      469 non-null object
# win_team_id     469 non-null object
# lose_seed       469 non-null int64
# lose_market     469 non-null object
# lose_team_id    469 non-null object
# dtypes: int64(4), object(5)
# memory usage: 36.6+ KB

# %%
tourney_data.head()
# Out:
#     season  round   game_date  win_seed             win_market  \
# 10    2013     64  2013-03-22         9                 Temple
# 17    2011     64  2011-03-17         7                 Temple
# 27    2013     64  2013-03-21         5  Virginia Commonwealth
# 29    2012     64  2012-03-15        12  Virginia Commonwealth
# 30    2011      8  2011-03-27        11  Virginia Commonwealth
#
#                              win_team_id  lose_seed           lose_market  \
# 10  8598d1b6-106b-4083-a512-2e495729525a          8  North Carolina State
# 17  8598d1b6-106b-4083-a512-2e495729525a         10            Penn State
# 27  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518         12                 Akron
# 29  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518          5         Wichita State
# 30  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518          1                Kansas
#
#                             lose_team_id
# 10  52df1e19-b142-4a76-a439-ad68455d0581
# 17  4aebd148-8119-4875-954c-66779867989b
# 27  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20
# 29  f38b58de-3273-4723-a78b-2f918e9aa2d5
# 30  fae4855b-1b64-4b40-a632-9ed345e1e952

# %%
# recode the tourney data so that the teams are not marked with  win/lose status and the game result is encoded as a binary
tourney_data['game_result'] = 1
tourney_data.game_result = tourney_data.game_result.astype(int)
tourney_data.rename(columns={"win_seed":"team_seed","win_market":"team","win_team_id":"team_id"}, inplace=True)
tourney_data.rename(columns={"lose_seed":"opp_team_seed","lose_market":"opp_team","lose_team_id":"opp_team_id"}, inplace=True)
tourney_data['start_season'] = tourney_data['season'] -1
tourney_data
# Out:
#       season  round   game_date  team_seed                   team  \
# 10      2013     64  2013-03-22          9                 Temple
# 17      2011     64  2011-03-17          7                 Temple
# 27      2013     64  2013-03-21          5  Virginia Commonwealth
# 29      2012     64  2012-03-15         12  Virginia Commonwealth
# 30      2011      8  2011-03-27         11  Virginia Commonwealth
# 31      2011     16  2011-03-25         11  Virginia Commonwealth
# 33      2011     32  2011-03-20         11  Virginia Commonwealth
# 34      2011     64  2011-03-18         11  Virginia Commonwealth
# 35      2011     68  2011-03-16         11  Virginia Commonwealth
# 36      2016     64  2016-03-18         10  Virginia Commonwealth
# 37      2013     64  2013-03-21          8         Colorado State
# 44      2017     64  2017-03-17         11           Rhode Island
# 46      2015     64  2015-03-19          5                   Utah
# 48      2016     64  2016-03-17          3                   Utah
# 49      2015     32  2015-03-21          5                   Utah
# 72      2017     64  2017-03-17          3                 Baylor
# 73      2017     32  2017-03-19          3                 Baylor
# 77      2012     16  2012-03-23          3                 Baylor
# 78      2012     64  2012-03-15          3                 Baylor
# 79      2012     32  2012-03-17          3                 Baylor
# 80      2014     64  2014-03-21          6                 Baylor
# 81      2014     32  2014-03-23          6                 Baylor
# 82      2014     64  2014-03-21         14                 Mercer
# 88      2014     64  2014-03-20         12     North Dakota State
# 89      2012     68  2012-03-14         12          South Florida
# 90      2012     64  2012-03-16         12          South Florida
# 94      2017     64  2017-03-17          3                 Oregon
# 95      2017     16  2017-03-23          3                 Oregon
# 97      2013     32  2013-03-23         12                 Oregon
# 98      2013     64  2013-03-21         12                 Oregon
# ...      ...    ...         ...        ...                    ...
# 1919    2012     64  2012-03-16         10                 Purdue
# 1925    2017     32  2017-03-18          4                 Purdue
# 1926    2017     64  2017-03-16          4                 Purdue
# 1928    2011     64  2011-03-18          3                 Purdue
# 1957    2013     64  2013-03-21         12             California
# 1964    2011     64  2011-03-17          5          West Virginia
# 1976    2017     64  2017-03-16          4          West Virginia
# 1978    2017     32  2017-03-18          4          West Virginia
# 1979    2015     32  2015-03-22          5          West Virginia
# 1980    2015     64  2015-03-20          5          West Virginia
# 1984    2017     68  2017-03-14         16       Mount St. Mary's
# 2001    2011     64  2011-03-18         11              Marquette
# 2002    2013     16  2013-03-28          3              Marquette
# 2003    2013     64  2013-03-21          3              Marquette
# 2004    2013     32  2013-03-23          3              Marquette
# 2005    2011     32  2011-03-20         11              Marquette
# 2014    2012     64  2012-03-15          3              Marquette
# 2015    2012     32  2012-03-17          3              Marquette
# 2023    2016     16  2016-03-25          6             Notre Dame
# 2024    2016     32  2016-03-20          6             Notre Dame
# 2028    2016     64  2016-03-18          6             Notre Dame
# 2029    2017     64  2017-03-16          5             Notre Dame
# 2030    2015     32  2015-03-21          3             Notre Dame
# 2031    2015     16  2015-03-26          3             Notre Dame
# 2034    2015     64  2015-03-19          3             Notre Dame
# 2037    2011     64  2011-03-18          2             Notre Dame
# 2045    2013     64  2013-03-22         11              Minnesota
# 2054    2012     64  2012-03-16         15                 Lehigh
# 2082    2013     64  2013-03-22          7               Illinois
# 2104    2011     64  2011-03-18          9               Illinois
#
#                                    team_id  opp_team_seed  \
# 10    8598d1b6-106b-4083-a512-2e495729525a              8
# 17    8598d1b6-106b-4083-a512-2e495729525a             10
# 27    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             12
# 29    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5
# 30    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              1
# 31    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             10
# 33    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              3
# 34    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              6
# 35    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             11
# 36    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              7
# 37    1a470730-f328-4fb1-8bbf-36a069e4d6b2              9
# 44    7e42bca2-3cd7-4aca-aa46-f190fe5d8eb4              6
# 46    0d037a5d-827a-44dd-8b70-57603d671d5d             12
# 48    0d037a5d-827a-44dd-8b70-57603d671d5d             14
# 49    0d037a5d-827a-44dd-8b70-57603d671d5d              4
# 72    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 73    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 77    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             10
# 78    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 79    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 80    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 81    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf              3
# 82    a14b0057-8eb5-43d2-a33b-666196da933e              3
# 88    984e7518-e418-45d5-9797-979b8c2085c1              5
# 89    55af9c69-3675-4b9b-a882-96640b782fff             12
# 90    55af9c69-3675-4b9b-a882-96640b782fff              5
# 94    1da70895-f77f-44ef-b216-d63c02e696eb             14
# 95    1da70895-f77f-44ef-b216-d63c02e696eb              7
# 97    1da70895-f77f-44ef-b216-d63c02e696eb              4
# 98    1da70895-f77f-44ef-b216-d63c02e696eb              5
# ...                                    ...            ...
# 1919  12d7f888-675b-459f-9099-a38f771d8a95              7
# 1925  12d7f888-675b-459f-9099-a38f771d8a95              5
# 1926  12d7f888-675b-459f-9099-a38f771d8a95             13
# 1928  12d7f888-675b-459f-9099-a38f771d8a95             14
# 1957  aacdc78d-b7fa-48f6-9686-2fdb8a95030e              5
# 1964  f770d3a2-221c-49ce-9c7a-680f7417fe9e             12
# 1976  f770d3a2-221c-49ce-9c7a-680f7417fe9e             13
# 1978  f770d3a2-221c-49ce-9c7a-680f7417fe9e              5
# 1979  f770d3a2-221c-49ce-9c7a-680f7417fe9e              4
# 1980  f770d3a2-221c-49ce-9c7a-680f7417fe9e             12
# 1984  5fe4a398-1699-4442-a364-305b2f0ac01e             16
# 2001  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2002  06f7c904-0ac7-4125-b0f4-f4871bb69057              2
# 2003  06f7c904-0ac7-4125-b0f4-f4871bb69057             14
# 2004  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2005  06f7c904-0ac7-4125-b0f4-f4871bb69057              3
# 2014  06f7c904-0ac7-4125-b0f4-f4871bb69057             14
# 2015  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2023  80962f09-8821-48b6-8cf0-0cf0eea56aa8              7
# 2024  80962f09-8821-48b6-8cf0-0cf0eea56aa8             14
# 2028  80962f09-8821-48b6-8cf0-0cf0eea56aa8             11
# 2029  80962f09-8821-48b6-8cf0-0cf0eea56aa8             12
# 2030  80962f09-8821-48b6-8cf0-0cf0eea56aa8              6
# 2031  80962f09-8821-48b6-8cf0-0cf0eea56aa8              7
# 2034  80962f09-8821-48b6-8cf0-0cf0eea56aa8             14
# 2037  80962f09-8821-48b6-8cf0-0cf0eea56aa8             15
# 2045  fa416692-7e09-4f0a-9bcf-0cf7d5149a14              6
# 2054  508f503f-dc57-4f4c-a01e-4f195e5c05c8              2
# 2082  150148c2-ca8f-414f-8f41-d94a55d4a122             10
# 2104  150148c2-ca8f-414f-8f41-d94a55d4a122              8
#
#                   opp_team                           opp_team_id  game_result  \
# 10    North Carolina State  52df1e19-b142-4a76-a439-ad68455d0581            1
# 17              Penn State  4aebd148-8119-4875-954c-66779867989b            1
# 27                   Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20            1
# 29           Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 30                  Kansas  fae4855b-1b64-4b40-a632-9ed345e1e952            1
# 31           Florida State  d3c8a767-b6fc-45d4-a5f2-18406f2993f1            1
# 33                  Purdue  12d7f888-675b-459f-9099-a38f771d8a95            1
# 34              Georgetown  8736b67f-5924-400b-bf94-3bd804c36600            1
# 35                     USC  3a000455-de7c-4ca8-880e-abdce7f21da9            1
# 36            Oregon State  532d3874-b4b3-4c5c-acc6-749a6db26c8f            1
# 37                Missouri  77ca152a-cb2f-48a5-97b2-492351250d94            1
# 44               Creighton  7d797407-623e-476d-b299-46de4275414d            1
# 46       Stephen F. Austin  5ef64f01-86ae-4553-9834-c79cc0859eaf            1
# 48            Fresno State  dd8db4d8-d984-4cab-b7f6-22c6b8c2c45f            1
# 49              Georgetown  8736b67f-5924-400b-bf94-3bd804c36600            1
# 72        New Mexico State  5016fe1a-9571-4d10-bf5b-b9c1b496bd57            1
# 73                     USC  3a000455-de7c-4ca8-880e-abdce7f21da9            1
# 77                  Xavier  0d8a328f-20ce-410b-bed1-15fc01308aaf            1
# 78      South Dakota State  6ef40534-5fad-4755-84de-7dcbd645d1f0            1
# 79                Colorado  9fccbf28-2858-4263-821c-fdefb3c7efa3            1
# 80                Nebraska  f8b1bf00-5b73-4ac4-98c0-ec554027ae32            1
# 81               Creighton  7d797407-623e-476d-b299-46de4275414d            1
# 82                    Duke  faeb1160-5d15-4f26-99fc-c441cf21fc7f            1
# 88                Oklahoma  b2fda957-e15c-4fb2-8a13-6e58496f561e            1
# 89              California  aacdc78d-b7fa-48f6-9686-2fdb8a95030e            1
# 90                  Temple  8598d1b6-106b-4083-a512-2e495729525a            1
# 94                    Iona  255c2a87-40c0-4989-bbb9-d286aac5d28e            1
# 95                Michigan  bdc2561d-f603-4fab-a262-f1d2af462277            1
# 97             Saint Louis  1e42cce3-236b-4f3e-9650-2c45e6332e1e            1
# 98          Oklahoma State  8ab00d43-840a-4c96-bdee-bf88fa6e3f11            1
# ...                    ...                                   ...          ...
# 1919          Saint Mary's  b18f34af-a7f1-4659-a2e5-fc11a31cd316            1
# 1925            Iowa State  0e4258fa-3154-4c16-b693-adecab184c6c            1
# 1926               Vermont  18e89867-9201-41ce-ba19-fadddf92fa17            1
# 1928           St. Peter's  e66d7ed2-9b4c-48c8-adaa-a276793b057d            1
# 1957                  UNLV  68a3227f-677f-43b0-9a3a-cad79d0df9e2            1
# 1964               Clemson  dcf5c2e7-c227-4c20-af26-715d5f859412            1
# 1976              Bucknell  98d2123a-c7b9-4b5f-8a81-43f76d8537dc            1
# 1978            Notre Dame  80962f09-8821-48b6-8cf0-0cf0eea56aa8            1
# 1979              Maryland  2778d005-cc14-4e58-9bf2-3fc37bffb62f            1
# 1980               Buffalo  a9f5c9a2-342c-4881-9996-5d5c05ec9bd9            1
# 1984           New Orleans  e7ff6d5c-07e9-42af-955d-0a0b8c1e2288            1
# 2001                Xavier  0d8a328f-20ce-410b-bed1-15fc01308aaf            1
# 2002            Miami (FL)  7aec5187-cb1b-45e5-8f7d-406d766cdc73            1
# 2003              Davidson  2920c5fa-1e86-4958-a7c4-1e97b8e201d8            1
# 2004                Butler  bdb7d7a4-45f8-4bf3-ab85-15488c451494            1
# 2005              Syracuse  8cd24de1-2be8-4b77-bcfa-47be0495a5f4            1
# 2014                   BYU  c31455b2-8a45-4248-aa8f-ce7eab1c6b02            1
# 2015          Murray State  77a69fb0-1355-4342-ac09-b4cc7949d95e            1
# 2023             Wisconsin  c7569eae-5b93-4197-b204-6f3a62146b25            1
# 2024     Stephen F. Austin  5ef64f01-86ae-4553-9834-c79cc0859eaf            1
# 2028              Michigan  bdc2561d-f603-4fab-a262-f1d2af462277            1
# 2029             Princeton  fe406882-9f22-495e-9df6-ef357a6803c6            1
# 2030                Butler  bdb7d7a4-45f8-4bf3-ab85-15488c451494            1
# 2031         Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 2034          Northeastern  93df9b18-e9fc-42a7-bb45-a736c203b4dc            1
# 2037                 Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20            1
# 2045                  UCLA  ec0d6b67-4b16-4b50-92b2-1a651dae6b0f            1
# 2054                  Duke  faeb1160-5d15-4f26-99fc-c441cf21fc7f            1
# 2082              Colorado  9fccbf28-2858-4263-821c-fdefb3c7efa3            1
# 2104                  UNLV  68a3227f-677f-43b0-9a3a-cad79d0df9e2            1
#
#       start_season
# 10            2012
# 17            2010
# 27            2012
# 29            2011
# 30            2010
# 31            2010
# 33            2010
# 34            2010
# 35            2010
# 36            2015
# 37            2012
# 44            2016
# 46            2014
# 48            2015
# 49            2014
# 72            2016
# 73            2016
# 77            2011
# 78            2011
# 79            2011
# 80            2013
# 81            2013
# 82            2013
# 88            2013
# 89            2011
# 90            2011
# 94            2016
# 95            2016
# 97            2012
# 98            2012
# ...            ...
# 1919          2011
# 1925          2016
# 1926          2016
# 1928          2010
# 1957          2012
# 1964          2010
# 1976          2016
# 1978          2016
# 1979          2014
# 1980          2014
# 1984          2016
# 2001          2010
# 2002          2012
# 2003          2012
# 2004          2012
# 2005          2010
# 2014          2011
# 2015          2011
# 2023          2015
# 2024          2015
# 2028          2015
# 2029          2016
# 2030          2014
# 2031          2014
# 2034          2014
# 2037          2010
# 2045          2012
# 2054          2011
# 2082          2012
# 2104          2010
#
# [469 rows x 11 columns]

# %%
# We need to recode the game data so that we have representation of the losing game result class.
# Swap the team and opp team data on the odd rows and reverse the sense of the game result.

#create some temporary buffer columns
tourney_data['copy_team'] = tourney_data['team']
tourney_data['copy_team_seed'] = tourney_data['team_seed']
tourney_data['copy_team_id'] = tourney_data['team_id']

#swap the team and opp team data
tourney_data.loc[1::2,'team'] = tourney_data.loc[1::2,'opp_team']
tourney_data.loc[1::2,'opp_team'] = tourney_data.loc[1::2,'copy_team']
tourney_data.loc[1::2,'team_seed'] = tourney_data.loc[1::2,'opp_team_seed']
tourney_data.loc[1::2,'opp_team_seed'] = tourney_data.loc[1::2,'copy_team_seed']
tourney_data.loc[1::2,'team_id'] = tourney_data.loc[1::2,'opp_team_id']
tourney_data.loc[1::2,'opp_team_id'] = tourney_data.loc[1::2,'copy_team_id']

# flip the game result
tourney_data.loc[1::2,'game_result'] = 0

#drop the temporary columns
tourney_data.drop(columns=['copy_team','copy_team_seed','copy_team_id'],inplace=True)
tourney_data.head()
# Out:
#     season  round   game_date  team_seed                   team  \
# 10    2013     64  2013-03-22          8   North Carolina State
# 17    2011     64  2011-03-17          7                 Temple
# 27    2013     64  2013-03-21         12                  Akron
# 29    2012     64  2012-03-15         12  Virginia Commonwealth
# 30    2011      8  2011-03-27          1                 Kansas
#
#                                  team_id  opp_team_seed  \
# 10  52df1e19-b142-4a76-a439-ad68455d0581              9
# 17  8598d1b6-106b-4083-a512-2e495729525a             10
# 27  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5
# 29  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5
# 30  fae4855b-1b64-4b40-a632-9ed345e1e952             11
#
#                  opp_team                           opp_team_id  game_result  \
# 10                 Temple  8598d1b6-106b-4083-a512-2e495729525a            0
# 17             Penn State  4aebd148-8119-4875-954c-66779867989b            1
# 27  Virginia Commonwealth  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0
# 29          Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 30  Virginia Commonwealth  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0
#
#     start_season
# 10          2012
# 17          2010
# 27          2012
# 29          2011
# 30          2010

# %%
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','team_id'], 
                                right_on=['season', 'team_id'],how='left',suffixes=('','_y'))

tourney_data.drop(columns=['season_y'],inplace=True)
tourney_data.describe()
# Out:
#             season       round   team_seed  opp_team_seed  game_result  \
# count   469.000000  469.000000  469.000000     469.000000   469.000000
# mean   2014.000000   44.805970    7.132196       7.345416     0.498934
# std       2.002136   22.479399    4.761806       4.713148     0.500533
# min    2011.000000    2.000000    1.000000       1.000000     0.000000
# 25%    2012.000000   32.000000    3.000000       3.000000     0.000000
# 50%    2014.000000   64.000000    7.000000       7.000000     0.000000
# 75%    2016.000000   64.000000   11.000000      11.000000     1.000000
# max    2017.000000   68.000000   16.000000      16.000000     1.000000
#
#        start_season       Games         SRS         SOS     win_pct  \
# count    469.000000  469.000000  469.000000  469.000000  469.000000
# mean    2013.000000   35.837953   14.375139    5.725778    0.744311
# std        2.002136    2.089700    7.756872    4.892262    0.101390
# min     2010.000000   30.000000  -13.370000  -10.310000    0.417000
# 25%     2011.000000   34.000000   11.240000    4.130000    0.676000
# 50%     2013.000000   36.000000   15.480000    7.620000    0.750000
# 75%     2015.000000   37.000000   19.690000    9.070000    0.800000
# max     2016.000000   41.000000   28.720000   12.230000    0.974000
#
#           pts_avg  opp_pts_avg      fg_pct  allow_fg_pct      ft_pct  \
# count  469.000000   469.000000  469.000000    469.000000  469.000000
# mean    73.298507    64.255864    0.458851      0.411640    0.710539
# std      4.859173     4.781396    0.022766      0.021989    0.034649
# min     59.000000    51.000000    0.394000      0.354000    0.603000
# 25%     70.000000    61.000000    0.444000      0.395000    0.686000
# 50%     73.000000    65.000000    0.458000      0.412000    0.709000
# 75%     77.000000    67.000000    0.474000      0.425000    0.734000
# max     89.000000    78.000000    0.522000      0.495000    0.818000
#
#        allow_ft_att_avg    poss_avg  off_rebs_avg  allow_off_rebs_avg  \
# count        469.000000  469.000000    469.000000          469.000000
# mean          17.904051   76.729769     10.791045           10.023454
# std            2.748225    3.846108      1.684217            1.330720
# min           11.000000   63.960000      5.000000            7.000000
# 25%           16.000000   74.684848     10.000000            9.000000
# 50%           18.000000   76.515789     11.000000           10.000000
# 75%           20.000000   79.171429     12.000000           11.000000
# max           28.000000   86.810000     16.000000           14.000000
#
#        def_rebs_avg  allow_def_rebs_avg      to_avg   steal_avg  off_rating  \
# count    469.000000          469.000000  469.000000  469.000000  469.000000
# mean      23.707889           21.972281   11.270789    6.221748   95.572509
# std        2.346565            1.659368    1.462209    1.261645    5.049279
# min       18.000000           18.000000    7.000000    3.000000   77.919708
# 25%       22.000000           21.000000   10.000000    5.000000   92.345893
# 50%       24.000000           22.000000   11.000000    6.000000   95.554872
# 75%       25.000000           23.000000   12.000000    7.000000   99.287345
# max       31.000000           26.000000   15.000000   10.000000  107.777180
#
#        ft_att_avg
# count  469.000000
# mean    20.923241
# std      2.555887
# min     13.000000
# 25%     19.000000
# 50%     21.000000
# 75%     23.000000
# max     30.000000

# %%
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','opp_team_id'], 
                                right_on=['season', 'team_id'], how='left',suffixes=('_t','_o'))
#tourney_data.info()

# %%
tourney_data.describe()
# Out:
#           season_t       round   team_seed  opp_team_seed  game_result  \
# count   469.000000  469.000000  469.000000     469.000000   469.000000
# mean   2014.000000   44.805970    7.132196       7.345416     0.498934
# std       2.002136   22.479399    4.761806       4.713148     0.500533
# min    2011.000000    2.000000    1.000000       1.000000     0.000000
# 25%    2012.000000   32.000000    3.000000       3.000000     0.000000
# 50%    2014.000000   64.000000    7.000000       7.000000     0.000000
# 75%    2016.000000   64.000000   11.000000      11.000000     1.000000
# max    2017.000000   68.000000   16.000000      16.000000     1.000000
#
#        start_season     Games_t       SRS_t       SOS_t   win_pct_t  \
# count    469.000000  469.000000  469.000000  469.000000  469.000000
# mean    2013.000000   35.837953   14.375139    5.725778    0.744311
# std        2.002136    2.089700    7.756872    4.892262    0.101390
# min     2010.000000   30.000000  -13.370000  -10.310000    0.417000
# 25%     2011.000000   34.000000   11.240000    4.130000    0.676000
# 50%     2013.000000   36.000000   15.480000    7.620000    0.750000
# 75%     2015.000000   37.000000   19.690000    9.070000    0.800000
# max     2016.000000   41.000000   28.720000   12.230000    0.974000
#
#         pts_avg_t  opp_pts_avg_t    fg_pct_t  allow_fg_pct_t    ft_pct_t  \
# count  469.000000     469.000000  469.000000      469.000000  469.000000
# mean    73.298507      64.255864    0.458851        0.411640    0.710539
# std      4.859173       4.781396    0.022766        0.021989    0.034649
# min     59.000000      51.000000    0.394000        0.354000    0.603000
# 25%     70.000000      61.000000    0.444000        0.395000    0.686000
# 50%     73.000000      65.000000    0.458000        0.412000    0.709000
# 75%     77.000000      67.000000    0.474000        0.425000    0.734000
# max     89.000000      78.000000    0.522000        0.495000    0.818000
#
#        allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  \
# count          469.000000  469.000000      469.000000            469.000000
# mean            17.904051   76.729769       10.791045             10.023454
# std              2.748225    3.846108        1.684217              1.330720
# min             11.000000   63.960000        5.000000              7.000000
# 25%             16.000000   74.684848       10.000000              9.000000
# 50%             18.000000   76.515789       11.000000             10.000000
# 75%             20.000000   79.171429       12.000000             11.000000
# max             28.000000   86.810000       16.000000             14.000000
#
#        def_rebs_avg_t  allow_def_rebs_avg_t    to_avg_t  steal_avg_t  \
# count      469.000000            469.000000  469.000000   469.000000
# mean        23.707889             21.972281   11.270789     6.221748
# std          2.346565              1.659368    1.462209     1.261645
# min         18.000000             18.000000    7.000000     3.000000
# 25%         22.000000             21.000000   10.000000     5.000000
# 50%         24.000000             22.000000   11.000000     6.000000
# 75%         25.000000             23.000000   12.000000     7.000000
# max         31.000000             26.000000   15.000000    10.000000
#
#        off_rating_t  ft_att_avg_t     season_o     Games_o       SRS_o  \
# count    469.000000    469.000000   469.000000  469.000000  469.000000
# mean      95.572509     20.923241  2013.000000   35.827292   14.028038
# std        5.049279      2.555887     2.002136    2.195085    7.591618
# min       77.919708     13.000000  2010.000000   30.000000  -10.900000
# 25%       92.345893     19.000000  2011.000000   34.000000   10.800000
# 50%       95.554872     21.000000  2013.000000   35.000000   15.260000
# 75%       99.287345     23.000000  2015.000000   37.000000   19.230000
# max      107.777180     30.000000  2016.000000   41.000000   28.720000
#
#             SOS_o   win_pct_o   pts_avg_o  opp_pts_avg_o    fg_pct_o  \
# count  469.000000  469.000000  469.000000     469.000000  469.000000
# mean     5.795203    0.736113   73.411514      64.816631    0.459083
# std      4.928852    0.095084    4.937554       4.589618    0.022139
# min    -12.120000    0.412000   59.000000      54.000000    0.394000
# 25%      4.010000    0.676000   70.000000      62.000000    0.444000
# 50%      7.570000    0.743000   73.000000      65.000000    0.459000
# 75%      9.320000    0.795000   77.000000      68.000000    0.474000
# max     12.230000    0.974000   89.000000      80.000000    0.522000
#
#        allow_fg_pct_o    ft_pct_o  allow_ft_att_avg_o  poss_avg_o  \
# count      469.000000  469.000000          469.000000  469.000000
# mean         0.414190    0.709235           17.957356   76.955509
# std          0.020946    0.033761            2.745294    3.950489
# min          0.354000    0.616000           11.000000   63.960000
# 25%          0.401000    0.686000           16.000000   74.833333
# 50%          0.414000    0.708000           18.000000   76.705000
# 75%          0.427000    0.731000           20.000000   79.502857
# max          0.488000    0.818000           29.000000   88.716667
#
#        off_rebs_avg_o  allow_off_rebs_avg_o  def_rebs_avg_o  \
# count      469.000000            469.000000      469.000000
# mean        10.795309             10.108742       23.631130
# std          1.786912              1.359875        2.371116
# min          5.000000              7.000000       18.000000
# 25%         10.000000              9.000000       22.000000
# 50%         11.000000             10.000000       24.000000
# 75%         12.000000             11.000000       25.000000
# max         16.000000             14.000000       31.000000
#
#        allow_def_rebs_avg_o    to_avg_o  steal_avg_o  off_rating_o  \
# count            469.000000  469.000000   469.000000    469.000000
# mean              21.976546   11.411514     6.202559     95.435353
# std                1.720131    1.507515     1.392714      4.987337
# min               18.000000    7.000000     3.000000     80.000000
# 25%               21.000000   10.000000     5.000000     91.767881
# 50%               22.000000   11.000000     6.000000     95.238095
# 75%               23.000000   12.000000     7.000000     98.951462
# max               28.000000   16.000000    11.000000    107.899807
#
#        ft_att_avg_o
# count    469.000000
# mean      20.859275
# std        2.701184
# min       13.000000
# 25%       19.000000
# 50%       21.000000
# 75%       23.000000
# max       30.000000

# %% [markdown]
# Incorporate additional features here.
# Team conference, seeding deltas.

# %%
tourney_data = tourney_data.join(teams, on='team_id_t', how='left')

# %%
tourney_data = tourney_data.join(teams, on='opp_team_id', how='left', lsuffix='_t', rsuffix='_o')
tourney_data.head()
# Out:
#    season_t  round   game_date  team_seed                   team  \
# 0      2013     64  2013-03-22          8   North Carolina State
# 1      2011     64  2011-03-17          7                 Temple
# 2      2013     64  2013-03-21         12                  Akron
# 3      2012     64  2012-03-15         12  Virginia Commonwealth
# 4      2011      8  2011-03-27          1                 Kansas
#
#                               team_id_t  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#                  School_t  Games_t  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0   North Carolina State        35  14.32   7.17      0.686         77
# 1                 Temple        34  12.35   4.23      0.765         70
# 2                  Akron        33   8.11   0.18      0.788         71
# 3  Virginia Commonwealth        36   8.79   0.63      0.806         68
# 4                 Kansas        38  24.10   7.62      0.921         81
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0             70     0.496           0.419     0.681                  17
# 1             62     0.447           0.435     0.698                  19
# 2             62     0.455           0.395     0.643                  19
# 3             59     0.410           0.424     0.685                  18
# 4             64     0.508           0.380     0.679                  18
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286              11                    12              22
# 1   75.688235              11                    11              24
# 2   78.884848              12                    10              21
# 3   76.305556              12                    10              18
# 4   80.126316              11                    10              27
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0                    21        12            6     98.171354            23
# 1                    22        10            6     92.484651            19
# 2                    21        13            7     90.004610            20
# 3                    24        11           10     89.115399            20
# 4                    21        13            7    101.090384            22
#
#    season_o                School_o                             team_id_o  \
# 0      2012                 Temple   8598d1b6-106b-4083-a512-2e495729525a
# 1      2010             Penn State   4aebd148-8119-4875-954c-66779867989b
# 2      2012  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 3      2011          Wichita State   f38b58de-3273-4723-a78b-2f918e9aa2d5
# 4      2010  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
#
#    Games_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0       34   9.52   5.20      0.706         72             67     0.428
# 1       34  11.98  11.45      0.559         63             62     0.439
# 2       36  16.89   4.47      0.750         76             64     0.450
# 3       33  17.42   3.80      0.818         77             62     0.482
# 4       40   8.56   3.78      0.700         71             66     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723                  18   77.494118              11
# 1           0.434     0.724                  21   68.341176               9
# 2           0.444     0.701                  20   81.044444              13
# 3           0.393     0.748                  18   77.496970              10
# 4           0.424     0.715                  18   75.240000              10
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0                    10              19                    25        10
# 1                     8              21                    23        10
# 2                    11              18                    23        11
# 3                     9              24                    21        12
# 4                    10              21                    24        11
#
#    steal_avg_o  off_rating_o  ft_att_avg_o        conf_name_t  \
# 0            7     92.910278            20     Atlantic Coast
# 1            4     92.184541            16  American Athletic
# 2           11     93.775706            18       Mid-American
# 3            6     99.358724            19        Atlantic 10
# 4            8     94.364700            20             Big 12
#
#          conf_name_o
# 0  American Athletic
# 1            Big Ten
# 2        Atlantic 10
# 3  American Athletic
# 4        Atlantic 10

# %% [markdown]
# #### Add a feature
# top_conf = 1 if team is a top conference and opponent is not
# top_conf = -1 if opp_team is a top_conference and team is not
# top_conf = 0 otherwise

# %%
print(top_tournament_conferences_list)
tourney_data['top_conf'] = tourney_data.apply(lambda row: conf_compare(row.conf_name_t, row.conf_name_o),axis=1)
tourney_data.head(10)[['game_result','conf_name_t','conf_name_o','top_conf']]
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']
#    game_result        conf_name_t        conf_name_o  top_conf
# 0            0     Atlantic Coast  American Athletic         1
# 1            1  American Athletic            Big Ten        -1
# 2            0       Mid-American        Atlantic 10         0
# 3            1        Atlantic 10  American Athletic         0
# 4            0             Big 12        Atlantic 10         1
# 5            1        Atlantic 10     Atlantic Coast        -1
# 6            0            Big Ten        Atlantic 10         1
# 7            1        Atlantic 10           Big East         0
# 8            0         Pacific 12        Atlantic 10         1
# 9            1        Atlantic 10         Pacific 12        -1

# %%
# Upsets occur less than 30% of the time when seeding deltas are more than 6
tourney_data['upset_seed_threshold'] = tourney_data.apply(lambda row: abs(row.team_seed - row.opp_team_seed) > 6, axis=1).astype(int)
tourney_data.head()
# Out:
#    season_t  round   game_date  team_seed                   team  \
# 0      2013     64  2013-03-22          8   North Carolina State
# 1      2011     64  2011-03-17          7                 Temple
# 2      2013     64  2013-03-21         12                  Akron
# 3      2012     64  2012-03-15         12  Virginia Commonwealth
# 4      2011      8  2011-03-27          1                 Kansas
#
#                               team_id_t  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#                  School_t  Games_t  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0   North Carolina State        35  14.32   7.17      0.686         77
# 1                 Temple        34  12.35   4.23      0.765         70
# 2                  Akron        33   8.11   0.18      0.788         71
# 3  Virginia Commonwealth        36   8.79   0.63      0.806         68
# 4                 Kansas        38  24.10   7.62      0.921         81
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0             70     0.496           0.419     0.681                  17
# 1             62     0.447           0.435     0.698                  19
# 2             62     0.455           0.395     0.643                  19
# 3             59     0.410           0.424     0.685                  18
# 4             64     0.508           0.380     0.679                  18
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286              11                    12              22
# 1   75.688235              11                    11              24
# 2   78.884848              12                    10              21
# 3   76.305556              12                    10              18
# 4   80.126316              11                    10              27
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0                    21        12            6     98.171354            23
# 1                    22        10            6     92.484651            19
# 2                    21        13            7     90.004610            20
# 3                    24        11           10     89.115399            20
# 4                    21        13            7    101.090384            22
#
#    season_o                School_o                             team_id_o  \
# 0      2012                 Temple   8598d1b6-106b-4083-a512-2e495729525a
# 1      2010             Penn State   4aebd148-8119-4875-954c-66779867989b
# 2      2012  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 3      2011          Wichita State   f38b58de-3273-4723-a78b-2f918e9aa2d5
# 4      2010  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
#
#    Games_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0       34   9.52   5.20      0.706         72             67     0.428
# 1       34  11.98  11.45      0.559         63             62     0.439
# 2       36  16.89   4.47      0.750         76             64     0.450
# 3       33  17.42   3.80      0.818         77             62     0.482
# 4       40   8.56   3.78      0.700         71             66     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723                  18   77.494118              11
# 1           0.434     0.724                  21   68.341176               9
# 2           0.444     0.701                  20   81.044444              13
# 3           0.393     0.748                  18   77.496970              10
# 4           0.424     0.715                  18   75.240000              10
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0                    10              19                    25        10
# 1                     8              21                    23        10
# 2                    11              18                    23        11
# 3                     9              24                    21        12
# 4                    10              21                    24        11
#
#    steal_avg_o  off_rating_o  ft_att_avg_o        conf_name_t  \
# 0            7     92.910278            20     Atlantic Coast
# 1            4     92.184541            16  American Athletic
# 2           11     93.775706            18       Mid-American
# 3            6     99.358724            19        Atlantic 10
# 4            8     94.364700            20             Big 12
#
#          conf_name_o  top_conf  upset_seed_threshold
# 0  American Athletic         1                     0
# 1            Big Ten        -1                     0
# 2        Atlantic 10         0                     1
# 3  American Athletic         0                     1
# 4        Atlantic 10         1                     1

# %%
tourney_data['srs_sqr_t'] = tourney_data['SRS_t'] * tourney_data['SRS_t'] 
tourney_data['srs_sqr_o'] = tourney_data['SRS_o'] * tourney_data['SRS_o'] 
tourney_data['off_rating_sqr_t'] = tourney_data['off_rating_t'] * tourney_data['off_rating_t'] 
tourney_data['off_rating_sqr_o'] = tourney_data['off_rating_o'] * tourney_data['off_rating_o']

# %%
numeric_feature_to_scale = ['pts_avg_t','opp_pts_avg_t',
                            'off_rebs_avg_t','allow_off_rebs_avg_t',
                            'def_rebs_avg_t','allow_def_rebs_avg_t',
                            'ft_att_avg_t','allow_ft_att_avg_t',
                            'to_avg_t','steal_avg_t',
                            'SRS_t',
                            'off_rating_t',
                            'pts_avg_o','opp_pts_avg_o',
                            'off_rebs_avg_o','allow_off_rebs_avg_o',
                            'def_rebs_avg_o','allow_def_rebs_avg_o',
                            'ft_att_avg_o','allow_ft_att_avg_o',
                            'to_avg_o','steal_avg_o',
                            'SRS_o',
                            'off_rating_o',
                             'srs_sqr_t','srs_sqr_o','off_rating_sqr_t','off_rating_sqr_o']

scaler =StandardScaler()
tourney_data[numeric_feature_to_scale] = scaler.fit_transform(tourney_data[numeric_feature_to_scale])
tourney_data.head()
# Out:
#    season_t  round   game_date  team_seed                   team  \
# 0      2013     64  2013-03-22          8   North Carolina State
# 1      2011     64  2011-03-17          7                 Temple
# 2      2013     64  2013-03-21         12                  Akron
# 3      2012     64  2012-03-15         12  Virginia Commonwealth
# 4      2011      8  2011-03-27          1                 Kansas
#
#                               team_id_t  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#                  School_t  Games_t     SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0   North Carolina State        35 -0.007116   7.17      0.686   0.762567
# 1                 Temple        34 -0.261355   4.23      0.765  -0.679546
# 2                  Akron        33 -0.808551   0.18      0.788  -0.473530
# 3  Virginia Commonwealth        36 -0.720793   0.63      0.806  -1.091578
# 4                 Kansas        38  1.255048   7.62      0.921   1.586632
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0       1.202634     0.496           0.419     0.681           -0.329309
# 1      -0.472304     0.447           0.435     0.698            0.399210
# 2      -0.472304     0.455           0.395     0.643            0.399210
# 3      -1.100406     0.410           0.424     0.685            0.034950
# 4      -0.053569     0.508           0.380     0.679            0.034950
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286        0.124199              1.486906       -0.728602
# 1   75.688235        0.124199              0.734631        0.124617
# 2   78.884848        0.718581             -0.017644       -1.155212
# 3   76.305556        0.718581             -0.017644       -2.435041
# 4   80.126316        0.124199             -0.017644        1.404447
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0             -0.586560  0.499238    -0.175949      0.515246      0.813407
# 1              0.016722 -0.870016    -0.175949     -0.612197     -0.753279
# 2             -0.586560  1.183865     0.617513     -1.103889     -0.361607
# 3              1.223287 -0.185389     2.997900     -1.280184     -0.361607
# 4             -0.586560  1.183865     0.617513      1.093971      0.421736
#
#    season_o                School_o                             team_id_o  \
# 0      2012                 Temple   8598d1b6-106b-4083-a512-2e495729525a
# 1      2010             Penn State   4aebd148-8119-4875-954c-66779867989b
# 2      2012  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 3      2011          Wichita State   f38b58de-3273-4723-a78b-2f918e9aa2d5
# 4      2010  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
#
#    Games_o     SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0       34 -0.594452   5.20      0.706  -0.286178       0.476227     0.428
# 1       34 -0.270064  11.45      0.559  -2.110890      -0.614351     0.439
# 2       36  0.377392   4.47      0.750   0.524804      -0.178120     0.450
# 3       33  0.447281   3.80      0.818   0.727550      -0.614351     0.482
# 4       40 -0.721042   3.78      0.700  -0.488924       0.258111     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723            0.015550   77.494118        0.114672
# 1           0.434     0.724            1.109496   68.341176       -1.005772
# 2           0.444     0.701            0.744847   81.044444        1.235117
# 3           0.393     0.748            0.015550   77.496970       -0.445550
# 4           0.424     0.715            0.015550   75.240000       -0.445550
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0             -0.080050       -1.955229              1.759565 -0.937318
# 1             -1.552344       -1.110844              0.595622 -0.937318
# 2              0.656097       -2.377422              0.595622 -0.273266
# 3             -0.816197        0.155734             -0.568322  0.390785
# 4             -0.080050       -1.110844              1.177593 -0.273266
#
#    steal_avg_o  off_rating_o  ft_att_avg_o        conf_name_t  \
# 0     0.573192     -0.506838     -0.318450     Atlantic Coast
# 1    -1.583176     -0.652509     -1.800864  American Athletic
# 2     3.448350     -0.333128     -1.059657       Mid-American
# 3    -0.145597      0.787506     -0.689054        Atlantic 10
# 4     1.291982     -0.214904     -0.318450             Big 12
#
#          conf_name_o  top_conf  upset_seed_threshold  srs_sqr_t  srs_sqr_o  \
# 0  American Athletic         1                     0  -0.334103  -0.924116
# 1            Big Ten        -1                     0  -0.618959  -0.625479
# 2        Atlantic 10         0                     1  -1.089296   0.174905
# 3  American Athletic         0                     1  -1.026990   0.277580
# 4        Atlantic 10         1                     1   1.703097  -1.022119
#
#    off_rating_sqr_t  off_rating_sqr_o
# 0          0.497393         -0.524693
# 1         -0.630635         -0.665542
# 2         -1.101510         -0.355289
# 3         -1.267223          0.775315
# 4          1.102555         -0.239097

# %%
feature_data = tourney_data.drop(columns=['season_t','round','game_date','team','team_id_t',
                                         'opp_team','opp_team_id','game_result','start_season',
                                         'season_o','team_id_o','Games_t','Games_o',
                                          'School_o','School_t','SOS_o','SOS_t',
                                         'conf_name_t','conf_name_o']).copy()
feature_data.head()
# Out:
#    team_seed  opp_team_seed     SRS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  \
# 0          8              9 -0.007116      0.686   0.762567       1.202634
# 1          7             10 -0.261355      0.765  -0.679546      -0.472304
# 2         12              5 -0.808551      0.788  -0.473530      -0.472304
# 3         12              5 -0.720793      0.806  -1.091578      -1.100406
# 4          1             11  1.255048      0.921   1.586632      -0.053569
#
#    fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  \
# 0     0.496           0.419     0.681           -0.329309   78.434286
# 1     0.447           0.435     0.698            0.399210   75.688235
# 2     0.455           0.395     0.643            0.399210   78.884848
# 3     0.410           0.424     0.685            0.034950   76.305556
# 4     0.508           0.380     0.679            0.034950   80.126316
#
#    off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  \
# 0        0.124199              1.486906       -0.728602             -0.586560
# 1        0.124199              0.734631        0.124617              0.016722
# 2        0.718581             -0.017644       -1.155212             -0.586560
# 3        0.718581             -0.017644       -2.435041              1.223287
# 4        0.124199             -0.017644        1.404447             -0.586560
#
#    to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t     SRS_o  win_pct_o  \
# 0  0.499238    -0.175949      0.515246      0.813407 -0.594452      0.706
# 1 -0.870016    -0.175949     -0.612197     -0.753279 -0.270064      0.559
# 2  1.183865     0.617513     -1.103889     -0.361607  0.377392      0.750
# 3 -0.185389     2.997900     -1.280184     -0.361607  0.447281      0.818
# 4  1.183865     0.617513      1.093971      0.421736 -0.721042      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0  -0.286178       0.476227     0.428           0.438     0.723
# 1  -2.110890      -0.614351     0.439           0.434     0.724
# 2   0.524804      -0.178120     0.450           0.444     0.701
# 3   0.727550      -0.614351     0.482           0.393     0.748
# 4  -0.488924       0.258111     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0            0.015550   77.494118        0.114672             -0.080050
# 1            1.109496   68.341176       -1.005772             -1.552344
# 2            0.744847   81.044444        1.235117              0.656097
# 3            0.015550   77.496970       -0.445550             -0.816197
# 4            0.015550   75.240000       -0.445550             -0.080050
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0       -1.955229              1.759565 -0.937318     0.573192     -0.506838
# 1       -1.110844              0.595622 -0.937318    -1.583176     -0.652509
# 2       -2.377422              0.595622 -0.273266     3.448350     -0.333128
# 3        0.155734             -0.568322  0.390785    -0.145597      0.787506
# 4       -1.110844              1.177593 -0.273266     1.291982     -0.214904
#
#    ft_att_avg_o  top_conf  upset_seed_threshold  srs_sqr_t  srs_sqr_o  \
# 0     -0.318450         1                     0  -0.334103  -0.924116
# 1     -1.800864        -1                     0  -0.618959  -0.625479
# 2     -1.059657         0                     1  -1.089296   0.174905
# 3     -0.689054         0                     1  -1.026990   0.277580
# 4     -0.318450         1                     1   1.703097  -1.022119
#
#    off_rating_sqr_t  off_rating_sqr_o
# 0          0.497393         -0.524693
# 1         -0.630635         -0.665542
# 2         -1.101510         -0.355289
# 3         -1.267223          0.775315
# 4          1.102555         -0.239097

# %%
X= feature_data
y= tourney_data['game_result']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
X_train.head()
# Out:
# (375, 42)
# (375,)
# (94, 42)
# (94,)
#      team_seed  opp_team_seed     SRS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  \
# 212         16              1 -2.078459      0.583  -1.709626      -0.053569
# 191          2             15  0.870462      0.921   0.968583      -0.681671
# 263          3             14  0.550404      0.750  -1.091578      -1.100406
# 466          2             15  0.345206      0.794   0.762567       0.783900
# 241         14              3 -1.149258      0.714  -0.473530      -0.472304
#
#      fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  \
# 212     0.421           0.428     0.699            0.763470   72.988889
# 191     0.520           0.390     0.691           -0.329309   73.747368
# 263     0.459           0.390     0.714           -0.329309   74.833333
# 466     0.456           0.433     0.701            0.399210   78.694118
# 241     0.480           0.388     0.725            0.763470   72.331429
#
#      off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 212       -0.470183             -0.017644       -2.008432
# 191       -0.470183             -0.017644        1.404447
# 263        0.124199             -0.769919       -0.728602
# 466        0.124199              0.734631       -1.155212
# 241       -1.064564              0.734631       -0.728602
#
#      allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 212              1.223287 -0.185389     0.617513     -1.292228     -0.753279
# 191             -1.793125 -0.870016    -0.969411      2.021053      0.030064
# 263             -1.189843  1.183865     1.410976     -0.932595     -0.753279
# 466              0.016722  0.499238    -0.175949      0.450982      1.596750
# 241             -0.586560 -0.870016     2.204438      0.512849     -0.361607
#
#         SRS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  \
# 212  1.433630      0.806   0.930296      -0.614351     0.482           0.390
# 191 -2.076613      0.697  -1.908144      -0.614351     0.434           0.421
# 263 -0.906972      0.765  -0.488924      -0.614351     0.484           0.415
# 466 -1.286743      0.771   0.322059       0.039996     0.444           0.414
# 241  0.503983      0.706  -0.894415      -1.050583     0.434           0.402
#
#      ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 212     0.743           -1.078396   77.822222        0.674895
# 191     0.692           -1.078396   69.200000       -1.565994
# 263     0.731            0.380199   72.652941       -1.565994
# 466     0.768            0.015550   77.948571        0.114672
# 241     0.674           -0.349099   76.388235        1.795339
#
#      allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 212              0.656097       -0.266458             -1.732266  1.054837
# 191             -2.288490        0.155734              1.177593 -1.601369
# 263             -0.816197       -1.533036             -1.732266  1.718888
# 466             -0.080050       -1.533036              0.595622 -0.273266
# 241              0.656097        0.155734             -1.732266  0.390785
#
#      steal_avg_o  off_rating_o  ft_att_avg_o  top_conf  upset_seed_threshold  \
# 212     0.573192      0.962078      1.534567        -1                     1
# 191    -1.583176     -0.592090     -1.059657         0                     1
# 263    -0.145597      0.459558     -0.318450         1                     1
# 466     0.573192      0.156951      0.052153         1                     1
# 241     0.573192     -1.025149      0.052153        -1                     1
#
#      srs_sqr_t  srs_sqr_o  off_rating_sqr_t  off_rating_sqr_o
# 212  -1.429667   2.064963         -1.278484          0.957323
# 191   0.972489  -1.419146          2.108938         -0.607258
# 263   0.437881  -1.147193         -0.938921          0.437684
# 466   0.130214  -1.332900          0.431287          0.131107
# 241  -1.283671   0.363214          0.494924         -1.020820

# %%
mlp = MLPClassifier(hidden_layer_sizes=(4,4), max_iter=1000)

result = mlp.fit(X_train,y_train)

#print("Coeffs ",logreg.coef_)
#print("Intercept ", logreg.intercept_)

# %%
y_pred = mlp.predict(X_test)
prediction_probabilities = mlp.predict_proba(X_test)
print("LR model prediction accuracy is %2.2f" % metrics.accuracy_score(y_test, y_pred))
# Out:
# LR model prediction accuracy is 0.53

# %%
print("Log loss= ",log_loss(y_test,mlp.predict_proba(X_test)))
# Out:
# Log loss=  0.7049870254532762

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[ 7, 38],
#        [ 6, 43]], dtype=int64)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5,257.44,'Predicted label')

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.5212765957446809
# Precision: 0.5222222222222223
# Recall: 0.9591836734693877
# Log loss=  1.6455230187976158

# %%
# Retrieve the non-normalized game stats
prediction_probabilities[:,1]
pred_probs = pd.Series(prediction_probabilities[:,1], index=X_test.index)
predictions = pd.Series(y_pred, index=y_test.index)
test_games = tourney_data[tourney_data.index.isin(X_test.index)].copy()

test_games[numeric_feature_to_scale] = scaler.inverse_transform(test_games[numeric_feature_to_scale])
test_games['predicted_result'] = predictions
test_games['pred_win_prob'] = pred_probs

test_games.head()
# Out:
#     season_t  round   game_date  team_seed                   team  \
# 9       2016     64  2016-03-18         10  Virginia Commonwealth
# 21      2014     32  2014-03-23          6                 Baylor
# 34      2016     64  2016-03-18         16             Holy Cross
# 40      2016     64  2016-03-18          9             Cincinnati
# 43      2012     64  2012-03-15          5             New Mexico
#
#                                team_id_t  opp_team_seed             opp_team  \
# 9   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              7         Oregon State
# 21  db6e1cab-3fa3-4a93-a673-8b2a358ff4bf              3            Creighton
# 34  31aedd91-a77e-46c1-8bdc-80e9860c159d              1               Oregon
# 40  a17dfc54-415f-49c3-a2e6-d6fa9db18b0a              8  Saint Joseph's (PA)
# 43  1b1977ec-b32f-4ce3-95a4-d07bab4816cd             12     Long Beach State
#
#                              opp_team_id  game_result  start_season  \
# 9   532d3874-b4b3-4c5c-acc6-749a6db26c8f            1          2015
# 21  7d797407-623e-476d-b299-46de4275414d            1          2013
# 34  1da70895-f77f-44ef-b216-d63c02e696eb            0          2015
# 40  f9e4261e-d11d-46c4-bd33-c7bbc94ef0e8            0          2015
# 43  11a617d5-af03-4cce-bc8a-51114d9e41fe            1          2011
#
#                   School_t  Games_t  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 9   Virginia Commonwealth        36  13.83   4.35      0.694       77.0
# 21                 Baylor        38  15.80  10.11      0.684       74.0
# 34             Holy Cross        35 -11.20  -6.11      0.429       64.0
# 40             Cincinnati        33  15.19   5.25      0.667       73.0
# 43             New Mexico        35  15.60   3.34      0.800       72.0
#
#     opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 9            67.0     0.451           0.440     0.692                20.0
# 21           67.0     0.455           0.425     0.680                18.0
# 34           69.0     0.412           0.459     0.687                17.0
# 40           63.0     0.430           0.393     0.705                15.0
# 43           59.0     0.462           0.384     0.707                16.0
#
#     poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 9    81.427778            12.0                   9.0            25.0
# 21   77.042105            13.0                  11.0            24.0
# 34   72.462857             7.0                   9.0            22.0
# 40   78.975758            13.0                  11.0            25.0
# 43   76.120000            11.0                  10.0            23.0
#
#     allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 9                   25.0      11.0          8.0     94.562325          20.0
# 21                  20.0      11.0          5.0     96.051373          24.0
# 34                  26.0      11.0          6.0     88.321110          19.0
# 40                  23.0      11.0          7.0     92.433428          19.0
# 43                  21.0      13.0          6.0     94.587493          21.0
#
#     season_o           School_o                             team_id_o  \
# 9       2015      Oregon State   532d3874-b4b3-4c5c-acc6-749a6db26c8f
# 21      2013         Creighton   7d797407-623e-476d-b299-46de4275414d
# 34      2015            Oregon   1da70895-f77f-44ef-b216-d63c02e696eb
# 40      2015    Saint Joseph's   f9e4261e-d11d-46c4-bd33-c7bbc94ef0e8
# 43      2011  Long Beach State   11a617d5-af03-4cce-bc8a-51114d9e41fe
#
#     Games_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 9        32  10.39   9.26      0.594       71.0           70.0     0.440
# 21       35  18.03   7.17      0.771       78.0           67.0     0.497
# 34       38  18.05   8.64      0.816       78.0           68.0     0.467
# 40       36  12.10   4.93      0.778       77.0           70.0     0.453
# 43       34   9.52   0.87      0.735       73.0           63.0     0.468
#
#     allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 9            0.428     0.671                21.0   77.462500            10.0
# 21           0.426     0.743                18.0   72.302857             8.0
# 34           0.423     0.715                18.0   79.563158            11.0
# 40           0.417     0.716                15.0   78.622222             9.0
# 43           0.421     0.670                15.0   77.529412            11.0
#
#     allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 9                   11.0            23.0                  25.0      11.0
# 21                   9.0            25.0                  21.0       9.0
# 34                  10.0            24.0                  22.0      11.0
# 40                   9.0            28.0                  25.0       9.0
# 43                  10.0            22.0                  21.0      12.0
#
#     steal_avg_o  off_rating_o  ft_att_avg_o        conf_name_t  conf_name_o  \
# 9           7.0     91.657254          21.0        Atlantic 10   Pacific 12
# 21          3.0    107.879554          18.0             Big 12     Big East
# 34          7.0     98.035324          23.0     Patriot League   Pacific 12
# 40          5.0     97.936687          22.0  American Athletic  Atlantic 10
# 43          7.0     94.157815          23.0      Mountain West     Big West
#
#     top_conf  upset_seed_threshold  srs_sqr_t  srs_sqr_o  off_rating_sqr_t  \
# 9         -1                     0   191.2689   107.9521       8942.033342
# 21         1                     0   249.6400   325.0809       9225.866282
# 34        -1                     1   125.4400   325.8025       7800.618528
# 40         0                     0   230.7361   146.4100       8543.938608
# 43         0                     1   243.3600    90.6304       8946.793913
#
#     off_rating_sqr_o  predicted_result  pred_win_prob
# 9        8401.052121                 1       0.680911
# 21      11637.998236                 1       0.521366
# 34       9610.924844                 1       0.700947
# 40       9591.594737                 1       0.642359
# 43       8865.694101                 1       0.591049

# %%
missed_predictions = test_games[test_games['game_result'] != 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)
missed_predictions[['predicted_result','game_result','pred_win_prob','team','team_seed','conf_name_t', 'opp_team','opp_team_seed', 
                    'conf_name_o','top_conf','season_t','round']]

print("Total missed predictions= ", missed_predictions.shape[0])
# Out:
# Total missed predictions=  44

# %% [markdown]
# ### Missed Prediction Analysis

# %% [markdown]
# #### Missed predictions where higher seed was upset

# %%
f_list=['season_t','round', 'team_seed','SRS_t','team','opp_team','opp_team_seed','SRS_o','game_result','predicted_result']

cond_1 = ((missed_predictions['team_seed'] > missed_predictions['opp_team_seed']) & 
          (missed_predictions['game_result'] == 1))

cond_2 = ((missed_predictions['team_seed'] < missed_predictions['opp_team_seed']) &  
          (missed_predictions['game_result'] == 0))

upset_seeds = missed_predictions[cond_2 | cond_1][f_list]
print("Total missed predictions with seeding upset= ", upset_seeds.shape[0])
upset_seeds
# Out:
# Total missed predictions with seeding upset=  12
#      season_t  round  team_seed  SRS_t                  team  \
# 434      2016     64          3  21.61         West Virginia
# 288      2014     16          4  24.69            Louisville
# 170      2012      8          1  21.12              Syracuse
# 238      2016     64          6  14.80                 Texas
# 197      2011     64         11  13.86               Gonzaga
# 21       2014     32          6  15.80                Baylor
# 319      2012     32         11  12.10  North Carolina State
# 99       2016      8         10  14.62              Syracuse
# 155      2017     64         11  11.48                   USC
# 201      2014     32         10  13.42              Stanford
# 123      2015     64         14   1.94                   UAB
# 253      2012     64         15  -3.68         Norfolk State
#
#               opp_team  opp_team_seed  SRS_o  game_result  predicted_result
# 434  Stephen F. Austin             14   9.23            0                 1
# 288           Kentucky              8  18.07            0                 1
# 170         Ohio State              2  23.95            0                 1
# 238      Northern Iowa             11   8.78            0                 1
# 197         St. John's              6  13.10            1                 0
# 21           Creighton              3  18.03            1                 0
# 319         Georgetown              3  16.81            1                 0
# 99            Virginia              1  22.04            1                 0
# 155                SMU              6  18.71            1                 0
# 201             Kansas              2  20.25            1                 0
# 123         Iowa State              3  17.94            1                 0
# 253           Missouri              2  19.77            1                 0

# %%
for index, row in upset_seeds.iterrows():
    print_game_info(test_games, row['season_t'], row['round'], row['team'])
    print("------\n")
# Out:
# 		 West Virginia 	 Stephen F. Austin
# Seed 		      3 	     14
# PPG 		  78.00 	  80.00
# Allow PPG 	  66.00 	  63.00
# Poss Avg 	  85.39 	  80.10
# FG % 		  44.90 	  47.80
# Allow FG % 	  42.40 	  43.80
# Off Rb Avg 	  15.00 	  11.00
# Allow Off Rb Avg   8.00 	   9.00
# Def Rb Avg 	  23.00 	  23.00
# Allow Def Rb Avg  22.00 	  22.00
# FT ATT Avg 	  27.00 	  20.00
# Allow FT ATT Avg  27.00 	  20.00
# FT % 		  67.30 	  73.50
# Turnover Avg 	  14.00 	  12.00
# Takeaway Avg 	   9.00 	   9.00
# Win % 		  74.30 	  82.40
# Off Rating 	  91.34 	  99.88
# SRS Rating 	  21.61 	   9.23
#
#
# Top Conference=  1
# Game Result=  0  (One indicates win for  West Virginia )
# Predicted Result=  1
# Predicted Probability=   0.760
# ------
#
# 		 Louisville 	 Kentucky
# Seed 		      4 	      8
# PPG 		  81.00 	  74.00
# Allow PPG 	  61.00 	  66.00
# Poss Avg 	  80.84 	  78.51
# FG % 		  47.10 	  45.40
# Allow FG % 	  39.60 	  41.10
# Off Rb Avg 	  13.00 	  14.00
# Allow Off Rb Avg  11.00 	  10.00
# Def Rb Avg 	  24.00 	  26.00
# Allow Def Rb Avg  23.00 	  19.00
# FT ATT Avg 	  24.00 	  28.00
# Allow FT ATT Avg  20.00 	  20.00
# FT % 		  66.10 	  68.20
# Turnover Avg 	  10.00 	  11.00
# Takeaway Avg 	  10.00 	   4.00
# Win % 		  83.80 	  72.50
# Off Rating 	 100.20 	  94.26
# SRS Rating 	  24.69 	  18.07
#
#
# Top Conference=  0
# Game Result=  0  (One indicates win for  Louisville )
# Predicted Result=  1
# Predicted Probability=   0.699
# ------
#
# 		 Syracuse 	 Ohio State
# Seed 		      1 	      2
# PPG 		  74.00 	  74.00
# Allow PPG 	  61.00 	  59.00
# Poss Avg 	  76.45 	  77.09
# FG % 		  46.70 	  47.60
# Allow FG % 	  38.50 	  40.70
# Off Rb Avg 	  12.00 	  11.00
# Allow Off Rb Avg  14.00 	   8.00
# Def Rb Avg 	  19.00 	  23.00
# Allow Def Rb Avg  21.00 	  21.00
# FT ATT Avg 	  19.00 	  21.00
# Allow FT ATT Avg  17.00 	  15.00
# FT % 		  69.80 	  70.90
# Turnover Avg 	  10.00 	  11.00
# Takeaway Avg 	   9.00 	   7.00
# Win % 		  91.90 	  79.50
# Off Rating 	  96.80 	  96.00
# SRS Rating 	  21.12 	  23.95
#
#
# Top Conference=  0
# Game Result=  0  (One indicates win for  Syracuse )
# Predicted Result=  1
# Predicted Probability=   0.592
# ------
#
# 		 Texas 	 Northern Iowa
# Seed 		      6 	     11
# PPG 		  71.00 	  68.00
# Allow PPG 	  68.00 	  63.00
# Poss Avg 	  76.43 	  68.73
# FG % 		  43.20 	  45.50
# Allow FG % 	  42.00 	  42.30
# Off Rb Avg 	  11.00 	   5.00
# Allow Off Rb Avg  10.00 	   9.00
# Def Rb Avg 	  23.00 	  24.00
# Allow Def Rb Avg  24.00 	  25.00
# FT ATT Avg 	  22.00 	  17.00
# Allow FT ATT Avg  21.00 	  13.00
# FT % 		  66.60 	  75.70
# Turnover Avg 	  10.00 	   9.00
# Takeaway Avg 	   5.00 	   5.00
# Win % 		  60.60 	  63.90
# Off Rating 	  92.90 	  98.94
# SRS Rating 	  14.80 	   8.78
#
#
# Top Conference=  1
# Game Result=  0  (One indicates win for  Texas )
# Predicted Result=  1
# Predicted Probability=   0.533
# ------
#
# 		 Gonzaga 	 St. John's
# Seed 		     11 	      6
# PPG 		  76.00 	  70.00
# Allow PPG 	  65.00 	  67.00
# Poss Avg 	  78.43 	  75.58
# FG % 		  47.90 	  45.50
# Allow FG % 	  41.30 	  44.00
# Off Rb Avg 	  11.00 	  10.00
# Allow Off Rb Avg  10.00 	  14.00
# Def Rb Avg 	  26.00 	  21.00
# Allow Def Rb Avg  20.00 	  23.00
# FT ATT Avg 	  23.00 	  23.00
# Allow FT ATT Avg  15.00 	  16.00
# FT % 		  76.20 	  71.00
# Turnover Avg 	  13.00 	  12.00
# Takeaway Avg 	   7.00 	   8.00
# Win % 		  71.40 	  63.60
# Off Rating 	  96.90 	  92.61
# SRS Rating 	  13.86 	  13.10
#
#
# Top Conference=  0
# Game Result=  1  (One indicates win for  Gonzaga )
# Predicted Result=  0
# Predicted Probability=   0.393
# ------
#
# 		 Baylor 	 Creighton
# Seed 		      6 	      3
# PPG 		  74.00 	  78.00
# Allow PPG 	  67.00 	  67.00
# Poss Avg 	  77.04 	  72.30
# FG % 		  45.50 	  49.70
# Allow FG % 	  42.50 	  42.60
# Off Rb Avg 	  13.00 	   8.00
# Allow Off Rb Avg  11.00 	   9.00
# Def Rb Avg 	  24.00 	  25.00
# Allow Def Rb Avg  20.00 	  21.00
# FT ATT Avg 	  24.00 	  18.00
# Allow FT ATT Avg  18.00 	  18.00
# FT % 		  68.00 	  74.30
# Turnover Avg 	  11.00 	   9.00
# Takeaway Avg 	   5.00 	   3.00
# Win % 		  68.40 	  77.10
# Off Rating 	  96.05 	 107.88
# SRS Rating 	  15.80 	  18.03
#
#
# Top Conference=  1
# Game Result=  1  (One indicates win for  Baylor )
# Predicted Result=  0
# Predicted Probability=   0.386
# ------
#
# 		 North Carolina State 	 Georgetown
# Seed 		     11 	      3
# PPG 		  72.00 	  69.00
# Allow PPG 	  67.00 	  59.00
# Poss Avg 	  78.75 	  73.61
# FG % 		  45.80 	  46.50
# Allow FG % 	  41.50 	  38.70
# Off Rb Avg 	  12.00 	  11.00
# Allow Off Rb Avg  11.00 	  10.00
# Def Rb Avg 	  22.00 	  22.00
# Allow Def Rb Avg  22.00 	  19.00
# FT ATT Avg 	  20.00 	  20.00
# Allow FT ATT Avg  18.00 	  19.00
# FT % 		  70.40 	  69.80
# Turnover Avg 	  12.00 	  12.00
# Takeaway Avg 	   6.00 	   6.00
# Win % 		  64.90 	  72.70
# Off Rating 	  91.43 	  93.73
# SRS Rating 	  12.10 	  16.81
#
#
# Top Conference=  1
# Game Result=  1  (One indicates win for  North Carolina State )
# Predicted Result=  0
# Predicted Probability=   0.349
# ------
#
# 		 Syracuse 	 Virginia
# Seed 		     10 	      1
# PPG 		  69.00 	  70.00
# Allow PPG 	  65.00 	  60.00
# Poss Avg 	  76.06 	  69.22
# FG % 		  42.50 	  49.10
# Allow FG % 	  41.20 	  42.00
# Off Rb Avg 	  12.00 	   8.00
# Allow Off Rb Avg  12.00 	   7.00
# Def Rb Avg 	  23.00 	  23.00
# Allow Def Rb Avg  23.00 	  20.00
# FT ATT Avg 	  19.00 	  17.00
# Allow FT ATT Avg  16.00 	  16.00
# FT % 		  68.80 	  75.20
# Turnover Avg 	  11.00 	   9.00
# Takeaway Avg 	   8.00 	   5.00
# Win % 		  62.20 	  78.40
# Off Rating 	  90.71 	 101.13
# SRS Rating 	  14.62 	  22.04
#
#
# Top Conference=  0
# Game Result=  1  (One indicates win for  Syracuse )
# Predicted Result=  0
# Predicted Probability=   0.246
# ------
#
# 		 USC 	 SMU
# Seed 		     11 	      6
# PPG 		  78.00 	  74.00
# Allow PPG 	  73.00 	  60.00
# Poss Avg 	  79.22 	  73.98
# FG % 		  45.60 	  47.30
# Allow FG % 	  43.40 	  38.60
# Off Rb Avg 	  10.00 	  11.00
# Allow Off Rb Avg  11.00 	   9.00
# Def Rb Avg 	  24.00 	  26.00
# Allow Def Rb Avg  24.00 	  20.00
# FT ATT Avg 	  21.00 	  19.00
# Allow FT ATT Avg  14.00 	  13.00
# FT % 		  74.10 	  69.70
# Turnover Avg 	  11.00 	  10.00
# Takeaway Avg 	   7.00 	   5.00
# Win % 		  72.20 	  85.70
# Off Rating 	  98.46 	 100.02
# SRS Rating 	  11.48 	  18.71
#
#
# Top Conference=  1
# Game Result=  1  (One indicates win for  USC )
# Predicted Result=  0
# Predicted Probability=   0.225
# ------
#
# 		 Stanford 	 Kansas
# Seed 		     10 	      2
# PPG 		  72.00 	  78.00
# Allow PPG 	  68.00 	  70.00
# Poss Avg 	  75.27 	  79.26
# FG % 		  45.90 	  49.30
# Allow FG % 	  42.10 	  41.60
# Off Rb Avg 	   9.00 	  11.00
# Allow Off Rb Avg   9.00 	  10.00
# Def Rb Avg 	  25.00 	  26.00
# Allow Def Rb Avg  23.00 	  20.00
# FT ATT Avg 	  24.00 	  26.00
# Allow FT ATT Avg  20.00 	  25.00
# FT % 		  70.20 	  71.10
# Turnover Avg 	  11.00 	  13.00
# Takeaway Avg 	   5.00 	   5.00
# Win % 		  63.90 	  71.40
# Off Rating 	  95.65 	  98.41
# SRS Rating 	  13.42 	  20.25
#
#
# Top Conference=  0
# Game Result=  1  (One indicates win for  Stanford )
# Predicted Result=  0
# Predicted Probability=   0.176
# ------
#
# 		 UAB 	 Iowa State
# Seed 		     14 	      3
# PPG 		  68.00 	  77.00
# Allow PPG 	  68.00 	  69.00
# Poss Avg 	  78.06 	  77.54
# FG % 		  42.80 	  47.60
# Allow FG % 	  42.40 	  41.60
# Off Rb Avg 	  12.00 	   9.00
# Allow Off Rb Avg  12.00 	  11.00
# Def Rb Avg 	  24.00 	  26.00
# Allow Def Rb Avg  23.00 	  24.00
# FT ATT Avg 	  19.00 	  21.00
# Allow FT ATT Avg  19.00 	  14.00
# FT % 		  73.80 	  69.60
# Turnover Avg 	  13.00 	  11.00
# Takeaway Avg 	   6.00 	   6.00
# Win % 		  55.60 	  73.50
# Off Rating 	  87.12 	  99.30
# SRS Rating 	   1.94 	  17.94
#
#
# Top Conference=  -1
# Game Result=  1  (One indicates win for  UAB )
# Predicted Result=  0
# Predicted Probability=   0.174
# ------
#
# 		 Norfolk State 	 Missouri
# Seed 		     15 	      2
# PPG 		  68.00 	  80.00
# Allow PPG 	  67.00 	  66.00
# Poss Avg 	  79.10 	  74.14
# FG % 		  44.00 	  50.40
# Allow FG % 	  41.20 	  44.40
# Off Rb Avg 	  11.00 	   9.00
# Allow Off Rb Avg  11.00 	  10.00
# Def Rb Avg 	  21.00 	  20.00
# Allow Def Rb Avg  22.00 	  20.00
# FT ATT Avg 	  23.00 	  20.00
# Allow FT ATT Avg  21.00 	  15.00
# FT % 		  65.60 	  76.60
# Turnover Avg 	  14.00 	  10.00
# Takeaway Avg 	   6.00 	   8.00
# Win % 		  72.20 	  85.70
# Off Rating 	  85.97 	 107.90
# SRS Rating 	  -3.68 	  19.77
#
#
# Top Conference=  -1
# Game Result=  1  (One indicates win for  Norfolk State )
# Predicted Result=  0
# Predicted Probability=   0.030
# ------

# %% [markdown]
# #### Missed predictions where Lower SRS Won Game

# %%
cond_srs_1 = ((missed_predictions['SRS_t'] > missed_predictions['SRS_o']) & 
          (missed_predictions['game_result'] == 0))

cond_srs_2 = ((missed_predictions['SRS_t'] < missed_predictions['SRS_o']) & 
          (missed_predictions['game_result'] == 1))

upset_srs = missed_predictions[cond_srs_1 | cond_srs_2][f_list]
print("Total missed predictions with SRS upset= ", upset_srs.shape[0])
upset_srs
# Out:
# Total missed predictions with SRS upset=  14
#      season_t  round  team_seed  SRS_t                  team  \
# 40       2016     64          9  15.19            Cincinnati
# 434      2016     64          3  21.61         West Virginia
# 440      2017     32          5  20.51            Iowa State
# 288      2014     16          4  24.69            Louisville
# 138      2011      4          4  20.30              Kentucky
# 238      2016     64          6  14.80                 Texas
# 21       2014     32          6  15.80                Baylor
# 319      2012     32         11  12.10  North Carolina State
# 99       2016      8         10  14.62              Syracuse
# 155      2017     64         11  11.48                   USC
# 201      2014     32         10  13.42              Stanford
# 123      2015     64         14   1.94                   UAB
# 145      2015     68         16  -8.25               Hampton
# 253      2012     64         15  -3.68         Norfolk State
#
#                 opp_team  opp_team_seed  SRS_o  game_result  predicted_result
# 40   Saint Joseph's (PA)              8  12.10            0                 1
# 434    Stephen F. Austin             14   9.23            0                 1
# 440               Purdue              4  20.13            0                 1
# 288             Kentucky              8  18.07            0                 1
# 138          Connecticut              3  17.95            0                 1
# 238        Northern Iowa             11   8.78            0                 1
# 21             Creighton              3  18.03            1                 0
# 319           Georgetown              3  16.81            1                 0
# 99              Virginia              1  22.04            1                 0
# 155                  SMU              6  18.71            1                 0
# 201               Kansas              2  20.25            1                 0
# 123           Iowa State              3  17.94            1                 0
# 145            Manhattan             16  -1.34            1                 0
# 253             Missouri              2  19.77            1                 0

# %%
train_sizes, train_scores, test_scores = learning_curve(MLPClassifier(hidden_layer_sizes=(4,4), max_iter=1000), 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# %%
# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cross validation error

# %%
scores = cross_val_score(MLPClassifier(hidden_layer_sizes=(4,4), max_iter=1000), X,y, cv=10, scoring='accuracy')
print(scores.mean())
# Out:
# 0.578918054270737
