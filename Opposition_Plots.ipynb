# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import learning_curve
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)
# Out:
# Seaborn version:  0.9.0

# %% [markdown]
# #### Power Conference Feature
#
# From EDA we know that a small number of conferences account for 70% of all conference wins.
#
# If one of the two teams is in a power conference, indicate the advantage that team has for winning the game.

# %%
# Compare the conferences of two teams playing in a game.
# If both teams are in power conference or both teams are not in a power conference return 0.
# If the opponent team is in a power conference and the first team is not in a power conference return -1
# If the first team is a power conference team and opponent is not then return 1.

def conf_compare(team_conf, opp_conf):
    team_top = team_conf in top_tournament_conferences_list
    opp_top = opp_conf in top_tournament_conferences_list
    if team_top == opp_top:
        return 0
    elif team_top :
        return 1
    else:
        return -1

# %%
def join_feature_name_with_importance_value(features, importances):
    """
    Join via a list of tuples, feature names with their importance values
    :param features: data frame whose features are represented by columns used by classifier
    :param importances: feature importance scores assigned by classifier
    :return: sorted list (highest importances first) of feature,importance tuples
    """
    if features.columns.shape[0] != importances.shape[0]:
        return []

    feature_importances = []
    for item in range(features.columns.shape[0]):
        feature_importances.append((features.columns[item], importances[item]))
    feature_importances_sorted = sorted(feature_importances, reverse=True, key=lambda kv: abs(kv[1]))

    return feature_importances_sorted

# %%
def display_important_features_rf_forest(classifier, features):
    importances = classifier.feature_importances_
    #print("Importances: ", importances) 
    feature_importances = join_feature_name_with_importance_value(features, importances)
    print('Coefficient Values')
    for items in feature_importances:
        print(items[0]," ", items[1])

# %%
def get_tournament_record(df, season, round_, team):
    return df[(df['season_t'] == season) & (df['round']== round_) & (df['team']==team)]

# %%
def print_game_info(df, season, round_, team):
    t_rec = get_tournament_record(df, season, round_, team)
    opp_team = t_rec['opp_team'].iloc[0]
    print('\t\t',team,'\t',opp_team)
    print('Seed','\t\t',"%6d"%t_rec['team_seed'].iloc[0],'\t',"%6d"%t_rec['opp_team_seed'].iloc[0])
    print('PPG','\t\t',"%6.2f"%t_rec['pts_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['pts_avg_o'].iloc[0])
    print('Allow PPG','\t',"%6.2f"%t_rec['opp_pts_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['opp_pts_avg_o'].iloc[0])
    print('Poss Avg','\t',"%6.2f"%t_rec['poss_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['poss_avg_o'].iloc[0])
    print('FG %','\t\t',"%6.2f"%(100*t_rec['fg_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['fg_pct_o'].iloc[0]))
    print('Allow FG %','\t',"%6.2f"%(100*t_rec['allow_fg_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['allow_fg_pct_o'].iloc[0]))
    print('Off Rb Avg','\t',"%6.2f"%t_rec['off_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['off_rebs_avg_o'].iloc[0])
    print('Allow Off Rb Avg',"%6.2f"%t_rec['allow_off_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['allow_off_rebs_avg_o'].iloc[0])
    print('Def Rb Avg','\t',"%6.2f"%t_rec['def_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['def_rebs_avg_o'].iloc[0])
    print('Allow Def Rb Avg',"%6.2f"%t_rec['allow_def_rebs_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['allow_def_rebs_avg_o'].iloc[0])  
    print('FT ATT Avg','\t',"%6.2f"%t_rec['ft_att_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['ft_att_avg_o'].iloc[0]) 
    print('Allow FT ATT Avg',"%6.2f"%t_rec['allow_ft_att_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['allow_ft_att_avg_o'].iloc[0])
    print('FT %','\t\t',"%6.2f"%(100*t_rec['ft_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['ft_pct_o'].iloc[0]))
    print('Turnover Avg','\t',"%6.2f"%t_rec['to_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['to_avg_o'].iloc[0])
    print('Takeaway Avg','\t',"%6.2f"%t_rec['steal_avg_t'].iloc[0],'\t',"%6.2f"%t_rec['steal_avg_o'].iloc[0])
    print('Win %','\t\t',"%6.2f"%(100*t_rec['win_pct_t'].iloc[0]),'\t',"%6.2f"%(100*t_rec['win_pct_o'].iloc[0]))
    print('Off Rating','\t',"%6.2f"%t_rec['off_rating_t'].iloc[0],'\t',"%6.2f"%t_rec['off_rating_o'].iloc[0])
    print('\n\nTop Conference= ', t_rec['top_conf'].iloc[0])
    print('Game Result= ', t_rec['game_result'].iloc[0], ' (One indicates win for ', team,')')
    print('Predicted Result= ', t_rec['predicted_result'].iloc[0])
    print('Predicted Probability= ',"%6.3f"%t_rec['pred_win_prob'].iloc[0])
    return

# %% [markdown]
# #### Read in regular season team statistics from SRCBB https://www.sports-reference.com/cbb/

# %%
#Note season indicates start of season, e.g. 2013 to 2014, the corresponding tournament season is 1 greater than this value
# The tournament season for season 2013 is 2014
summary_data = pd.read_csv('sr_summaries_kaggle_id.csv')
print(summary_data.shape)

#display rows with NaNs
summary_data[summary_data.isnull().any(axis=1)]
# Out:
# (2773, 22)
#     season          School team_id  Games    SRS   SOS  win_pct  pts_avg  \
# 38    2009  Centenary (LA)     NaN     29 -17.16 -5.08    0.276       70
#
#     opp_pts_avg  fg_pct  allow_fg_pct  ft_pct  allow_ft_att_avg   poss_avg  \
# 38           80   0.416          0.49   0.733                25  80.641379
#
#     off_rebs_avg  allow_off_rebs_avg  def_rebs_avg  allow_def_rebs_avg  \
# 38             9                  11            20                  27
#
#     to_avg  steal_avg  off_rating  ft_att_avg
# 38      15          7   86.804071          21

# %%
#drop records with NaNs
summary_data.dropna(inplace=True)
print(summary_data.shape)
# Out:
# (2772, 22)

# %% [markdown]
# #### Read table of team names and associated team meta data from the Kaggle data set.
#
# https://console.cloud.google.com/bigquery?project=bigqueryncaa&p=bigquery-public-data&d=ncaa_basketball&page=dataset

# %%
# Read table of team names and associated team meta data
teams = pd.read_csv('D1_teams.csv')
teams.drop(columns=['code_ncaa','school_ncaa','turner_name','league_name','league_alias','conf_alias',
                    'conf_id','division_name','division_alias','division_id',
                    'kaggle_team_id','venue_id'], inplace=True)
teams.info()
teams.set_index('id',inplace=True)
teams.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 2 columns):
# id           351 non-null object
# conf_name    351 non-null object
# dtypes: object(2)
# memory usage: 5.6+ KB
#                                      conf_name
# id
# fe406882-9f22-495e-9df6-ef357a6803c6       Ivy
# ca478771-aa3d-4231-81e0-b70f519134fb       Ivy
# 5c7bf63f-bc39-43c5-9907-73b50b7a6b34       Ivy
# d60357bd-1205-42e9-9092-d986a2843a34       Ivy
# 88ff8c00-958e-4ccf-a21d-77fab9e93692       Ivy

# %% [markdown]
# #### Read in the NCAA Men's Tournament results from the the Kaggle data set.

# %%
tourney_data = pd.read_csv('tournament_results.csv')
tourney_data.drop(columns=['days_from_epoch','day','num_ot','academic_year','win_region','win_alias','lose_region',
                           'lose_alias','lose_code_ncaa','win_school_ncaa','win_code_ncaa','win_name','lose_name',
                           'win_pts','win_kaggle_team_id','lose_school_ncaa','lose_kaggle_team_id','lose_pts'],inplace=True)

tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 9 columns):
# season          2117 non-null int64
# round           2117 non-null int64
# game_date       2117 non-null object
# win_seed        2117 non-null int64
# win_market      2117 non-null object
# win_team_id     2117 non-null object
# lose_seed       2117 non-null int64
# lose_market     2117 non-null object
# lose_team_id    2117 non-null object
# dtypes: int64(4), object(5)
# memory usage: 148.9+ KB

# %% [markdown]
# ### Extract some historical data

# %%
game_data = tourney_data.join(teams, on='win_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'win_kaggle_team_id','conf_name':'win_conf_name'}, inplace=True)
game_data = game_data.join(teams,on='lose_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'lose_kaggle_team_id','conf_name':'lose_conf_name'}, inplace=True)
games_won_conf = game_data.groupby('win_conf_name').size().reset_index(name='count').sort_values(by=['count'], ascending=False)

games_won_conf['percent'] = 100 * games_won_conf['count']/games_won_conf['count'].sum()
games_won_conf['cum_percent'] = games_won_conf['percent'].cumsum()
games_won_conf.head()
# Out:
#      win_conf_name  count    percent  cum_percent
# 3   Atlantic Coast    431  20.358999    20.358999
# 9          Big Ten    313  14.785073    35.144072
# 24    Southeastern    269  12.706660    47.850732
# 5           Big 12    231  10.911667    58.762400
# 22      Pacific 12    197   9.305621    68.068021

# %% [markdown]
# Identify the conferences that have won 70% of all conference games

# %%
top_tournament_conferences_list = games_won_conf[games_won_conf['cum_percent']<= 70]['win_conf_name'].tolist()
top_tournament_conferences_list
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']

# %%
tourney_data.describe()['season']
# Out:
# count    2117.000000
# mean     2001.193198
# std         9.563883
# min      1985.000000
# 25%      1993.000000
# 50%      2001.000000
# 75%      2010.000000
# max      2017.000000
# Name: season, dtype: float64

# %% [markdown]
# Note the tournament data is available for tournament years 1985 through 2017.

# %%
summary_data.describe()['season']
# Out:
# count    2772.00000
# mean     2012.53355
# std         2.28420
# min      2009.00000
# 25%      2011.00000
# 50%      2013.00000
# 75%      2015.00000
# max      2016.00000
# Name: season, dtype: float64

# %% [markdown]
# The summary season data in this set goes back to 2010.
#
# So the intersection of season summary data with tournament data are regular seasons 2010 through 2016.

# %%
tourney_data = tourney_data[tourney_data['season'] >= 2010]
tourney_data.describe()['season']
# Out:
# count     533.000000
# mean     2013.519700
# std         2.284733
# min      2010.000000
# 25%      2012.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 533 entries, 10 to 2104
# Data columns (total 9 columns):
# season          533 non-null int64
# round           533 non-null int64
# game_date       533 non-null object
# win_seed        533 non-null int64
# win_market      533 non-null object
# win_team_id     533 non-null object
# lose_seed       533 non-null int64
# lose_market     533 non-null object
# lose_team_id    533 non-null object
# dtypes: int64(4), object(5)
# memory usage: 41.6+ KB

# %%
tourney_data.head()
# Out:
#     season  round   game_date  win_seed             win_market  \
# 10    2013     64  2013-03-22         9                 Temple
# 17    2011     64  2011-03-17         7                 Temple
# 27    2013     64  2013-03-21         5  Virginia Commonwealth
# 29    2012     64  2012-03-15        12  Virginia Commonwealth
# 30    2011      8  2011-03-27        11  Virginia Commonwealth
#
#                              win_team_id  lose_seed           lose_market  \
# 10  8598d1b6-106b-4083-a512-2e495729525a          8  North Carolina State
# 17  8598d1b6-106b-4083-a512-2e495729525a         10            Penn State
# 27  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518         12                 Akron
# 29  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518          5         Wichita State
# 30  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518          1                Kansas
#
#                             lose_team_id
# 10  52df1e19-b142-4a76-a439-ad68455d0581
# 17  4aebd148-8119-4875-954c-66779867989b
# 27  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20
# 29  f38b58de-3273-4723-a78b-2f918e9aa2d5
# 30  fae4855b-1b64-4b40-a632-9ed345e1e952

# %%
# recode the tourney data so that the teams are not marked with  win/lose status and the game result is encoded as a binary
tourney_data['game_result'] = 1
tourney_data.game_result = tourney_data.game_result.astype(int)
tourney_data.rename(columns={"win_seed":"team_seed","win_market":"team","win_team_id":"team_id"}, inplace=True)
tourney_data.rename(columns={"lose_seed":"opp_team_seed","lose_market":"opp_team","lose_team_id":"opp_team_id"}, inplace=True)
tourney_data['start_season'] = tourney_data['season'] -1
tourney_data
# Out:
#       season  round   game_date  team_seed                   team  \
# 10      2013     64  2013-03-22          9                 Temple
# 17      2011     64  2011-03-17          7                 Temple
# 27      2013     64  2013-03-21          5  Virginia Commonwealth
# 29      2012     64  2012-03-15         12  Virginia Commonwealth
# 30      2011      8  2011-03-27         11  Virginia Commonwealth
# 31      2011     16  2011-03-25         11  Virginia Commonwealth
# 33      2011     32  2011-03-20         11  Virginia Commonwealth
# 34      2011     64  2011-03-18         11  Virginia Commonwealth
# 35      2011     68  2011-03-16         11  Virginia Commonwealth
# 36      2016     64  2016-03-18         10  Virginia Commonwealth
# 37      2013     64  2013-03-21          8         Colorado State
# 44      2017     64  2017-03-17         11           Rhode Island
# 46      2015     64  2015-03-19          5                   Utah
# 48      2016     64  2016-03-17          3                   Utah
# 49      2015     32  2015-03-21          5                   Utah
# 72      2017     64  2017-03-17          3                 Baylor
# 73      2017     32  2017-03-19          3                 Baylor
# 74      2010     32  2010-03-20          3                 Baylor
# 75      2010     64  2010-03-18          3                 Baylor
# 76      2010     16  2010-03-26          3                 Baylor
# 77      2012     16  2012-03-23          3                 Baylor
# 78      2012     64  2012-03-15          3                 Baylor
# 79      2012     32  2012-03-17          3                 Baylor
# 80      2014     64  2014-03-21          6                 Baylor
# 81      2014     32  2014-03-23          6                 Baylor
# 82      2014     64  2014-03-21         14                 Mercer
# 88      2014     64  2014-03-20         12     North Dakota State
# 89      2012     68  2012-03-14         12          South Florida
# 90      2012     64  2012-03-16         12          South Florida
# 94      2017     64  2017-03-17          3                 Oregon
# ...      ...    ...         ...        ...                    ...
# 1966    2010     64  2010-03-19          2          West Virginia
# 1967    2010     32  2010-03-21          2          West Virginia
# 1968    2010     16  2010-03-25          2          West Virginia
# 1973    2010      8  2010-03-27          2          West Virginia
# 1976    2017     64  2017-03-16          4          West Virginia
# 1978    2017     32  2017-03-18          4          West Virginia
# 1979    2015     32  2015-03-22          5          West Virginia
# 1980    2015     64  2015-03-20          5          West Virginia
# 1984    2017     68  2017-03-14         16       Mount St. Mary's
# 1989    2010     64  2010-03-18          9            Wake Forest
# 2001    2011     64  2011-03-18         11              Marquette
# 2002    2013     16  2013-03-28          3              Marquette
# 2003    2013     64  2013-03-21          3              Marquette
# 2004    2013     32  2013-03-23          3              Marquette
# 2005    2011     32  2011-03-20         11              Marquette
# 2014    2012     64  2012-03-15          3              Marquette
# 2015    2012     32  2012-03-17          3              Marquette
# 2023    2016     16  2016-03-25          6             Notre Dame
# 2024    2016     32  2016-03-20          6             Notre Dame
# 2028    2016     64  2016-03-18          6             Notre Dame
# 2029    2017     64  2017-03-16          5             Notre Dame
# 2030    2015     32  2015-03-21          3             Notre Dame
# 2031    2015     16  2015-03-26          3             Notre Dame
# 2034    2015     64  2015-03-19          3             Notre Dame
# 2037    2011     64  2011-03-18          2             Notre Dame
# 2045    2013     64  2013-03-22         11              Minnesota
# 2054    2012     64  2012-03-16         15                 Lehigh
# 2064    2010     64  2010-03-19         10           Georgia Tech
# 2082    2013     64  2013-03-22          7               Illinois
# 2104    2011     64  2011-03-18          9               Illinois
#
#                                    team_id  opp_team_seed  \
# 10    8598d1b6-106b-4083-a512-2e495729525a              8
# 17    8598d1b6-106b-4083-a512-2e495729525a             10
# 27    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             12
# 29    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5
# 30    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              1
# 31    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             10
# 33    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              3
# 34    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              6
# 35    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             11
# 36    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              7
# 37    1a470730-f328-4fb1-8bbf-36a069e4d6b2              9
# 44    7e42bca2-3cd7-4aca-aa46-f190fe5d8eb4              6
# 46    0d037a5d-827a-44dd-8b70-57603d671d5d             12
# 48    0d037a5d-827a-44dd-8b70-57603d671d5d             14
# 49    0d037a5d-827a-44dd-8b70-57603d671d5d              4
# 72    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 73    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 74    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 75    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 76    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             10
# 77    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             10
# 78    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 79    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 80    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 81    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf              3
# 82    a14b0057-8eb5-43d2-a33b-666196da933e              3
# 88    984e7518-e418-45d5-9797-979b8c2085c1              5
# 89    55af9c69-3675-4b9b-a882-96640b782fff             12
# 90    55af9c69-3675-4b9b-a882-96640b782fff              5
# 94    1da70895-f77f-44ef-b216-d63c02e696eb             14
# ...                                    ...            ...
# 1966  f770d3a2-221c-49ce-9c7a-680f7417fe9e             15
# 1967  f770d3a2-221c-49ce-9c7a-680f7417fe9e             10
# 1968  f770d3a2-221c-49ce-9c7a-680f7417fe9e             11
# 1973  f770d3a2-221c-49ce-9c7a-680f7417fe9e              1
# 1976  f770d3a2-221c-49ce-9c7a-680f7417fe9e             13
# 1978  f770d3a2-221c-49ce-9c7a-680f7417fe9e              5
# 1979  f770d3a2-221c-49ce-9c7a-680f7417fe9e              4
# 1980  f770d3a2-221c-49ce-9c7a-680f7417fe9e             12
# 1984  5fe4a398-1699-4442-a364-305b2f0ac01e             16
# 1989  4fbebf0a-e117-4a0c-8f15-c247535a2a1b              8
# 2001  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2002  06f7c904-0ac7-4125-b0f4-f4871bb69057              2
# 2003  06f7c904-0ac7-4125-b0f4-f4871bb69057             14
# 2004  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2005  06f7c904-0ac7-4125-b0f4-f4871bb69057              3
# 2014  06f7c904-0ac7-4125-b0f4-f4871bb69057             14
# 2015  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2023  80962f09-8821-48b6-8cf0-0cf0eea56aa8              7
# 2024  80962f09-8821-48b6-8cf0-0cf0eea56aa8             14
# 2028  80962f09-8821-48b6-8cf0-0cf0eea56aa8             11
# 2029  80962f09-8821-48b6-8cf0-0cf0eea56aa8             12
# 2030  80962f09-8821-48b6-8cf0-0cf0eea56aa8              6
# 2031  80962f09-8821-48b6-8cf0-0cf0eea56aa8              7
# 2034  80962f09-8821-48b6-8cf0-0cf0eea56aa8             14
# 2037  80962f09-8821-48b6-8cf0-0cf0eea56aa8             15
# 2045  fa416692-7e09-4f0a-9bcf-0cf7d5149a14              6
# 2054  508f503f-dc57-4f4c-a01e-4f195e5c05c8              2
# 2064  0f63a6f5-bda7-4fd9-9271-8d33f555ca19              7
# 2082  150148c2-ca8f-414f-8f41-d94a55d4a122             10
# 2104  150148c2-ca8f-414f-8f41-d94a55d4a122              8
#
#                   opp_team                           opp_team_id  game_result  \
# 10    North Carolina State  52df1e19-b142-4a76-a439-ad68455d0581            1
# 17              Penn State  4aebd148-8119-4875-954c-66779867989b            1
# 27                   Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20            1
# 29           Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 30                  Kansas  fae4855b-1b64-4b40-a632-9ed345e1e952            1
# 31           Florida State  d3c8a767-b6fc-45d4-a5f2-18406f2993f1            1
# 33                  Purdue  12d7f888-675b-459f-9099-a38f771d8a95            1
# 34              Georgetown  8736b67f-5924-400b-bf94-3bd804c36600            1
# 35                     USC  3a000455-de7c-4ca8-880e-abdce7f21da9            1
# 36            Oregon State  532d3874-b4b3-4c5c-acc6-749a6db26c8f            1
# 37                Missouri  77ca152a-cb2f-48a5-97b2-492351250d94            1
# 44               Creighton  7d797407-623e-476d-b299-46de4275414d            1
# 46       Stephen F. Austin  5ef64f01-86ae-4553-9834-c79cc0859eaf            1
# 48            Fresno State  dd8db4d8-d984-4cab-b7f6-22c6b8c2c45f            1
# 49              Georgetown  8736b67f-5924-400b-bf94-3bd804c36600            1
# 72        New Mexico State  5016fe1a-9571-4d10-bf5b-b9c1b496bd57            1
# 73                     USC  3a000455-de7c-4ca8-880e-abdce7f21da9            1
# 74            Old Dominion  ce967953-5c50-4220-87b2-99acb9606e84            1
# 75       Sam Houston State  67322042-9c40-4dc2-b33a-4754c02ec82a            1
# 76            Saint Mary's  b18f34af-a7f1-4659-a2e5-fc11a31cd316            1
# 77                  Xavier  0d8a328f-20ce-410b-bed1-15fc01308aaf            1
# 78      South Dakota State  6ef40534-5fad-4755-84de-7dcbd645d1f0            1
# 79                Colorado  9fccbf28-2858-4263-821c-fdefb3c7efa3            1
# 80                Nebraska  f8b1bf00-5b73-4ac4-98c0-ec554027ae32            1
# 81               Creighton  7d797407-623e-476d-b299-46de4275414d            1
# 82                    Duke  faeb1160-5d15-4f26-99fc-c441cf21fc7f            1
# 88                Oklahoma  b2fda957-e15c-4fb2-8a13-6e58496f561e            1
# 89              California  aacdc78d-b7fa-48f6-9686-2fdb8a95030e            1
# 90                  Temple  8598d1b6-106b-4083-a512-2e495729525a            1
# 94                    Iona  255c2a87-40c0-4989-bbb9-d286aac5d28e            1
# ...                    ...                                   ...          ...
# 1966          Morgan State  576b816b-5b9a-4768-a62b-f8435a8272c2            1
# 1967              Missouri  77ca152a-cb2f-48a5-97b2-492351250d94            1
# 1968            Washington  e52c9644-717a-46f4-bf16-aeca000b3b44            1
# 1973              Kentucky  2267a1f4-68f6-418b-aaf6-2aa0c4b291f1            1
# 1976              Bucknell  98d2123a-c7b9-4b5f-8a81-43f76d8537dc            1
# 1978            Notre Dame  80962f09-8821-48b6-8cf0-0cf0eea56aa8            1
# 1979              Maryland  2778d005-cc14-4e58-9bf2-3fc37bffb62f            1
# 1980               Buffalo  a9f5c9a2-342c-4881-9996-5d5c05ec9bd9            1
# 1984           New Orleans  e7ff6d5c-07e9-42af-955d-0a0b8c1e2288            1
# 1989                 Texas  6ed15092-2670-450a-99c2-61d861e87644            1
# 2001                Xavier  0d8a328f-20ce-410b-bed1-15fc01308aaf            1
# 2002            Miami (FL)  7aec5187-cb1b-45e5-8f7d-406d766cdc73            1
# 2003              Davidson  2920c5fa-1e86-4958-a7c4-1e97b8e201d8            1
# 2004                Butler  bdb7d7a4-45f8-4bf3-ab85-15488c451494            1
# 2005              Syracuse  8cd24de1-2be8-4b77-bcfa-47be0495a5f4            1
# 2014                   BYU  c31455b2-8a45-4248-aa8f-ce7eab1c6b02            1
# 2015          Murray State  77a69fb0-1355-4342-ac09-b4cc7949d95e            1
# 2023             Wisconsin  c7569eae-5b93-4197-b204-6f3a62146b25            1
# 2024     Stephen F. Austin  5ef64f01-86ae-4553-9834-c79cc0859eaf            1
# 2028              Michigan  bdc2561d-f603-4fab-a262-f1d2af462277            1
# 2029             Princeton  fe406882-9f22-495e-9df6-ef357a6803c6            1
# 2030                Butler  bdb7d7a4-45f8-4bf3-ab85-15488c451494            1
# 2031         Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 2034          Northeastern  93df9b18-e9fc-42a7-bb45-a736c203b4dc            1
# 2037                 Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20            1
# 2045                  UCLA  ec0d6b67-4b16-4b50-92b2-1a651dae6b0f            1
# 2054                  Duke  faeb1160-5d15-4f26-99fc-c441cf21fc7f            1
# 2064        Oklahoma State  8ab00d43-840a-4c96-bdee-bf88fa6e3f11            1
# 2082              Colorado  9fccbf28-2858-4263-821c-fdefb3c7efa3            1
# 2104                  UNLV  68a3227f-677f-43b0-9a3a-cad79d0df9e2            1
#
#       start_season
# 10            2012
# 17            2010
# 27            2012
# 29            2011
# 30            2010
# 31            2010
# 33            2010
# 34            2010
# 35            2010
# 36            2015
# 37            2012
# 44            2016
# 46            2014
# 48            2015
# 49            2014
# 72            2016
# 73            2016
# 74            2009
# 75            2009
# 76            2009
# 77            2011
# 78            2011
# 79            2011
# 80            2013
# 81            2013
# 82            2013
# 88            2013
# 89            2011
# 90            2011
# 94            2016
# ...            ...
# 1966          2009
# 1967          2009
# 1968          2009
# 1973          2009
# 1976          2016
# 1978          2016
# 1979          2014
# 1980          2014
# 1984          2016
# 1989          2009
# 2001          2010
# 2002          2012
# 2003          2012
# 2004          2012
# 2005          2010
# 2014          2011
# 2015          2011
# 2023          2015
# 2024          2015
# 2028          2015
# 2029          2016
# 2030          2014
# 2031          2014
# 2034          2014
# 2037          2010
# 2045          2012
# 2054          2011
# 2064          2009
# 2082          2012
# 2104          2010
#
# [533 rows x 11 columns]

# %%
# We need to recode the game data so that we have representation of the losing game result class.
# Swap the team and opp team data on the odd rows and reverse the sense of the game result.

#create some temporary buffer columns
tourney_data['copy_team'] = tourney_data['team']
tourney_data['copy_team_seed'] = tourney_data['team_seed']
tourney_data['copy_team_id'] = tourney_data['team_id']

#swap the team and opp team data
tourney_data.loc[1::2,'team'] = tourney_data.loc[1::2,'opp_team']
tourney_data.loc[1::2,'opp_team'] = tourney_data.loc[1::2,'copy_team']
tourney_data.loc[1::2,'team_seed'] = tourney_data.loc[1::2,'opp_team_seed']
tourney_data.loc[1::2,'opp_team_seed'] = tourney_data.loc[1::2,'copy_team_seed']
tourney_data.loc[1::2,'team_id'] = tourney_data.loc[1::2,'opp_team_id']
tourney_data.loc[1::2,'opp_team_id'] = tourney_data.loc[1::2,'copy_team_id']

# flip the game result
tourney_data.loc[1::2,'game_result'] = 0

#drop the temporary columns
tourney_data.drop(columns=['copy_team','copy_team_seed','copy_team_id'],inplace=True)
tourney_data.head()
# Out:
#     season  round   game_date  team_seed                   team  \
# 10    2013     64  2013-03-22          8   North Carolina State
# 17    2011     64  2011-03-17          7                 Temple
# 27    2013     64  2013-03-21         12                  Akron
# 29    2012     64  2012-03-15         12  Virginia Commonwealth
# 30    2011      8  2011-03-27          1                 Kansas
#
#                                  team_id  opp_team_seed  \
# 10  52df1e19-b142-4a76-a439-ad68455d0581              9
# 17  8598d1b6-106b-4083-a512-2e495729525a             10
# 27  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5
# 29  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5
# 30  fae4855b-1b64-4b40-a632-9ed345e1e952             11
#
#                  opp_team                           opp_team_id  game_result  \
# 10                 Temple  8598d1b6-106b-4083-a512-2e495729525a            0
# 17             Penn State  4aebd148-8119-4875-954c-66779867989b            1
# 27  Virginia Commonwealth  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0
# 29          Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 30  Virginia Commonwealth  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0
#
#     start_season
# 10          2012
# 17          2010
# 27          2012
# 29          2011
# 30          2010

# %%
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','team_id'], 
                                right_on=['season', 'team_id'],how='left',suffixes=('','_y'))

tourney_data.drop(columns=['season_y'],inplace=True)
#tourney_data.info()

# %%
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','opp_team_id'], 
                                right_on=['season', 'team_id'], how='left',suffixes=('_t','_o'))
#tourney_data.info()

# %%
tourney_data.head()
# Out:
#    season_t  round   game_date  team_seed                   team  \
# 0      2013     64  2013-03-22          8   North Carolina State
# 1      2011     64  2011-03-17          7                 Temple
# 2      2013     64  2013-03-21         12                  Akron
# 3      2012     64  2012-03-15         12  Virginia Commonwealth
# 4      2011      8  2011-03-27          1                 Kansas
#
#                               team_id_t  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#                  School_t  Games_t  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0   North Carolina State        35  14.32   7.17      0.686         77
# 1                 Temple        34  12.35   4.23      0.765         70
# 2                  Akron        33   8.11   0.18      0.788         71
# 3  Virginia Commonwealth        36   8.79   0.63      0.806         68
# 4                 Kansas        38  24.10   7.62      0.921         81
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0             70     0.496           0.419     0.681                  17
# 1             62     0.447           0.435     0.698                  19
# 2             62     0.455           0.395     0.643                  19
# 3             59     0.410           0.424     0.685                  18
# 4             64     0.508           0.380     0.679                  18
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286              11                    12              22
# 1   75.688235              11                    11              24
# 2   78.884848              12                    10              21
# 3   76.305556              12                    10              18
# 4   80.126316              11                    10              27
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0                    21        12            6     98.171354            23
# 1                    22        10            6     92.484651            19
# 2                    21        13            7     90.004610            20
# 3                    24        11           10     89.115399            20
# 4                    21        13            7    101.090384            22
#
#    season_o                School_o                             team_id_o  \
# 0      2012                 Temple   8598d1b6-106b-4083-a512-2e495729525a
# 1      2010             Penn State   4aebd148-8119-4875-954c-66779867989b
# 2      2012  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 3      2011          Wichita State   f38b58de-3273-4723-a78b-2f918e9aa2d5
# 4      2010  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
#
#    Games_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0       34   9.52   5.20      0.706         72             67     0.428
# 1       34  11.98  11.45      0.559         63             62     0.439
# 2       36  16.89   4.47      0.750         76             64     0.450
# 3       33  17.42   3.80      0.818         77             62     0.482
# 4       40   8.56   3.78      0.700         71             66     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723                  18   77.494118              11
# 1           0.434     0.724                  21   68.341176               9
# 2           0.444     0.701                  20   81.044444              13
# 3           0.393     0.748                  18   77.496970              10
# 4           0.424     0.715                  18   75.240000              10
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0                    10              19                    25        10
# 1                     8              21                    23        10
# 2                    11              18                    23        11
# 3                     9              24                    21        12
# 4                    10              21                    24        11
#
#    steal_avg_o  off_rating_o  ft_att_avg_o
# 0            7     92.910278            20
# 1            4     92.184541            16
# 2           11     93.775706            18
# 3            6     99.358724            19
# 4            8     94.364700            20

# %% [markdown]
# Incorporate additional features here.
# Team conference, seeding deltas.

# %%
tourney_data = tourney_data.join(teams, on='team_id_t', how='left')

# %%
tourney_data = tourney_data.join(teams, on='opp_team_id', how='left', lsuffix='_t', rsuffix='_o')
tourney_data.head()
# Out:
#    season_t  round   game_date  team_seed                   team  \
# 0      2013     64  2013-03-22          8   North Carolina State
# 1      2011     64  2011-03-17          7                 Temple
# 2      2013     64  2013-03-21         12                  Akron
# 3      2012     64  2012-03-15         12  Virginia Commonwealth
# 4      2011      8  2011-03-27          1                 Kansas
#
#                               team_id_t  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#                  School_t  Games_t  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0   North Carolina State        35  14.32   7.17      0.686         77
# 1                 Temple        34  12.35   4.23      0.765         70
# 2                  Akron        33   8.11   0.18      0.788         71
# 3  Virginia Commonwealth        36   8.79   0.63      0.806         68
# 4                 Kansas        38  24.10   7.62      0.921         81
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0             70     0.496           0.419     0.681                  17
# 1             62     0.447           0.435     0.698                  19
# 2             62     0.455           0.395     0.643                  19
# 3             59     0.410           0.424     0.685                  18
# 4             64     0.508           0.380     0.679                  18
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286              11                    12              22
# 1   75.688235              11                    11              24
# 2   78.884848              12                    10              21
# 3   76.305556              12                    10              18
# 4   80.126316              11                    10              27
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0                    21        12            6     98.171354            23
# 1                    22        10            6     92.484651            19
# 2                    21        13            7     90.004610            20
# 3                    24        11           10     89.115399            20
# 4                    21        13            7    101.090384            22
#
#    season_o                School_o                             team_id_o  \
# 0      2012                 Temple   8598d1b6-106b-4083-a512-2e495729525a
# 1      2010             Penn State   4aebd148-8119-4875-954c-66779867989b
# 2      2012  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 3      2011          Wichita State   f38b58de-3273-4723-a78b-2f918e9aa2d5
# 4      2010  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
#
#    Games_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0       34   9.52   5.20      0.706         72             67     0.428
# 1       34  11.98  11.45      0.559         63             62     0.439
# 2       36  16.89   4.47      0.750         76             64     0.450
# 3       33  17.42   3.80      0.818         77             62     0.482
# 4       40   8.56   3.78      0.700         71             66     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723                  18   77.494118              11
# 1           0.434     0.724                  21   68.341176               9
# 2           0.444     0.701                  20   81.044444              13
# 3           0.393     0.748                  18   77.496970              10
# 4           0.424     0.715                  18   75.240000              10
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0                    10              19                    25        10
# 1                     8              21                    23        10
# 2                    11              18                    23        11
# 3                     9              24                    21        12
# 4                    10              21                    24        11
#
#    steal_avg_o  off_rating_o  ft_att_avg_o        conf_name_t  \
# 0            7     92.910278            20     Atlantic Coast
# 1            4     92.184541            16  American Athletic
# 2           11     93.775706            18       Mid-American
# 3            6     99.358724            19        Atlantic 10
# 4            8     94.364700            20             Big 12
#
#          conf_name_o
# 0  American Athletic
# 1            Big Ten
# 2        Atlantic 10
# 3  American Athletic
# 4        Atlantic 10

# %% [markdown]
# #### Add a feature
# top_conf = 1 if team is a top conference and opponent is not
# top_conf = -1 if opp_team is a top_conference and team is not
# top_conf = 0 otherwise

# %%
print(top_tournament_conferences_list)
tourney_data['top_conf'] = tourney_data.apply(lambda row: conf_compare(row.conf_name_t, row.conf_name_o),axis=1)
tourney_data.head(10)[['game_result','conf_name_t','conf_name_o','top_conf']]
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']
#    game_result        conf_name_t        conf_name_o  top_conf
# 0            0     Atlantic Coast  American Athletic         1
# 1            1  American Athletic            Big Ten        -1
# 2            0       Mid-American        Atlantic 10         0
# 3            1        Atlantic 10  American Athletic         0
# 4            0             Big 12        Atlantic 10         1
# 5            1        Atlantic 10     Atlantic Coast        -1
# 6            0            Big Ten        Atlantic 10         1
# 7            1        Atlantic 10           Big East         0
# 8            0         Pacific 12        Atlantic 10         1
# 9            1        Atlantic 10         Pacific 12        -1

# %%
# Upsets occur less than 30% of the time when seeding deltas are more than 6
tourney_data['upset_seed_threshold'] = tourney_data.apply(lambda row: abs(row.team_seed - row.opp_team_seed) > 6, axis=1).astype(int)
tourney_data.head()
# Out:
#    season_t  round   game_date  team_seed                   team  \
# 0      2013     64  2013-03-22          8   North Carolina State
# 1      2011     64  2011-03-17          7                 Temple
# 2      2013     64  2013-03-21         12                  Akron
# 3      2012     64  2012-03-15         12  Virginia Commonwealth
# 4      2011      8  2011-03-27          1                 Kansas
#
#                               team_id_t  opp_team_seed               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581              9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a             10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20              5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952             11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#                  School_t  Games_t  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0   North Carolina State        35  14.32   7.17      0.686         77
# 1                 Temple        34  12.35   4.23      0.765         70
# 2                  Akron        33   8.11   0.18      0.788         71
# 3  Virginia Commonwealth        36   8.79   0.63      0.806         68
# 4                 Kansas        38  24.10   7.62      0.921         81
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0             70     0.496           0.419     0.681                  17
# 1             62     0.447           0.435     0.698                  19
# 2             62     0.455           0.395     0.643                  19
# 3             59     0.410           0.424     0.685                  18
# 4             64     0.508           0.380     0.679                  18
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286              11                    12              22
# 1   75.688235              11                    11              24
# 2   78.884848              12                    10              21
# 3   76.305556              12                    10              18
# 4   80.126316              11                    10              27
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0                    21        12            6     98.171354            23
# 1                    22        10            6     92.484651            19
# 2                    21        13            7     90.004610            20
# 3                    24        11           10     89.115399            20
# 4                    21        13            7    101.090384            22
#
#    season_o                School_o                             team_id_o  \
# 0      2012                 Temple   8598d1b6-106b-4083-a512-2e495729525a
# 1      2010             Penn State   4aebd148-8119-4875-954c-66779867989b
# 2      2012  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 3      2011          Wichita State   f38b58de-3273-4723-a78b-2f918e9aa2d5
# 4      2010  Virginia Commonwealth   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
#
#    Games_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0       34   9.52   5.20      0.706         72             67     0.428
# 1       34  11.98  11.45      0.559         63             62     0.439
# 2       36  16.89   4.47      0.750         76             64     0.450
# 3       33  17.42   3.80      0.818         77             62     0.482
# 4       40   8.56   3.78      0.700         71             66     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723                  18   77.494118              11
# 1           0.434     0.724                  21   68.341176               9
# 2           0.444     0.701                  20   81.044444              13
# 3           0.393     0.748                  18   77.496970              10
# 4           0.424     0.715                  18   75.240000              10
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0                    10              19                    25        10
# 1                     8              21                    23        10
# 2                    11              18                    23        11
# 3                     9              24                    21        12
# 4                    10              21                    24        11
#
#    steal_avg_o  off_rating_o  ft_att_avg_o        conf_name_t  \
# 0            7     92.910278            20     Atlantic Coast
# 1            4     92.184541            16  American Athletic
# 2           11     93.775706            18       Mid-American
# 3            6     99.358724            19        Atlantic 10
# 4            8     94.364700            20             Big 12
#
#          conf_name_o  top_conf  upset_seed_threshold
# 0  American Athletic         1                     0
# 1            Big Ten        -1                     0
# 2        Atlantic 10         0                     1
# 3  American Athletic         0                     1
# 4        Atlantic 10         1                     1

# %% [markdown]
# ### Opponent Plots

# %%
tourney_data['Game Result'] = tourney_data.game_result.map({1:'Win', 0:'Lose'})

# %%
tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 533 entries, 0 to 532
# Data columns (total 58 columns):
# season_t                533 non-null int64
# round                   533 non-null int64
# game_date               533 non-null object
# team_seed               533 non-null int64
# team                    533 non-null object
# team_id_t               533 non-null object
# opp_team_seed           533 non-null int64
# opp_team                533 non-null object
# opp_team_id             533 non-null object
# game_result             533 non-null int32
# start_season            533 non-null int64
# School_t                533 non-null object
# Games_t                 533 non-null int64
# SRS_t                   533 non-null float64
# SOS_t                   533 non-null float64
# win_pct_t               533 non-null float64
# pts_avg_t               533 non-null int64
# opp_pts_avg_t           533 non-null int64
# fg_pct_t                533 non-null float64
# allow_fg_pct_t          533 non-null float64
# ft_pct_t                533 non-null float64
# allow_ft_att_avg_t      533 non-null int64
# poss_avg_t              533 non-null float64
# off_rebs_avg_t          533 non-null int64
# allow_off_rebs_avg_t    533 non-null int64
# def_rebs_avg_t          533 non-null int64
# allow_def_rebs_avg_t    533 non-null int64
# to_avg_t                533 non-null int64
# steal_avg_t             533 non-null int64
# off_rating_t            533 non-null float64
# ft_att_avg_t            533 non-null int64
# season_o                533 non-null int64
# School_o                533 non-null object
# team_id_o               533 non-null object
# Games_o                 533 non-null int64
# SRS_o                   533 non-null float64
# SOS_o                   533 non-null float64
# win_pct_o               533 non-null float64
# pts_avg_o               533 non-null int64
# opp_pts_avg_o           533 non-null int64
# fg_pct_o                533 non-null float64
# allow_fg_pct_o          533 non-null float64
# ft_pct_o                533 non-null float64
# allow_ft_att_avg_o      533 non-null int64
# poss_avg_o              533 non-null float64
# off_rebs_avg_o          533 non-null int64
# allow_off_rebs_avg_o    533 non-null int64
# def_rebs_avg_o          533 non-null int64
# allow_def_rebs_avg_o    533 non-null int64
# to_avg_o                533 non-null int64
# steal_avg_o             533 non-null int64
# off_rating_o            533 non-null float64
# ft_att_avg_o            533 non-null int64
# conf_name_t             533 non-null object
# conf_name_o             533 non-null object
# top_conf                533 non-null int64
# upset_seed_threshold    533 non-null int32
# Game Result             533 non-null object
# dtypes: float64(16), int32(2), int64(29), object(11)
# memory usage: 241.5+ KB

# %%
g = sns.catplot(x="team_seed", y="opp_team_seed", hue="Game Result", 
                height=4, aspect=4,data=tourney_data,kind='swarm')
plt.title('Seed vs Seed')
plt.show()

# %%
tourney_data[(tourney_data['team_seed']==16) & (tourney_data['opp_team_seed']==16) ]
# Out:
#      season_t  round   game_date  team_seed                  team  \
# 40       2013     68  2013-03-20         16          LIU Brooklyn
# 50       2013     68  2013-03-19         16               Liberty
# 51       2017     68  2017-03-15         16              UC Davis
# 68       2016     68  2016-03-15         16   Fairleigh Dickinson
# 163      2015     68  2015-03-17         16               Hampton
# 226      2011     68  2011-03-15         16  Arkansas-Little Rock
# 264      2014     68  2014-03-19         16        Texas Southern
# 390      2015     68  2015-03-18         16         North Florida
# 391      2016     68  2016-03-16         16            Holy Cross
# 430      2012     68  2012-03-14         16                 Lamar
# 486      2014     68  2014-03-18         16      Mount St. Mary's
# 487      2012     68  2012-03-13         16      Western Kentucky
# 490      2011     68  2011-03-16         16         Alabama State
# 501      2010     68  2010-03-16         16   Arkansas-Pine Bluff
# 511      2017     68  2017-03-14         16      Mount St. Mary's
#
#                                 team_id_t  opp_team_seed  \
# 40   82c12e8d-7c6c-47d8-b100-3cbc190d268e             16
# 50   559db90c-741f-40d1-aa81-3fdd1d4889f3             16
# 51   8aaad1c0-d16e-4b9f-8541-dac670addd71             16
# 68   b71d5a1b-2671-4e5a-b94b-06bfb22a27dd             16
# 163  161354af-1f3e-4d58-88f7-e016ec74b7b6             16
# 226  0dadedb0-2bd3-45e7-91a3-93af6c4e87f2             16
# 264  eb157f98-0697-459c-9293-ddb162ceb28b             16
# 390  09920a5f-1b25-466c-b5ae-6167214f5ba9             16
# 391  31aedd91-a77e-46c1-8bdc-80e9860c159d             16
# 430  eda6c307-1e0f-4a28-82f4-ee9653b343fb             16
# 486  5fe4a398-1699-4442-a364-305b2f0ac01e             16
# 487  881380da-861c-4ab6-a7d2-20699d8ea883             16
# 490  267d417a-8f85-4c87-a15a-068c089a74c6             16
# 501  1394dd8a-040e-4509-9ee3-761d60eaf6c9             16
# 511  5fe4a398-1699-4442-a364-305b2f0ac01e             16
#
#                      opp_team                           opp_team_id  \
# 40              James Madison  524e3eec-7dde-45c7-b3cc-6308cec73350
# 50         North Carolina A&T  53aaac6a-796e-41a6-a04e-6ce74c5717f8
# 51     North Carolina Central  e4c315a0-e83f-4d14-856e-34a0463059e3
# 68         Florida Gulf Coast  5326c079-3dc3-468f-a601-b776dd9c1e62
# 163                 Manhattan  7a270923-01d6-4a6f-a93e-e8786266d502
# 226             UNC Asheville  ad9fce12-6b1a-400c-bcbe-29d84d065fc0
# 264                  Cal Poly  45439cdb-af7a-4743-936c-dccc76b30877
# 390             Robert Morris  6906e22d-92fa-40cb-8c05-ec8391ac1979
# 391       Southern University  a3b13d27-ec14-4a7d-88a2-0bc9f7b58984
# 430                   Vermont  18e89867-9201-41ce-ba19-fadddf92fa17
# 486                    Albany  290a5130-836d-45e6-824f-28704d6ba246
# 487  Mississippi Valley State  5873529e-e5e3-4a06-8a03-fa4cbe509880
# 490                      UTSA  953151f2-1e42-4cb0-a99e-202493a64dcf
# 501                  Winthrop  ca441726-0c57-4456-b1e7-fff098484fb5
# 511               New Orleans  e7ff6d5c-07e9-42af-955d-0a0b8c1e2288
#
#      game_result  start_season                 School_t  Games_t  SRS_t  \
# 40             0          2012  Long Island University        34  -3.21
# 50             0          2012                 Liberty        36  -9.13
# 51             1          2016                UC-Davis        36  -5.21
# 68             0          2015     Fairleigh Dickinson        33 -10.90
# 163            1          2014                 Hampton        35  -8.25
# 226            0          2010             Little Rock        36  -4.32
# 264            0          2013          Texas Southern        34  -8.41
# 390            0          2014           North Florida        35  -0.82
# 391            1          2015              Holy Cross        35 -11.20
# 430            0          2011                   Lamar        35   2.41
# 486            0          2013        Mount St. Mary's        33  -6.32
# 487            1          2011        Western Kentucky        35  -2.66
# 490            0          2010           Alabama State        35 -13.37
# 501            1          2009     Arkansas-Pine Bluff        34  -8.29
# 511            1          2016        Mount St. Mary's        36  -4.29
#
#      SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  \
# 40   -5.80      0.588         78             76     0.479           0.468
# 50   -5.80      0.417         69             69     0.429           0.422
# 51   -4.68      0.639         70             69     0.435           0.426
# 68   -8.31      0.545         77             78     0.458           0.457
# 163  -7.08      0.486         67             68     0.406           0.413
# 226  -2.97      0.528         68             67     0.426           0.420
# 264 -10.07      0.559         76             73     0.462           0.451
# 390  -5.94      0.657         75             68     0.470           0.432
# 391  -6.11      0.429         64             69     0.412           0.459
# 430  -3.77      0.657         73             65     0.432           0.421
# 486  -4.44      0.485         75             77     0.438           0.495
# 487   0.51      0.457         64             68     0.394           0.432
# 490 -10.31      0.486         61             63     0.395           0.436
# 501  -7.68      0.529         63             64     0.408           0.406
# 511  -3.51      0.556         67             68     0.444           0.453
#
#      ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 40      0.691                  19   80.676471              11
# 50      0.730                  22   76.111111              10
# 51      0.674                  18   79.227778              10
# 68      0.697                  26   82.339394              10
# 163     0.652                  25   79.902857              11
# 226     0.690                  22   74.822222              10
# 264     0.718                  17   78.588235              11
# 390     0.723                  19   75.565714               9
# 391     0.687                  17   72.462857               7
# 430     0.720                  18   81.342857              14
# 486     0.739                  20   78.587879               9
# 487     0.687                  21   80.000000              12
# 490     0.603                  21   78.285714              13
# 501     0.668                  27   79.158824              12
# 511     0.673                  18   75.138889               7
#
#      allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 40                     11              19                    21        14
# 50                     12              22                    24        13
# 51                      9              25                    24        14
# 68                     12              23                    26        12
# 163                    11              25                    25        14
# 226                    10              22                    25        11
# 264                    11              25                    22        13
# 390                    11              25                    22        12
# 391                     9              22                    26        11
# 430                    11              22                    23        11
# 486                    10              21                    25        11
# 487                    11              20                    24        15
# 490                    11              23                    26        15
# 501                     9              25                    22        16
# 511                    11              22                    25        13
#
#      steal_avg_t  off_rating_t  ft_att_avg_t  season_o  \
# 40             6     96.682464            25      2012
# 50             5     90.656934            21      2012
# 51             5     88.352850            23      2016
# 68             7     93.515383            20      2015
# 163            6     83.851820            24      2014
# 226            5     90.882091            22      2010
# 264            4     96.706587            26      2013
# 390            6     99.251361            21      2014
# 391            6     88.321110            19      2015
# 430            8     89.743590            24      2011
# 486            7     95.434565            21      2013
# 487            5     80.000000            22      2011
# 490            7     77.919708            24      2010
# 501            6     79.586832            25      2009
# 511            6     89.168207            17      2016
#
#                       School_o                             team_id_o  Games_o  \
# 40              James Madison   524e3eec-7dde-45c7-b3cc-6308cec73350       36
# 50         North Carolina A&T   53aaac6a-796e-41a6-a04e-6ce74c5717f8       37
# 51     North Carolina Central   e4c315a0-e83f-4d14-856e-34a0463059e3       34
# 68         Florida Gulf Coast   5326c079-3dc3-468f-a601-b776dd9c1e62       35
# 163                 Manhattan   7a270923-01d6-4a6f-a93e-e8786266d502       33
# 226  North Carolina-Asheville   ad9fce12-6b1a-400c-bcbe-29d84d065fc0       34
# 264                  Cal Poly   45439cdb-af7a-4743-936c-dccc76b30877       34
# 390             Robert Morris   6906e22d-92fa-40cb-8c05-ec8391ac1979       35
# 391                  Southern   a3b13d27-ec14-4a7d-88a2-0bc9f7b58984       35
# 430                   Vermont   18e89867-9201-41ce-ba19-fadddf92fa17       36
# 486               Albany (NY)   290a5130-836d-45e6-824f-28704d6ba246       34
# 487  Mississippi Valley State   5873529e-e5e3-4a06-8a03-fa4cbe509880       34
# 490         Texas-San Antonio   953151f2-1e42-4cb0-a99e-202493a64dcf       34
# 501                  Winthrop   ca441726-0c57-4456-b1e7-fff098484fb5       33
# 511               New Orleans   e7ff6d5c-07e9-42af-955d-0a0b8c1e2288       32
#
#      SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 40   -1.73  -2.28      0.583         65             64     0.421
# 50   -6.94  -6.30      0.541         62             61     0.403
# 51   -3.18 -12.12      0.735         74             63     0.454
# 68   -0.79  -3.82      0.600         77             70     0.479
# 163  -1.34  -3.34      0.576         69             67     0.432
# 226  -0.69  -2.89      0.588         73             68     0.452
# 264  -1.34   1.69      0.412         62             63     0.408
# 390  -3.02  -3.50      0.571         68             68     0.443
# 391  -7.68  -9.37      0.629         72             68     0.444
# 430   0.98  -5.19      0.667         67             60     0.443
# 486  -3.31  -5.22      0.559         65             63     0.441
# 487  -8.03  -7.65      0.618         68             68     0.401
# 490  -5.80  -4.93      0.588         70             69     0.429
# 501  -8.68  -7.31      0.576         61             61     0.380
# 511  -4.10  -5.34      0.625         72             69     0.473
#
#      allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 40            0.428     0.699                  20   72.988889              10
# 50            0.388     0.658                  21   76.070270              10
# 51            0.393     0.683                  16   78.958824              11
# 68            0.412     0.644                  20   81.577143              11
# 163           0.437     0.691                  26   77.593939              10
# 226           0.444     0.711                  20   81.764706              11
# 264           0.434     0.688                  20   70.417647              11
# 390           0.431     0.709                  20   76.188571              10
# 391           0.416     0.670                  21   78.245714              10
# 430           0.406     0.739                  17   73.461111              11
# 486           0.419     0.750                  15   72.123529              10
# 487           0.433     0.644                  22   82.917647              13
# 490           0.419     0.705                  18   77.694118              10
# 501           0.397     0.644                  20   79.224242              13
# 511           0.442     0.710                  19   80.893750              12
#
#      allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 40                     10              19                    24        11
# 50                     12              21                    24        15
# 51                     12              26                    23        11
# 68                     11              28                    24        12
# 163                    10              21                    23        14
# 226                    12              23                    21        14
# 264                    10              21                    23         8
# 390                    12              22                    23        13
# 391                    11              25                    25        11
# 430                    10              21                    21        12
# 486                     9              24                    21        12
# 487                    11              20                    26        15
# 490                    11              24                    23        13
# 501                    10              25                    26        12
# 511                    10              23                    20        16
#
#      steal_avg_o  off_rating_o  ft_att_avg_o            conf_name_t  \
# 40             7     89.054651            19              Northeast
# 50             7     81.503588            21              Big South
# 51             6     93.719735            20               Big West
# 68             6     94.389185            22              Northeast
# 163            8     88.924471            25   Mid Eastern Athletic
# 226            9     89.280576            23               Sun Belt
# 264            5     88.046111            17  Southwestern Athletic
# 390            8     89.252231            19           Atlantic Sun
# 391            7     92.017819            21         Patriot League
# 430            6     91.204719            19              Southland
# 486            5     90.123155            21              Northeast
# 487            8     82.009081            20         Conference USA
# 490            7     90.096911            22  Southwestern Athletic
# 501            8     76.996634            21  Southwestern Athletic
# 511            7     89.005640            23              Northeast
#
#                  conf_name_o  top_conf  upset_seed_threshold Game Result
# 40                  Colonial         0                     0        Lose
# 50      Mid Eastern Athletic         0                     0        Lose
# 51      Mid Eastern Athletic         0                     0         Win
# 68              Atlantic Sun         0                     0        Lose
# 163  Metro Atlantic Athletic         0                     0         Win
# 226                Big South         0                     0        Lose
# 264                 Big West         0                     0        Lose
# 390                Northeast         0                     0        Lose
# 391    Southwestern Athletic         0                     0         Win
# 430             America East         0                     0        Lose
# 486             America East         0                     0        Lose
# 487    Southwestern Athletic         0                     0         Win
# 490           Conference USA         0                     0        Lose
# 501                Big South         0                     0         Win
# 511                Southland         0                     0         Win

# %% [markdown]
# ### Upset Plots

# %% [markdown]
# ##### High Stats

# %%
total_games =0
tournament_games = {}
for year in range(2003,2018,1):
    tournament_games[year] = tourney_data[tourney_data['season_t'] == year].shape[0]
    total_games += tournament_games[year]
    
print('total games= ', total_games)
# Out:
# total games=  533

# %%
def compute_percentage(x):
    #print(x)
    game_count = tournament_games[x[0]]
    #set_trace()
    val = 100.0 * len(x)/ game_count
    
    return val

# %%
ratings_dict={}
high_stats = ['SRS','win_pct','pts_avg','fg_pct','off_rebs_avg','def_rebs_avg','steal_avg','off_rating','ft_att_avg']
#high_stats = ['off_rating']
for stat in high_stats:
    stat_t = stat + '_t'
    stat_o = stat + '_o'
    upset_cond_1 = (tourney_data['game_result'] == 0) & (tourney_data[stat_t] > tourney_data[stat_o])
    upset_cond_2 = (tourney_data['game_result'] == 1) & (tourney_data[stat_t] < tourney_data[stat_o])
    upsets = tourney_data[upset_cond_1 | upset_cond_2][['season_t', 'team','team_seed','opp_team',
                                                        'opp_team_seed','game_result',stat_t , stat_o ]]
    plot = sns.barplot(x='season_t', y='season_t',data=upsets, orient='v',estimator=lambda x: compute_percentage(x))
    plot.set(xlabel='Season', ylabel=stat +' Upset Percent')
    plot.set_title(stat + " Upsets")
    plt.show()
    print("Total upsets= ", upsets.shape[0])
    avg_upsets = upsets.shape[0]*100/total_games
    print("Average upsets = {:.3f}%".format(avg_upsets))
    ratings_dict[stat] = avg_upsets
# Out:
# Total upsets=  145
# Average upsets = 27.205%
# Total upsets=  178
# Average upsets = 33.396%
# Total upsets=  216
# Average upsets = 40.525%
# Total upsets=  237
# Average upsets = 44.465%
# Total upsets=  194
# Average upsets = 36.398%
# Total upsets=  213
# Average upsets = 39.962%
# Total upsets=  187
# Average upsets = 35.084%
# Total upsets=  232
# Average upsets = 43.527%
# Total upsets=  243
# Average upsets = 45.591%

# %% [markdown]
# ##### Low Stats

# %%
tourney_data['seed_t'] = tourney_data['team_seed']
tourney_data['seed_o'] = tourney_data['opp_team_seed']
low_stats = ['seed','allow_fg_pct','allow_off_rebs_avg','to_avg','allow_ft_att_avg']
#high_stats = ['off_rating']
for stat in low_stats:
    stat_t = stat + '_t'
    stat_o = stat + '_o'
    upset_cond_1 = (tourney_data['game_result'] == 0) & (tourney_data[stat_t] < tourney_data[stat_o])
    upset_cond_2 = (tourney_data['game_result'] == 1) & (tourney_data[stat_t] > tourney_data[stat_o])
    upsets = tourney_data[upset_cond_1 | upset_cond_2][['season_t', 'team','team_seed','opp_team',
                                                        'opp_team_seed','game_result',stat_t , stat_o ]]
    plot = sns.barplot(x='season_t', y='season_t',data=upsets, orient='v',estimator=lambda x: compute_percentage(x))
    plot.set(xlabel='Season', ylabel=stat +' Upset Percent')
    plot.set_title(stat + " Upsets")
    plt.show()
    avg_upsets = upsets.shape[0]*100/total_games
    print("Average upsets = {:.3f}%".format(avg_upsets))
    ratings_dict[stat] = avg_upsets
# Out:
# Average upsets = 27.205%
# Average upsets = 38.462%
# Average upsets = 40.901%
# Average upsets = 33.396%
# Average upsets = 38.649%

# %%
sorted_ratings = sorted(ratings_dict.items(), key=operator.itemgetter(1))
sorted_ratings
g= plt.scatter(*zip(*sorted_ratings))
plt.title('Percentage Upsets Per Tournament History')
plt.xlabel('Rating')
plt.ylabel('Upsets')
plt.xticks(rotation=30)
g.figure.set_size_inches(10,4)
plt.show()
