# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
import sys
sys.path.insert(0,'../py_utils')
import utils
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import learning_curve
from pathlib import Path
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)
# Out:
# Seaborn version:  0.9.0

# %% [markdown]
# #### Read in regular season team statistics from SRCBB https://www.sports-reference.com/cbb/

# %%
summary_data = pd.read_csv(Path( '../Data/sr_summaries_kaggle_id.csv'))
print(summary_data.shape)

#display rows with NaNs
summary_data[summary_data.isnull().any(axis=1)]
# Out:
# (2773, 22)
#     season          School team_id  Games    SRS   SOS  win_pct  pts_avg  \
# 38    2009  Centenary (LA)     NaN     29 -17.16 -5.08    0.276       70
#
#     opp_pts_avg  fg_pct  allow_fg_pct  ft_pct  allow_ft_att_avg   poss_avg  \
# 38           80   0.416          0.49   0.733                25  80.641379
#
#     off_rebs_avg  allow_off_rebs_avg  def_rebs_avg  allow_def_rebs_avg  \
# 38             9                  11            20                  27
#
#     to_avg  steal_avg  off_rating  ft_att_avg
# 38      15          7   86.804071          21

# %%
#drop records with NaNs
summary_data.dropna(inplace=True)
print(summary_data.shape)
# Out:
# (2772, 22)

# %% [markdown]
# #### Read table of team names and associated team meta data from the Kaggle data set.
#
# https://console.cloud.google.com/bigquery?project=bigqueryncaa&p=bigquery-public-data&d=ncaa_basketball&page=dataset

# %%
# Read table of team names and associated team meta data
teams = pd.read_csv(Path('../Data/D1_teams.csv'))
teams.drop(columns=['code_ncaa','school_ncaa','turner_name','league_name','league_alias','conf_alias',
                    'conf_id','division_name','division_alias','division_id',
                    'kaggle_team_id','venue_id'], inplace=True)
teams.info()
teams.set_index('id',inplace=True)
teams.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 2 columns):
# id           351 non-null object
# conf_name    351 non-null object
# dtypes: object(2)
# memory usage: 5.6+ KB
#                                      conf_name
# id
# fe406882-9f22-495e-9df6-ef357a6803c6       Ivy
# ca478771-aa3d-4231-81e0-b70f519134fb       Ivy
# 5c7bf63f-bc39-43c5-9907-73b50b7a6b34       Ivy
# d60357bd-1205-42e9-9092-d986a2843a34       Ivy
# 88ff8c00-958e-4ccf-a21d-77fab9e93692       Ivy

# %% [markdown]
# #### Read in the NCAA Men's Tournament results from the the Kaggle data set.

# %%
tourney_data = pd.read_csv(Path('../Data/tournament_results.csv'))
tourney_data.drop(columns=['days_from_epoch','day','num_ot','academic_year','win_region','win_alias','lose_region',
                           'lose_alias','lose_code_ncaa','win_school_ncaa','win_code_ncaa','win_name','lose_name',
                           'win_pts','win_kaggle_team_id','lose_school_ncaa','lose_kaggle_team_id','lose_pts'],inplace=True)



tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 9 columns):
# season          2117 non-null int64
# round           2117 non-null int64
# game_date       2117 non-null object
# win_seed        2117 non-null int64
# win_market      2117 non-null object
# win_team_id     2117 non-null object
# lose_seed       2117 non-null int64
# lose_market     2117 non-null object
# lose_team_id    2117 non-null object
# dtypes: int64(4), object(5)
# memory usage: 148.9+ KB

# %%
game_data = tourney_data.join(teams, on='win_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'win_kaggle_team_id','conf_name':'win_conf_name'}, inplace=True)
game_data = game_data.join(teams,on='lose_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'lose_kaggle_team_id','conf_name':'lose_conf_name'}, inplace=True)
games_won_conf = game_data.groupby('win_conf_name').size().reset_index(name='count').sort_values(by=['count'], ascending=False)

games_won_conf['percent'] = 100 * games_won_conf['count']/games_won_conf['count'].sum()
games_won_conf['cum_percent'] = games_won_conf['percent'].cumsum()
games_won_conf.head()
# Out:
#      win_conf_name  count    percent  cum_percent
# 3   Atlantic Coast    431  20.358999    20.358999
# 9          Big Ten    313  14.785073    35.144072
# 24    Southeastern    269  12.706660    47.850732
# 5           Big 12    231  10.911667    58.762400
# 22      Pacific 12    197   9.305621    68.068021

# %% [markdown]
# Identify the conferences that have won 70% of all conference games

# %%
top_tournament_conferences_list = games_won_conf[games_won_conf['cum_percent']<= 70]['win_conf_name'].tolist()
top_tournament_conferences_list
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']

# %% [markdown]
# The summary season data in this set goes back to 2010. If more training data is needed we can go back to earlier seasons.
#
# So the intersection of season summary data with tournament data are regular seasons 2010 through 2016.

# %%
tourney_data = tourney_data[tourney_data['season'] >= 2010]
tourney_data.describe()['season']
# Out:
# count     533.000000
# mean     2013.519700
# std         2.284733
# min      2010.000000
# 25%      2012.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
# recode the tourney data so that the teams are not marked with  win/lose status and the game result is encoded as a binary
tourney_data['game_result'] = 1
tourney_data.game_result = tourney_data.game_result.astype(int)
tourney_data.rename(columns={"win_seed":"team_seed","win_market":"team","win_team_id":"team_id"}, inplace=True)
tourney_data.rename(columns={"lose_seed":"opp_team_seed","lose_market":"opp_team","lose_team_id":"opp_team_id"}, inplace=True)
tourney_data['start_season'] = tourney_data['season'] -1
tourney_data
# Out:
#       season  round   game_date  team_seed                   team  \
# 10      2013     64  2013-03-22          9                 Temple
# 17      2011     64  2011-03-17          7                 Temple
# 27      2013     64  2013-03-21          5  Virginia Commonwealth
# 29      2012     64  2012-03-15         12  Virginia Commonwealth
# 30      2011      8  2011-03-27         11  Virginia Commonwealth
# 31      2011     16  2011-03-25         11  Virginia Commonwealth
# 33      2011     32  2011-03-20         11  Virginia Commonwealth
# 34      2011     64  2011-03-18         11  Virginia Commonwealth
# 35      2011     68  2011-03-16         11  Virginia Commonwealth
# 36      2016     64  2016-03-18         10  Virginia Commonwealth
# 37      2013     64  2013-03-21          8         Colorado State
# 44      2017     64  2017-03-17         11           Rhode Island
# 46      2015     64  2015-03-19          5                   Utah
# 48      2016     64  2016-03-17          3                   Utah
# 49      2015     32  2015-03-21          5                   Utah
# 72      2017     64  2017-03-17          3                 Baylor
# 73      2017     32  2017-03-19          3                 Baylor
# 74      2010     32  2010-03-20          3                 Baylor
# 75      2010     64  2010-03-18          3                 Baylor
# 76      2010     16  2010-03-26          3                 Baylor
# 77      2012     16  2012-03-23          3                 Baylor
# 78      2012     64  2012-03-15          3                 Baylor
# 79      2012     32  2012-03-17          3                 Baylor
# 80      2014     64  2014-03-21          6                 Baylor
# 81      2014     32  2014-03-23          6                 Baylor
# 82      2014     64  2014-03-21         14                 Mercer
# 88      2014     64  2014-03-20         12     North Dakota State
# 89      2012     68  2012-03-14         12          South Florida
# 90      2012     64  2012-03-16         12          South Florida
# 94      2017     64  2017-03-17          3                 Oregon
# ...      ...    ...         ...        ...                    ...
# 1966    2010     64  2010-03-19          2          West Virginia
# 1967    2010     32  2010-03-21          2          West Virginia
# 1968    2010     16  2010-03-25          2          West Virginia
# 1973    2010      8  2010-03-27          2          West Virginia
# 1976    2017     64  2017-03-16          4          West Virginia
# 1978    2017     32  2017-03-18          4          West Virginia
# 1979    2015     32  2015-03-22          5          West Virginia
# 1980    2015     64  2015-03-20          5          West Virginia
# 1984    2017     68  2017-03-14         16       Mount St. Mary's
# 1989    2010     64  2010-03-18          9            Wake Forest
# 2001    2011     64  2011-03-18         11              Marquette
# 2002    2013     16  2013-03-28          3              Marquette
# 2003    2013     64  2013-03-21          3              Marquette
# 2004    2013     32  2013-03-23          3              Marquette
# 2005    2011     32  2011-03-20         11              Marquette
# 2014    2012     64  2012-03-15          3              Marquette
# 2015    2012     32  2012-03-17          3              Marquette
# 2023    2016     16  2016-03-25          6             Notre Dame
# 2024    2016     32  2016-03-20          6             Notre Dame
# 2028    2016     64  2016-03-18          6             Notre Dame
# 2029    2017     64  2017-03-16          5             Notre Dame
# 2030    2015     32  2015-03-21          3             Notre Dame
# 2031    2015     16  2015-03-26          3             Notre Dame
# 2034    2015     64  2015-03-19          3             Notre Dame
# 2037    2011     64  2011-03-18          2             Notre Dame
# 2045    2013     64  2013-03-22         11              Minnesota
# 2054    2012     64  2012-03-16         15                 Lehigh
# 2064    2010     64  2010-03-19         10           Georgia Tech
# 2082    2013     64  2013-03-22          7               Illinois
# 2104    2011     64  2011-03-18          9               Illinois
#
#                                    team_id  opp_team_seed  \
# 10    8598d1b6-106b-4083-a512-2e495729525a              8
# 17    8598d1b6-106b-4083-a512-2e495729525a             10
# 27    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             12
# 29    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              5
# 30    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              1
# 31    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             10
# 33    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              3
# 34    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              6
# 35    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518             11
# 36    c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518              7
# 37    1a470730-f328-4fb1-8bbf-36a069e4d6b2              9
# 44    7e42bca2-3cd7-4aca-aa46-f190fe5d8eb4              6
# 46    0d037a5d-827a-44dd-8b70-57603d671d5d             12
# 48    0d037a5d-827a-44dd-8b70-57603d671d5d             14
# 49    0d037a5d-827a-44dd-8b70-57603d671d5d              4
# 72    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 73    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 74    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 75    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 76    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             10
# 77    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             10
# 78    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             14
# 79    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 80    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf             11
# 81    db6e1cab-3fa3-4a93-a673-8b2a358ff4bf              3
# 82    a14b0057-8eb5-43d2-a33b-666196da933e              3
# 88    984e7518-e418-45d5-9797-979b8c2085c1              5
# 89    55af9c69-3675-4b9b-a882-96640b782fff             12
# 90    55af9c69-3675-4b9b-a882-96640b782fff              5
# 94    1da70895-f77f-44ef-b216-d63c02e696eb             14
# ...                                    ...            ...
# 1966  f770d3a2-221c-49ce-9c7a-680f7417fe9e             15
# 1967  f770d3a2-221c-49ce-9c7a-680f7417fe9e             10
# 1968  f770d3a2-221c-49ce-9c7a-680f7417fe9e             11
# 1973  f770d3a2-221c-49ce-9c7a-680f7417fe9e              1
# 1976  f770d3a2-221c-49ce-9c7a-680f7417fe9e             13
# 1978  f770d3a2-221c-49ce-9c7a-680f7417fe9e              5
# 1979  f770d3a2-221c-49ce-9c7a-680f7417fe9e              4
# 1980  f770d3a2-221c-49ce-9c7a-680f7417fe9e             12
# 1984  5fe4a398-1699-4442-a364-305b2f0ac01e             16
# 1989  4fbebf0a-e117-4a0c-8f15-c247535a2a1b              8
# 2001  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2002  06f7c904-0ac7-4125-b0f4-f4871bb69057              2
# 2003  06f7c904-0ac7-4125-b0f4-f4871bb69057             14
# 2004  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2005  06f7c904-0ac7-4125-b0f4-f4871bb69057              3
# 2014  06f7c904-0ac7-4125-b0f4-f4871bb69057             14
# 2015  06f7c904-0ac7-4125-b0f4-f4871bb69057              6
# 2023  80962f09-8821-48b6-8cf0-0cf0eea56aa8              7
# 2024  80962f09-8821-48b6-8cf0-0cf0eea56aa8             14
# 2028  80962f09-8821-48b6-8cf0-0cf0eea56aa8             11
# 2029  80962f09-8821-48b6-8cf0-0cf0eea56aa8             12
# 2030  80962f09-8821-48b6-8cf0-0cf0eea56aa8              6
# 2031  80962f09-8821-48b6-8cf0-0cf0eea56aa8              7
# 2034  80962f09-8821-48b6-8cf0-0cf0eea56aa8             14
# 2037  80962f09-8821-48b6-8cf0-0cf0eea56aa8             15
# 2045  fa416692-7e09-4f0a-9bcf-0cf7d5149a14              6
# 2054  508f503f-dc57-4f4c-a01e-4f195e5c05c8              2
# 2064  0f63a6f5-bda7-4fd9-9271-8d33f555ca19              7
# 2082  150148c2-ca8f-414f-8f41-d94a55d4a122             10
# 2104  150148c2-ca8f-414f-8f41-d94a55d4a122              8
#
#                   opp_team                           opp_team_id  game_result  \
# 10    North Carolina State  52df1e19-b142-4a76-a439-ad68455d0581            1
# 17              Penn State  4aebd148-8119-4875-954c-66779867989b            1
# 27                   Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20            1
# 29           Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 30                  Kansas  fae4855b-1b64-4b40-a632-9ed345e1e952            1
# 31           Florida State  d3c8a767-b6fc-45d4-a5f2-18406f2993f1            1
# 33                  Purdue  12d7f888-675b-459f-9099-a38f771d8a95            1
# 34              Georgetown  8736b67f-5924-400b-bf94-3bd804c36600            1
# 35                     USC  3a000455-de7c-4ca8-880e-abdce7f21da9            1
# 36            Oregon State  532d3874-b4b3-4c5c-acc6-749a6db26c8f            1
# 37                Missouri  77ca152a-cb2f-48a5-97b2-492351250d94            1
# 44               Creighton  7d797407-623e-476d-b299-46de4275414d            1
# 46       Stephen F. Austin  5ef64f01-86ae-4553-9834-c79cc0859eaf            1
# 48            Fresno State  dd8db4d8-d984-4cab-b7f6-22c6b8c2c45f            1
# 49              Georgetown  8736b67f-5924-400b-bf94-3bd804c36600            1
# 72        New Mexico State  5016fe1a-9571-4d10-bf5b-b9c1b496bd57            1
# 73                     USC  3a000455-de7c-4ca8-880e-abdce7f21da9            1
# 74            Old Dominion  ce967953-5c50-4220-87b2-99acb9606e84            1
# 75       Sam Houston State  67322042-9c40-4dc2-b33a-4754c02ec82a            1
# 76            Saint Mary's  b18f34af-a7f1-4659-a2e5-fc11a31cd316            1
# 77                  Xavier  0d8a328f-20ce-410b-bed1-15fc01308aaf            1
# 78      South Dakota State  6ef40534-5fad-4755-84de-7dcbd645d1f0            1
# 79                Colorado  9fccbf28-2858-4263-821c-fdefb3c7efa3            1
# 80                Nebraska  f8b1bf00-5b73-4ac4-98c0-ec554027ae32            1
# 81               Creighton  7d797407-623e-476d-b299-46de4275414d            1
# 82                    Duke  faeb1160-5d15-4f26-99fc-c441cf21fc7f            1
# 88                Oklahoma  b2fda957-e15c-4fb2-8a13-6e58496f561e            1
# 89              California  aacdc78d-b7fa-48f6-9686-2fdb8a95030e            1
# 90                  Temple  8598d1b6-106b-4083-a512-2e495729525a            1
# 94                    Iona  255c2a87-40c0-4989-bbb9-d286aac5d28e            1
# ...                    ...                                   ...          ...
# 1966          Morgan State  576b816b-5b9a-4768-a62b-f8435a8272c2            1
# 1967              Missouri  77ca152a-cb2f-48a5-97b2-492351250d94            1
# 1968            Washington  e52c9644-717a-46f4-bf16-aeca000b3b44            1
# 1973              Kentucky  2267a1f4-68f6-418b-aaf6-2aa0c4b291f1            1
# 1976              Bucknell  98d2123a-c7b9-4b5f-8a81-43f76d8537dc            1
# 1978            Notre Dame  80962f09-8821-48b6-8cf0-0cf0eea56aa8            1
# 1979              Maryland  2778d005-cc14-4e58-9bf2-3fc37bffb62f            1
# 1980               Buffalo  a9f5c9a2-342c-4881-9996-5d5c05ec9bd9            1
# 1984           New Orleans  e7ff6d5c-07e9-42af-955d-0a0b8c1e2288            1
# 1989                 Texas  6ed15092-2670-450a-99c2-61d861e87644            1
# 2001                Xavier  0d8a328f-20ce-410b-bed1-15fc01308aaf            1
# 2002            Miami (FL)  7aec5187-cb1b-45e5-8f7d-406d766cdc73            1
# 2003              Davidson  2920c5fa-1e86-4958-a7c4-1e97b8e201d8            1
# 2004                Butler  bdb7d7a4-45f8-4bf3-ab85-15488c451494            1
# 2005              Syracuse  8cd24de1-2be8-4b77-bcfa-47be0495a5f4            1
# 2014                   BYU  c31455b2-8a45-4248-aa8f-ce7eab1c6b02            1
# 2015          Murray State  77a69fb0-1355-4342-ac09-b4cc7949d95e            1
# 2023             Wisconsin  c7569eae-5b93-4197-b204-6f3a62146b25            1
# 2024     Stephen F. Austin  5ef64f01-86ae-4553-9834-c79cc0859eaf            1
# 2028              Michigan  bdc2561d-f603-4fab-a262-f1d2af462277            1
# 2029             Princeton  fe406882-9f22-495e-9df6-ef357a6803c6            1
# 2030                Butler  bdb7d7a4-45f8-4bf3-ab85-15488c451494            1
# 2031         Wichita State  f38b58de-3273-4723-a78b-2f918e9aa2d5            1
# 2034          Northeastern  93df9b18-e9fc-42a7-bb45-a736c203b4dc            1
# 2037                 Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20            1
# 2045                  UCLA  ec0d6b67-4b16-4b50-92b2-1a651dae6b0f            1
# 2054                  Duke  faeb1160-5d15-4f26-99fc-c441cf21fc7f            1
# 2064        Oklahoma State  8ab00d43-840a-4c96-bdee-bf88fa6e3f11            1
# 2082              Colorado  9fccbf28-2858-4263-821c-fdefb3c7efa3            1
# 2104                  UNLV  68a3227f-677f-43b0-9a3a-cad79d0df9e2            1
#
#       start_season
# 10            2012
# 17            2010
# 27            2012
# 29            2011
# 30            2010
# 31            2010
# 33            2010
# 34            2010
# 35            2010
# 36            2015
# 37            2012
# 44            2016
# 46            2014
# 48            2015
# 49            2014
# 72            2016
# 73            2016
# 74            2009
# 75            2009
# 76            2009
# 77            2011
# 78            2011
# 79            2011
# 80            2013
# 81            2013
# 82            2013
# 88            2013
# 89            2011
# 90            2011
# 94            2016
# ...            ...
# 1966          2009
# 1967          2009
# 1968          2009
# 1973          2009
# 1976          2016
# 1978          2016
# 1979          2014
# 1980          2014
# 1984          2016
# 1989          2009
# 2001          2010
# 2002          2012
# 2003          2012
# 2004          2012
# 2005          2010
# 2014          2011
# 2015          2011
# 2023          2015
# 2024          2015
# 2028          2015
# 2029          2016
# 2030          2014
# 2031          2014
# 2034          2014
# 2037          2010
# 2045          2012
# 2054          2011
# 2064          2009
# 2082          2012
# 2104          2010
#
# [533 rows x 11 columns]

# %%
# We need to recode the game data so that we have representation of the losing game result class.
# Swap the team and opp team data on the odd rows and reverse the sense of the game result.

#create some temporary buffer columns
tourney_data['copy_team'] = tourney_data['team']
tourney_data['copy_team_seed'] = tourney_data['team_seed']
tourney_data['copy_team_id'] = tourney_data['team_id']

#swap the team and opp team data
tourney_data.loc[1::2,'team'] = tourney_data.loc[1::2,'opp_team']
tourney_data.loc[1::2,'opp_team'] = tourney_data.loc[1::2,'copy_team']
tourney_data.loc[1::2,'team_seed'] = tourney_data.loc[1::2,'opp_team_seed']
tourney_data.loc[1::2,'opp_team_seed'] = tourney_data.loc[1::2,'copy_team_seed']
tourney_data.loc[1::2,'team_id'] = tourney_data.loc[1::2,'opp_team_id']
tourney_data.loc[1::2,'opp_team_id'] = tourney_data.loc[1::2,'copy_team_id']

# flip the game result
tourney_data.loc[1::2,'game_result'] = 0

#drop the temporary columns
tourney_data.drop(columns=['copy_team','copy_team_seed','copy_team_id'],inplace=True)
tourney_data.rename(columns={"team_seed":"seed_t","opp_team_seed":"seed_o"}, inplace=True)

tourney_data.head()
# Out:
#     season  round   game_date  seed_t                   team  \
# 10    2013     64  2013-03-22       8   North Carolina State
# 17    2011     64  2011-03-17       7                 Temple
# 27    2013     64  2013-03-21      12                  Akron
# 29    2012     64  2012-03-15      12  Virginia Commonwealth
# 30    2011      8  2011-03-27       1                 Kansas
#
#                                  team_id  seed_o               opp_team  \
# 10  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 17  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 27  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 29  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 30  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                              opp_team_id  game_result  start_season
# 10  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 17  4aebd148-8119-4875-954c-66779867989b            1          2010
# 27  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 29  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 30  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010

# %%
tourney_data['Game Result'] = tourney_data.game_result.map({1:'Win', 0:'Lose'})
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','team_id'], 
                                right_on=['season', 'team_id'],how='left',suffixes=('','_y'))

tourney_data.drop(columns=['season_y'],inplace=True)
tourney_data.head()
# Out:
#    season  round   game_date  seed_t                   team  \
# 0    2013     64  2013-03-22       8   North Carolina State
# 1    2011     64  2011-03-17       7                 Temple
# 2    2013     64  2013-03-21      12                  Akron
# 3    2012     64  2012-03-15      12  Virginia Commonwealth
# 4    2011      8  2011-03-27       1                 Kansas
#
#                                 team_id  seed_o               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result                  School  Games    SRS   SOS  win_pct  pts_avg  \
# 0        Lose   North Carolina State      35  14.32  7.17    0.686       77
# 1         Win                 Temple      34  12.35  4.23    0.765       70
# 2        Lose                  Akron      33   8.11  0.18    0.788       71
# 3         Win  Virginia Commonwealth      36   8.79  0.63    0.806       68
# 4        Lose                 Kansas      38  24.10  7.62    0.921       81
#
#    opp_pts_avg  fg_pct  allow_fg_pct  ft_pct  allow_ft_att_avg   poss_avg  \
# 0           70   0.496         0.419   0.681                17  78.434286
# 1           62   0.447         0.435   0.698                19  75.688235
# 2           62   0.455         0.395   0.643                19  78.884848
# 3           59   0.410         0.424   0.685                18  76.305556
# 4           64   0.508         0.380   0.679                18  80.126316
#
#    off_rebs_avg  allow_off_rebs_avg  def_rebs_avg  allow_def_rebs_avg  to_avg  \
# 0            11                  12            22                  21      12
# 1            11                  11            24                  22      10
# 2            12                  10            21                  21      13
# 3            12                  10            18                  24      11
# 4            11                  10            27                  21      13
#
#    steal_avg  off_rating  ft_att_avg
# 0          6   98.171354          23
# 1          6   92.484651          19
# 2          7   90.004610          20
# 3         10   89.115399          20
# 4          7  101.090384          22

# %%
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','opp_team_id'], 
                                right_on=['season', 'team_id'], how='left',suffixes=('_t','_o'))

# %%
tourney_data.drop(columns=['School_t','School_o','Games_t','Games_o','team_id_o'],inplace=True)
tourney_data.head()
# Out:
#    season_t  round   game_date  seed_t                   team  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o
# 0            20
# 1            16
# 2            18
# 3            19
# 4            20

# %%
tourney_data = tourney_data.join(teams, on='team_id_t', how='left')

# %%
tourney_data = tourney_data.join(teams, on='opp_team_id', how='left', lsuffix='_t', rsuffix='_o')
tourney_data.head()
# Out:
#    season_t  round   game_date  seed_t                   team  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o               opp_team  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                             opp_team_id  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o
# 0            20     Atlantic Coast  American Athletic
# 1            16  American Athletic            Big Ten
# 2            18       Mid-American        Atlantic 10
# 3            19        Atlantic 10  American Athletic
# 4            20             Big 12        Atlantic 10

# %%
tourney_data.rename(index=str,columns={'team':'team_t','opp_team':'team_o', 'opp_team_id':'team_id_o'},inplace=True)
tourney_data.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o
# 0            20     Atlantic Coast  American Athletic
# 1            16  American Athletic            Big Ten
# 2            18       Mid-American        Atlantic 10
# 3            19        Atlantic 10  American Athletic
# 4            20             Big 12        Atlantic 10

# %%
computer_rankings = pd.read_csv(Path( '../Data/massey_seasons_with_id.csv'))
computer_rankings = computer_rankings[computer_rankings['season']>=2010]
computer_rankings[computer_rankings.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SAG, WLK, WOL, Team, RTH, COL, POM, DOL, RPI, MOR, season, win_pct, kaggle_id]
# Index: []

# %%
temp_merge = tourney_data.merge(computer_rankings, left_on=['season_t','team_id_t'], 
                                right_on=['season', 'kaggle_id'],how='left',suffixes=('','_y'))


temp_merge.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG   WLK  WOL  \
# 0            20     Atlantic Coast  American Athletic   25  27.0   36
# 1            16  American Athletic            Big Ten   32  30.0   25
# 2            18       Mid-American        Atlantic 10   62  55.0   52
# 3            19        Atlantic 10  American Athletic   50  43.0   32
# 4            20             Big 12        Atlantic 10    2   2.0    3
#
#               Team  RTH   COL   POM   DOL   RPI  MOR  season   win_pct  \
# 0         NC State   28  32.0  35.0  32.0  33.0   24    2013  0.705882
# 1           Temple   32  27.0  38.0  25.0  30.0   45    2011  0.781250
# 2            Akron   59  50.0  54.0  46.0  42.0   60    2013  0.812500
# 3  VA Commonwealth   54  35.0  47.0  33.0  38.0   55    2012  0.823529
# 4           Kansas    2   1.0   3.0   2.0   1.0    3    2011  0.942857
#
#                               kaggle_id
# 0  52df1e19-b142-4a76-a439-ad68455d0581
# 1  8598d1b6-106b-4083-a512-2e495729525a
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952

# %%
temp_merge.drop(columns=['Team','season','win_pct','kaggle_id'],inplace=True)
temp_merge.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG   WLK  WOL  RTH  \
# 0            20     Atlantic Coast  American Athletic   25  27.0   36   28
# 1            16  American Athletic            Big Ten   32  30.0   25   32
# 2            18       Mid-American        Atlantic 10   62  55.0   52   59
# 3            19        Atlantic 10  American Athletic   50  43.0   32   54
# 4            20             Big 12        Atlantic 10    2   2.0    3    2
#
#     COL   POM   DOL   RPI  MOR
# 0  32.0  35.0  32.0  33.0   24
# 1  27.0  38.0  25.0  30.0   45
# 2  50.0  54.0  46.0  42.0   60
# 3  35.0  47.0  33.0  38.0   55
# 4   1.0   3.0   2.0   1.0    3

# %%
tourney_comp_ratings = temp_merge.merge(computer_rankings,left_on=['season_t','team_id_o'], 
                                right_on=['season', 'kaggle_id'], how='left',suffixes=('_t','_o'))

tourney_comp_ratings.drop(columns=['Team','season','win_pct','kaggle_id'],inplace=True)
tourney_comp_ratings.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG_t  WLK_t  WOL_t  \
# 0            20     Atlantic Coast  American Athletic     25   27.0     36
# 1            16  American Athletic            Big Ten     32   30.0     25
# 2            18       Mid-American        Atlantic 10     62   55.0     52
# 3            19        Atlantic 10  American Athletic     50   43.0     32
# 4            20             Big 12        Atlantic 10      2    2.0      3
#
#    RTH_t  COL_t  POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  \
# 0     28   32.0   35.0   32.0   33.0     24     55   58.0     35     47
# 1     32   27.0   38.0   25.0   30.0     45     45   42.0     43     37
# 2     59   50.0   54.0   46.0   42.0     60     26   19.0     27     27
# 3     54   35.0   47.0   33.0   38.0     55     10   10.0     16     16
# 4      2    1.0    3.0    2.0    1.0      3     77   55.0     54     74
#
#    COL_o  POM_o  DOL_o  RPI_o  MOR_o
# 0   40.0   68.0   45.0   41.0     52
# 1   39.0   39.0   39.0   39.0     27
# 2   27.0   21.0   31.0   24.0     16
# 3   11.0   10.0   15.0   12.0     10
# 4   59.0   84.0   72.0   49.0     80

# %% [markdown]
# #### Add a feature
# top_conf = 1 if team is a top conference and opponent is not
# top_conf = -1 if opp_team is a top_conference and team is not
# top_conf = 0 otherwise

# %%
print(top_tournament_conferences_list)
tourney_comp_ratings['top_conf'] = tourney_comp_ratings.apply(lambda row: utils.conf_compare(row.conf_name_t, 
                                                                                             row.conf_name_o,
                                                                                             top_tournament_conferences_list),
                                                              axis=1)

tourney_comp_ratings.head(10)[['game_result','conf_name_t','conf_name_o','top_conf']]
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']
#    game_result        conf_name_t        conf_name_o  top_conf
# 0            0     Atlantic Coast  American Athletic         1
# 1            1  American Athletic            Big Ten        -1
# 2            0       Mid-American        Atlantic 10         0
# 3            1        Atlantic 10  American Athletic         0
# 4            0             Big 12        Atlantic 10         1
# 5            1        Atlantic 10     Atlantic Coast        -1
# 6            0            Big Ten        Atlantic 10         1
# 7            1        Atlantic 10           Big East         0
# 8            0         Pacific 12        Atlantic 10         1
# 9            1        Atlantic 10         Pacific 12        -1

# %%
# Upsets occur less than 30% of the time when seeding deltas are more than 6
tourney_comp_ratings['upset_seed_threshold'] = tourney_comp_ratings.apply(
    lambda row: abs(row.seed_t - row.seed_o) > 6, axis=1).astype(int)
    
tourney_comp_ratings.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a            0          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            0          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG_t  WLK_t  WOL_t  \
# 0            20     Atlantic Coast  American Athletic     25   27.0     36
# 1            16  American Athletic            Big Ten     32   30.0     25
# 2            18       Mid-American        Atlantic 10     62   55.0     52
# 3            19        Atlantic 10  American Athletic     50   43.0     32
# 4            20             Big 12        Atlantic 10      2    2.0      3
#
#    RTH_t  COL_t  POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  \
# 0     28   32.0   35.0   32.0   33.0     24     55   58.0     35     47
# 1     32   27.0   38.0   25.0   30.0     45     45   42.0     43     37
# 2     59   50.0   54.0   46.0   42.0     60     26   19.0     27     27
# 3     54   35.0   47.0   33.0   38.0     55     10   10.0     16     16
# 4      2    1.0    3.0    2.0    1.0      3     77   55.0     54     74
#
#    COL_o  POM_o  DOL_o  RPI_o  MOR_o  top_conf  upset_seed_threshold
# 0   40.0   68.0   45.0   41.0     52         1                     0
# 1   39.0   39.0   39.0   39.0     27        -1                     0
# 2   27.0   21.0   31.0   24.0     16         0                     1
# 3   11.0   10.0   15.0   12.0     10         0                     1
# 4   59.0   84.0   72.0   49.0     80         1                     1

# %%
feature_data = tourney_comp_ratings.drop(columns=['round','game_date','team_t','team_id_t','team_id_o',
                                         'team_o','team_id_o','game_result','start_season','Game Result',
                                         'conf_name_t','conf_name_o']).copy()
feature_data.head()
# Out:
#    season_t  seed_t  seed_o  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0      2013       8       9  14.32   7.17      0.686         77
# 1      2011       7      10  12.35   4.23      0.765         70
# 2      2013      12       5   8.11   0.18      0.788         71
# 3      2012      12       5   8.79   0.63      0.806         68
# 4      2011       1      11  24.10   7.62      0.921         81
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0             70     0.496           0.419     0.681                  17
# 1             62     0.447           0.435     0.698                  19
# 2             62     0.455           0.395     0.643                  19
# 3             59     0.410           0.424     0.685                  18
# 4             64     0.508           0.380     0.679                  18
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286              11                    12              22
# 1   75.688235              11                    11              24
# 2   78.884848              12                    10              21
# 3   76.305556              12                    10              18
# 4   80.126316              11                    10              27
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0                    21        12            6     98.171354            23
# 1                    22        10            6     92.484651            19
# 2                    21        13            7     90.004610            20
# 3                    24        11           10     89.115399            20
# 4                    21        13            7    101.090384            22
#
#    season_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0      2012   9.52   5.20      0.706         72             67     0.428
# 1      2010  11.98  11.45      0.559         63             62     0.439
# 2      2012  16.89   4.47      0.750         76             64     0.450
# 3      2011  17.42   3.80      0.818         77             62     0.482
# 4      2010   8.56   3.78      0.700         71             66     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723                  18   77.494118              11
# 1           0.434     0.724                  21   68.341176               9
# 2           0.444     0.701                  20   81.044444              13
# 3           0.393     0.748                  18   77.496970              10
# 4           0.424     0.715                  18   75.240000              10
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0                    10              19                    25        10
# 1                     8              21                    23        10
# 2                    11              18                    23        11
# 3                     9              24                    21        12
# 4                    10              21                    24        11
#
#    steal_avg_o  off_rating_o  ft_att_avg_o  SAG_t  WLK_t  WOL_t  RTH_t  COL_t  \
# 0            7     92.910278            20     25   27.0     36     28   32.0
# 1            4     92.184541            16     32   30.0     25     32   27.0
# 2           11     93.775706            18     62   55.0     52     59   50.0
# 3            6     99.358724            19     50   43.0     32     54   35.0
# 4            8     94.364700            20      2    2.0      3      2    1.0
#
#    POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  COL_o  POM_o  \
# 0   35.0   32.0   33.0     24     55   58.0     35     47   40.0   68.0
# 1   38.0   25.0   30.0     45     45   42.0     43     37   39.0   39.0
# 2   54.0   46.0   42.0     60     26   19.0     27     27   27.0   21.0
# 3   47.0   33.0   38.0     55     10   10.0     16     16   11.0   10.0
# 4    3.0    2.0    1.0      3     77   55.0     54     74   59.0   84.0
#
#    DOL_o  RPI_o  MOR_o  top_conf  upset_seed_threshold
# 0   45.0   41.0     52         1                     0
# 1   39.0   39.0     27        -1                     0
# 2   31.0   24.0     16         0                     1
# 3   15.0   12.0     10         0                     1
# 4   72.0   49.0     80         1                     1

# %%
X= feature_data[feature_data['season_t']>=2010]
y= tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']
X= X.drop(columns=['season_t'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
X_train.head()
# Out:
# (426, 59)
# (426,)
# (107, 59)
# (107,)
#      seed_t  seed_o  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  \
# 140       3      14  17.03   9.56      0.676         73             66
# 293       5       4  15.33   8.17      0.757         71             63
# 368      13       4   3.63   0.45      0.618         67             62
# 53        3      11  18.45   8.45      0.757         76             66
# 33        3       1  20.80   8.38      0.846         78             65
#
#      fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  \
# 140     0.499           0.417     0.711                  18   75.200000
# 293     0.471           0.406     0.685                  17   78.043243
# 368     0.461           0.394     0.684                  19   72.452941
# 53      0.449           0.407     0.672                  18   80.497297
# 33      0.481           0.403     0.712                  15   77.917949
#
#      off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 140               9                    11              23
# 293              13                    10              25
# 368               9                    11              25
# 53               12                    10              27
# 33               10                    10              26
#
#      allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 140                    19        13            6     97.074468            19
# 293                    19        13            6     90.975204            20
# 368                    22        11            5     92.473817            15
# 53                     24        11            7     94.413108            22
# 33                     22        11            6    100.105305            20
#
#      season_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 140      2009   4.56  -0.03      0.595         74             69     0.430
# 293      2009  17.75   7.95      0.727         79             68     0.471
# 368      2014  18.12   8.98      0.750         68             59     0.429
# 53       2015   8.78   4.44      0.639         68             63     0.455
# 33       2016  23.53  12.23      0.861         83             71     0.488
#
#      allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 140           0.418     0.719                  20   80.518919              11
# 293           0.394     0.729                  18   82.139394              12
# 368           0.392     0.668                  18   77.022222              12
# 53            0.423     0.757                  13   68.727778               5
# 33            0.420     0.678                  18   82.350000              11
#
#      allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 140                    12              25                    25        12
# 293                    14              25                    23        11
# 368                    11              24                    23        11
# 53                      9              24                    25         9
# 33                     11              26                    23        12
#
#      steal_avg_o  off_rating_o  ft_att_avg_o  SAG_t  WLK_t  WOL_t  RTH_t  \
# 140            7     91.903867            23     11    9.0     14      9
# 293            7     96.177968            20     25   28.0     30     22
# 368            7     88.286209            22     97  103.0    103    113
# 53             5     98.941072            17     17   16.0     26     21
# 33             6    100.789314            21     13   14.0      8     11
#
#      COL_t  POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  COL_o  \
# 140   12.0   11.0   16.0    7.0      7    112   91.0    119    116  106.0
# 293   26.0   24.0   20.0   28.0     18     15   14.0     25     19   23.0
# 368  107.0   94.0  112.0   88.0    103     15   15.0     13     12   15.0
# 53    13.0   17.0   17.0   17.0     12     73   87.0     89     92   87.0
# 33     7.0   16.0   12.0    9.0     24      6    5.0      5      3    2.0
#
#      POM_o  DOL_o  RPI_o  MOR_o  top_conf  upset_seed_threshold
# 140  100.0  126.0   95.0    101         0                     1
# 293   10.0   19.0   24.0     10         0                     0
# 368   18.0   14.0   21.0     13        -1                     1
# 53    77.0   85.0   70.0     66         1                     1
# 33    10.0    2.0    3.0      8         0                     0

# %%
#tree_count =2000

bdt= AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME", n_estimators=200)
    
bdt.fit(X_train, y_train)
score = bdt.score(X_train, y_train)
print("Training Model Score= ", score)
# Out:
# Training Model Score=  0.971830985915493

# %%
#display_important_features_rf_forest(rf_classifier, X_train)

# %%
y_pred = bdt.predict(X_test)
print("RF model accuracy is %2.2f" % metrics.accuracy_score(y_test, y_pred))
# Out:
# RF model accuracy is 0.60

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5,257.44,'Predicted label')

# %%
prediction_probabilities = bdt.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.5981308411214953
# Precision: 0.6363636363636364
# Recall: 0.509090909090909
# Log loss=  0.6890481339724575

# %%
# Retrieve the non-normalized game stats
prediction_probabilities[:,1]
pred_probs = pd.Series(prediction_probabilities[:,1], index=X_test.index)
predictions = pd.Series(y_pred, index=y_test.index)
test_games = tourney_comp_ratings[tourney_comp_ratings.index.isin(X_test.index)].copy()


test_games['predicted_result'] = predictions
test_games['pred_win_prob'] = pred_probs

test_games.head()
# Out:
#     season_t  round   game_date  seed_t                 team_t  \
# 7       2011     64  2011-03-18      11  Virginia Commonwealth
# 28      2012     64  2012-03-16       5                 Temple
# 34      2017     32  2017-03-19      11           Rhode Island
# 40      2013     68  2013-03-20      16           LIU Brooklyn
# 43      2017     64  2017-03-16       7           Saint Mary's
#
#                                team_id_t  seed_o                 team_o  \
# 7   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       6             Georgetown
# 28  8598d1b6-106b-4083-a512-2e495729525a      12          South Florida
# 34  7e42bca2-3cd7-4aca-aa46-f190fe5d8eb4       3                 Oregon
# 40  82c12e8d-7c6c-47d8-b100-3cbc190d268e      16          James Madison
# 43  b18f34af-a7f1-4659-a2e5-fc11a31cd316      10  Virginia Commonwealth
#
#                                team_id_o  game_result  start_season  \
# 7   8736b67f-5924-400b-bf94-3bd804c36600            1          2010
# 28  55af9c69-3675-4b9b-a882-96640b782fff            0          2011
# 34  1da70895-f77f-44ef-b216-d63c02e696eb            0          2016
# 40  524e3eec-7dde-45c7-b3cc-6308cec73350            0          2012
# 43  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            1          2016
#
#    Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 7          Win   8.56   3.78      0.700         71             66     0.434
# 28        Lose  10.44   4.94      0.750         75             69     0.469
# 34        Lose  12.88   4.62      0.714         73             65     0.454
# 40        Lose  -3.21  -5.80      0.588         78             76     0.479
# 43         Win  16.75   2.19      0.853         72             57     0.496
#
#     allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 7            0.424     0.715                  18   75.240000              10
# 28           0.435     0.719                  19   77.743750              10
# 34           0.406     0.668                  24   77.840000              11
# 40           0.468     0.691                  19   80.676471              11
# 43           0.412     0.745                  14   69.458824               9
#
#     allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 7                     10              21                    24        11
# 28                    11              21                    22        12
# 34                    10              25                    23        11
# 40                    11              19                    21        14
# 43                     7              25                    19        10
#
#     steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  \
# 7             8     94.364700            20      2010  14.61  10.39
# 28            7     96.470777            19      2011   9.20   7.29
# 34            6     93.782117            22      2016  20.80   8.38
# 40            6     96.682464            25      2012  -1.73  -2.28
# 43            4    103.658537            14      2016  11.57   3.77
#
#     win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 7       0.656         70             66     0.475           0.387     0.734
# 28      0.611         59             56     0.437           0.386     0.705
# 34      0.846         78             65     0.481           0.403     0.712
# 40      0.583         65             64     0.421           0.428     0.699
# 43      0.743         74             66     0.461           0.422     0.705
#
#     allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 7                   19   73.850000              10                    10
# 28                  16   69.133333              10                    10
# 34                  15   77.917949              10                    10
# 40                  20   72.988889              10                    10
# 43                  22   79.537143              11                     9
#
#     def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 7               23                    19        13            6     94.786730
# 28              20                    20        13            5     85.342334
# 34              26                    22        11            6    100.105305
# 40              19                    24        11            7     89.054651
# 43              25                    24        12            7     93.038293
#
#     ft_att_avg_o        conf_name_t        conf_name_o  SAG_t  WLK_t  WOL_t  \
# 7             17        Atlantic 10           Big East     77   55.0     54
# 28            16  American Athletic  American Athletic     36   29.0     28
# 34            20        Atlantic 10         Pacific 12     48   40.0     48
# 40            19          Northeast           Colonial    163  182.0    171
# 43            21         West Coast        Atlantic 10     25   25.0     11
#
#     RTH_t  COL_t  POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  \
# 7      74   59.0   84.0   72.0   49.0     80     16   19.0     16     17
# 28     35   22.0   34.0   20.0   20.0     42     70   51.0     60     53
# 34     53   43.0   37.0   52.0   31.0     31     13   14.0      8     11
# 40    182  173.0  185.0  193.0  179.0    134    169  183.0    183    184
# 43     20   18.0   14.0   23.0   17.0     26     50   43.0     46     54
#
#     COL_o  POM_o  DOL_o  RPI_o  MOR_o  top_conf  upset_seed_threshold  \
# 7    16.0   31.0   19.0   13.0     42         0                     0
# 28   59.0   66.0   60.0   52.0     47         0                     1
# 34    7.0   16.0   12.0    9.0     24        -1                     1
# 40  179.0  179.0  168.0  182.0    155         0                     0
# 43   30.0   52.0   44.0   22.0     50         0                     0
#
#     predicted_result  pred_win_prob
# 7                  0       0.499060
# 28                 1       0.505769
# 34                 0       0.494570
# 40                 0       0.498768
# 43                 1       0.500336

# %%
missed_predictions = test_games[test_games['game_result'] != 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)
missed_predictions[['predicted_result','game_result','pred_win_prob','team_t','seed_t','conf_name_t', 'team_o',
                    'seed_o', 'conf_name_o','top_conf','season_t','round']]
# Out:
#      predicted_result  game_result  pred_win_prob                 team_t  \
# 488                 1            0       0.514872          West Virginia
# 50                  1            0       0.513409                Liberty
# 162                 1            0       0.510277             New Mexico
# 51                  0            1       0.506909               UC Davis
# 496                 1            0       0.506659             Iowa State
# 352                 1            0       0.506348             Utah State
# 56                  1            0       0.505967             St. John's
# 28                  1            0       0.505769                 Temple
# 358                 1            0       0.505630              Villanova
# 514                 1            0       0.505317             Miami (FL)
# 292                 1            0       0.505208              Tennessee
# 486                 1            0       0.504244       Mount St. Mary's
# 366                 1            0       0.503222                   UNLV
# 394                 1            0       0.502122               Ole Miss
# 189                 0            1       0.502085             Ohio State
# 201                 0            1       0.501966                 Butler
# 494                 1            0       0.501137           Saint Mary's
# 197                 0            1       0.500972                 Butler
# 52                  1            0       0.500737             Utah State
# 319                 0            1       0.500605               Kentucky
# 445                 0            1       0.499521                 Xavier
# 363                 0            1       0.499477            Saint Louis
# 465                 0            1       0.499453               Michigan
# 151                 0            1       0.499327            Connecticut
# 71                  0            1       0.499076         Morehead State
# 301                 0            1       0.499070                 Hawaii
# 7                   0            1       0.499060  Virginia Commonwealth
# 316                 1            0       0.498944            Stony Brook
# 525                 0            1       0.498563             Notre Dame
# 511                 0            1       0.498492       Mount St. Mary's
# 513                 0            1       0.498215              Marquette
# 441                 0            1       0.498106                 Xavier
# 123                 0            1       0.497507              Wisconsin
# 145                 0            1       0.497313                Harvard
# 281                 0            1       0.496546          Wichita State
# 199                 0            1       0.496389                 Butler
# 75                  0            1       0.495897                 Dayton
# 223                 0            1       0.495823                Gonzaga
# 517                 0            1       0.495570              Marquette
# 283                 0            1       0.494088          Wichita State
# 99                  0            1       0.493138               Syracuse
# 203                 0            1       0.492227                 Butler
# 321                 0            1       0.485779               Kentucky
#
#      seed_t        conf_name_t                  team_o  seed_o  \
# 488       3             Big 12       Stephen F. Austin      14
# 50       16          Big South      North Carolina A&T      16
# 162       3      Mountain West              Washington      11
# 51       16           Big West  North Carolina Central      16
# 496       5             Big 12                  Purdue       4
# 352      12      Mountain West            Kansas State       5
# 56        9           Big East         San Diego State       8
# 28        5  American Athletic           South Florida      12
# 358       1           Big East    North Carolina State       8
# 514       2     Atlantic Coast               Marquette       3
# 292       6       Southeastern          Michigan State       5
# 486      16          Northeast                  Albany      16
# 366       6      Mountain West                Colorado      11
# 394      12       Southeastern                La Salle      13
# 189       2            Big Ten            Georgia Tech      10
# 201       6           Big East                   Texas      11
# 494       7         West Coast                  Purdue      10
# 197       9           Big East              Texas Tech       8
# 52       12      Mountain West               Texas A&M       5
# 319       4       Southeastern          North Carolina       2
# 445       6           Big East           Georgia State      14
# 363       5        Atlantic 10    North Carolina State      12
# 465       2            Big Ten               Tennessee      11
# 151       7  American Athletic              Iowa State       3
# 71       13        Ohio Valley              Louisville       4
# 301      13           Big West              California       4
# 7        11        Atlantic 10              Georgetown       6
# 316      13       America East                Kentucky       4
# 525       3     Atlantic Coast           Wichita State       7
# 511      16          Northeast             New Orleans      16
# 513      11           Big East                  Xavier       6
# 441      10           Big East                  Lehigh      15
# 123       7            Big Ten                  Xavier       2
# 145      12                Ivy              Cincinnati       5
# 281       9  American Athletic                 Gonzaga       1
# 199       8           Big East                 Florida       2
# 75       11        Atlantic 10              Ohio State       6
# 223       8         West Coast           Florida State       9
# 517      11           Big East                Syracuse       3
# 283       9  American Athletic              Ohio State       2
# 99        4     Atlantic Coast                 Indiana       1
# 203       8           Big East              Pittsburgh       1
# 321       4       Southeastern              Ohio State       1
#
#               conf_name_o  top_conf  season_t  round
# 488             Southland         1      2016     64
# 50   Mid Eastern Athletic         0      2013     68
# 162            Pacific 12        -1      2010     32
# 51   Mid Eastern Athletic         0      2017     68
# 496               Big Ten         0      2017     32
# 352                Big 12        -1      2011     64
# 56          Mountain West         0      2015     64
# 28      American Athletic         0      2012     64
# 358        Atlantic Coast        -1      2015     32
# 514              Big East         1      2013     16
# 292               Big Ten         0      2010      8
# 486          America East         0      2014     68
# 366            Pacific 12        -1      2012     64
# 394           Atlantic 10         1      2013     32
# 189        Atlantic Coast         0      2010     32
# 201                Big 12        -1      2015     64
# 494               Big Ten        -1      2012     64
# 197                Big 12        -1      2016     64
# 52           Southeastern        -1      2010     64
# 319        Atlantic Coast         0      2011      8
# 445              Sun Belt         0      2015     32
# 363        Atlantic Coast        -1      2014     64
# 465          Southeastern         0      2014     16
# 151                Big 12        -1      2014     16
# 71         Atlantic Coast        -1      2011     64
# 301            Pacific 12        -1      2016     64
# 7                Big East         0      2011     64
# 316          Southeastern        -1      2016     64
# 525     American Athletic         1      2015     16
# 511             Southland         0      2017     68
# 513              Big East         0      2011     64
# 441        Patriot League         0      2012     32
# 123              Big East         1      2016     32
# 145     American Athletic         0      2014     64
# 281            West Coast         0      2013     32
# 199          Southeastern        -1      2011      8
# 75                Big Ten        -1      2014     64
# 223        Atlantic Coast        -1      2010     64
# 517        Atlantic Coast        -1      2011     32
# 283               Big Ten        -1      2013      8
# 99                Big Ten         0      2013     16
# 203        Atlantic Coast        -1      2011     32
# 321               Big Ten         0      2011     16

# %%
train_sizes, train_scores, test_scores = learning_curve(AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME", n_estimators=200), 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# %%
# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()
