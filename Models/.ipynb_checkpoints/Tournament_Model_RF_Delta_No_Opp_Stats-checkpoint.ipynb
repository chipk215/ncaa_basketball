# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# Non pythonic hack to reuse some utility code
if sys.path[0] != '../py_utils':
    sys.path.insert(0,'../py_utils')

import utils
import file_utils
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
from pathlib import Path
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)
# Out:
# Seaborn version:  0.9.0

# %%
def eliminate_features(classifier, X, y ):
    iteration = 0
    print("Iteration= ", iteration)
    iteration += 1
    model_stats = {}
    drop_list = []
    # get baseline by identifying sorted important features using all of the provided features
    model_stats = utils.save_model_stats(classifier,X,y,model_stats)
    
    important_features = utils.display_important_features(classifier.feature_importances_, X,0)
    # least important feature
    least_important_label = important_features[-1][0]
    print("least_important label= ", least_important_label)
    
    drop_list.append(least_important_label)
    del important_features[-1]
    
    # drop list contains all of the feature labels except for the feature label identified as being most important
    list_count = len(important_features)
    while list_count > 0:
        print("Iteration= ", iteration)
        iteration += 1
        model_stats = utils.save_model_stats(classifier,X.drop(columns=drop_list),y,model_stats)
        least_important_label = important_features[-1][0]
        print("least_important label= ", least_important_label)
        drop_list.append(least_important_label)
        del important_features[-1]
        list_count-=1
    return model_stats

# %%
def get_missed_predictions(tourney_comp_ratings, prediction_probabilities, X, y, y_pred):
    
    pred_probs = pd.Series(prediction_probabilities[:,1], index=X.index)
    predictions = pd.Series(y_pred, index=y.index)
    test_games = tourney_comp_ratings[tourney_comp_ratings.index.isin(X.index)].copy()
    test_games['predicted_result'] = predictions
    test_games['pred_win_prob'] = pred_probs
    missed_predictions = test_games[test_games['game_result'] != 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)
   
    missed_predictions.apply(lambda x: feature_dictionary.print_game_info(test_games,x['season_t'], x['round'], x['team_t'] ), axis=1)
    supporting_features = missed_predictions.apply(lambda row: utils.get_supporting_features(row,
                                                                                         feature_dictionary, 
                                                                                         feature_list),axis=1)

    supporting_model_features = missed_predictions.apply(lambda row: utils.get_supporting_features(row, 
                                                                                               feature_dictionary,
                                                                                               model_features),axis=1)
    
    missed_predictions = missed_predictions.merge(supporting_features.to_frame(name='supporting_features'),how='left',
                                              left_index=True, right_index=True)

    missed_predictions = missed_predictions.merge(supporting_model_features.to_frame(name='supporting_model_features'),how='left', 
                                              left_index=True, right_index=True)

    missed_predictions['features'] = 100 * missed_predictions['supporting_features'].apply(lambda x: len(x)) / len(feature_list)

    missed_predictions['model_features'] = 100 * missed_predictions['supporting_model_features'].apply(lambda x: len(x)) / \
        len(model_features)

    missed_predictions['game_index'] = missed_predictions.index
    
    return missed_predictions

# %%
summary_team_file = '../Data/sr_summaries_kaggle_id_no_opp_2018.csv'
team_meta_data_file = '../Data/D1_teams.csv'
tournament_data_file = '../Data/tournament_results_2018.csv'
rankings_data_file = '../data/massey_seasons_with_id.csv'

feature_dictionary = utils.Feature_Dictionary()

# %%
# earliest season data starts in 2000 corresponding to tournament season date of 2001
start_tournament = 2003
stop_tournament = 2017

# %% [markdown]
# #### Read in regular season team statistics from SRCBB https://www.sports-reference.com/cbb/

# %%
summary_data = file_utils.read_summary_team_data(summary_team_file)
teams = file_utils.read_team_meta_data(team_meta_data_file)
summary_data.head()
# Out:
#    season          school                               team_id  games    srs  \
# 0    2000       Air Force  aa7af640-5762-4686-9181-39f7b8a8186e     29  -3.57
# 1    2000           Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20     28  -3.09
# 2    2000         Alabama  c2104cdc-c83d-40d2-a3cd-df986e29f5d3     36  14.02
# 3    2000     Alabama A&M  949c3398-85e4-4c63-ba71-9a82e06ddea4     28 -13.46
# 4    2000  Alabama State   267d417a-8f85-4c87-a15a-068c089a74c6     31  -8.86
#
#      sos  win_pct  pts_avg  opp_pts_avg  fg_pct  ft_pct   poss_avg  \
# 0   1.99    0.276       57           63   0.435   0.697  63.020690
# 1   1.67    0.429       67           72   0.452   0.725  73.857143
# 2   6.27    0.694       76           68   0.433   0.698  86.200000
# 3 -11.79    0.607       73           74   0.391   0.626  94.264286
# 4 -13.61    0.710       68           63   0.441   0.658  80.690323
#
#    off_rebs_avg  def_rebs_avg  to_avg  steal_avg  off_rating  ft_att_avg
# 0           6.0          16.0      13          7   90.446487          16
# 1           9.0          20.0      15          5   90.715667          23
# 2          16.0          26.0      15          7   88.167053          24
# 3          17.0          22.0      16         12   77.441843          23
# 4          12.0          25.0      16          8   84.272807          22

# %% [markdown]
# #### Read table of team names and associated team meta data from the Kaggle data set.
#
# https://console.cloud.google.com/bigquery?project=bigqueryncaa&p=bigquery-public-data&d=ncaa_basketball&page=dataset

# %% [markdown]
# #### Read in the NCAA Men's Tournament results from the the Kaggle data set.

# %%
tourney_data = file_utils.read_tournament_results(tournament_data_file,start_tournament)
game_data = utils.compute_game_data(tourney_data, teams)
computer_rankings = pd.read_csv(Path(rankings_data_file))
computer_rankings = computer_rankings[computer_rankings['season'] >= start_tournament]

tourney_data = utils.recode_tourney_data(tourney_data)
tourney_data = file_utils.merge_tourney_summary_data(tourney_data, summary_data)
tourney_data = file_utils.join_tourney_team_data(tourney_data, teams)
tourney_comp_ratings = file_utils.merge_tourney_ranking_data(tourney_data, computer_rankings)
tourney_comp_ratings = utils.implement_top_conference_feature(tourney_data, teams, game_data, tourney_comp_ratings)
tourney_comp_ratings = utils.implement_seed_threshold_feature(tourney_comp_ratings)
tourney_comp_ratings = utils.compute_delta_features(tourney_comp_ratings)

tourney_comp_ratings.dropna(inplace=True)
tourney_comp_ratings[tourney_comp_ratings.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [season_t, round, game_date, seed_t, team_t, team_id_t, win_pts, seed_o, team_o, team_id_o, lose_pts, game_result, start_season, game result, srs_t, sos_t, win_pct_t, pts_avg_t, opp_pts_avg_t, fg_pct_t, ft_pct_t, poss_avg_t, off_rebs_avg_t, def_rebs_avg_t, to_avg_t, steal_avg_t, off_rating_t, ft_att_avg_t, srs_o, sos_o, win_pct_o, pts_avg_o, opp_pts_avg_o, fg_pct_o, ft_pct_o, poss_avg_o, off_rebs_avg_o, def_rebs_avg_o, to_avg_o, steal_avg_o, off_rating_o, ft_att_avg_o, conf_name_t, conf_name_o, sag_t, wlk_t, wol_t, rth_t, col_t, pom_t, dol_t, rpi_t, mor_t, sag_o, wlk_o, wol_o, rth_o, col_o, pom_o, dol_o, rpi_o, mor_o, top_conf_t, top_conf_o, upset_seed_threshold, margin_victory_avg_t, margin_victory_avg_o, delta_margin_victory_avg, delta_fg_pct, delta_off_rebs_avg, delta_def_rebs_avg, delta_ft_pct, to_net_avg_t, to_net_avg_o, delta_to_net_avg, delta_win_pct, delta_off_rating, delta_ft_att_avg, delta_seed, delta_srs, delta_sos, delta_sag, delta_wlk, delta_wol, delta_rth, delta_col, delta_pom, delta_dol, delta_rpi, delta_mor]
# Index: []

# %%
feature_data = tourney_comp_ratings.drop(columns=['round','game_date','seed_t','team_t','team_id_t','team_id_o',
                                         'team_o','seed_o','team_id_o','game_result','start_season','game result',
                                         'conf_name_t','conf_name_o']).copy()


feature_data.head()
# Out:
#    season_t  win_pts  lose_pts  srs_t  sos_t  win_pct_t  pts_avg_t  \
# 0      2003       60        58  14.05   6.11      0.697       81.0
# 1      2003       85        55  18.54   7.76      0.758       75.0
# 2      2003       68        62  16.96   6.96      0.806       77.0
# 3      2003       65        63  12.68   8.34      0.647       70.0
# 4      2003       95        84  18.91   9.27      0.788       79.0
#
#    opp_pts_avg_t  fg_pct_t  ft_pct_t  poss_avg_t  off_rebs_avg_t  \
# 0           73.0     0.458     0.774   85.363636            11.0
# 1           64.0     0.476     0.703   76.945455            10.0
# 2           67.0     0.453     0.752   83.167742            14.0
# 3           65.0     0.465     0.660   79.558824            12.0
# 4           69.0     0.446     0.721   85.248485            16.0
#
#    def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  srs_o  \
# 0            24.0      15.0          7.0     94.888179          20.0  11.00
# 1            24.0      13.0          7.0     97.471645          18.0  -1.65
# 2            26.0      15.0          6.0     92.583973          26.0  12.68
# 3            23.0      15.0          7.0     87.985213          20.0  14.61
# 4            25.0      13.0          6.0     92.670269          24.0  19.02
#
#    sos_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  ft_pct_o  poss_avg_o  \
# 0   5.25      0.758       66.0           60.0     0.451     0.711   71.333333
# 1  -6.87      0.767       72.0           65.0     0.459     0.705   79.620000
# 2   8.34      0.647       70.0           65.0     0.465     0.660   79.558824
# 3   3.71      0.767       70.0           59.0     0.443     0.686   75.666667
# 4   9.02      0.857       79.0           69.0     0.475     0.694   84.640000
#
#    off_rebs_avg_o  def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0            10.0            23.0      12.0          4.0     92.523364
# 1            11.0            25.0      15.0          8.0     90.429540
# 2            12.0            23.0      15.0          7.0     87.985213
# 3            11.0            24.0      12.0          7.0     92.511013
# 4            13.0            27.0      14.0          8.0     93.336484
#
#    ft_att_avg_o  sag_t  wlk_t  wol_t  rth_t  col_t  pom_t  dol_t  rpi_t  \
# 0          18.0     30   43.0     33     36   32.0   42.0   29.0   50.0
# 1          23.0      7   11.0     11     10   14.0    6.0    8.0   15.0
# 2          20.0      9    9.0      4      7    8.0   12.0    4.0    7.0
# 3          20.0     43   47.0     40     40   44.0   45.0   43.0   36.0
# 4          23.0      5    7.0      7      6    4.0    7.0    7.0    4.0
#
#    mor_t  sag_o  wlk_o  wol_o  rth_o  col_o  pom_o  dol_o  rpi_o  mor_o  \
# 0     27     38   31.0     25     34   20.0   37.0   33.0   16.0     66
# 1      7    138  102.0    115    143   87.0  134.0   93.0   91.0    169
# 2     20     43   47.0     40     40   44.0   45.0   43.0   36.0     44
# 3     44     20   16.0     27     28   27.0   18.0   22.0   27.0     38
# 4     12     12   14.0      5     12    9.0   15.0    5.0    9.0     21
#
#    top_conf_t  top_conf_o  upset_seed_threshold  margin_victory_avg_t  \
# 0           0           0                     0                   8.0
# 1           1           0                     1                  11.0
# 2           0           0                     1                  10.0
# 3           1           0                     0                   5.0
# 4           0           0                     0                  10.0
#
#    margin_victory_avg_o  delta_margin_victory_avg  delta_fg_pct  \
# 0                   6.0                       2.0         0.007
# 1                   7.0                       4.0         0.017
# 2                   5.0                       5.0        -0.012
# 3                  11.0                      -6.0         0.022
# 4                  10.0                       0.0        -0.029
#
#    delta_off_rebs_avg  delta_def_rebs_avg  delta_ft_pct  to_net_avg_t  \
# 0                 1.0                 1.0         0.063           8.0
# 1                -1.0                -1.0        -0.002           6.0
# 2                 2.0                 3.0         0.092           9.0
# 3                 1.0                -1.0        -0.026           8.0
# 4                 3.0                -2.0         0.027           7.0
#
#    to_net_avg_o  delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 0           8.0               0.0         -0.061          2.364814
# 1           7.0              -1.0         -0.009          7.042104
# 2           8.0               1.0          0.159          4.598761
# 3           5.0               3.0         -0.120         -4.525801
# 4           6.0               1.0         -0.069         -0.666215
#
#    delta_ft_att_avg  delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  \
# 0               2.0          -1       3.05       0.86         -8       12.0
# 1              -5.0         -13      20.19      14.63       -131      -91.0
# 2               6.0          -8       4.28      -1.38        -34      -38.0
# 3               0.0           3      -1.93       4.63         23       31.0
# 4               1.0          -2      -0.11       0.25         -7       -7.0
#
#    delta_wol  delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor
# 0          8          2       12.0        5.0       -4.0       34.0        -39
# 1       -104       -133      -73.0     -128.0      -85.0      -76.0       -162
# 2        -36        -33      -36.0      -33.0      -39.0      -29.0        -24
# 3         13         12       17.0       27.0       21.0        9.0          6
# 4          2         -6       -5.0       -8.0        2.0       -5.0         -9

# %%
feature_data.drop(columns=['pts_avg_t','pts_avg_o', 'opp_pts_avg_t','opp_pts_avg_o',
                                'margin_victory_avg_t', 'margin_victory_avg_o',
                                'poss_avg_t','poss_avg_o',
                                'fg_pct_t','fg_pct_o',
                                'off_rebs_avg_t','off_rebs_avg_o','def_rebs_avg_t','def_rebs_avg_o',
                                'ft_pct_t','ft_pct_o',
                                'to_avg_t','to_avg_o','steal_avg_t','steal_avg_o',
                                'to_net_avg_t','to_net_avg_o',
                                'win_pct_t','win_pct_o','off_rating_t','off_rating_o',
                                'ft_att_avg_t','ft_att_avg_o','opp_pts_avg_t','opp_pts_avg_o',
                                'srs_t','srs_o','sos_t','sos_o',
                                'sag_t','sag_o','wlk_t','wlk_o','wol_t','wol_o',
                                'rth_t','rth_o','col_t','col_o','pom_t','pom_o',
                                'dol_t','dol_o','rpi_t','rpi_o','mor_t','mor_o'], inplace=True)


# for now drop the delta seed features
feature_data.drop(columns=['upset_seed_threshold'], inplace=True)
feature_data.head()
# Out:
#    season_t  win_pts  lose_pts  top_conf_t  top_conf_o  \
# 0      2003       60        58           0           0
# 1      2003       85        55           1           0
# 2      2003       68        62           0           0
# 3      2003       65        63           1           0
# 4      2003       95        84           0           0
#
#    delta_margin_victory_avg  delta_fg_pct  delta_off_rebs_avg  \
# 0                       2.0         0.007                 1.0
# 1                       4.0         0.017                -1.0
# 2                       5.0        -0.012                 2.0
# 3                      -6.0         0.022                 1.0
# 4                       0.0        -0.029                 3.0
#
#    delta_def_rebs_avg  delta_ft_pct  delta_to_net_avg  delta_win_pct  \
# 0                 1.0         0.063               0.0         -0.061
# 1                -1.0        -0.002              -1.0         -0.009
# 2                 3.0         0.092               1.0          0.159
# 3                -1.0        -0.026               3.0         -0.120
# 4                -2.0         0.027               1.0         -0.069
#
#    delta_off_rating  delta_ft_att_avg  delta_seed  delta_srs  delta_sos  \
# 0          2.364814               2.0          -1       3.05       0.86
# 1          7.042104              -5.0         -13      20.19      14.63
# 2          4.598761               6.0          -8       4.28      -1.38
# 3         -4.525801               0.0           3      -1.93       4.63
# 4         -0.666215               1.0          -2      -0.11       0.25
#
#    delta_sag  delta_wlk  delta_wol  delta_rth  delta_col  delta_pom  \
# 0         -8       12.0          8          2       12.0        5.0
# 1       -131      -91.0       -104       -133      -73.0     -128.0
# 2        -34      -38.0        -36        -33      -36.0      -33.0
# 3         23       31.0         13         12       17.0       27.0
# 4         -7       -7.0          2         -6       -5.0       -8.0
#
#    delta_dol  delta_rpi  delta_mor
# 0       -4.0       34.0        -39
# 1      -85.0      -76.0       -162
# 2      -39.0      -29.0        -24
# 3       21.0        9.0          6
# 4        2.0       -5.0         -9

# %%
X= feature_data[feature_data['season_t']<= stop_tournament]
y=tourney_comp_ratings[tourney_comp_ratings['season_t']<= stop_tournament]['game_result']
X= X.drop(columns=['season_t'])

feature_list = list(X)
feature_list
# Out:
# ['win_pts',
#  'lose_pts',
#  'top_conf_t',
#  'top_conf_o',
#  'delta_margin_victory_avg',
#  'delta_fg_pct',
#  'delta_off_rebs_avg',
#  'delta_def_rebs_avg',
#  'delta_ft_pct',
#  'delta_to_net_avg',
#  'delta_win_pct',
#  'delta_off_rating',
#  'delta_ft_att_avg',
#  'delta_seed',
#  'delta_srs',
#  'delta_sos',
#  'delta_sag',
#  'delta_wlk',
#  'delta_wol',
#  'delta_rth',
#  'delta_col',
#  'delta_pom',
#  'delta_dol',
#  'delta_rpi',
#  'delta_mor']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
X_train.head()
# Out:
# (782, 25)
# (782,)
# (196, 25)
# (196,)
#      win_pts  lose_pts  top_conf_t  top_conf_o  delta_margin_victory_avg  \
# 784       92        75           0           1                      -3.0
# 125       70        65           0           1                       8.0
# 236       62        54           0           0                       3.0
# 719       78        65           0           0                       0.0
# 808       57        56           1           0                       0.0
#
#      delta_fg_pct  delta_off_rebs_avg  delta_def_rebs_avg  delta_ft_pct  \
# 784        -0.015                 0.0                -1.0         0.062
# 125         0.011                -2.0                 0.0        -0.039
# 236         0.022                -4.0                -3.0         0.071
# 719        -0.010                 0.0                -2.0        -0.016
# 808        -0.046                 5.0                 2.0        -0.051
#
#      delta_to_net_avg  delta_win_pct  delta_off_rating  delta_ft_att_avg  \
# 784               2.0         -0.055         -3.232509              -1.0
# 125              -1.0          0.262          8.822234              -1.0
# 236              -3.0          0.139         12.896390               4.0
# 719               1.0          0.043         -2.544287              -4.0
# 808               4.0         -0.008         -7.831221               1.0
#
#      delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 784           3     -10.13      -6.65         97      106.0         98
# 125          -7       5.32      -3.24        -24      -33.0        -25
# 236          -3       4.23       0.00        -11      -11.0        -15
# 719           0      -1.24       0.41          8        1.0          3
# 808         -11      12.38      11.36        -64      -66.0        -58
#
#      delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor
# 784         94       88.0       80.0      103.0       81.0        102
# 125        -25      -28.0      -24.0      -30.0      -27.0        -19
# 236        -13      -14.0      -12.0      -18.0      -12.0        -14
# 719          2       -4.0      -16.0       12.0      -14.0         -7
# 808        -98      -79.0      -56.0      -78.0      -43.0        -73

# %% [markdown]
# #### Baseline Model

# %%
tree_count =2000

rf_classifier: RandomForestClassifier = RandomForestClassifier(tree_count, max_features='sqrt',
                                                                   min_samples_split=10, min_samples_leaf=2,
                                                                   max_depth=10, random_state=0)
    
rf_classifier.fit(X_train, y_train)
score = rf_classifier.score(X_train, y_train)
print("Training Model Score= ", score)
# Out:
# Training Model Score=  0.9616368286445013

# %%
importances = rf_classifier.feature_importances_
important_features = utils.display_important_features(importances, X_train)
# Out:
# Coefficient Values
# delta_srs   0.1676170927063868
# delta_pom   0.06946648436528038
# delta_rth   0.06727098331743066
# delta_win_pct   0.06583599768060824
# delta_sag   0.06490791994485313
# delta_mor   0.05730980907849232
# delta_wlk   0.05711339179953795
# delta_sos   0.05582226910410517
# delta_dol   0.04671863481054626
# delta_col   0.04035562802219272
# delta_wol   0.038750511790967924
# delta_seed   0.031367460247830575
# delta_rpi   0.03086392662728799
# win_pts   0.02751041999581406
# delta_ft_pct   0.02539754220555252
# delta_off_rating   0.024548925799309024
# delta_fg_pct   0.022759486894317966
# lose_pts   0.021207936267989703
# delta_margin_victory_avg   0.020179101403026214
# delta_to_net_avg   0.016512292094509884
# delta_ft_att_avg   0.016207773250348174
# delta_off_rebs_avg   0.013667866940074174
# delta_def_rebs_avg   0.011612054442931794
# top_conf_o   0.004129434318784434
# top_conf_t   0.0028670568918218566

# %%
y_pred = rf_classifier.predict(X_test)

# %%
utils.display_confusion_matrix(y_test, y_pred)
# Out:
# array([[58, 31],
#        [32, 75]], dtype=int64)

# %%
prediction_probabilities = rf_classifier.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.6785714285714286
# Precision: 0.7075471698113207
# Recall: 0.7009345794392523
# Log loss=  0.5890514019606105

# %%
cross_val_scores = cross_val_score(rf_classifier, X,y, cv=10, scoring='accuracy')
print("Baseline Cross Validation average= ",cross_val_scores.mean())
# Out:
# Baseline Cross Validation average=  0.7516305491268672

# %%
train_sizes, train_scores, test_scores = learning_curve(rf_classifier, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# %%
# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Model Feature Optimization

# %%
model_stats = eliminate_features(rf_classifier, X,y)
# Out:
# Iteration=  0
# least_important label=  top_conf_t
# Iteration=  1
# least_important label=  top_conf_o
# Iteration=  2
# least_important label=  delta_def_rebs_avg
# Iteration=  3
# least_important label=  delta_off_rebs_avg
# Iteration=  4
# least_important label=  delta_ft_att_avg
# Iteration=  5
# least_important label=  delta_to_net_avg
# Iteration=  6
# least_important label=  delta_margin_victory_avg
# Iteration=  7
# least_important label=  lose_pts
# Iteration=  8
# least_important label=  delta_fg_pct
# Iteration=  9
# least_important label=  delta_off_rating
# Iteration=  10
# least_important label=  delta_ft_pct
# Iteration=  11
# least_important label=  win_pts
# Iteration=  12
# least_important label=  delta_rpi
# Iteration=  13
# least_important label=  delta_seed
# Iteration=  14
# least_important label=  delta_wol
# Iteration=  15
# least_important label=  delta_col
# Iteration=  16
# least_important label=  delta_dol
# Iteration=  17
# least_important label=  delta_sos
# Iteration=  18
# least_important label=  delta_wlk
# Iteration=  19
# least_important label=  delta_mor
# Iteration=  20
# least_important label=  delta_sag
# Iteration=  21
# least_important label=  delta_win_pct
# Iteration=  22
# least_important label=  delta_rth
# Iteration=  23
# least_important label=  delta_pom
# Iteration=  24
# least_important label=  delta_srs

# %%
max_accuracy = 0
max_cross_val = 0
min_log_loss = 10000
for key, value in model_stats.items():
    accuracy = value['accuracy']
    cross_val = value['cross_validation']
    log_loss_val = value['log_loss']
    print('Accuracy= {0:6.4f} Cross Val= {1:6.4f}  Log Loss= {2:6.4f}'.format(accuracy ,cross_val, log_loss_val ))
    if accuracy > max_accuracy:
        max_accuracy = accuracy
        accuracy_hash = key
    if cross_val > max_cross_val:
        max_cross_val = cross_val
        cross_hash = key
    if log_loss_val < min_log_loss:
        min_log_loss = log_loss_val
        log_hash = key

print("\n")

print('Max Accuracy= {0:6.4f}'.format( model_stats[accuracy_hash]['accuracy']))
print('Max Cross Validation= {0:6.4f}'.format( model_stats[cross_hash]['cross_validation']))
print ("Minimum Log Loss= {0:6.4f}".format(  model_stats[log_hash]['log_loss']))
print('Log Loss at Max Accuracy= {0:6.4f}'.format( model_stats[accuracy_hash]['log_loss'] ))
print('Log Loss at Max Cross Validation= {0:6.4f} '.format( model_stats[cross_hash]['log_loss'] ))
# Out:
# Accuracy= 0.6786 Cross Val= 0.7516  Log Loss= 0.5891
# Accuracy= 0.6633 Cross Val= 0.7465  Log Loss= 0.5889
# Accuracy= 0.6735 Cross Val= 0.7434  Log Loss= 0.5913
# Accuracy= 0.6684 Cross Val= 0.7485  Log Loss= 0.5918
# Accuracy= 0.6684 Cross Val= 0.7516  Log Loss= 0.5891
# Accuracy= 0.6684 Cross Val= 0.7557  Log Loss= 0.5888
# Accuracy= 0.6786 Cross Val= 0.7608  Log Loss= 0.5924
# Accuracy= 0.6786 Cross Val= 0.7598  Log Loss= 0.5921
# Accuracy= 0.6786 Cross Val= 0.7628  Log Loss= 0.6035
# Accuracy= 0.6786 Cross Val= 0.7608  Log Loss= 0.5976
# Accuracy= 0.6735 Cross Val= 0.7608  Log Loss= 0.5970
# Accuracy= 0.6735 Cross Val= 0.7720  Log Loss= 0.6055
# Accuracy= 0.6633 Cross Val= 0.7720  Log Loss= 0.5983
# Accuracy= 0.6582 Cross Val= 0.7771  Log Loss= 0.5986
# Accuracy= 0.6786 Cross Val= 0.7792  Log Loss= 0.5997
# Accuracy= 0.6735 Cross Val= 0.7812  Log Loss= 0.5959
# Accuracy= 0.6939 Cross Val= 0.7782  Log Loss= 0.5974
# Accuracy= 0.6888 Cross Val= 0.7771  Log Loss= 0.5992
# Accuracy= 0.6480 Cross Val= 0.7363  Log Loss= 0.6156
# Accuracy= 0.6531 Cross Val= 0.7485  Log Loss= 0.6280
# Accuracy= 0.6582 Cross Val= 0.7424  Log Loss= 0.6439
# Accuracy= 0.6684 Cross Val= 0.7434  Log Loss= 0.6479
# Accuracy= 0.6684 Cross Val= 0.7577  Log Loss= 0.8180
# Accuracy= 0.6531 Cross Val= 0.7434  Log Loss= 0.8489
# Accuracy= 0.6837 Cross Val= 0.7280  Log Loss= 1.0557
#
#
# Max Accuracy= 0.6939
# Max Cross Validation= 0.7812
# Minimum Log Loss= 0.5888
# Log Loss at Max Accuracy= 0.5974
# Log Loss at Max Cross Validation= 0.5959

# %%
model_features = model_stats[cross_hash]['labels']
print(model_features)
# Out:
# ['delta_win_pct', 'delta_srs', 'delta_sos', 'delta_sag', 'delta_wlk', 'delta_rth', 'delta_col', 'delta_pom', 'delta_dol', 'delta_mor']

# %%
X=X[model_features]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
rf_classifier.fit(X_train, y_train)



train_sizes, train_scores, test_scores = learning_curve(rf_classifier, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))


train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
y_pred = rf_classifier.predict(X_test)
# save model stats
prediction_probabilities = rf_classifier.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
cross_val_scores = cross_val_score(rf_classifier, X,y, cv=10, scoring='accuracy')
print("Cross Validation: ", cross_val_scores.mean())
utils.display_confusion_matrix(y_test, y_pred)
# Out:
# Accuracy: 0.673469387755102
# Precision: 0.7047619047619048
# Recall: 0.6915887850467289
# Log loss=  0.595865001258662
# Cross Validation:  0.781222385861561
# array([[58, 31],
#        [33, 74]], dtype=int64)

# %%
missed_predictions = get_missed_predictions(tourney_comp_ratings, prediction_probabilities, X_test, y_test, y_pred)
missed_predictions
# Out:
#                                        Purdue      Virginia Commonwealth     Stat Supports Winner
# Net Turnover Avg                 4.00                               3.00         True  (L)
# FT ATT Avg                      19.00                              20.00         True  (H)
# Takeaway Avg                     6.00                               8.00         True  (H)
# Seed                              3                                 11          False  (L)
# SAG                              9.00                              77.00        False  (L)
# WLK                              8.00                              55.00        False  (L)
# WOL                             10.00                              54.00        False  (L)
# RTH                              9.00                              74.00        False  (L)
# COL                             13.00                              59.00        False  (L)
# POM                              8.00                              84.00        False  (L)
# DOL                              8.00                              72.00        False  (L)
# RPI                             12.00                              49.00        False  (L)
# MOR                             10.00                              80.00        False  (L)
# Allow PPG                       61.00                              66.00        False  (L)
# Turnover Avg                    10.00                              11.00        False  (L)
# SRS                             19.36                               8.56        False  (H)
# SOS                              8.69                               3.78        False  (H)
# PPG                             72.00                              71.00        False  (H)
# Poss Avg                        75.89                              75.24        False  (H)
# FG %                            44.70                              43.40        False  (H)
# Off Rb Avg                      11.00                              10.00        False  (H)
# Def Rb Avg                      24.00                              21.00        False  (H)
# FT %                            71.50                              71.50        False  (H)
# Margin Victory Avg              11.00                               5.00        False  (H)
# Win %                           76.50                              70.00        False  (H)
# Off Rating                      94.88                              94.36        False  (H)
#
#
# Top Conference=  Purdue
#
#  Virginia Commonwealth Wins.
#
# Supporting Stat Count= 3  out of 26  stats.
#
#
#
#                                        Kansas                   Bucknell     Stat Supports Winner
# Allow PPG                       65.00                              58.00         True  (L)
# FT %                            69.50                              70.10         True  (H)
# Takeaway Avg                     6.00                               7.00         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              9.00                             114.00        False  (L)
# WLK                              7.00                              97.00        False  (L)
# WOL                             10.00                              84.00        False  (L)
# RTH                              7.00                             137.00        False  (L)
# COL                              4.00                             102.00        False  (L)
# POM                             12.00                             110.00        False  (L)
# DOL                              8.00                              87.00        False  (L)
# RPI                              1.00                              64.00        False  (L)
# MOR                             19.00                             151.00        False  (L)
# Turnover Avg                    14.00                              15.00        False  (L)
# Net Turnover Avg                 8.00                               8.00        False  (L)
# SRS                             20.68                               2.12        False  (H)
# SOS                             10.85                              -2.19        False  (H)
# PPG                             75.00                              63.00        False  (H)
# Poss Avg                        79.22                              71.57        False  (H)
# FG %                            47.60                              44.40        False  (H)
# Off Rb Avg                      11.00                               9.00        False  (H)
# Def Rb Avg                      25.00                              22.00        False  (H)
# FT ATT Avg                      21.00                              20.00        False  (H)
# Margin Victory Avg              10.00                               5.00        False  (H)
# Win %                           76.70                              69.70        False  (H)
# Off Rating                      94.67                              88.03        False  (H)
#
#
# Top Conference=  Kansas
#
#  Bucknell Wins.
#
# Supporting Stat Count= 3  out of 26  stats.
#
#
#
#                                   Wake Forest              West Virginia     Stat Supports Winner
# Allow PPG                       73.00                              67.00         True  (L)
# Turnover Avg                    14.00                              11.00         True  (L)
# Net Turnover Avg                 6.00                               3.00         True  (L)
# FT %                            68.40                              74.20         True  (H)
# Seed                              2                                  7          False  (L)
# SAG                              4.00                              38.00        False  (L)
# WLK                              4.00                              39.00        False  (L)
# WOL                              3.00                              28.00        False  (L)
# RTH                              4.00                              32.00        False  (L)
# COL                              6.00                              34.00        False  (L)
# POM                              5.00                              35.00        False  (L)
# DOL                              3.00                              30.00        False  (L)
# RPI                              7.00                              34.00        False  (L)
# MOR                              5.00                              30.00        False  (L)
# SRS                             20.24                              11.76        False  (H)
# SOS                             10.27                               7.62        False  (H)
# PPG                             84.00                              71.00        False  (H)
# Poss Avg                        85.22                              73.78        False  (H)
# FG %                            49.10                              45.00        False  (H)
# Off Rb Avg                      14.00                               9.00        False  (H)
# Def Rb Avg                      25.00                              20.00        False  (H)
# FT ATT Avg                      27.00                              17.00        False  (H)
# Takeaway Avg                     8.00                               8.00        False  (H)
# Margin Victory Avg              11.00                               4.00        False  (H)
# Win %                           81.80                              68.60        False  (H)
# Off Rating                      98.56                              96.23        False  (H)
#
#  West Virginia Wins.
#
# Supporting Stat Count= 4  out of 26  stats.
#
#
#
#                                    Georgetown         Florida Gulf Coast     Stat Supports Winner
# PPG                             64.00                              72.00         True  (H)
# Poss Avg                        71.05                              79.77         True  (H)
# FG %                            45.30                              46.20         True  (H)
# Off Rb Avg                       9.00                              11.00         True  (H)
# Def Rb Avg                      20.00                              22.00         True  (H)
# FT ATT Avg                      18.00                              19.00         True  (H)
# Takeaway Avg                     7.00                               8.00         True  (H)
# Off Rating                      90.08                              90.26         True  (H)
# Seed                              2                                 15          False  (L)
# SAG                              9.00                             126.00        False  (L)
# WLK                             11.00                             124.00        False  (L)
# WOL                              7.00                             113.00        False  (L)
# RTH                              8.00                             146.00        False  (L)
# COL                              9.00                             115.00        False  (L)
# POM                             12.00                             126.00        False  (L)
# DOL                              9.00                             120.00        False  (L)
# RPI                             11.00                              93.00        False  (L)
# MOR                             11.00                             110.00        False  (L)
# Allow PPG                       56.00                              66.00        False  (L)
# Turnover Avg                    12.00                              14.00        False  (L)
# Net Turnover Avg                 5.00                               6.00        False  (L)
# SRS                             15.84                               2.76        False  (H)
# SOS                              7.59                              -2.07        False  (H)
# FT %                            67.90                              67.50        False  (H)
# Margin Victory Avg               8.00                               6.00        False  (H)
# Win %                           78.10                              70.30        False  (H)
#
#
# Top Conference=  Georgetown
#
#  Florida Gulf Coast Wins.
#
# Supporting Stat Count= 8  out of 26  stats.
#
#
#
#                                   Connecticut               George Mason     Stat Supports Winner
# Allow PPG                       67.00                              60.00         True  (L)
# Turnover Avg                    14.00                              12.00         True  (L)
# Net Turnover Avg                 8.00                               5.00         True  (L)
# FG %                            47.30                              48.10         True  (H)
# Takeaway Avg                     6.00                               7.00         True  (H)
# Seed                              1                                 11          False  (L)
# SAG                              2.00                              38.00        False  (L)
# WLK                              2.00                              25.00        False  (L)
# WOL                              2.00                              37.00        False  (L)
# RTH                              2.00                              53.00        False  (L)
# COL                              3.00                              45.00        False  (L)
# POM                              2.00                              28.00        False  (L)
# DOL                              2.00                              43.00        False  (L)
# RPI                              3.00                              26.00        False  (L)
# MOR                              2.00                              75.00        False  (L)
# SRS                             21.22                              12.11        False  (H)
# SOS                              6.57                               2.77        False  (H)
# PPG                             81.00                              69.00        False  (H)
# Poss Avg                        86.08                              73.44        False  (H)
# Off Rb Avg                      15.00                              10.00        False  (H)
# Def Rb Avg                      28.00                              24.00        False  (H)
# FT ATT Avg                      25.00                              18.00        False  (H)
# FT %                            70.60                              66.40        False  (H)
# Margin Victory Avg              14.00                               9.00        False  (H)
# Win %                           88.20                              77.10        False  (H)
# Off Rating                      94.10                              93.95        False  (H)
#
#
# Top Conference=  Connecticut
#
#  George Mason Wins.
#
# Supporting Stat Count= 5  out of 26  stats.
#
#
#
#                                 West Virginia          Stephen F. Austin     Stat Supports Winner
# Allow PPG                       66.00                              63.00         True  (L)
# Turnover Avg                    14.00                              12.00         True  (L)
# Net Turnover Avg                 5.00                               3.00         True  (L)
# PPG                             78.00                              80.00         True  (H)
# FG %                            44.90                              47.80         True  (H)
# FT %                            67.30                              73.50         True  (H)
# Margin Victory Avg              12.00                              17.00         True  (H)
# Win %                           74.30                              82.40         True  (H)
# Off Rating                      91.34                              99.88         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              6.00                              57.00        False  (L)
# WLK                              6.00                              55.00        False  (L)
# WOL                              8.00                              62.00        False  (L)
# RTH                              8.00                             101.00        False  (L)
# COL                             11.00                              83.00        False  (L)
# POM                              6.00                              33.00        False  (L)
# DOL                              7.00                              80.00        False  (L)
# RPI                             10.00                              62.00        False  (L)
# MOR                             11.00                              36.00        False  (L)
# SRS                             21.61                               9.23        False  (H)
# SOS                              9.78                              -5.47        False  (H)
# Poss Avg                        85.39                              80.10        False  (H)
# Off Rb Avg                      15.00                              11.00        False  (H)
# Def Rb Avg                      23.00                              23.00        False  (H)
# FT ATT Avg                      27.00                              20.00        False  (H)
# Takeaway Avg                     9.00                               9.00        False  (H)
#
#
# Top Conference=  West Virginia
#
#  Stephen F. Austin Wins.
#
# Supporting Stat Count= 9  out of 26  stats.
#
#
#
#                                     Villanova       North Carolina State     Stat Supports Winner
# SOS                              7.55                               9.72         True  (H)
# Poss Avg                        73.86                              75.55         True  (H)
# Off Rb Avg                      10.00                              12.00         True  (H)
# Def Rb Avg                      24.00                              25.00         True  (H)
# Seed                              1                                  8          False  (L)
# SAG                              6.00                              32.00        False  (L)
# WLK                              4.00                              33.00        False  (L)
# WOL                              2.00                              40.00        False  (L)
# RTH                              2.00                              32.00        False  (L)
# COL                              2.00                              40.00        False  (L)
# POM                              5.00                              38.00        False  (L)
# DOL                              2.00                              40.00        False  (L)
# RPI                              2.00                              39.00        False  (L)
# MOR                              4.00                              22.00        False  (L)
# Allow PPG                       60.00                              65.00        False  (L)
# Turnover Avg                    10.00                              10.00        False  (L)
# Net Turnover Avg                 3.00                               7.00        False  (L)
# SRS                             23.13                              14.11        False  (H)
# PPG                             76.00                              70.00        False  (H)
# FG %                            47.00                              43.60        False  (H)
# FT ATT Avg                      22.00                              20.00        False  (H)
# FT %                            73.10                              68.60        False  (H)
# Takeaway Avg                     7.00                               3.00        False  (H)
# Margin Victory Avg              16.00                               5.00        False  (H)
# Win %                           91.70                              61.10        False  (H)
# Off Rating                     102.90                              92.65        False  (H)
#
#  North Carolina State Wins.
#
# Supporting Stat Count= 4  out of 26  stats.
#
#
#
#                                          Duke                     Mercer     Stat Supports Winner
# Allow PPG                       67.00                              66.00         True  (L)
# Poss Avg                        76.03                              77.71         True  (H)
# FG %                            46.00                              47.60         True  (H)
# Def Rb Avg                      22.00                              25.00         True  (H)
# FT %                            72.90                              73.60         True  (H)
# Margin Victory Avg              11.00                              12.00         True  (H)
# Win %                           74.30                              75.00         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              7.00                              89.00        False  (L)
# WLK                              8.00                              97.00        False  (L)
# WOL                             15.00                              90.00        False  (L)
# RTH                              9.00                             124.00        False  (L)
# COL                             14.00                              93.00        False  (L)
# POM                              6.00                              95.00        False  (L)
# DOL                             14.00                             100.00        False  (L)
# RPI                              9.00                              81.00        False  (L)
# MOR                              8.00                              94.00        False  (L)
# Turnover Avg                     9.00                              11.00        False  (L)
# Net Turnover Avg                 3.00                               6.00        False  (L)
# SRS                             19.51                               5.33        False  (H)
# SOS                              8.48                              -3.42        False  (H)
# PPG                             78.00                              78.00        False  (H)
# Off Rb Avg                      11.00                              11.00        False  (H)
# FT ATT Avg                      22.00                              21.00        False  (H)
# Takeaway Avg                     6.00                               5.00        False  (H)
# Off Rating                     102.59                             100.38        False  (H)
#
#
# Top Conference=  Duke
#
#  Mercer Wins.
#
# Supporting Stat Count= 7  out of 26  stats.
#
#
#
#                                    Louisville                   Kentucky     Stat Supports Winner
# RPI                             19.00                              17.00         True  (L)
# SOS                              4.80                               9.90         True  (H)
# Off Rb Avg                      13.00                              14.00         True  (H)
# Def Rb Avg                      24.00                              26.00         True  (H)
# FT ATT Avg                      24.00                              28.00         True  (H)
# FT %                            66.10                              68.20         True  (H)
# Seed                              4                                  8          False  (L)
# SAG                              2.00                              18.00        False  (L)
# WLK                              2.00                              16.00        False  (L)
# WOL                             11.00                              33.00        False  (L)
# RTH                              8.00                              19.00        False  (L)
# COL                             16.00                              22.00        False  (L)
# POM                              2.00                              17.00        False  (L)
# DOL                             13.00                              25.00        False  (L)
# MOR                              1.00                              26.00        False  (L)
# Allow PPG                       61.00                              66.00        False  (L)
# Turnover Avg                    10.00                              11.00        False  (L)
# Net Turnover Avg                 0.00                               7.00        False  (L)
# SRS                             24.69                              18.07        False  (H)
# PPG                             81.00                              74.00        False  (H)
# Poss Avg                        80.84                              78.51        False  (H)
# FG %                            47.10                              45.40        False  (H)
# Takeaway Avg                    10.00                               4.00        False  (H)
# Margin Victory Avg              20.00                               8.00        False  (H)
# Win %                           83.80                              72.50        False  (H)
# Off Rating                     100.20                              94.26        False  (H)
#
#  Kentucky Wins.
#
# Supporting Stat Count= 6  out of 26  stats.
#
#
#
#                                       Alabama                  Milwaukee     Stat Supports Winner
# Allow PPG                       65.00                              64.00         True  (L)
# Net Turnover Avg                 7.00                               5.00         True  (L)
# Poss Avg                        74.90                              80.15         True  (H)
# Off Rb Avg                      10.00                              13.00         True  (H)
# Takeaway Avg                     5.00                               8.00         True  (H)
# Margin Victory Avg              10.00                              11.00         True  (H)
# Win %                           75.00                              81.30         True  (H)
# Seed                              5                                 12          False  (L)
# SAG                             16.00                              36.00        False  (L)
# WLK                             16.00                              38.00        False  (L)
# WOL                             20.00                              40.00        False  (L)
# RTH                             20.00                              60.00        False  (L)
# COL                             20.00                              45.00        False  (L)
# POM                             18.00                              42.00        False  (L)
# DOL                             15.00                              35.00        False  (L)
# RPI                             17.00                              58.00        False  (L)
# MOR                             11.00                              56.00        False  (L)
# Turnover Avg                    12.00                              13.00        False  (L)
# SRS                             16.74                              10.41        False  (H)
# SOS                              6.81                               1.44        False  (H)
# PPG                             75.00                              75.00        False  (H)
# FG %                            48.30                              44.70        False  (H)
# Def Rb Avg                      26.00                              22.00        False  (H)
# FT ATT Avg                      22.00                              21.00        False  (H)
# FT %                            73.60                              70.30        False  (H)
# Off Rating                     100.13                              93.57        False  (H)
#
#
# Top Conference=  Alabama
#
#  Milwaukee Wins.
#
# Supporting Stat Count= 7  out of 26  stats.
#
#
#
#                                          Duke                Connecticut     Stat Supports Winner
# Allow PPG                       65.00                              63.00         True  (L)
# Poss Avg                        81.84                              83.75         True  (H)
# FG %                            47.10                              48.00         True  (H)
# Off Rb Avg                      12.00                              15.00         True  (H)
# Def Rb Avg                      23.00                              29.00         True  (H)
# Margin Victory Avg              14.00                              15.00         True  (H)
# Win %                           83.80                              84.60         True  (H)
# Seed                              1                                  2          False  (L)
# SAG                              1.00                               7.00        False  (L)
# WLK                              2.00                               9.00        False  (L)
# WOL                              3.00                               8.00        False  (L)
# RTH                              1.00                              10.00        False  (L)
# COL                              2.00                               9.00        False  (L)
# POM                              1.00                               8.00        False  (L)
# DOL                              3.00                              10.00        False  (L)
# RPI                              1.00                               5.00        False  (L)
# MOR                              1.00                               3.00        False  (L)
# Turnover Avg                    13.00                              13.00        False  (L)
# Net Turnover Avg                 4.00                               8.00        False  (L)
# SRS                             25.67                              22.64        False  (H)
# SOS                             10.86                               7.77        False  (H)
# PPG                             79.00                              78.00        False  (H)
# FT ATT Avg                      24.00                              21.00        False  (H)
# FT %                            73.60                              62.30        False  (H)
# Takeaway Avg                     9.00                               5.00        False  (H)
# Off Rating                      96.53                              93.14        False  (H)
#
#  Connecticut Wins.
#
# Supporting Stat Count= 7  out of 26  stats.
#
#
#
#                                      Syracuse                     Dayton     Stat Supports Winner
# PPG                             67.00                              72.00         True  (H)
# Poss Avg                        72.50                              75.34         True  (H)
# FG %                            43.70                              46.30         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# FT ATT Avg                      21.00                              22.00         True  (H)
# Off Rating                      92.41                              95.57         True  (H)
# Seed                              3                                 11          False  (L)
# SAG                             19.00                              58.00        False  (L)
# WLK                             18.00                              54.00        False  (L)
# WOL                              5.00                              44.00        False  (L)
# RTH                              5.00                              56.00        False  (L)
# COL                              8.00                              40.00        False  (L)
# POM                             14.00                              51.00        False  (L)
# DOL                              9.00                              56.00        False  (L)
# RPI                             16.00                              43.00        False  (L)
# MOR                             21.00                              56.00        False  (L)
# Allow PPG                       59.00                              66.00        False  (L)
# Turnover Avg                     9.00                              11.00        False  (L)
# Net Turnover Avg                 2.00                               5.00        False  (L)
# SRS                             16.05                              10.55        False  (H)
# SOS                              7.25                               5.34        False  (H)
# Off Rb Avg                      13.00                              11.00        False  (H)
# FT %                            70.80                              68.10        False  (H)
# Takeaway Avg                     7.00                               6.00        False  (H)
# Margin Victory Avg               8.00                               6.00        False  (H)
# Win %                           82.40                              70.30        False  (H)
#
#
# Top Conference=  Syracuse
#
#  Dayton Wins.
#
# Supporting Stat Count= 6  out of 26  stats.
#
#
#
#                                     Wisconsin                    Cornell     Stat Supports Winner
# WOL                             28.00                              20.00         True  (L)
# PPG                             67.00                              76.00         True  (H)
# Poss Avg                        68.67                              74.21         True  (H)
# FG %                            44.30                              48.20         True  (H)
# Off Rb Avg                       9.00                              10.00         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# Takeaway Avg                     5.00                               7.00         True  (H)
# Margin Victory Avg              11.00                              12.00         True  (H)
# Win %                           72.70                              85.30         True  (H)
# Off Rating                      97.56                             102.41         True  (H)
# Seed                              4                                 12          False  (L)
# SAG                             14.00                              52.00        False  (L)
# WLK                             17.00                              47.00        False  (L)
# RTH                             13.00                              62.00        False  (L)
# COL                             22.00                              49.00        False  (L)
# POM                              3.00                              66.00        False  (L)
# DOL                             18.00                              37.00        False  (L)
# RPI                             21.00                              46.00        False  (L)
# MOR                              5.00                              70.00        False  (L)
# Allow PPG                       56.00                              64.00        False  (L)
# Turnover Avg                     8.00                              12.00        False  (L)
# Net Turnover Avg                 3.00                               5.00        False  (L)
# SRS                             17.84                               8.76        False  (H)
# SOS                              7.66                              -0.91        False  (H)
# FT ATT Avg                      17.00                              15.00        False  (H)
# FT %                            73.20                              73.00        False  (H)
#
#
# Top Conference=  Wisconsin
#
#  Cornell Wins.
#
# Supporting Stat Count= 10  out of 26  stats.
#
#
#
#                                       Gonzaga              Wichita State     Stat Supports Winner
# SOS                              4.18                               6.09         True  (H)
# Poss Avg                        75.37                              76.27         True  (H)
# Off Rb Avg                      11.00                              13.00         True  (H)
# Seed                              1                                  9          False  (L)
# SAG                              6.00                              42.00        False  (L)
# WLK                              5.00                              31.00        False  (L)
# WOL                              1.00                              38.00        False  (L)
# RTH                              3.00                              43.00        False  (L)
# COL                              5.00                              34.00        False  (L)
# POM                              4.00                              33.00        False  (L)
# DOL                              1.00                              33.00        False  (L)
# RPI                              6.00                              37.00        False  (L)
# MOR                              4.00                              35.00        False  (L)
# Allow PPG                       59.00                              61.00        False  (L)
# Turnover Avg                    11.00                              12.00        False  (L)
# Net Turnover Avg                 4.00                               5.00        False  (L)
# SRS                             20.47                              14.68        False  (H)
# PPG                             77.00                              69.00        False  (H)
# FG %                            49.70                              44.00        False  (H)
# Def Rb Avg                      22.00                              21.00        False  (H)
# FT ATT Avg                      22.00                              20.00        False  (H)
# FT %                            70.50                              69.90        False  (H)
# Takeaway Avg                     7.00                               7.00        False  (H)
# Margin Victory Avg              18.00                               8.00        False  (H)
# Win %                           91.40                              76.90        False  (H)
# Off Rating                     102.17                              90.47        False  (H)
#
#
# Top Conference=  Wichita State
#
#  Wichita State Wins.
#
# Supporting Stat Count= 3  out of 26  stats.
#
#
#
#                                    Cincinnati                    Harvard     Stat Supports Winner
# PPG                             68.00                              73.00         True  (H)
# FG %                            42.50                              46.50         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# FT ATT Avg                      21.00                              25.00         True  (H)
# FT %                            70.80                              72.40         True  (H)
# Margin Victory Avg              10.00                              12.00         True  (H)
# Win %                           79.40                              84.40         True  (H)
# Off Rating                      90.20                              98.13         True  (H)
# Seed                              5                                 12          False  (L)
# SAG                             28.00                              35.00        False  (L)
# WLK                             28.00                              39.00        False  (L)
# WOL                             14.00                              34.00        False  (L)
# RTH                             17.00                              62.00        False  (L)
# COL                             19.00                              47.00        False  (L)
# POM                             24.00                              33.00        False  (L)
# DOL                             15.00                              36.00        False  (L)
# RPI                             21.00                              46.00        False  (L)
# MOR                             25.00                              37.00        False  (L)
# Allow PPG                       58.00                              61.00        False  (L)
# Turnover Avg                    11.00                              11.00        False  (L)
# Net Turnover Avg                 4.00                               4.00        False  (L)
# SRS                             15.26                              10.79        False  (H)
# SOS                              5.28                              -0.47        False  (H)
# Poss Avg                        75.39                              74.39        False  (H)
# Off Rb Avg                      13.00                              10.00        False  (H)
# Takeaway Avg                     7.00                               7.00        False  (H)
#
#
# Top Conference=  Cincinnati
#
#  Harvard Wins.
#
# Supporting Stat Count= 8  out of 26  stats.
#
#
#
#                                     Tennessee                 Louisville     Stat Supports Winner
# POM                             12.00                               7.00         True  (L)
# Allow PPG                       69.00                              61.00         True  (L)
# SRS                             18.41                              19.00         True  (H)
# SOS                              7.84                               8.00         True  (H)
# FG %                            45.80                              46.30         True  (H)
# Def Rb Avg                      23.00                              25.00         True  (H)
# Seed                              2                                  3          False  (L)
# SAG                              6.00                              11.00        False  (L)
# WLK                              6.00                              11.00        False  (L)
# WOL                              3.00                              14.00        False  (L)
# RTH                              6.00                              10.00        False  (L)
# COL                              2.00                              13.00        False  (L)
# DOL                              4.00                              18.00        False  (L)
# RPI                              1.00                              11.00        False  (L)
# MOR                              5.00                               7.00        False  (L)
# Turnover Avg                    13.00                              13.00        False  (L)
# Net Turnover Avg                 4.00                               5.00        False  (L)
# PPG                             81.00                              72.00        False  (H)
# Poss Avg                        85.40                              77.66        False  (H)
# Off Rb Avg                      13.00                              11.00        False  (H)
# FT ATT Avg                      23.00                              20.00        False  (H)
# FT %                            65.90                              64.70        False  (H)
# Takeaway Avg                     9.00                               8.00        False  (H)
# Margin Victory Avg              12.00                              11.00        False  (H)
# Win %                           86.10                              75.00        False  (H)
# Off Rating                      94.85                              92.72        False  (H)
#
#  Louisville Wins.
#
# Supporting Stat Count= 6  out of 26  stats.
#
#
#
#                                    Ohio State                      Siena     Stat Supports Winner
# RPI                             32.00                              18.00         True  (L)
# Net Turnover Avg                 8.00                               5.00         True  (L)
# PPG                             66.00                              77.00         True  (H)
# Poss Avg                        69.84                              83.62         True  (H)
# Off Rb Avg                       8.00                              12.00         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# FT ATT Avg                      18.00                              21.00         True  (H)
# Takeaway Avg                     5.00                               8.00         True  (H)
# Margin Victory Avg               4.00                               7.00         True  (H)
# Win %                           66.70                              77.10         True  (H)
# Seed                              8                                  9          False  (L)
# SAG                             25.00                              58.00        False  (L)
# WLK                             28.00                              34.00        False  (L)
# WOL                             22.00                              39.00        False  (L)
# RTH                             23.00                              63.00        False  (L)
# COL                             25.00                              33.00        False  (L)
# POM                             36.00                              65.00        False  (L)
# DOL                             26.00                              45.00        False  (L)
# MOR                             35.00                              62.00        False  (L)
# Allow PPG                       62.00                              70.00        False  (L)
# Turnover Avg                    13.00                              13.00        False  (L)
# SRS                             12.48                               8.05        False  (H)
# SOS                              8.23                               0.99        False  (H)
# FG %                            48.10                              46.70        False  (H)
# FT %                            70.10                              66.40        False  (H)
# Off Rating                      94.51                              92.09        False  (H)
#
#
# Top Conference=  Ohio State
#
#  Siena Wins.
#
# Supporting Stat Count= 10  out of 26  stats.
#
#
#
#                                    Ohio State                 Georgetown     Stat Supports Winner
# Allow PPG                       63.00                              58.00         True  (L)
# SOS                              5.90                               6.92         True  (H)
# FG %                            46.50                              46.80         True  (H)
# Seed                              2                                  7          False  (L)
# SAG                              8.00                              16.00        False  (L)
# WLK                              6.00                              19.00        False  (L)
# WOL                              7.00                              23.00        False  (L)
# RTH                              6.00                              21.00        False  (L)
# COL                              5.00                              27.00        False  (L)
# POM                              9.00                              17.00        False  (L)
# DOL                              7.00                              21.00        False  (L)
# RPI                              5.00                              36.00        False  (L)
# MOR                             12.00                              20.00        False  (L)
# Turnover Avg                    11.00                              11.00        False  (L)
# Net Turnover Avg                 5.00                               5.00        False  (L)
# SRS                             16.08                              13.98        False  (H)
# PPG                             73.00                              65.00        False  (H)
# Poss Avg                        75.39                              69.04        False  (H)
# Off Rb Avg                      10.00                              10.00        False  (H)
# Def Rb Avg                      23.00                              21.00        False  (H)
# FT ATT Avg                      18.00                              16.00        False  (H)
# FT %                            71.80                              70.60        False  (H)
# Takeaway Avg                     6.00                               6.00        False  (H)
# Margin Victory Avg              10.00                               7.00        False  (H)
# Win %                           81.30                              69.70        False  (H)
# Off Rating                      96.83                              94.15        False  (H)
#
#  Georgetown Wins.
#
# Supporting Stat Count= 3  out of 26  stats.
#
#
#
#                                    Louisville                   Michigan     Stat Supports Winner
# Turnover Avg                    11.00                               9.00         True  (L)
# Net Turnover Avg                 5.00                               4.00         True  (L)
# FG %                            45.70                              48.30         True  (H)
# FT %                            68.60                              77.90         True  (H)
# Off Rating                      95.47                             106.60         True  (H)
# Seed                              2                                  7          False  (L)
# SAG                              7.00                              23.00        False  (L)
# WLK                              6.00                              24.00        False  (L)
# WOL                             13.00                              26.00        False  (L)
# RTH                              9.00                              24.00        False  (L)
# COL                             10.00                              29.00        False  (L)
# POM                              6.00                              21.00        False  (L)
# DOL                             10.00                              26.00        False  (L)
# RPI                              7.00                              25.00        False  (L)
# MOR                              4.00                              15.00        False  (L)
# Allow PPG                       65.00                              66.00        False  (L)
# SRS                             22.47                              18.80        False  (H)
# SOS                             11.15                              10.17        False  (H)
# PPG                             77.00                              75.00        False  (H)
# Poss Avg                        80.65                              70.36        False  (H)
# Off Rb Avg                      13.00                               7.00        False  (H)
# ...
# 3           23       31.0         13         12       17.0       27.0
# 659         16       20.0         22         25        8.0       25.0
# 271         23       20.0        -10         36       40.0       54.0
# 905          1        3.0        -17         -7      -14.0       -3.0
# 337         28       29.0         37         27       27.0       18.0
# 491         19       11.0         10         21        8.0       21.0
# 749         27       28.0         33         30       33.0       28.0
# 665         -7       -6.0        -16        -16      -18.0       17.0
# 249         27       22.0         35         40       36.0       24.0
# 123         18        8.0          3          7       -8.0       11.0
# 419         17       21.0         19          2       31.0       14.0
# 921         21       14.0         26         30       21.0       10.0
# 789         15       14.0         20          5       17.0       13.0
# 557          7      -10.0        -10         20       -6.0       -2.0
# 973         27       22.0          8         30       19.0       15.0
# 507         23       23.0         18         21       17.0       28.0
# 201        -27      -15.0        -24        -18      -11.0      -25.0
# 23          29       23.0         19         36       23.0       37.0
# 583         81       78.0         62        103       93.0       66.0
# 607        175      180.0        124        169      110.0      207.0
#
#      delta_dol  delta_rpi  delta_mor  predicted_result  pred_win_prob  \
# 512      -64.0      -37.0        -70                 1       0.986514
# 128      -79.0      -63.0       -132                 1       0.957127
# 178      -27.0      -27.0        -25                 1       0.941157
# 656     -111.0      -82.0        -99                 1       0.900365
# 214      -41.0      -23.0        -73                 1       0.899981
# 852      -73.0      -52.0        -25                 1       0.857121
# 816      -38.0      -37.0        -18                 1       0.829553
# 778      -86.0      -72.0        -86                 1       0.828251
# 734      -12.0        2.0        -25                 1       0.823880
# 150      -20.0      -41.0        -45                 1       0.816813
# 106       -7.0       -4.0         -2                 1       0.774091
# 770      -47.0      -27.0        -35                 1       0.727226
# 498      -19.0      -25.0        -65                 1       0.675258
# 684      -32.0      -31.0        -31                 1       0.647580
# 752      -21.0      -25.0        -12                 1       0.647270
# 346      -14.0      -10.0         -2                 1       0.628985
# 388      -19.0       14.0        -27                 1       0.608106
# 252      -14.0      -31.0         -8                 1       0.604282
# 960      -16.0      -18.0        -11                 1       0.599532
# 290      -18.0      -11.0        -58                 1       0.598562
# 516      -30.0        6.0        -43                 1       0.597747
# 444       -9.0       -6.0         -1                 1       0.596615
# 928      -23.0      -35.0        -17                 1       0.581560
# 246       -6.0       -6.0          3                 1       0.573711
# 84        -3.0      -11.0         -2                 1       0.560952
# 536        6.0       -7.0         -8                 1       0.555002
# 480       -1.0       -4.0         -8                 1       0.528146
# 430       -8.0      -11.0         -9                 1       0.519435
# 72        -3.0      -10.0         -5                 1       0.513751
# 842       -8.0      -11.0          1                 1       0.507950
# ..         ...        ...        ...               ...            ...
# 397        8.0        3.0          9                -1       0.481946
# 319       13.0       28.0          6                -1       0.471977
# 427       -8.0      -20.0          3                -1       0.461287
# 653      -57.0      -74.0         -3                -1       0.460531
# 579        9.0       19.0        -25                -1       0.459312
# 847       -7.0      -25.0         -8                -1       0.449928
# 623        5.0        6.0         -5                -1       0.448174
# 209       48.0       42.0         65                -1       0.442393
# 593      -10.0      -16.0         -9                -1       0.423563
# 735       17.0        6.0         19                -1       0.418740
# 3         21.0        9.0          6                -1       0.412622
# 659       18.0       16.0         20                -1       0.408757
# 271       -6.0       39.0         68                -1       0.405910
# 905      -14.0      -12.0         -3                -1       0.404685
# 337       41.0       26.0         -4                -1       0.395470
# 491        8.0        7.0         18                -1       0.388598
# 749       26.0       38.0         28                -1       0.375202
# 665      -12.0      -17.0          1                -1       0.367779
# 249       38.0       22.0         36                -1       0.353966
# 123        5.0       -4.0          7                -1       0.342585
# 419       10.0       53.0         -5                -1       0.333526
# 921       27.0        5.0          4                -1       0.326778
# 789       19.0       24.0         22                -1       0.319829
# 557        7.0      -14.0          5                -1       0.308106
# 973       14.0       15.0         29                -1       0.278451
# 507       21.0       24.0         33                -1       0.267485
# 201      -10.0       -1.0        -18                -1       0.256503
# 23        12.0       24.0         60                -1       0.233739
# 583       75.0       86.0         99                -1       0.014105
# 607      123.0      118.0        229                -1       0.008850
#
#                                    supporting_features  \
# 512                           [to_net_avg, ft_att_avg]
# 128                                           [ft_pct]
# 178                               [ft_pct, to_net_avg]
# 656  [fg_pct, off_rebs_avg, def_rebs_avg, off_ratin...
# 214                               [fg_pct, to_net_avg]
# 852  [margin_victory_avg, fg_pct, ft_pct, to_net_av...
# 816                  [off_rebs_avg, def_rebs_avg, sos]
# 778  [margin_victory_avg, fg_pct, def_rebs_avg, ft_...
# 734  [off_rebs_avg, def_rebs_avg, ft_pct, ft_att_av...
# 150  [margin_victory_avg, off_rebs_avg, to_net_avg,...
# 106  [margin_victory_avg, fg_pct, off_rebs_avg, def...
# 770     [fg_pct, def_rebs_avg, off_rating, ft_att_avg]
# 498  [margin_victory_avg, fg_pct, off_rebs_avg, def...
# 684                                [off_rebs_avg, sos]
# 752  [margin_victory_avg, fg_pct, def_rebs_avg, ft_...
# 346              [fg_pct, def_rebs_avg, srs, sos, pom]
# 388  [margin_victory_avg, off_rebs_avg, def_rebs_av...
# 252                                      [fg_pct, sos]
# 960           [fg_pct, ft_pct, to_net_avg, off_rating]
# 290          [ft_pct, to_net_avg, win_pct, off_rating]
# 516     [ft_pct, to_net_avg, win_pct, off_rating, rpi]
# 444  [margin_victory_avg, ft_pct, to_net_avg, off_r...
# 928                    [off_rebs_avg, ft_att_avg, sos]
# 246                         [fg_pct, ft_pct, sos, mor]
# 84                 [fg_pct, win_pct, off_rating, seed]
# 536  [off_rebs_avg, ft_pct, win_pct, seed, sos, wol...
# 480                       [off_rebs_avg, win_pct, sos]
# 430                          [ft_pct, ft_att_avg, sos]
# 72                     [def_rebs_avg, ft_att_avg, sos]
# 842  [off_rebs_avg, to_net_avg, ft_att_avg, srs, so...
# ..                                                 ...
# 397              [fg_pct, to_net_avg, off_rating, sos]
# 319     [margin_victory_avg, to_net_avg, win_pct, pom]
# 427  [off_rebs_avg, def_rebs_avg, ft_pct, win_pct, ...
# 653  [margin_victory_avg, win_pct, srs, sag, wlk, w...
# 579    [to_net_avg, srs, sos, sag, wlk, rth, pom, mor]
# 847  [fg_pct, off_rebs_avg, def_rebs_avg, ft_pct, w...
# 623  [margin_victory_avg, fg_pct, def_rebs_avg, ft_...
# 209       [fg_pct, to_net_avg, off_rating, ft_att_avg]
# 593  [off_rebs_avg, def_rebs_avg, win_pct, ft_att_a...
# 735      [off_rebs_avg, def_rebs_avg, ft_att_avg, sos]
# 3                          [fg_pct, off_rebs_avg, sos]
# 659  [margin_victory_avg, fg_pct, off_rebs_avg, ft_...
# 271                        [fg_pct, win_pct, wol, dol]
# 905  [ft_pct, to_net_avg, win_pct, sos, wol, rth, c...
# 337                   [fg_pct, off_rebs_avg, sos, mor]
# 491          [ft_pct, to_net_avg, win_pct, ft_att_avg]
# 749                                       [to_net_avg]
# 665  [fg_pct, win_pct, ft_att_avg, seed, sag, wlk, ...
# 249                                           [ft_pct]
# 123  [margin_victory_avg, fg_pct, ft_pct, to_net_av...
# 419               [off_rebs_avg, to_net_avg, sos, mor]
# 921             [off_rebs_avg, to_net_avg, ft_att_avg]
# 789                                      [ft_pct, sos]
# 557  [margin_victory_avg, fg_pct, win_pct, off_rati...
# 973  [margin_victory_avg, fg_pct, to_net_avg, win_p...
# 507  [margin_victory_avg, fg_pct, ft_pct, win_pct, ...
# 201  [margin_victory_avg, fg_pct, def_rebs_avg, ft_...
# 23   [fg_pct, ft_pct, to_net_avg, win_pct, off_rating]
# 583           [margin_victory_avg, ft_pct, to_net_avg]
# 607           [off_rebs_avg, def_rebs_avg, ft_att_avg]
#
#                              supporting_model_features  features  \
# 512                                                 []       8.0
# 128                                                 []       4.0
# 178                                                 []       8.0
# 656                                                 []      20.0
# 214                                                 []       8.0
# 852                                          [win_pct]      24.0
# 816                                              [sos]      12.0
# 778                                          [win_pct]      20.0
# 734                                              [sos]      24.0
# 150                                          [win_pct]      16.0
# 106                                          [win_pct]      20.0
# 770                                                 []      16.0
# 498                                          [win_pct]      28.0
# 684                                              [sos]       8.0
# 752                                          [win_pct]      28.0
# 346                                    [srs, sos, pom]      20.0
# 388                                          [win_pct]      28.0
# 252                                              [sos]       8.0
# 960                                                 []      16.0
# 290                                          [win_pct]      16.0
# 516                                          [win_pct]      20.0
# 444                               [sag, wlk, rth, pom]      36.0
# 928                                              [sos]      12.0
# 246                                         [sos, mor]      16.0
# 84                                           [win_pct]      16.0
# 536                      [win_pct, sos, rth, col, dol]      36.0
# 480                                     [win_pct, sos]      12.0
# 430                                              [sos]      12.0
# 72                                               [sos]      12.0
# 842                     [srs, sos, sag, wlk, pom, mor]      36.0
# ..                                                 ...       ...
# 397                                              [sos]      16.0
# 319                                     [win_pct, pom]      16.0
# 427            [win_pct, sos, sag, wlk, rth, col, dol]      56.0
# 653  [win_pct, srs, sag, wlk, rth, col, pom, dol, mor]      48.0
# 579                [srs, sos, sag, wlk, rth, pom, mor]      32.0
# 847  [win_pct, srs, sos, sag, wlk, rth, col, pom, d...      76.0
# 623                     [srs, sos, sag, wlk, pom, mor]      44.0
# 209                                                 []      16.0
# 593                 [win_pct, sos, rth, col, dol, mor]      48.0
# 735                                              [sos]      16.0
# 3                                                [sos]      12.0
# 659                                          [win_pct]      32.0
# 271                                     [win_pct, dol]      16.0
# 905            [win_pct, sos, rth, col, pom, dol, mor]      44.0
# 337                                         [sos, mor]      16.0
# 491                                          [win_pct]      16.0
# 749                                                 []       4.0
# 665                 [win_pct, sag, wlk, rth, col, dol]      44.0
# 249                                                 []       4.0
# 123                                     [win_pct, col]      32.0
# 419                                         [sos, mor]      16.0
# 921                                                 []      12.0
# 789                                              [sos]       8.0
# 557                           [win_pct, wlk, col, pom]      40.0
# 973                                          [win_pct]      20.0
# 507                                          [win_pct]      20.0
# 201  [win_pct, srs, sag, wlk, rth, col, pom, dol, mor]      68.0
# 23                                           [win_pct]      20.0
# 583                                                 []      12.0
# 607                                                 []      12.0
#
#      model_features  game_index
# 512             0.0         512
# 128             0.0         128
# 178             0.0         178
# 656             0.0         656
# 214             0.0         214
# 852            10.0         852
# 816            10.0         816
# 778            10.0         778
# 734            10.0         734
# 150            10.0         150
# 106            10.0         106
# 770             0.0         770
# 498            10.0         498
# 684            10.0         684
# 752            10.0         752
# 346            30.0         346
# 388            10.0         388
# 252            10.0         252
# 960             0.0         960
# 290            10.0         290
# 516            10.0         516
# 444            40.0         444
# 928            10.0         928
# 246            20.0         246
# 84             10.0          84
# 536            50.0         536
# 480            20.0         480
# 430            10.0         430
# 72             10.0          72
# 842            60.0         842
# ..              ...         ...
# 397            10.0         397
# 319            20.0         319
# 427            70.0         427
# 653            90.0         653
# 579            70.0         579
# 847           100.0         847
# 623            60.0         623
# 209             0.0         209
# 593            60.0         593
# 735            10.0         735
# 3              10.0           3
# 659            10.0         659
# 271            20.0         271
# 905            70.0         905
# 337            20.0         337
# 491            10.0         491
# 749             0.0         749
# 665            60.0         665
# 249             0.0         249
# 123            20.0         123
# 419            20.0         419
# 921             0.0         921
# 789            10.0         789
# 557            40.0         557
# 973            10.0         973
# 507            10.0         507
# 201            90.0         201
# 23             10.0          23
# 583             0.0         583
# 607             0.0         607
#
# [64 rows x 97 columns]

# %%
plot_missed_predictions_df = missed_predictions[['game_index','features','model_features']]
plot_missed_predictions_df = pd.melt(plot_missed_predictions_df, id_vars='game_index', var_name= 'Features Supporting Outcome')
m_plot = sns.barplot(x='game_index', y='value', hue='Features Supporting Outcome', data= plot_missed_predictions_df) 
plt.title("Percentage Of Features Consistent With Game Outcomes")
plt.ylabel('Percentage')
plt.xlabel('Missed Prediction Game Index')
m_plot.figure.set_size_inches(20,6)

# %% [markdown]
# #### The bar chart depicts the percentage of features that correctly corresponded to the game outcome but were out weighed by other features in predicting the game incorrectly. Games corresponding to bar heights exceeding 50% should be scrutinized.

# %% [markdown]
# ### Run Model Against 2018 Tournament

# %%
test_year = 2018
X_season = feature_data[feature_data['season_t']== test_year][model_features]
y_season = tourney_comp_ratings[tourney_comp_ratings['season_t']== test_year]['game_result']
X_season.shape
# Out:
# (67, 10)

# %%
y_pred_season = rf_classifier.predict(X_season)
utils.display_confusion_matrix(y_season,y_pred_season)
# Out:
# array([[21, 12],
#        [ 9, 25]], dtype=int64)
