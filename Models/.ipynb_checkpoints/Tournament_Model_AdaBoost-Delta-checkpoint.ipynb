# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
import sys

# Non pythonic hack to reuse some utility code
if sys.path[0] != '../py_utils':
    sys.path.insert(0,'../py_utils')

import utils
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
from pathlib import Path
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)

# %%
def eliminate_features(classifier, X, y ):
    iteration = 0
    print("Iteration= ", iteration)
    iteration += 1
    model_stats = {}
    drop_list = []
    # get baseline by identifying sorted important features using all of the provided features
    model_stats = utils.save_model_stats(classifier,X,y,model_stats)
    
    important_features = utils.display_important_features(classifier.feature_importances_, X,0)
    # least important feature
    least_important_label = important_features[-1][0]
    print("least_important label= ", least_important_label)
    
    drop_list.append(least_important_label)
    del important_features[-1]
    
    # drop list contains all of the feature labels except for the feature label identified as being most important
    list_count = len(important_features)
    while list_count > 0:
        print("Iteration= ", iteration)
        iteration += 1
        model_stats = utils.save_model_stats(classifier,X.drop(columns=drop_list),y,model_stats)
        least_important_label = important_features[-1][0]
        print("least_important label= ", least_important_label)
        drop_list.append(least_important_label)
        del important_features[-1]
        list_count-=1
    return model_stats

# %% [markdown]
# #### Read in regular season team statistics from SRCBB https://www.sports-reference.com/cbb/

# %%
summary_data = pd.read_csv(Path( '../Data/sr_summaries_kaggle_id.csv'))
print(summary_data.shape)

#display rows with NaNs
summary_data[summary_data.isnull().any(axis=1)]
# Out:
# (2773, 22)
#     season          School team_id  Games    SRS   SOS  win_pct  pts_avg  \
# 38    2009  Centenary (LA)     NaN     29 -17.16 -5.08    0.276       70
#
#     opp_pts_avg  fg_pct  allow_fg_pct  ft_pct  allow_ft_att_avg   poss_avg  \
# 38           80   0.416          0.49   0.733                25  80.641379
#
#     off_rebs_avg  allow_off_rebs_avg  def_rebs_avg  allow_def_rebs_avg  \
# 38             9                  11            20                  27
#
#     to_avg  steal_avg  off_rating  ft_att_avg
# 38      15          7   86.804071          21

# %%
#drop records with NaNs
summary_data.dropna(inplace=True)
print(summary_data.shape)
# Out:
# (2772, 22)

# %% [markdown]
# #### Read table of team names and associated team meta data from the Kaggle data set.
#
# https://console.cloud.google.com/bigquery?project=bigqueryncaa&p=bigquery-public-data&d=ncaa_basketball&page=dataset

# %%
# Read table of team names and associated team meta data
teams = pd.read_csv(Path('../Data/D1_teams.csv'))
teams.drop(columns=['code_ncaa','school_ncaa','turner_name','league_name','league_alias','conf_alias',
                    'conf_id','division_name','division_alias','division_id',
                    'kaggle_team_id','venue_id'], inplace=True)
teams.info()
teams.set_index('id',inplace=True)
teams.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 2 columns):
# id           351 non-null object
# conf_name    351 non-null object
# dtypes: object(2)
# memory usage: 5.6+ KB
#                                      conf_name
# id
# fe406882-9f22-495e-9df6-ef357a6803c6       Ivy
# ca478771-aa3d-4231-81e0-b70f519134fb       Ivy
# 5c7bf63f-bc39-43c5-9907-73b50b7a6b34       Ivy
# d60357bd-1205-42e9-9092-d986a2843a34       Ivy
# 88ff8c00-958e-4ccf-a21d-77fab9e93692       Ivy

# %% [markdown]
# #### Read in the NCAA Men's Tournament results from the the Kaggle data set.

# %%
tourney_data = pd.read_csv(Path('../Data/tournament_results.csv'))
tourney_data.drop(columns=['days_from_epoch','day','num_ot','academic_year','win_region','win_alias','lose_region',
                           'lose_alias','lose_code_ncaa','win_school_ncaa','win_code_ncaa','win_name','lose_name',
                           'win_pts','win_kaggle_team_id','lose_school_ncaa','lose_kaggle_team_id','lose_pts'],inplace=True)



tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 9 columns):
# season          2117 non-null int64
# round           2117 non-null int64
# game_date       2117 non-null object
# win_seed        2117 non-null int64
# win_market      2117 non-null object
# win_team_id     2117 non-null object
# lose_seed       2117 non-null int64
# lose_market     2117 non-null object
# lose_team_id    2117 non-null object
# dtypes: int64(4), object(5)
# memory usage: 148.9+ KB

# %%
game_data = tourney_data.join(teams, on='win_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'win_kaggle_team_id','conf_name':'win_conf_name'}, inplace=True)
game_data = game_data.join(teams,on='lose_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'lose_kaggle_team_id','conf_name':'lose_conf_name'}, inplace=True)
games_won_conf = game_data.groupby('win_conf_name').size().reset_index(name='count').sort_values(by=['count'], ascending=False)

games_won_conf['percent'] = 100 * games_won_conf['count']/games_won_conf['count'].sum()
games_won_conf['cum_percent'] = games_won_conf['percent'].cumsum()
games_won_conf.head()
# Out:
#      win_conf_name  count    percent  cum_percent
# 3   Atlantic Coast    431  20.358999    20.358999
# 9          Big Ten    313  14.785073    35.144072
# 24    Southeastern    269  12.706660    47.850732
# 5           Big 12    231  10.911667    58.762400
# 22      Pacific 12    197   9.305621    68.068021

# %% [markdown]
# Identify the conferences that have won 70% of all conference games

# %%
top_tournament_conferences_list = games_won_conf[games_won_conf['cum_percent']<= 70]['win_conf_name'].tolist()
top_tournament_conferences_list
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']

# %% [markdown]
# The summary season data in this set goes back to 2010. If more training data is needed we can go back to earlier seasons.
#
# So the intersection of season summary data with tournament data are regular seasons 2010 through 2016.

# %%
tourney_data = tourney_data[tourney_data['season'] >= 2010]
tourney_data.describe()['season']
# Out:
# count     533.000000
# mean     2013.519700
# std         2.284733
# min      2010.000000
# 25%      2012.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
# recode the tourney data so that the teams are not marked with  win/lose status and the game result is encoded as a binary
tourney_data['game_result'] = 1
tourney_data.game_result = tourney_data.game_result.astype(int)
tourney_data.rename(columns={"win_seed":"team_seed","win_market":"team","win_team_id":"team_id"}, inplace=True)
tourney_data.rename(columns={"lose_seed":"opp_team_seed","lose_market":"opp_team","lose_team_id":"opp_team_id"}, inplace=True)
tourney_data['start_season'] = tourney_data['season'] -1

#create some temporary buffer columns
tourney_data['copy_team'] = tourney_data['team']
tourney_data['copy_team_seed'] = tourney_data['team_seed']
tourney_data['copy_team_id'] = tourney_data['team_id']

#swap the team and opp team data
tourney_data.loc[1::2,'team'] = tourney_data.loc[1::2,'opp_team']
tourney_data.loc[1::2,'opp_team'] = tourney_data.loc[1::2,'copy_team']
tourney_data.loc[1::2,'team_seed'] = tourney_data.loc[1::2,'opp_team_seed']
tourney_data.loc[1::2,'opp_team_seed'] = tourney_data.loc[1::2,'copy_team_seed']
tourney_data.loc[1::2,'team_id'] = tourney_data.loc[1::2,'opp_team_id']
tourney_data.loc[1::2,'opp_team_id'] = tourney_data.loc[1::2,'copy_team_id']

# flip the game result
tourney_data.loc[1::2,'game_result'] = 0

#drop the temporary columns
tourney_data.drop(columns=['copy_team','copy_team_seed','copy_team_id'],inplace=True)
tourney_data.rename(columns={"team_seed":"seed_t","opp_team_seed":"seed_o"}, inplace=True)

tourney_data['Game Result'] = tourney_data.game_result.map({1:'Win', 0:'Lose'})
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','team_id'], 
                                right_on=['season', 'team_id'],how='left',suffixes=('','_y'))

tourney_data.drop(columns=['season_y'],inplace=True)
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','opp_team_id'], 
                                right_on=['season', 'team_id'], how='left',suffixes=('_t','_o'))

tourney_data.drop(columns=['School_t','School_o','Games_t','Games_o','team_id_o'],inplace=True)

tourney_data = tourney_data.join(teams, on='team_id_t', how='left')
tourney_data = tourney_data.join(teams, on='opp_team_id', how='left', lsuffix='_t', rsuffix='_o')
tourney_data.rename(index=str,columns={'team':'team_t','opp_team':'team_o', 'opp_team_id':'team_id_o'},inplace=True)

tourney_data['game_result'] = tourney_data.game_result.apply(utils.negate_loser)
tourney_data.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o
# 0            20     Atlantic Coast  American Athletic
# 1            16  American Athletic            Big Ten
# 2            18       Mid-American        Atlantic 10
# 3            19        Atlantic 10  American Athletic
# 4            20             Big 12        Atlantic 10

# %%
computer_rankings = pd.read_csv(Path( '../Data/massey_seasons_with_id.csv'))
computer_rankings = computer_rankings[computer_rankings['season']>=2010]
computer_rankings[computer_rankings.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SAG, WLK, WOL, Team, RTH, COL, POM, DOL, RPI, MOR, season, win_pct, kaggle_id]
# Index: []

# %%
temp_merge = tourney_data.merge(computer_rankings, left_on=['season_t','team_id_t'], 
                                right_on=['season', 'kaggle_id'],how='left',suffixes=('','_y'))

temp_merge.drop(columns=['Team','season','win_pct','kaggle_id'],inplace=True)
temp_merge.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG   WLK  WOL  RTH  \
# 0            20     Atlantic Coast  American Athletic   25  27.0   36   28
# 1            16  American Athletic            Big Ten   32  30.0   25   32
# 2            18       Mid-American        Atlantic 10   62  55.0   52   59
# 3            19        Atlantic 10  American Athletic   50  43.0   32   54
# 4            20             Big 12        Atlantic 10    2   2.0    3    2
#
#     COL   POM   DOL   RPI  MOR
# 0  32.0  35.0  32.0  33.0   24
# 1  27.0  38.0  25.0  30.0   45
# 2  50.0  54.0  46.0  42.0   60
# 3  35.0  47.0  33.0  38.0   55
# 4   1.0   3.0   2.0   1.0    3

# %%
tourney_comp_ratings = temp_merge.merge(computer_rankings,left_on=['season_t','team_id_o'], 
                                right_on=['season', 'kaggle_id'], how='left',suffixes=('_t','_o'))

tourney_comp_ratings.drop(columns=['Team','season','win_pct','kaggle_id'],inplace=True)
tourney_comp_ratings.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG_t  WLK_t  WOL_t  \
# 0            20     Atlantic Coast  American Athletic     25   27.0     36
# 1            16  American Athletic            Big Ten     32   30.0     25
# 2            18       Mid-American        Atlantic 10     62   55.0     52
# 3            19        Atlantic 10  American Athletic     50   43.0     32
# 4            20             Big 12        Atlantic 10      2    2.0      3
#
#    RTH_t  COL_t  POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  \
# 0     28   32.0   35.0   32.0   33.0     24     55   58.0     35     47
# 1     32   27.0   38.0   25.0   30.0     45     45   42.0     43     37
# 2     59   50.0   54.0   46.0   42.0     60     26   19.0     27     27
# 3     54   35.0   47.0   33.0   38.0     55     10   10.0     16     16
# 4      2    1.0    3.0    2.0    1.0      3     77   55.0     54     74
#
#    COL_o  POM_o  DOL_o  RPI_o  MOR_o
# 0   40.0   68.0   45.0   41.0     52
# 1   39.0   39.0   39.0   39.0     27
# 2   27.0   21.0   31.0   24.0     16
# 3   11.0   10.0   15.0   12.0     10
# 4   59.0   84.0   72.0   49.0     80

# %% [markdown]
# #### Add a feature
# top_conf = 1 if team is a top conference and opponent is not
# top_conf = -1 if opp_team is a top_conference and team is not
# top_conf = 0 otherwise

# %%
print(top_tournament_conferences_list)
tourney_comp_ratings['top_conf'] = tourney_comp_ratings.apply(lambda row: utils.conf_compare(row.conf_name_t, 
                                                                                             row.conf_name_o,
                                                                                             top_tournament_conferences_list),
                                                              axis=1)

tourney_comp_ratings.head(10)[['game_result','conf_name_t','conf_name_o','top_conf']]
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']
#    game_result        conf_name_t        conf_name_o  top_conf
# 0           -1     Atlantic Coast  American Athletic         1
# 1            1  American Athletic            Big Ten        -1
# 2           -1       Mid-American        Atlantic 10         0
# 3            1        Atlantic 10  American Athletic         0
# 4           -1             Big 12        Atlantic 10         1
# 5            1        Atlantic 10     Atlantic Coast        -1
# 6           -1            Big Ten        Atlantic 10         1
# 7            1        Atlantic 10           Big East         0
# 8           -1         Pacific 12        Atlantic 10         1
# 9            1        Atlantic 10         Pacific 12        -1

# %%
# Upsets occur less than 30% of the time when seeding deltas are more than 6
tourney_comp_ratings['upset_seed_threshold'] = tourney_comp_ratings.apply(
    lambda row: abs(row.seed_t - row.seed_o) > 6, axis=1).astype(int)
    
tourney_comp_ratings.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG_t  WLK_t  WOL_t  \
# 0            20     Atlantic Coast  American Athletic     25   27.0     36
# 1            16  American Athletic            Big Ten     32   30.0     25
# 2            18       Mid-American        Atlantic 10     62   55.0     52
# 3            19        Atlantic 10  American Athletic     50   43.0     32
# 4            20             Big 12        Atlantic 10      2    2.0      3
#
#    RTH_t  COL_t  POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  \
# 0     28   32.0   35.0   32.0   33.0     24     55   58.0     35     47
# 1     32   27.0   38.0   25.0   30.0     45     45   42.0     43     37
# 2     59   50.0   54.0   46.0   42.0     60     26   19.0     27     27
# 3     54   35.0   47.0   33.0   38.0     55     10   10.0     16     16
# 4      2    1.0    3.0    2.0    1.0      3     77   55.0     54     74
#
#    COL_o  POM_o  DOL_o  RPI_o  MOR_o  top_conf  upset_seed_threshold
# 0   40.0   68.0   45.0   41.0     52         1                     0
# 1   39.0   39.0   39.0   39.0     27        -1                     0
# 2   27.0   21.0   31.0   24.0     16         0                     1
# 3   11.0   10.0   15.0   12.0     10         0                     1
# 4   59.0   84.0   72.0   49.0     80         1                     1

# %%
feature_data = tourney_comp_ratings.drop(columns=['round','game_date','team_t','team_id_t','team_id_o',
                                         'team_o','team_id_o','game_result','start_season','Game Result',
                                         'conf_name_t','conf_name_o']).copy()
feature_data.head()
# Out:
#    season_t  seed_t  seed_o  SRS_t  SOS_t  win_pct_t  pts_avg_t  \
# 0      2013       8       9  14.32   7.17      0.686         77
# 1      2011       7      10  12.35   4.23      0.765         70
# 2      2013      12       5   8.11   0.18      0.788         71
# 3      2012      12       5   8.79   0.63      0.806         68
# 4      2011       1      11  24.10   7.62      0.921         81
#
#    opp_pts_avg_t  fg_pct_t  allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  \
# 0             70     0.496           0.419     0.681                  17
# 1             62     0.447           0.435     0.698                  19
# 2             62     0.455           0.395     0.643                  19
# 3             59     0.410           0.424     0.685                  18
# 4             64     0.508           0.380     0.679                  18
#
#    poss_avg_t  off_rebs_avg_t  allow_off_rebs_avg_t  def_rebs_avg_t  \
# 0   78.434286              11                    12              22
# 1   75.688235              11                    11              24
# 2   78.884848              12                    10              21
# 3   76.305556              12                    10              18
# 4   80.126316              11                    10              27
#
#    allow_def_rebs_avg_t  to_avg_t  steal_avg_t  off_rating_t  ft_att_avg_t  \
# 0                    21        12            6     98.171354            23
# 1                    22        10            6     92.484651            19
# 2                    21        13            7     90.004610            20
# 3                    24        11           10     89.115399            20
# 4                    21        13            7    101.090384            22
#
#    season_o  SRS_o  SOS_o  win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  \
# 0      2012   9.52   5.20      0.706         72             67     0.428
# 1      2010  11.98  11.45      0.559         63             62     0.439
# 2      2012  16.89   4.47      0.750         76             64     0.450
# 3      2011  17.42   3.80      0.818         77             62     0.482
# 4      2010   8.56   3.78      0.700         71             66     0.434
#
#    allow_fg_pct_o  ft_pct_o  allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  \
# 0           0.438     0.723                  18   77.494118              11
# 1           0.434     0.724                  21   68.341176               9
# 2           0.444     0.701                  20   81.044444              13
# 3           0.393     0.748                  18   77.496970              10
# 4           0.424     0.715                  18   75.240000              10
#
#    allow_off_rebs_avg_o  def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  \
# 0                    10              19                    25        10
# 1                     8              21                    23        10
# 2                    11              18                    23        11
# 3                     9              24                    21        12
# 4                    10              21                    24        11
#
#    steal_avg_o  off_rating_o  ft_att_avg_o  SAG_t  WLK_t  WOL_t  RTH_t  COL_t  \
# 0            7     92.910278            20     25   27.0     36     28   32.0
# 1            4     92.184541            16     32   30.0     25     32   27.0
# 2           11     93.775706            18     62   55.0     52     59   50.0
# 3            6     99.358724            19     50   43.0     32     54   35.0
# 4            8     94.364700            20      2    2.0      3      2    1.0
#
#    POM_t  DOL_t  RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  COL_o  POM_o  \
# 0   35.0   32.0   33.0     24     55   58.0     35     47   40.0   68.0
# 1   38.0   25.0   30.0     45     45   42.0     43     37   39.0   39.0
# 2   54.0   46.0   42.0     60     26   19.0     27     27   27.0   21.0
# 3   47.0   33.0   38.0     55     10   10.0     16     16   11.0   10.0
# 4    3.0    2.0    1.0      3     77   55.0     54     74   59.0   84.0
#
#    DOL_o  RPI_o  MOR_o  top_conf  upset_seed_threshold
# 0   45.0   41.0     52         1                     0
# 1   39.0   39.0     27        -1                     0
# 2   31.0   24.0     16         0                     1
# 3   15.0   12.0     10         0                     1
# 4   72.0   49.0     80         1                     1

# %%
feature_data_diff = feature_data.copy()
feature_data_diff['margin_victory_t'] = feature_data_diff['pts_avg_t'] - feature_data_diff['opp_pts_avg_t']
feature_data_diff['margin_victory_o'] = feature_data_diff['pts_avg_o'] - feature_data_diff['opp_pts_avg_o']
feature_data_diff['delta_margin_victory_avg'] = feature_data_diff['margin_victory_t'] - feature_data_diff['margin_victory_o']

feature_data_diff['delta_fg_pct'] = feature_data_diff['fg_pct_t'] - feature_data_diff['fg_pct_o']

#feature_data_diff['allow_fg_pct'] = feature_data_diff['allow_fg_pct_t'] - feature_data_diff['allow_fg_pct_o']
feature_data_diff['delta_off_rebs_avg'] = feature_data_diff['off_rebs_avg_t'] - feature_data_diff['off_rebs_avg_o']
feature_data_diff['delta_def_rebs_avg'] = feature_data_diff['def_rebs_avg_t'] - feature_data_diff['def_rebs_avg_o']
feature_data_diff['delta_allow_def_rebs_avg'] = feature_data_diff['allow_def_rebs_avg_t'] - feature_data_diff['allow_def_rebs_avg_o']
feature_data_diff['delta_ft_pct'] = feature_data_diff['ft_pct_t'] - feature_data_diff['ft_pct_o']

feature_data_diff['to_net_avg_t'] = feature_data_diff['to_avg_t'] - feature_data_diff['steal_avg_t']
feature_data_diff['to_net_avg_o'] = feature_data_diff['to_avg_o'] - feature_data_diff['steal_avg_o']
feature_data_diff['delta_to_net_avg'] = feature_data_diff['to_net_avg_t'] - feature_data_diff['to_net_avg_o']

feature_data_diff['delta_win_pct'] = feature_data_diff['win_pct_t'] - feature_data_diff['win_pct_o']
feature_data_diff['delta_off_rating'] = feature_data_diff['off_rating_t'] - feature_data_diff['off_rating_o']

feature_data_diff['delta_allow_off_rebs_avg'] = feature_data_diff['allow_off_rebs_avg_t'] - feature_data_diff['allow_off_rebs_avg_o']
feature_data_diff['delta_ft_att_avg'] = feature_data_diff['ft_att_avg_t'] - feature_data_diff['ft_att_avg_o']

feature_data_diff['delta_allow_ft_att_avg'] = feature_data_diff['allow_ft_att_avg_t'] - feature_data_diff['allow_ft_att_avg_o']

feature_data_diff['delta_seed'] = feature_data_diff['seed_t'] - feature_data_diff['seed_o']

feature_data_diff['delta_srs'] = feature_data_diff['SRS_t'] - feature_data_diff['SRS_o']
feature_data_diff['delta_sos'] = feature_data_diff['SOS_t'] - feature_data_diff['SOS_o']

feature_data_diff['delta_sag'] = feature_data_diff['SAG_t'] - feature_data_diff['SAG_o']
feature_data_diff['delta_wlk'] = feature_data_diff['WLK_t'] - feature_data_diff['WLK_o']
feature_data_diff['delta_wol'] = feature_data_diff['WOL_t'] - feature_data_diff['WOL_o']
feature_data_diff['delta_rth'] = feature_data_diff['RTH_t'] - feature_data_diff['RTH_o']
feature_data_diff['delta_col'] = feature_data_diff['COL_t'] - feature_data_diff['COL_o']
feature_data_diff['delta_pom'] = feature_data_diff['POM_t'] - feature_data_diff['POM_o']
feature_data_diff['delta_dol'] = feature_data_diff['DOL_t'] - feature_data_diff['DOL_o']
feature_data_diff['delta_rpi'] = feature_data_diff['RPI_t'] - feature_data_diff['RPI_o']
feature_data_diff['delta_mor'] = feature_data_diff['MOR_t'] - feature_data_diff['MOR_o']


feature_data_diff.drop(columns=['pts_avg_t','pts_avg_o', 'opp_pts_avg_t','opp_pts_avg_o',
                                'margin_victory_t', 'margin_victory_o',
                                'poss_avg_t','poss_avg_o',
                                'seed_t','seed_o','season_o',
                                'fg_pct_t','fg_pct_o','allow_fg_pct_t','allow_fg_pct_o',
                                'off_rebs_avg_t','off_rebs_avg_o','def_rebs_avg_t','def_rebs_avg_o',
                                'allow_def_rebs_avg_t','allow_def_rebs_avg_o','ft_pct_t','ft_pct_o',
                                'to_avg_t','to_avg_o','steal_avg_t','steal_avg_o',
                                'to_net_avg_t','to_net_avg_o',
                                'win_pct_t','win_pct_o','off_rating_t','off_rating_o',
                                'allow_off_rebs_avg_t','allow_off_rebs_avg_o',
                                'ft_att_avg_t','ft_att_avg_o','opp_pts_avg_t','opp_pts_avg_o',
                                'SRS_t','SRS_o','SOS_t','SOS_o',
                                'allow_ft_att_avg_t','allow_ft_att_avg_o',
                                'SAG_t','SAG_o','WLK_t','WLK_o','WOL_t','WOL_o',
                                'RTH_t','RTH_o','COL_t','COL_o','POM_t','POM_o',
                                'DOL_t','DOL_o','RPI_t','RPI_o','MOR_t','MOR_o'], inplace=True)

# %%
X= feature_data_diff[feature_data_diff['season_t']>=2010]
y=tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']
X= X.drop(columns=['season_t'])

feature_list = list(X)
feature_list
# Out:
# ['top_conf',
#  'upset_seed_threshold',
#  'delta_margin_victory_avg',
#  'delta_fg_pct',
#  'delta_off_rebs_avg',
#  'delta_def_rebs_avg',
#  'delta_allow_def_rebs_avg',
#  'delta_ft_pct',
#  'delta_to_net_avg',
#  'delta_win_pct',
#  'delta_off_rating',
#  'delta_allow_off_rebs_avg',
#  'delta_ft_att_avg',
#  'delta_allow_ft_att_avg',
#  'delta_seed',
#  'delta_srs',
#  'delta_sos',
#  'delta_sag',
#  'delta_wlk',
#  'delta_wol',
#  'delta_rth',
#  'delta_col',
#  'delta_pom',
#  'delta_dol',
#  'delta_rpi',
#  'delta_mor']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
X_train.head()
# Out:
# (426, 26)
# (426,)
# (107, 26)
# (107,)
#      top_conf  upset_seed_threshold  delta_margin_victory_avg  delta_fg_pct  \
# 140         0                     1                         2         0.069
# 293         0                     0                        -3         0.000
# 368        -1                     1                        -4         0.032
# 53          1                     1                         5        -0.006
# 33          0                     0                         1        -0.007
#
#      delta_off_rebs_avg  delta_def_rebs_avg  delta_allow_def_rebs_avg  \
# 140                  -2                  -2                        -6
# 293                   1                   0                        -4
# 368                  -3                   1                        -1
# 53                    7                   3                        -1
# 33                   -1                   0                        -1
#
#      delta_ft_pct  delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 140        -0.008                 2          0.081          5.170601
# 293        -0.044                 3          0.030         -5.202764
# 368         0.016                 2         -0.132          4.187608
# 53         -0.085                 0          0.118         -4.527964
# 33          0.034                -1         -0.015         -0.684009
#
#      delta_allow_off_rebs_avg  delta_ft_att_avg  delta_allow_ft_att_avg  \
# 140                        -1                -4                      -2
# 293                        -4                 0                      -1
# 368                         0                -7                       1
# 53                          1                 5                       5
# 33                         -1                -1                      -3
#
#      delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 140         -11      12.47       9.59       -101      -82.0       -105
# 293           1      -2.42       0.22         10       14.0          5
# 368           9     -14.49      -8.53         82       88.0         90
# 53           -8       9.67       4.01        -56      -71.0        -63
# 33            2      -2.73      -3.85          7        9.0          3
#
#      delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor
# 140       -107      -94.0      -89.0     -110.0      -88.0        -94
# 293          3        3.0       14.0        1.0        4.0          8
# 368        101       92.0       76.0       98.0       67.0         90
# 53         -71      -74.0      -60.0      -68.0      -53.0        -54
# 33           8        5.0        6.0       10.0        6.0         16

# %% [markdown]
# #### Baseline Model

# %%
number_estimators = 401

bdt= AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME.R", n_estimators=number_estimators)
    
bdt.fit(X_train, y_train)
score = bdt.score(X_train, y_train)
print("Training Model Score= ", score)
# Out:
# Training Model Score=  1.0

# %%
importances = bdt.feature_importances_
important_features = utils.display_important_features(importances, X_train)
# Out:
# Coefficient Values
# delta_win_pct   0.14214463840399003
# delta_sos   0.14214463840399003
# delta_fg_pct   0.07231920199501247
# delta_ft_pct   0.06483790523690773
# delta_dol   0.06234413965087282
# delta_rth   0.059850374064837904
# delta_srs   0.05486284289276808
# delta_mor   0.04987531172069826
# delta_wlk   0.03740648379052369
# delta_rpi   0.03740648379052369
# delta_pom   0.032418952618453865
# delta_seed   0.029925187032418952
# delta_sag   0.029925187032418952
# delta_allow_def_rebs_avg   0.022443890274314215
# delta_off_rating   0.022443890274314215
# delta_allow_off_rebs_avg   0.0199501246882793
# delta_ft_att_avg   0.0199501246882793
# delta_wol   0.0199501246882793
# delta_col   0.0199501246882793
# delta_margin_victory_avg   0.014962593516209476
# delta_def_rebs_avg   0.012468827930174564
# delta_to_net_avg   0.012468827930174564
# delta_allow_ft_att_avg   0.00997506234413965
# delta_off_rebs_avg   0.007481296758104738
# top_conf   0.0024937655860349127
# upset_seed_threshold   0.0

# %%
y_pred = bdt.predict(X_test)
print("RF model accuracy is %2.2f" % metrics.accuracy_score(y_test, y_pred))
# Out:
# RF model accuracy is 0.72

# %%
utils.display_confusion_matrix(y_test, y_pred)
# Out:
# array([[41, 11],
#        [19, 36]], dtype=int64)

# %% [markdown]
# ##### Baseline Confusion Matrix

# %%
prediction_probabilities = bdt.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.719626168224299
# Precision: 0.7659574468085106
# Recall: 0.6545454545454545
# Log loss=  0.6807620196762939

# %%
cross_val_scores = cross_val_score(bdt, X,y, cv=10, scoring='accuracy')
print("Baseline Cross Validation average= ",cross_val_scores.mean())
# Out:
# Baseline Cross Validation average=  0.7603330108047089

# %%
train_sizes, train_scores, test_scores = learning_curve(bdt, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
#                    Baseline Learning Curve

# %% [markdown]
# #### Model Feature Optimization

# %%
X = feature_data_diff[feature_data_diff['season_t']>=2010]
X = X.drop(columns=['season_t'])
y = tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']

model_stats = eliminate_features(bdt, X,y)
#print(model_stats)
# Out:
# Iteration=  0
# least_important label=  upset_seed_threshold
# Iteration=  1
# least_important label=  top_conf
# Iteration=  2
# least_important label=  delta_off_rebs_avg
# Iteration=  3
# least_important label=  delta_allow_ft_att_avg
# Iteration=  4
# least_important label=  delta_to_net_avg
# Iteration=  5
# least_important label=  delta_def_rebs_avg
# Iteration=  6
# least_important label=  delta_margin_victory_avg
# Iteration=  7
# least_important label=  delta_col
# Iteration=  8
# least_important label=  delta_wol
# Iteration=  9
# least_important label=  delta_ft_att_avg
# Iteration=  10
# least_important label=  delta_allow_off_rebs_avg
# Iteration=  11
# least_important label=  delta_off_rating
# Iteration=  12
# least_important label=  delta_allow_def_rebs_avg
# Iteration=  13
# least_important label=  delta_sag
# Iteration=  14
# least_important label=  delta_seed
# Iteration=  15
# least_important label=  delta_pom
# Iteration=  16
# least_important label=  delta_rpi
# Iteration=  17
# least_important label=  delta_wlk
# Iteration=  18
# least_important label=  delta_mor
# Iteration=  19
# least_important label=  delta_srs
# Iteration=  20
# least_important label=  delta_rth
# Iteration=  21
# least_important label=  delta_dol
# Iteration=  22
# least_important label=  delta_ft_pct
# Iteration=  23
# least_important label=  delta_fg_pct
# Iteration=  24
# least_important label=  delta_sos
# Iteration=  25
# least_important label=  delta_win_pct

# %%
max_accuracy = 0
max_cross_val = 0
min_log_loss = 10000
for key, value in model_stats.items():
    accuracy = value['accuracy']
    cross_val = value['cross_validation']
    log_loss_val = value['log_loss']
    print('Accuracy= {0:6.4f} Cross Val= {1:6.4f}  Log Loss= {2:6.4f}'.format(accuracy ,cross_val, log_loss_val ))
    if accuracy > max_accuracy:
        max_accuracy = accuracy
        accuracy_hash = key
    if cross_val > max_cross_val:
        max_cross_val = cross_val
        cross_hash = key
    if log_loss_val < min_log_loss:
        min_log_loss = log_loss_val
        log_hash = key

print("\n")

print('Max Accuracy= {0:6.4f}'.format( model_stats[accuracy_hash]['accuracy']))
print('Max Cross Validation= {0:6.4f}'.format( model_stats[cross_hash]['cross_validation']))
print ("Minimum Log Loss= {0:6.4f}".format(  model_stats[log_hash]['log_loss']))
print('Log Loss at Max Accuracy= {0:6.4f}'.format( model_stats[accuracy_hash]['log_loss'] ))
print('Log Loss at Max Cross Validation= {0:6.4f} '.format( model_stats[cross_hash]['log_loss'] ))
# Out:
# Accuracy= 0.7196 Cross Val= 0.7603  Log Loss= 0.6808
# Accuracy= 0.7196 Cross Val= 0.7622  Log Loss= 0.6808
# Accuracy= 0.7196 Cross Val= 0.7567  Log Loss= 0.6804
# Accuracy= 0.7009 Cross Val= 0.7433  Log Loss= 0.6834
# Accuracy= 0.6916 Cross Val= 0.7285  Log Loss= 0.6829
# Accuracy= 0.6822 Cross Val= 0.7453  Log Loss= 0.6830
# Accuracy= 0.6916 Cross Val= 0.7550  Log Loss= 0.6828
# Accuracy= 0.6916 Cross Val= 0.7565  Log Loss= 0.6823
# Accuracy= 0.7009 Cross Val= 0.7547  Log Loss= 0.6832
# Accuracy= 0.7009 Cross Val= 0.7622  Log Loss= 0.6833
# Accuracy= 0.6822 Cross Val= 0.7586  Log Loss= 0.6827
# Accuracy= 0.6822 Cross Val= 0.7473  Log Loss= 0.6833
# Accuracy= 0.7290 Cross Val= 0.7625  Log Loss= 0.6830
# Accuracy= 0.7383 Cross Val= 0.7905  Log Loss= 0.6828
# Accuracy= 0.7290 Cross Val= 0.7661  Log Loss= 0.6823
# Accuracy= 0.7383 Cross Val= 0.7867  Log Loss= 0.6824
# Accuracy= 0.7009 Cross Val= 0.7886  Log Loss= 0.6827
# Accuracy= 0.7383 Cross Val= 0.7753  Log Loss= 0.6821
# Accuracy= 0.7570 Cross Val= 0.7755  Log Loss= 0.6794
# Accuracy= 0.7664 Cross Val= 0.7865  Log Loss= 0.6811
# Accuracy= 0.7850 Cross Val= 0.7680  Log Loss= 0.6819
# Accuracy= 0.8131 Cross Val= 0.7771  Log Loss= 0.6846
# Accuracy= 0.6262 Cross Val= 0.6843  Log Loss= 0.6869
# Accuracy= 0.6729 Cross Val= 0.6880  Log Loss= 0.6868
# Accuracy= 0.6449 Cross Val= 0.6866  Log Loss= 0.6878
# Accuracy= 0.6168 Cross Val= 0.5750  Log Loss= 0.6909
#
#
# Max Accuracy= 0.8131
# Max Cross Validation= 0.7905
# Minimum Log Loss= 0.6794
# Log Loss at Max Accuracy= 0.6846
# Log Loss at Max Cross Validation= 0.6828

# %%
model_features = model_stats[cross_hash]['labels']
print(model_features)
# Out:
# ['delta_fg_pct', 'delta_ft_pct', 'delta_win_pct', 'delta_seed', 'delta_srs', 'delta_sos', 'delta_sag', 'delta_wlk', 'delta_rth', 'delta_pom', 'delta_dol', 'delta_rpi', 'delta_mor']

# %%
X = feature_data_diff[feature_data_diff['season_t']>=2010][model_features]

# %%
y = tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
bdt.fit(X_train, y_train)
y_pred = bdt.predict(X_test)
# save model stats
prediction_probabilities = bdt.predict_proba(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)
log_loss_value = log_loss(y_test, prediction_probabilities)
cross_val_scores = cross_val_score(bdt, X,y, cv=10, scoring='accuracy')
cross_validation_average = cross_val_scores.mean()

train_sizes, train_scores, test_scores = learning_curve(bdt, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))
utils.display_confusion_matrix(y_test, y_pred)
# Out:
# array([[39, 13],
#        [15, 40]], dtype=int64)

# %%
prediction_probabilities = bdt.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.7383177570093458
# Precision: 0.7547169811320755
# Recall: 0.7272727272727273
# Log loss=  0.6828013056072104

# %%
# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
# Retrieve the non-normalized game stats
prediction_probabilities[:,1]
pred_probs = pd.Series(prediction_probabilities[:,1], index=X_test.index)
predictions = pd.Series(y_pred, index=y_test.index)
test_games = tourney_comp_ratings[tourney_comp_ratings.index.isin(X_test.index)].copy()

test_games['predicted_result'] = predictions
test_games['pred_win_prob'] = pred_probs

#test_games['game_result'] = test_games.game_result.apply(negate_loser)

test_games.shape
# Out:
# (107, 73)

# %%
missed_predictions = test_games[test_games['game_result'] != 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)

print("Missed predictions= ", missed_predictions.shape[0])

#base_prediction_labels = ['predicted_result','game_result','pred_win_prob','team_t','seed_t','conf_name_t', 'team_o',
#                    'seed_o', 'conf_name_o','top_conf','season_t','round']


missed_predictions
# Out:
# Missed predictions=  28
#      season_t  round   game_date  seed_t          team_t  \
# 358      2015     32  2015-03-21       1       Villanova
# 488      2016     64  2016-03-18       3   West Virginia
# 52       2010     64  2010-03-19      12      Utah State
# 494      2012     64  2012-03-16       7    Saint Mary's
# 454      2016     68  2016-03-16      11           Tulsa
# 352      2011     64  2011-03-17      12      Utah State
# 514      2013     16  2013-03-28       2      Miami (FL)
# 432      2013     32  2013-03-24       7        Illinois
# 394      2013     32  2013-03-24      12        Ole Miss
# 286      2014     32  2014-03-22      12         Harvard
# 496      2017     32  2017-03-18       5      Iowa State
# 440      2012     64  2012-03-16       7      Notre Dame
# 292      2010      8  2010-03-28       6       Tennessee
# 281      2013     32  2013-03-23       9   Wichita State
# 319      2011      8  2011-03-27       4        Kentucky
# 197      2016     64  2016-03-17       9          Butler
# 329      2012      2  2012-04-02       1        Kentucky
# 191      2013     16  2013-03-28       2      Ohio State
# 43       2017     64  2017-03-16       7    Saint Mary's
# 203      2011     32  2011-03-19       8          Butler
# 123      2016     32  2016-03-20       7       Wisconsin
# 407      2016     32  2016-03-19       1  North Carolina
# 517      2011     32  2011-03-20      11       Marquette
# 71       2011     64  2011-03-17      13  Morehead State
# 445      2015     32  2015-03-21       6          Xavier
# 51       2017     68  2017-03-15      16        UC Davis
# 321      2011     16  2011-03-25       4        Kentucky
# 163      2015     68  2015-03-17      16         Hampton
#
#                                 team_id_t  seed_o                  team_o  \
# 358  4383eb6a-7fd8-4ff2-94c5-43c933121e88       8    North Carolina State
# 488  f770d3a2-221c-49ce-9c7a-680f7417fe9e      14       Stephen F. Austin
# 52   7672ff16-8436-47e6-8546-0fb5494ec7ee       5               Texas A&M
# 494  b18f34af-a7f1-4659-a2e5-fc11a31cd316      10                  Purdue
# 454  2959bd24-7007-41ae-a3a3-abdf26888cfc      11                Michigan
# 352  7672ff16-8436-47e6-8546-0fb5494ec7ee       5            Kansas State
# 514  7aec5187-cb1b-45e5-8f7d-406d766cdc73       3               Marquette
# 432  150148c2-ca8f-414f-8f41-d94a55d4a122       2              Miami (FL)
# 394  d7d668ec-edaa-4d6b-be25-2ebba4128643      13                La Salle
# 286  5c7bf63f-bc39-43c5-9907-73b50b7a6b34       4          Michigan State
# 496  0e4258fa-3154-4c16-b693-adecab184c6c       4                  Purdue
# 440  80962f09-8821-48b6-8cf0-0cf0eea56aa8      10                  Xavier
# 292  b827dbdf-230f-4916-9703-3bb9004e26eb       5          Michigan State
# 281  f38b58de-3273-4723-a78b-2f918e9aa2d5       1                 Gonzaga
# 319  2267a1f4-68f6-418b-aaf6-2aa0c4b291f1       2          North Carolina
# 197  bdb7d7a4-45f8-4bf3-ab85-15488c451494       8              Texas Tech
# 329  2267a1f4-68f6-418b-aaf6-2aa0c4b291f1       2                  Kansas
# 191  857462b3-0ab6-4d26-9669-10ca354e382b       6                 Arizona
# 43   b18f34af-a7f1-4659-a2e5-fc11a31cd316      10   Virginia Commonwealth
# 203  bdb7d7a4-45f8-4bf3-ab85-15488c451494       1              Pittsburgh
# 123  c7569eae-5b93-4197-b204-6f3a62146b25       2                  Xavier
# 407  e9ca48b2-00ba-41c0-a02b-6885a2da1ff1       9              Providence
# 517  06f7c904-0ac7-4125-b0f4-f4871bb69057       3                Syracuse
# 71   b7747a03-c85b-4de6-94bf-1b5b68553248       4              Louisville
# 445  0d8a328f-20ce-410b-bed1-15fc01308aaf      14           Georgia State
# 51   8aaad1c0-d16e-4b9f-8541-dac670addd71      16  North Carolina Central
# 321  2267a1f4-68f6-418b-aaf6-2aa0c4b291f1       1              Ohio State
# 163  161354af-1f3e-4d58-88f7-e016ec74b7b6      16               Manhattan
#
#                                 team_id_o  game_result  start_season  \
# 358  52df1e19-b142-4a76-a439-ad68455d0581           -1          2014
# 488  5ef64f01-86ae-4553-9834-c79cc0859eaf           -1          2015
# 52   ef184799-d79b-49d9-a662-991eaf4044cd           -1          2009
# 494  12d7f888-675b-459f-9099-a38f771d8a95           -1          2011
# 454  bdc2561d-f603-4fab-a262-f1d2af462277           -1          2015
# 352  d203f38a-a166-4258-bca2-e161b591ecfb           -1          2010
# 514  06f7c904-0ac7-4125-b0f4-f4871bb69057           -1          2012
# 432  7aec5187-cb1b-45e5-8f7d-406d766cdc73           -1          2012
# 394  ad9a3e21-4585-4e35-8946-290fe4a16f18           -1          2012
# 286  a41d5a05-4c11-4171-a57e-e7a1ea325a6d           -1          2013
# 496  12d7f888-675b-459f-9099-a38f771d8a95           -1          2016
# 440  0d8a328f-20ce-410b-bed1-15fc01308aaf           -1          2011
# 292  a41d5a05-4c11-4171-a57e-e7a1ea325a6d           -1          2009
# 281  2f4d21f8-6d5f-48a5-abca-52a30583871a            1          2012
# 319  e9ca48b2-00ba-41c0-a02b-6885a2da1ff1            1          2010
# 197  f8c705b7-87d3-411a-9c8b-5124daab0469            1          2015
# 329  fae4855b-1b64-4b40-a632-9ed345e1e952            1          2011
# 191  9b166a3f-e64b-4825-bb6b-92c6f0418263            1          2012
# 43   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            1          2016
# 203  24051034-96bb-4f78-a3a6-312f3258780f            1          2010
# 123  0d8a328f-20ce-410b-bed1-15fc01308aaf            1          2015
# 407  7d3b9c72-cbdd-4b64-9aa3-a5bde9b75fdc            1          2015
# 517  8cd24de1-2be8-4b77-bcfa-47be0495a5f4            1          2010
# 71   b795ddbc-baab-4499-8803-52e8608520ab            1          2010
# 445  94ea835b-8ce9-4de2-a5b1-971548fea974            1          2014
# 51   e4c315a0-e83f-4d14-856e-34a0463059e3            1          2016
# 321  857462b3-0ab6-4d26-9669-10ca354e382b            1          2010
# 163  7a270923-01d6-4a6f-a93e-e8786266d502            1          2014
#
#     Game Result  SRS_t  SOS_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 358        Lose  23.13   7.55      0.917         76             60     0.470
# 488        Lose  21.61   9.78      0.743         78             66     0.449
# 52         Lose  13.62   1.23      0.771         73             59     0.488
# 494        Lose  11.26   0.78      0.818         74             62     0.473
# 454        Lose   9.79   5.76      0.625         73             69     0.444
# 352        Lose  13.23   0.50      0.882         72             58     0.470
# 514        Lose  16.99   7.88      0.806         69             60     0.455
# 432        Lose  13.23  10.08      0.639         68             64     0.412
# 394        Lose  14.42   4.14      0.750         77             66     0.438
# 286        Lose  10.79  -0.47      0.844         73             61     0.465
# 496        Lose  20.51  11.94      0.686         80             72     0.472
# 440        Lose  11.18   6.47      0.647         66             61     0.434
# 292        Lose  16.05   7.75      0.757         73             65     0.456
# 281         Win  14.68   6.09      0.769         69             61     0.440
# 319         Win  20.30   8.91      0.763         74             63     0.459
# 197         Win  16.46   7.55      0.667         79             71     0.466
# 329         Win  24.73   7.93      0.950         77             60     0.488
# 191         Win  20.19   9.32      0.784         70             59     0.451
# 43          Win  16.75   2.19      0.853         72             57     0.496
# 203         Win  11.53   5.02      0.737         71             64     0.433
# 123         Win  13.40   9.40      0.629         67             63     0.426
# 407         Win  23.44  10.69      0.825         82             70     0.482
# 517         Win  14.89   8.51      0.595         75             68     0.465
# 71          Win   2.81  -3.13      0.714         68             61     0.454
# 445         Win  15.42   9.48      0.622         73             67     0.475
# 51          Win  -5.21  -4.68      0.639         70             69     0.435
# 321         Win  20.30   8.91      0.763         74             63     0.459
# 163         Win  -8.25  -7.08      0.486         67             68     0.406
#
#      allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 358           0.406     0.731                  16   73.861111              10
# 488           0.424     0.673                  27   85.394286              15
# 52            0.405     0.758                  15   71.874286              10
# 494           0.428     0.729                  15   74.933333              11
# 454           0.416     0.677                  19   77.731250              10
# 352           0.415     0.737                  17   73.400000              10
# 514           0.400     0.684                  15   72.694444               9
# 432           0.424     0.726                  19   76.483333              11
# 394           0.408     0.678                  18   82.538889              12
# 286           0.409     0.724                  18   74.387500              10
# 496           0.428     0.700                  15   79.502857               9
# 440           0.414     0.704                  14   70.917647              10
# 292           0.396     0.671                  22   80.378378              11
# 281           0.395     0.699                  19   76.266667              13
# 319           0.374     0.710                  15   76.436842              11
# 197           0.435     0.731                  20   79.200000              11
# 329           0.374     0.723                  15   76.705000              11
# 191           0.395     0.708                  15   73.664865              10
# 43            0.412     0.745                  14   69.458824               9
# 203           0.411     0.726                  21   75.200000              11
# 123           0.426     0.703                  17   74.120000              11
# 407           0.417     0.747                  18   83.035000              14
# 517           0.402     0.696                  18   78.913514              12
# 71            0.444     0.674                  19   77.125714              13
# 445           0.435     0.730                  18   74.810811               9
# 51            0.426     0.674                  18   79.227778              10
# 321           0.374     0.710                  15   76.436842              11
# 163           0.413     0.652                  25   79.902857              11
#
#      allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 358                    10              24                    21        10
# 488                     8              23                    22        14
# 52                      9              25                    20        10
# 494                     9              23                    20        11
# 454                    10              25                    26        10
# 352                    11              26                    20        11
# 514                    10              22                    22        10
# 432                    10              18                    24        11
# 394                    12              21                    25        10
# 286                     9              23                    21        11
# 496                    11              25                    26        10
# 440                    11              20                    23        10
# 292                    11              24                    23        13
# 281                     9              21                    21        12
# 319                    12              25                    19        10
# 197                     9              24                    23        10
# 329                    12              24                    19        11
# 191                     9              22                    22        10
# 43                      7              25                    19        10
# 203                     8              23                    22        10
# 123                     8              23                    23        11
# 407                    11              26                    21        10
# 517                    13              23                    23        12
# 71                      9              23                    19        15
# 445                     9              24                    21        12
# 51                      9              25                    24        14
# 321                    12              25                    19        10
# 163                    11              25                    25        14
#
#      steal_avg_t  off_rating_t  ft_att_avg_t  season_o  SRS_o  SOS_o  \
# 358            7    102.895826            22      2014  14.11   9.72
# 488            9     91.341006            27      2015   9.23  -5.47
# 52             4    101.566227            16      2009  15.24   9.80
# 494            6     98.754448            21      2011  13.88   8.05
# 454            6     93.913323            22      2015  13.75   7.92
# 352            4     98.092643            22      2010  14.59   8.41
# 514            6     94.917845            18      2012  14.04   8.58
# 432            6     88.908259            17      2012  16.99   7.88
# 394            8     93.289359            24      2012  10.14   4.46
# 286            7     98.134767            25      2013  19.35   9.38
# 496            7    100.625315            17      2016  20.13   8.79
# 440            5     93.065693            19      2011   9.59   6.22
# 292            7     90.820444            20      2009  15.33   8.17
# 281            7     90.472028            20      2012  20.47   4.18
# 319            5     96.811953            20      2010  18.87  10.15
# 197            6     99.747475            23      2015  12.41  10.25
# 329            6    100.384590            23      2011  21.72   9.93
# 191            6     95.024949            19      2012  17.30   7.47
# 43             4    103.658537            14      2016  11.57   3.77
# 203            5     94.414894            21      2010  20.82   7.85
# 123            5     90.393956            20      2015  18.58   8.43
# 407            6     98.753538            20      2015  11.94   8.46
# 517            7     95.040756            25      2010  18.85   8.79
# 71             8     88.167741            21      2010  18.60   8.20
# 445            6     97.579480            20      2014   5.47  -2.03
# 51             5     88.352850            23      2016  -3.18 -12.12
# 321            5     96.811953            20      2010  25.84   8.38
# 163            6     83.851820            24      2014  -1.34  -3.34
#
#      win_pct_o  pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 358      0.611         70             65     0.436           0.403     0.686
# 488      0.824         80             63     0.478           0.438     0.735
# 52       0.706         71             64     0.440           0.410     0.661
# 494      0.629         71             66     0.440           0.442     0.656
# 454      0.639         73             67     0.462           0.448     0.738
# 352      0.676         72             66     0.438           0.409     0.655
# 514      0.743         68             62     0.457           0.404     0.730
# 432      0.806         69             60     0.455           0.400     0.684
# 394      0.706         72             66     0.451           0.456     0.737
# 286      0.763         75             65     0.474           0.397     0.707
# 496      0.771         79             68     0.479           0.421     0.757
# 440      0.639         70             67     0.453           0.402     0.695
# 292      0.757         71             63     0.471           0.406     0.685
# 281      0.914         77             59     0.497           0.385     0.705
# 319      0.784         77             68     0.451           0.394     0.672
# 197      0.594         72             69     0.448           0.428     0.742
# 329      0.821         73             61     0.472           0.380     0.692
# 191      0.771         73             63     0.455           0.411     0.749
# 43       0.743         74             66     0.461           0.422     0.705
# 203      0.824         73             60     0.475           0.441     0.671
# 123      0.824         80             70     0.452           0.415     0.730
# 407      0.686         73             70     0.421           0.440     0.725
# 517      0.771         73             63     0.472           0.385     0.665
# 71       0.714         74             64     0.453           0.384     0.663
# 445      0.714         71             62     0.480           0.388     0.725
# 51       0.735         74             63     0.454           0.393     0.683
# 321      0.919         77             59     0.494           0.407     0.701
# 163      0.576         69             67     0.432           0.437     0.691
#
#      allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 358                  19   75.550000              12                    11
# 488                  20   80.100000              11                     9
# 52                   19   77.052941              11                    10
# 494                  18   74.302857              11                    10
# 454                  14   72.877778               8                     8
# 352                  22   81.417647              14                    11
# 514                  17   74.771429              11                    11
# 432                  15   72.694444               9                    10
# 394                  16   75.382353               9                    11
# 286                  21   75.794737              10                     9
# 496                  14   79.171429               9                     8
# 440                  20   76.711111              10                    11
# 292                  17   78.043243              13                    10
# 281                  16   75.365714              11                    10
# 319                  13   85.437838              14                    11
# 197                  18   76.106250              10                    11
# 329                  18   77.441026              11                    10
# 191                  17   76.565714              11                     9
# 43                   22   79.537143              11                     9
# 203                  17   76.029412              14                    10
# 123                  19   83.111765              12                     9
# 407                  16   80.068571              11                    10
# 517                  17   77.177143              12                    14
# 71                   19   80.194286              12                    12
# 445                  20   72.331429               9                    11
# 51                   16   78.958824              11                    12
# 321                  15   74.032432              11                     8
# 163                  26   77.593939              10                    10
#
#      def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  \
# 358              25                    23        10            3
# 488              23                    22        12            9
# 52               25                    23        12            6
# 494              18                    24         8            6
# 454              23                    24         9            5
# 352              23                    20        14            6
# 514              19                    19        13            6
# 432              22                    22        10            6
# 394              18                    23        11            7
# 286              26                    21        11            6
# 496              27                    22        13            5
# 440              22                    23        12            6
# 292              25                    19        13            6
# 281              22                    19        11            7
# 319              28                    23        13            6
# 197              23                    22        12            5
# 329              23                    21        12            7
# 191              22                    20        13            6
# 43               25                    24        12            7
# 203              25                    19        11            4
# 123              27                    23        12            7
# 407              24                    26        11            6
# 517              25                    21        12            8
# 71               23                    23        13            9
# 445              22                    21        10            9
# 51               26                    23        11            6
# 321              23                    21        10            7
# 163              21                    23        14            8
#
#      off_rating_o  ft_att_avg_o           conf_name_t  \
# 358     92.653872            20              Big East
# 488     99.875156            20                Big 12
# 52      92.144439            26         Mountain West
# 494     95.554872            19            West Coast
# 454    100.167709            15     American Athletic
# 352     88.432917            24         Mountain West
# 514     90.943829            21        Atlantic Coast
# 432     94.917845            18               Big Ten
# 394     95.513071            17          Southeastern
# 286     98.951462            19                   Ivy
# 496     99.783472            19                Big 12
# 440     91.251448            22        Atlantic Coast
# 292     90.975204            20          Southeastern
# 281    102.168474            22     American Athletic
# 319     90.124004            23          Southeastern
# 197     94.604582            23              Big East
# 329     94.265280            22          Southeastern
# 191     95.342936            20               Big Ten
# 43      93.038293            21            West Coast
# 203     96.015474            23              Big East
# 123     96.255928            25               Big Ten
# 407     91.171853            22        Atlantic Coast
# 517     94.587591            20              Big East
# 71      92.275901            17           Ohio Valley
# 445     98.159267            20              Big East
# 51      93.719735            20              Big West
# 321    104.008470            20          Southeastern
# 163     88.924471            25  Mid Eastern Athletic
#
#                  conf_name_o  SAG_t  WLK_t  WOL_t  RTH_t  COL_t  POM_t  DOL_t  \
# 358           Atlantic Coast      6    4.0      2      2    2.0    5.0    2.0
# 488                Southland      6    6.0      8      8   11.0    6.0    7.0
# 52              Southeastern     40   30.0     42     50   41.0   20.0   55.0
# 494                  Big Ten     35   38.0     18     30   29.0   44.0   25.0
# 454                  Big Ten     66   64.0     74     63   65.0   58.0   60.0
# 352                   Big 12     21   20.0     12     28   20.0   16.0   14.0
# 514                 Big East     14    9.0      9     11    6.0   14.0   12.0
# 432           Atlantic Coast     44   43.0     34     34   38.0   42.0   29.0
# 394              Atlantic 10     28   33.0     42     40   37.0   34.0   34.0
# 286                  Big Ten     35   39.0     34     62   47.0   33.0   36.0
# 496                  Big Ten     16   19.0     23     21   27.0   17.0   15.0
# 440                 Big East     42   39.0     36     36   37.0   41.0   36.0
# 292                  Big Ten     19   22.0     17     20   16.0   35.0   17.0
# 281               West Coast     42   31.0     38     43   34.0   33.0   33.0
# 319           Atlantic Coast     12   10.0     18     15   14.0    7.0   16.0
# 197                   Big 12     30   32.0     30     27   35.0   40.0   39.0
# 329                   Big 12      1    1.0      1      1    2.0    1.0    1.0
# 191               Pacific 12      5    7.0      8      6    8.0    5.0    5.0
# 43               Atlantic 10     25   25.0     11     20   18.0   14.0   23.0
# 203           Atlantic Coast     46   38.0     46     57   41.0   54.0   58.0
# 123                 Big East     36   34.0     47     36   44.0   32.0   42.0
# 407                 Big East      3    3.0      7      4    4.0    4.0    2.0
# 517           Atlantic Coast     29   33.0     37     22   58.0   33.0   43.0
# 71            Atlantic Coast    108   87.0     93    124  103.0   95.0   99.0
# 445                 Sun Belt     26   24.0     35     30   33.0   26.0   35.0
# 51      Mid Eastern Athletic    200  215.0    194    204  169.0  218.0  173.0
# 321                  Big Ten     12   10.0     18     15   14.0    7.0   16.0
# 163  Metro Atlantic Athletic    266  249.0    252    290  257.0  250.0  267.0
#
#      RPI_t  MOR_t  SAG_o  WLK_o  WOL_o  RTH_o  COL_o  POM_o  DOL_o  RPI_o  \
# 358    2.0      4     32   33.0     40     32   40.0   38.0   40.0   39.0
# 488   10.0     11     57   55.0     62    101   83.0   33.0   80.0   62.0
# 52    30.0     26     17   20.0     15     16   20.0   23.0   15.0   13.0
# 494   28.0     44     28   31.0     37     28   39.0   24.0   34.0   47.0
# 454   58.0     71     37   51.0     45     43   49.0   56.0   35.0   57.0
# 352   15.0     35     25   34.0     28     24   31.0   29.0   24.0   23.0
# 514    4.0     14     22   21.0     17     17   18.0   25.0   17.0   13.0
# 432   40.0     33     14    9.0      9     11    6.0   14.0   12.0    4.0
# 394   48.0     29     57   53.0     44     54   48.0   57.0   55.0   46.0
# 286   46.0     37      8   10.0     16     12   12.0   10.0   11.0   18.0
# 496   21.0     11     12   11.0     18     14   17.0   15.0   19.0   19.0
# 440   39.0     29     55   53.0     57     55   50.0   58.0   52.0   41.0
# 292   14.0     27     25   28.0     30     22   26.0   24.0   20.0   28.0
# 281   37.0     35      6    5.0      1      3    5.0    4.0    1.0    6.0
# 319    7.0      6     15    9.0     13     14    8.0   14.0    9.0    6.0
# 197   56.0     31     46   39.0     31     30   33.0   42.0   36.0   36.0
# 329    2.0      3      4    6.0      6      7    6.0    4.0    6.0    6.0
# 191   10.0      3     23   16.0     19     18   11.0   19.0   18.0   15.0
# 43    17.0     26     50   43.0     46     54   30.0   52.0   44.0   22.0
# 203   33.0     48      5    4.0      7      4    5.0    5.0    6.0   10.0
# 123   42.0     30     14   12.0      3      7    5.0   15.0    8.0    7.0
# 407    5.0      3     44   46.0     22     28   28.0   46.0   29.0   39.0
# 517   64.0     34     10   12.0      9     11    9.0   11.0   12.0   18.0
# 71    77.0    106     13   14.0     17     12   15.0   12.0   18.0   17.0
# 445   30.0     32     78   80.0     74    112   91.0   71.0   93.0   53.0
# 51   166.0    214    179  160.0    173    214  178.0  152.0  194.0  202.0
# 321    7.0      6      1    1.0      1      1    2.0    1.0    1.0    2.0
# 163  251.0    241    159  155.0    165    165  158.0  146.0  154.0  168.0
#
#      MOR_o  top_conf  upset_seed_threshold  predicted_result  pred_win_prob
# 358     22        -1                     1                 1       0.527068
# 488     36         1                     1                 1       0.520687
# 52      19        -1                     1                 1       0.506900
# 494     19        -1                     0                 1       0.506067
# 454     43        -1                     0                 1       0.505418
# 352     22        -1                     1                 1       0.502003
# 514     25         1                     0                 1       0.501753
# 432     14         0                     0                 1       0.501552
# 394     46         1                     0                 1       0.501448
# 286      5        -1                     1                 1       0.500610
# 496     13         0                     0                 1       0.500535
# 440     60         1                     0                 1       0.500232
# 292     18         0                     0                 1       0.500191
# 281      4         0                     1                -1       0.499669
# 319     12         0                     0                -1       0.498785
# 197     55        -1                     0                -1       0.498190
# 329      8         0                     0                -1       0.498133
# 191     42         0                     0                -1       0.497874
# 43      50         0                     0                -1       0.497729
# 203      4        -1                     1                -1       0.497398
# 123     14         1                     0                -1       0.496862
# 407     45         1                     1                -1       0.496609
# 517      5        -1                     1                -1       0.496601
# 71       9        -1                     1                -1       0.496281
# 445     91         0                     1                -1       0.495810
# 51     210         0                     0                -1       0.493800
# 321      1         0                     0                -1       0.492393
# 163    100         0                     0                -1       0.482802

# %%
result = missed_predictions.apply(lambda x: utils.print_game_info(test_games, x['season_t'],
                                                                  x['round'], x['team_t']), axis=1)
# Out:
#                                     Villanova       North Carolina State     Stat Supports Winner
# Allow FG %                      40.60                              40.30         True  (L)
# Turnover Avg                    10.00                              10.00         True  (L)
# SOS                              7.55                               9.72         True  (H)
# Poss Avg                        73.86                              75.55         True  (H)
# Off Rb Avg                      10.00                              12.00         True  (H)
# Def Rb Avg                      24.00                              25.00         True  (H)
# Seed                              1                                  8          False  (L)
# SAG                              6.00                              32.00        False  (L)
# WLK                              4.00                              33.00        False  (L)
# WOL                              2.00                              40.00        False  (L)
# RTH                              2.00                              32.00        False  (L)
# COL                              2.00                              40.00        False  (L)
# POM                              5.00                              38.00        False  (L)
# DOL                              2.00                              40.00        False  (L)
# RPI                              2.00                              39.00        False  (L)
# MOR                              4.00                              22.00        False  (L)
# Allow PPG                       60.00                              65.00        False  (L)
# Allow Off Rb Avg                10.00                              11.00        False  (L)
# Allow Def Rb Avg                21.00                              23.00        False  (L)
# Allow FT ATT Avg                16.00                              19.00        False  (L)
# SRS                             23.13                              14.11        False  (H)
# PPG                             76.00                              70.00        False  (H)
# FG %                            47.00                              43.60        False  (H)
# FT ATT Avg                      22.00                              20.00        False  (H)
# FT %                            73.10                              68.60        False  (H)
# Takeaway Avg                     7.00                               3.00        False  (H)
# Win %                           91.70                              61.10        False  (H)
# Off Rating                     102.90                              92.65        False  (H)
#
#
# Top Conference=  North Carolina State
#
#  North Carolina State Wins.
#
# Supporting Stat Count= 6  out of 28  stats.
#
#
#
#                                 West Virginia          Stephen F. Austin     Stat Supports Winner
# Allow PPG                       66.00                              63.00         True  (L)
# Allow Def Rb Avg                22.00                              22.00         True  (L)
# Allow FT ATT Avg                27.00                              20.00         True  (L)
# Turnover Avg                    14.00                              12.00         True  (L)
# PPG                             78.00                              80.00         True  (H)
# FG %                            44.90                              47.80         True  (H)
# Def Rb Avg                      23.00                              23.00         True  (H)
# FT %                            67.30                              73.50         True  (H)
# Takeaway Avg                     9.00                               9.00         True  (H)
# Win %                           74.30                              82.40         True  (H)
# Off Rating                      91.34                              99.88         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              6.00                              57.00        False  (L)
# WLK                              6.00                              55.00        False  (L)
# WOL                              8.00                              62.00        False  (L)
# RTH                              8.00                             101.00        False  (L)
# COL                             11.00                              83.00        False  (L)
# POM                              6.00                              33.00        False  (L)
# DOL                              7.00                              80.00        False  (L)
# RPI                             10.00                              62.00        False  (L)
# MOR                             11.00                              36.00        False  (L)
# Allow FG %                      42.40                              43.80        False  (L)
# Allow Off Rb Avg                 8.00                               9.00        False  (L)
# SRS                             21.61                               9.23        False  (H)
# SOS                              9.78                              -5.47        False  (H)
# Poss Avg                        85.39                              80.10        False  (H)
# Off Rb Avg                      15.00                              11.00        False  (H)
# FT ATT Avg                      27.00                              20.00        False  (H)
#
#
# Top Conference=  West Virginia
#
#  Stephen F. Austin Wins.
#
# Supporting Stat Count= 11  out of 28  stats.
#
#
#
#                                    Utah State                  Texas A&M     Stat Supports Winner
# Seed                             12                                  5           True  (L)
# SAG                             40.00                              17.00         True  (L)
# WLK                             30.00                              20.00         True  (L)
# WOL                             42.00                              15.00         True  (L)
# RTH                             50.00                              16.00         True  (L)
# COL                             41.00                              20.00         True  (L)
# DOL                             55.00                              15.00         True  (L)
# RPI                             30.00                              13.00         True  (L)
# MOR                             26.00                              19.00         True  (L)
# SRS                             13.62                              15.24         True  (H)
# SOS                              1.23                               9.80         True  (H)
# Poss Avg                        71.87                              77.05         True  (H)
# Off Rb Avg                      10.00                              11.00         True  (H)
# Def Rb Avg                      25.00                              25.00         True  (H)
# FT ATT Avg                      16.00                              26.00         True  (H)
# Takeaway Avg                     4.00                               6.00         True  (H)
# POM                             20.00                              23.00        False  (L)
# Allow PPG                       59.00                              64.00        False  (L)
# Allow FG %                      40.50                              41.00        False  (L)
# Allow Off Rb Avg                 9.00                              10.00        False  (L)
# Allow Def Rb Avg                20.00                              23.00        False  (L)
# Allow FT ATT Avg                15.00                              19.00        False  (L)
# Turnover Avg                    10.00                              12.00        False  (L)
# PPG                             73.00                              71.00        False  (H)
# FG %                            48.80                              44.00        False  (H)
# FT %                            75.80                              66.10        False  (H)
# Win %                           77.10                              70.60        False  (H)
# Off Rating                     101.57                              92.14        False  (H)
#
#
# Top Conference=  Texas A&M
#
#  Texas A&M Wins.
#
# Supporting Stat Count= 16  out of 28  stats.
#
#
#
#                                  Saint Mary's                     Purdue     Stat Supports Winner
# SAG                             35.00                              28.00         True  (L)
# WLK                             38.00                              31.00         True  (L)
# RTH                             30.00                              28.00         True  (L)
# POM                             44.00                              24.00         True  (L)
# MOR                             44.00                              19.00         True  (L)
# Turnover Avg                    11.00                               8.00         True  (L)
# SRS                             11.26                              13.88         True  (H)
# SOS                              0.78                               8.05         True  (H)
# Off Rb Avg                      11.00                              11.00         True  (H)
# Takeaway Avg                     6.00                               6.00         True  (H)
# Seed                              7                                 10          False  (L)
# WOL                             18.00                              37.00        False  (L)
# COL                             29.00                              39.00        False  (L)
# DOL                             25.00                              34.00        False  (L)
# RPI                             28.00                              47.00        False  (L)
# Allow PPG                       62.00                              66.00        False  (L)
# Allow FG %                      42.80                              44.20        False  (L)
# Allow Off Rb Avg                 9.00                              10.00        False  (L)
# Allow Def Rb Avg                20.00                              24.00        False  (L)
# Allow FT ATT Avg                15.00                              18.00        False  (L)
# PPG                             74.00                              71.00        False  (H)
# Poss Avg                        74.93                              74.30        False  (H)
# FG %                            47.30                              44.00        False  (H)
# Def Rb Avg                      23.00                              18.00        False  (H)
# FT ATT Avg                      21.00                              19.00        False  (H)
# FT %                            72.90                              65.60        False  (H)
# Win %                           81.80                              62.90        False  (H)
# Off Rating                      98.75                              95.55        False  (H)
#
#
# Top Conference=  Purdue
#
#  Purdue Wins.
#
# Supporting Stat Count= 10  out of 28  stats.
#
#
#
#                                         Tulsa                   Michigan     Stat Supports Winner
# Seed                             11                                 11           True  (L)
# SAG                             66.00                              37.00         True  (L)
# WLK                             64.00                              51.00         True  (L)
# WOL                             74.00                              45.00         True  (L)
# RTH                             63.00                              43.00         True  (L)
# COL                             65.00                              49.00         True  (L)
# POM                             58.00                              56.00         True  (L)
# DOL                             60.00                              35.00         True  (L)
# RPI                             58.00                              57.00         True  (L)
# MOR                             71.00                              43.00         True  (L)
# Allow PPG                       69.00                              67.00         True  (L)
# Allow Off Rb Avg                10.00                               8.00         True  (L)
# Allow Def Rb Avg                26.00                              24.00         True  (L)
# Allow FT ATT Avg                19.00                              14.00         True  (L)
# Turnover Avg                    10.00                               9.00         True  (L)
# SRS                              9.79                              13.75         True  (H)
# SOS                              5.76                               7.92         True  (H)
# PPG                             73.00                              73.00         True  (H)
# FG %                            44.40                              46.20         True  (H)
# FT %                            67.70                              73.80         True  (H)
# Win %                           62.50                              63.90         True  (H)
# Off Rating                      93.91                             100.17         True  (H)
# Allow FG %                      41.60                              44.80        False  (L)
# Poss Avg                        77.73                              72.88        False  (H)
# Off Rb Avg                      10.00                               8.00        False  (H)
# Def Rb Avg                      25.00                              23.00        False  (H)
# FT ATT Avg                      22.00                              15.00        False  (H)
# Takeaway Avg                     6.00                               5.00        False  (H)
#
#
# Top Conference=  Michigan
#
#  Michigan Wins.
#
# Supporting Stat Count= 22  out of 28  stats.
#
#
#
#                                    Utah State               Kansas State     Stat Supports Winner
# Seed                             12                                  5           True  (L)
# RTH                             28.00                              24.00         True  (L)
# MOR                             35.00                              22.00         True  (L)
# Allow FG %                      41.50                              40.90         True  (L)
# Allow Off Rb Avg                11.00                              11.00         True  (L)
# Allow Def Rb Avg                20.00                              20.00         True  (L)
# SRS                             13.23                              14.59         True  (H)
# SOS                              0.50                               8.41         True  (H)
# PPG                             72.00                              72.00         True  (H)
# Poss Avg                        73.40                              81.42         True  (H)
# Off Rb Avg                      10.00                              14.00         True  (H)
# FT ATT Avg                      22.00                              24.00         True  (H)
# Takeaway Avg                     4.00                               6.00         True  (H)
# SAG                             21.00                              25.00        False  (L)
# WLK                             20.00                              34.00        False  (L)
# WOL                             12.00                              28.00        False  (L)
# COL                             20.00                              31.00        False  (L)
# POM                             16.00                              29.00        False  (L)
# DOL                             14.00                              24.00        False  (L)
# RPI                             15.00                              23.00        False  (L)
# Allow PPG                       58.00                              66.00        False  (L)
# Allow FT ATT Avg                17.00                              22.00        False  (L)
# Turnover Avg                    11.00                              14.00        False  (L)
# FG %                            47.00                              43.80        False  (H)
# Def Rb Avg                      26.00                              23.00        False  (H)
# FT %                            73.70                              65.50        False  (H)
# Win %                           88.20                              67.60        False  (H)
# Off Rating                      98.09                              88.43        False  (H)
#
#
# Top Conference=  Kansas State
#
#  Kansas State Wins.
#
# Supporting Stat Count= 13  out of 28  stats.
#
#
#
#                                    Miami (FL)                  Marquette     Stat Supports Winner
# Allow Def Rb Avg                22.00                              19.00         True  (L)
# SOS                              7.88                               8.58         True  (H)
# Poss Avg                        72.69                              74.77         True  (H)
# FG %                            45.50                              45.70         True  (H)
# Off Rb Avg                       9.00                              11.00         True  (H)
# FT ATT Avg                      18.00                              21.00         True  (H)
# FT %                            68.40                              73.00         True  (H)
# Takeaway Avg                     6.00                               6.00         True  (H)
# Seed                              2                                  3          False  (L)
# SAG                             14.00                              22.00        False  (L)
# WLK                              9.00                              21.00        False  (L)
# WOL                              9.00                              17.00        False  (L)
# RTH                             11.00                              17.00        False  (L)
# COL                              6.00                              18.00        False  (L)
# POM                             14.00                              25.00        False  (L)
# DOL                             12.00                              17.00        False  (L)
# RPI                              4.00                              13.00        False  (L)
# MOR                             14.00                              25.00        False  (L)
# Allow PPG                       60.00                              62.00        False  (L)
# Allow FG %                      40.00                              40.40        False  (L)
# Allow Off Rb Avg                10.00                              11.00        False  (L)
# Allow FT ATT Avg                15.00                              17.00        False  (L)
# Turnover Avg                    10.00                              13.00        False  (L)
# SRS                             16.99                              14.04        False  (H)
# PPG                             69.00                              68.00        False  (H)
# Def Rb Avg                      22.00                              19.00        False  (H)
# Win %                           80.60                              74.30        False  (H)
# Off Rating                      94.92                              90.94        False  (H)
#
#
# Top Conference=  Miami (FL)
#
#  Marquette Wins.
#
# Supporting Stat Count= 8  out of 28  stats.
#
#
#
#                                      Illinois                 Miami (FL)     Stat Supports Winner
# Seed                              7                                  2           True  (L)
# SAG                             44.00                              14.00         True  (L)
# WLK                             43.00                               9.00         True  (L)
# WOL                             34.00                               9.00         True  (L)
# RTH                             34.00                              11.00         True  (L)
# COL                             38.00                               6.00         True  (L)
# POM                             42.00                              14.00         True  (L)
# DOL                             29.00                              12.00         True  (L)
# RPI                             40.00                               4.00         True  (L)
# MOR                             33.00                              14.00         True  (L)
# Allow PPG                       64.00                              60.00         True  (L)
# Allow FG %                      42.40                              40.00         True  (L)
# Allow Off Rb Avg                10.00                              10.00         True  (L)
# Allow Def Rb Avg                24.00                              22.00         True  (L)
# Allow FT ATT Avg                19.00                              15.00         True  (L)
# Turnover Avg                    11.00                              10.00         True  (L)
# SRS                             13.23                              16.99         True  (H)
# PPG                             68.00                              69.00         True  (H)
# FG %                            41.20                              45.50         True  (H)
# Def Rb Avg                      18.00                              22.00         True  (H)
# FT ATT Avg                      17.00                              18.00         True  (H)
# Takeaway Avg                     6.00                               6.00         True  (H)
# Win %                           63.90                              80.60         True  (H)
# Off Rating                      88.91                              94.92         True  (H)
# SOS                             10.08                               7.88        False  (H)
# Poss Avg                        76.48                              72.69        False  (H)
# Off Rb Avg                      11.00                               9.00        False  (H)
# FT %                            72.60                              68.40        False  (H)
#
#  Miami (FL) Wins.
#
# Supporting Stat Count= 24  out of 28  stats.
#
#
#
#                                      Ole Miss                   La Salle     Stat Supports Winner
# RPI                             48.00                              46.00         True  (L)
# Allow PPG                       66.00                              66.00         True  (L)
# Allow Off Rb Avg                12.00                              11.00         True  (L)
# Allow Def Rb Avg                25.00                              23.00         True  (L)
# Allow FT ATT Avg                18.00                              16.00         True  (L)
# SOS                              4.14                               4.46         True  (H)
# FG %                            43.80                              45.10         True  (H)
# FT %                            67.80                              73.70         True  (H)
# Off Rating                      93.29                              95.51         True  (H)
# Seed                             12                                 13          False  (L)
# SAG                             28.00                              57.00        False  (L)
# WLK                             33.00                              53.00        False  (L)
# WOL                             42.00                              44.00        False  (L)
# RTH                             40.00                              54.00        False  (L)
# COL                             37.00                              48.00        False  (L)
# POM                             34.00                              57.00        False  (L)
# DOL                             34.00                              55.00        False  (L)
# MOR                             29.00                              46.00        False  (L)
# Allow FG %                      40.80                              45.60        False  (L)
# Turnover Avg                    10.00                              11.00        False  (L)
# SRS                             14.42                              10.14        False  (H)
# PPG                             77.00                              72.00        False  (H)
# Poss Avg                        82.54                              75.38        False  (H)
# Off Rb Avg                      12.00                               9.00        False  (H)
# Def Rb Avg                      21.00                              18.00        False  (H)
# FT ATT Avg                      24.00                              17.00        False  (H)
# Takeaway Avg                     8.00                               7.00        False  (H)
# Win %                           75.00                              70.60        False  (H)
#
#
# Top Conference=  Ole Miss
#
#  La Salle Wins.
#
# Supporting Stat Count= 9  out of 28  stats.
#
#
#
#                                       Harvard             Michigan State     Stat Supports Winner
# Seed                             12                                  4           True  (L)
# SAG                             35.00                               8.00         True  (L)
# WLK                             39.00                              10.00         True  (L)
# WOL                             34.00                              16.00         True  (L)
# RTH                             62.00                              12.00         True  (L)
# COL                             47.00                              12.00         True  (L)
# POM                             33.00                              10.00         True  (L)
# DOL                             36.00                              11.00         True  (L)
# RPI                             46.00                              18.00         True  (L)
# MOR                             37.00                               5.00         True  (L)
# Allow FG %                      40.90                              39.70         True  (L)
# Allow Off Rb Avg                 9.00                               9.00         True  (L)
# Allow Def Rb Avg                21.00                              21.00         True  (L)
# Turnover Avg                    11.00                              11.00         True  (L)
# SRS                             10.79                              19.35         True  (H)
# SOS                             -0.47                               9.38         True  (H)
# PPG                             73.00                              75.00         True  (H)
# Poss Avg                        74.39                              75.79         True  (H)
# FG %                            46.50                              47.40         True  (H)
# Off Rb Avg                      10.00                              10.00         True  (H)
# Def Rb Avg                      23.00                              26.00         True  (H)
# Off Rating                      98.13                              98.95         True  (H)
# Allow PPG                       61.00                              65.00        False  (L)
# Allow FT ATT Avg                18.00                              21.00        False  (L)
# FT ATT Avg                      25.00                              19.00        False  (H)
# FT %                            72.40                              70.70        False  (H)
# Takeaway Avg                     7.00                               6.00        False  (H)
# Win %                           84.40                              76.30        False  (H)
#
#
# Top Conference=  Michigan State
#
#  Michigan State Wins.
#
# Supporting Stat Count= 22  out of 28  stats.
#
#
#
#                                    Iowa State                     Purdue     Stat Supports Winner
# Seed                              5                                  4           True  (L)
# SAG                             16.00                              12.00         True  (L)
# WLK                             19.00                              11.00         True  (L)
# WOL                             23.00                              18.00         True  (L)
# RTH                             21.00                              14.00         True  (L)
# COL                             27.00                              17.00         True  (L)
# POM                             17.00                              15.00         True  (L)
# RPI                             21.00                              19.00         True  (L)
# Allow PPG                       72.00                              68.00         True  (L)
# Allow FG %                      42.80                              42.10         True  (L)
# Allow Off Rb Avg                11.00                               8.00         True  (L)
# Allow Def Rb Avg                26.00                              22.00         True  (L)
# Allow FT ATT Avg                15.00                              14.00         True  (L)
# FG %                            47.20                              47.90         True  (H)
# Off Rb Avg                       9.00                               9.00         True  (H)
# Def Rb Avg                      25.00                              27.00         True  (H)
# FT ATT Avg                      17.00                              19.00         True  (H)
# FT %                            70.00                              75.70         True  (H)
# Win %                           68.60                              77.10         True  (H)
# DOL                             15.00                              19.00        False  (L)
# MOR                             11.00                              13.00        False  (L)
# Turnover Avg                    10.00                              13.00        False  (L)
# SRS                             20.51                              20.13        False  (H)
# SOS                             11.94                               8.79        False  (H)
# PPG                             80.00                              79.00        False  (H)
# Poss Avg                        79.50                              79.17        False  (H)
# Takeaway Avg                     7.00                               5.00        False  (H)
# Off Rating                     100.63                              99.78        False  (H)
#
#  Purdue Wins.
#
# Supporting Stat Count= 19  out of 28  stats.
#
#
#
#                                    Notre Dame                     Xavier     Stat Supports Winner
# Allow FG %                      41.40                              40.20         True  (L)
# Allow Off Rb Avg                11.00                              11.00         True  (L)
# Allow Def Rb Avg                23.00                              23.00         True  (L)
# PPG                             66.00                              70.00         True  (H)
# Poss Avg                        70.92                              76.71         True  (H)
# FG %                            43.40                              45.30         True  (H)
# Off Rb Avg                      10.00                              10.00         True  (H)
# Def Rb Avg                      20.00                              22.00         True  (H)
# FT ATT Avg                      19.00                              22.00         True  (H)
# Takeaway Avg                     5.00                               6.00         True  (H)
# Seed                              7                                 10          False  (L)
# SAG                             42.00                              55.00        False  (L)
# WLK                             39.00                              53.00        False  (L)
# WOL                             36.00                              57.00        False  (L)
# RTH                             36.00                              55.00        False  (L)
# COL                             37.00                              50.00        False  (L)
# POM                             41.00                              58.00        False  (L)
# DOL                             36.00                              52.00        False  (L)
# RPI                             39.00                              41.00        False  (L)
# MOR                             29.00                              60.00        False  (L)
# Allow PPG                       61.00                              67.00        False  (L)
# Allow FT ATT Avg                14.00                              20.00        False  (L)
# Turnover Avg                    10.00                              12.00        False  (L)
# SRS                             11.18                               9.59        False  (H)
# SOS                              6.47                               6.22        False  (H)
# FT %                            70.40                              69.50        False  (H)
# Win %                           64.70                              63.90        False  (H)
# Off Rating                      93.07                              91.25        False  (H)
#
#
# Top Conference=  Notre Dame
#
#  Xavier Wins.
#
# Supporting Stat Count= 10  out of 28  stats.
#
#
#
#                                     Tennessee             Michigan State     Stat Supports Winner
# Seed                              6                                  5           True  (L)
# POM                             35.00                              24.00         True  (L)
# MOR                             27.00                              18.00         True  (L)
# Allow PPG                       65.00                              63.00         True  (L)
# Allow Off Rb Avg                11.00                              10.00         True  (L)
# Allow Def Rb Avg                23.00                              19.00         True  (L)
# Allow FT ATT Avg                22.00                              17.00         True  (L)
# Turnover Avg                    13.00                              13.00         True  (L)
# SOS                              7.75                               8.17         True  (H)
# FG %                            45.60                              47.10         True  (H)
# Off Rb Avg                      11.00                              13.00         True  (H)
# Def Rb Avg                      24.00                              25.00         True  (H)
# FT ATT Avg                      20.00                              20.00         True  (H)
# FT %                            67.10                              68.50         True  (H)
# Win %                           75.70                              75.70         True  (H)
# Off Rating                      90.82                              90.98         True  (H)
# SAG                             19.00                              25.00        False  (L)
# WLK                             22.00                              28.00        False  (L)
# WOL                             17.00                              30.00        False  (L)
# RTH                             20.00                              22.00        False  (L)
# COL                             16.00                              26.00        False  (L)
# DOL                             17.00                              20.00        False  (L)
# RPI                             14.00                              28.00        False  (L)
# Allow FG %                      39.60                              40.60        False  (L)
# SRS                             16.05                              15.33        False  (H)
# PPG                             73.00                              71.00        False  (H)
# Poss Avg                        80.38                              78.04        False  (H)
# Takeaway Avg                     7.00                               6.00        False  (H)
#
#  Michigan State Wins.
#
# Supporting Stat Count= 16  out of 28  stats.
#
#
#
#                                 Wichita State                    Gonzaga     Stat Supports Winner
# Allow Off Rb Avg                 9.00                              10.00         True  (L)
# SOS                              6.09                               4.18         True  (H)
# Poss Avg                        76.27                              75.37         True  (H)
# Off Rb Avg                      13.00                              11.00         True  (H)
# Takeaway Avg                     7.00                               7.00         True  (H)
# Seed                              9                                  1          False  (L)
# SAG                             42.00                               6.00        False  (L)
# WLK                             31.00                               5.00        False  (L)
# WOL                             38.00                               1.00        False  (L)
# RTH                             43.00                               3.00        False  (L)
# COL                             34.00                               5.00        False  (L)
# POM                             33.00                               4.00        False  (L)
# DOL                             33.00                               1.00        False  (L)
# RPI                             37.00                               6.00        False  (L)
# MOR                             35.00                               4.00        False  (L)
# Allow PPG                       61.00                              59.00        False  (L)
# Allow FG %                      39.50                              38.50        False  (L)
# Allow Def Rb Avg                21.00                              19.00        False  (L)
# Allow FT ATT Avg                19.00                              16.00        False  (L)
# Turnover Avg                    12.00                              11.00        False  (L)
# SRS                             14.68                              20.47        False  (H)
# PPG                             69.00                              77.00        False  (H)
# FG %                            44.00                              49.70        False  (H)
# Def Rb Avg                      21.00                              22.00        False  (H)
# FT ATT Avg                      20.00                              22.00        False  (H)
# FT %                            69.90                              70.50        False  (H)
# Win %                           76.90                              91.40        False  (H)
# Off Rating                      90.47                             102.17        False  (H)
#
#  Wichita State Wins.
#
# Supporting Stat Count= 5  out of 28  stats.
#
#
#
#                                      Kentucky             North Carolina     Stat Supports Winner
# SAG                             12.00                              15.00         True  (L)
# POM                              7.00                              14.00         True  (L)
# MOR                              6.00                              12.00         True  (L)
# Allow PPG                       63.00                              68.00         True  (L)
# Allow FG %                      37.40                              39.40         True  (L)
# Allow Def Rb Avg                19.00                              23.00         True  (L)
# Turnover Avg                    10.00                              13.00         True  (L)
# SRS                             20.30                              18.87         True  (H)
# FG %                            45.90                              45.10         True  (H)
# FT %                            71.00                              67.20         True  (H)
# Off Rating                      96.81                              90.12         True  (H)
# Seed                              4                                  2          False  (L)
# WLK                             10.00                               9.00        False  (L)
# WOL                             18.00                              13.00        False  (L)
# RTH                             15.00                              14.00        False  (L)
# COL                             14.00                               8.00        False  (L)
# DOL                             16.00                               9.00        False  (L)
# RPI                              7.00                               6.00        False  (L)
# Allow Off Rb Avg                12.00                              11.00        False  (L)
# Allow FT ATT Avg                15.00                              13.00        False  (L)
# SOS                              8.91                              10.15        False  (H)
# PPG                             74.00                              77.00        False  (H)
# Poss Avg                        76.44                              85.44        False  (H)
# Off Rb Avg                      11.00                              14.00        False  (H)
# Def Rb Avg                      25.00                              28.00        False  (H)
# FT ATT Avg                      20.00                              23.00        False  (H)
# Takeaway Avg                     5.00                               6.00        False  (H)
# Win %                           76.30                              78.40        False  (H)
#
#  Kentucky Wins.
#
# Supporting Stat Count= 11  out of 28  stats.
#
#
#
#                                        Butler                 Texas Tech     Stat Supports Winner
# SAG                             30.00                              46.00         True  (L)
# WLK                             32.00                              39.00         True  (L)
# WOL                             30.00                              31.00         True  (L)
# RTH                             27.00                              30.00         True  (L)
# POM                             40.00                              42.00         True  (L)
# MOR                             31.00                              55.00         True  (L)
# Allow Off Rb Avg                 9.00                              11.00         True  (L)
# Turnover Avg                    10.00                              12.00         True  (L)
# SRS                             16.46                              12.41         True  (H)
# PPG                             79.00                              72.00         True  (H)
# Poss Avg                        79.20                              76.11         True  (H)
# FG %                            46.60                              44.80         True  (H)
# Off Rb Avg                      11.00                              10.00         True  (H)
# Def Rb Avg                      24.00                              23.00         True  (H)
# FT ATT Avg                      23.00                              23.00         True  (H)
# Takeaway Avg                     6.00                               5.00         True  (H)
# Win %                           66.70                              59.40         True  (H)
# Off Rating                      99.75                              94.60         True  (H)
# Seed                              9                                  8          False  (L)
# COL                             35.00                              33.00        False  (L)
# DOL                             39.00                              36.00        False  (L)
# RPI                             56.00                              36.00        False  (L)
# Allow PPG                       71.00                              69.00        False  (L)
# Allow FG %                      43.50                              42.80        False  (L)
# Allow Def Rb Avg                23.00                              22.00        False  (L)
# Allow FT ATT Avg                20.00                              18.00        False  (L)
# SOS                              7.55                              10.25        False  (H)
# FT %                            73.10                              74.20        False  (H)
#
#
# Top Conference=  Texas Tech
#
#  Butler Wins.
#
# Supporting Stat Count= 18  out of 28  stats.
#
#
#
#                                      Kentucky                     Kansas     Stat Supports Winner
# Seed                              1                                  2           True  (L)
# SAG                              1.00                               4.00         True  (L)
# WLK                              1.00                               6.00         True  (L)
# WOL                              1.00                               6.00         True  (L)
# RTH                              1.00                               7.00         True  (L)
# COL                              2.00                               6.00         True  (L)
# POM                              1.00                               4.00         True  (L)
# DOL                              1.00                               6.00         True  (L)
# RPI                              2.00                               6.00         True  (L)
# MOR                              3.00                               8.00         True  (L)
# Allow PPG                       60.00                              61.00         True  (L)
# Allow FG %                      37.40                              38.00         True  (L)
# Allow Def Rb Avg                19.00                              21.00         True  (L)
# Allow FT ATT Avg                15.00                              18.00         True  (L)
# Turnover Avg                    11.00                              12.00         True  (L)
# SRS                             24.73                              21.72         True  (H)
# PPG                             77.00                              73.00         True  (H)
# FG %                            48.80                              47.20         True  (H)
# Off Rb Avg                      11.00                              11.00         True  (H)
# Def Rb Avg                      24.00                              23.00         True  (H)
# FT ATT Avg                      23.00                              22.00         True  (H)
# FT %                            72.30                              69.20         True  (H)
# Win %                           95.00                              82.10         True  (H)
# Off Rating                     100.38                              94.27         True  (H)
# Allow Off Rb Avg                12.00                              10.00        False  (L)
# SOS                              7.93                               9.93        False  (H)
# Poss Avg                        76.70                              77.44        False  (H)
# Takeaway Avg                     6.00                               7.00        False  (H)
#
#  Kentucky Wins.
#
# Supporting Stat Count= 24  out of 28  stats.
#
#
#
#                                    Ohio State                    Arizona     Stat Supports Winner
# Seed                              2                                  6           True  (L)
# SAG                              5.00                              23.00         True  (L)
# WLK                              7.00                              16.00         True  (L)
# WOL                              8.00                              19.00         True  (L)
# RTH                              6.00                              18.00         True  (L)
# COL                              8.00                              11.00         True  (L)
# POM                              5.00                              19.00         True  (L)
# DOL                              5.00                              18.00         True  (L)
# RPI                             10.00                              15.00         True  (L)
# MOR                              3.00                              42.00         True  (L)
# Allow PPG                       59.00                              63.00         True  (L)
# Allow FG %                      39.50                              41.10         True  (L)
# Allow Off Rb Avg                 9.00                               9.00         True  (L)
# Allow FT ATT Avg                15.00                              17.00         True  (L)
# Turnover Avg                    10.00                              13.00         True  (L)
# ...
# Poss Avg                        78.91                              77.18         True  (H)
# Off Rb Avg                      12.00                              12.00         True  (H)
# FT ATT Avg                      25.00                              20.00         True  (H)
# FT %                            69.60                              66.50         True  (H)
# Off Rating                      95.04                              94.59         True  (H)
# Seed                             11                                  3          False  (L)
# SAG                             29.00                              10.00        False  (L)
# WLK                             33.00                              12.00        False  (L)
# WOL                             37.00                               9.00        False  (L)
# RTH                             22.00                              11.00        False  (L)
# COL                             58.00                               9.00        False  (L)
# POM                             33.00                              11.00        False  (L)
# DOL                             43.00                              12.00        False  (L)
# RPI                             64.00                              18.00        False  (L)
# MOR                             34.00                               5.00        False  (L)
# Allow PPG                       68.00                              63.00        False  (L)
# Allow FG %                      40.20                              38.50        False  (L)
# Allow Def Rb Avg                23.00                              21.00        False  (L)
# Allow FT ATT Avg                18.00                              17.00        False  (L)
# SRS                             14.89                              18.85        False  (H)
# SOS                              8.51                               8.79        False  (H)
# FG %                            46.50                              47.20        False  (H)
# Def Rb Avg                      23.00                              25.00        False  (H)
# Takeaway Avg                     7.00                               8.00        False  (H)
# Win %                           59.50                              77.10        False  (H)
#
#
# Top Conference=  Syracuse
#
#  Marquette Wins.
#
# Supporting Stat Count= 8  out of 28  stats.
#
#
#
#                                Morehead State                 Louisville     Stat Supports Winner
# Allow PPG                       61.00                              64.00         True  (L)
# Allow Off Rb Avg                 9.00                              12.00         True  (L)
# Allow Def Rb Avg                19.00                              23.00         True  (L)
# Allow FT ATT Avg                19.00                              19.00         True  (L)
# FG %                            45.40                              45.30         True  (H)
# Off Rb Avg                      13.00                              12.00         True  (H)
# Def Rb Avg                      23.00                              23.00         True  (H)
# FT ATT Avg                      21.00                              17.00         True  (H)
# FT %                            67.40                              66.30         True  (H)
# Win %                           71.40                              71.40         True  (H)
# Seed                             13                                  4          False  (L)
# SAG                            108.00                              13.00        False  (L)
# WLK                             87.00                              14.00        False  (L)
# WOL                             93.00                              17.00        False  (L)
# RTH                            124.00                              12.00        False  (L)
# COL                            103.00                              15.00        False  (L)
# POM                             95.00                              12.00        False  (L)
# DOL                             99.00                              18.00        False  (L)
# RPI                             77.00                              17.00        False  (L)
# MOR                            106.00                               9.00        False  (L)
# Allow FG %                      44.40                              38.40        False  (L)
# Turnover Avg                    15.00                              13.00        False  (L)
# SRS                              2.81                              18.60        False  (H)
# SOS                             -3.13                               8.20        False  (H)
# PPG                             68.00                              74.00        False  (H)
# Poss Avg                        77.13                              80.19        False  (H)
# Takeaway Avg                     8.00                               9.00        False  (H)
# Off Rating                      88.17                              92.28        False  (H)
#
#
# Top Conference=  Louisville
#
#  Morehead State Wins.
#
# Supporting Stat Count= 10  out of 28  stats.
#
#
#
#                                        Xavier              Georgia State     Stat Supports Winner
# Seed                              6                                 14           True  (L)
# SAG                             26.00                              78.00         True  (L)
# WLK                             24.00                              80.00         True  (L)
# WOL                             35.00                              74.00         True  (L)
# RTH                             30.00                             112.00         True  (L)
# COL                             33.00                              91.00         True  (L)
# POM                             26.00                              71.00         True  (L)
# DOL                             35.00                              93.00         True  (L)
# RPI                             30.00                              53.00         True  (L)
# MOR                             32.00                              91.00         True  (L)
# Allow Off Rb Avg                 9.00                              11.00         True  (L)
# Allow Def Rb Avg                21.00                              21.00         True  (L)
# Allow FT ATT Avg                18.00                              20.00         True  (L)
# SRS                             15.42                               5.47         True  (H)
# SOS                              9.48                              -2.03         True  (H)
# PPG                             73.00                              71.00         True  (H)
# Poss Avg                        74.81                              72.33         True  (H)
# Off Rb Avg                       9.00                               9.00         True  (H)
# Def Rb Avg                      24.00                              22.00         True  (H)
# FT ATT Avg                      20.00                              20.00         True  (H)
# FT %                            73.00                              72.50         True  (H)
# Allow PPG                       67.00                              62.00        False  (L)
# Allow FG %                      43.50                              38.80        False  (L)
# Turnover Avg                    12.00                              10.00        False  (L)
# FG %                            47.50                              48.00        False  (H)
# Takeaway Avg                     6.00                               9.00        False  (H)
# Win %                           62.20                              71.40        False  (H)
# Off Rating                      97.58                              98.16        False  (H)
#
#  Xavier Wins.
#
# Supporting Stat Count= 21  out of 28  stats.
#
#
#
#                                      UC Davis     North Carolina Central     Stat Supports Winner
# Seed                             16                                 16           True  (L)
# RTH                            204.00                             214.00         True  (L)
# COL                            169.00                             178.00         True  (L)
# DOL                            173.00                             194.00         True  (L)
# RPI                            166.00                             202.00         True  (L)
# Allow Off Rb Avg                 9.00                              12.00         True  (L)
# SOS                             -4.68                             -12.12         True  (H)
# Poss Avg                        79.23                              78.96         True  (H)
# FT ATT Avg                      23.00                              20.00         True  (H)
# SAG                            200.00                             179.00        False  (L)
# WLK                            215.00                             160.00        False  (L)
# WOL                            194.00                             173.00        False  (L)
# POM                            218.00                             152.00        False  (L)
# MOR                            214.00                             210.00        False  (L)
# Allow PPG                       69.00                              63.00        False  (L)
# Allow FG %                      42.60                              39.30        False  (L)
# Allow Def Rb Avg                24.00                              23.00        False  (L)
# Allow FT ATT Avg                18.00                              16.00        False  (L)
# Turnover Avg                    14.00                              11.00        False  (L)
# SRS                             -5.21                              -3.18        False  (H)
# PPG                             70.00                              74.00        False  (H)
# FG %                            43.50                              45.40        False  (H)
# Off Rb Avg                      10.00                              11.00        False  (H)
# Def Rb Avg                      25.00                              26.00        False  (H)
# FT %                            67.40                              68.30        False  (H)
# Takeaway Avg                     5.00                               6.00        False  (H)
# Win %                           63.90                              73.50        False  (H)
# Off Rating                      88.35                              93.72        False  (H)
#
#  UC Davis Wins.
#
# Supporting Stat Count= 9  out of 28  stats.
#
#
#
#                                      Kentucky                 Ohio State     Stat Supports Winner
# Allow FG %                      37.40                              40.70         True  (L)
# Allow Def Rb Avg                19.00                              21.00         True  (L)
# Allow FT ATT Avg                15.00                              15.00         True  (L)
# Turnover Avg                    10.00                              10.00         True  (L)
# SOS                              8.91                               8.38         True  (H)
# Poss Avg                        76.44                              74.03         True  (H)
# Off Rb Avg                      11.00                              11.00         True  (H)
# Def Rb Avg                      25.00                              23.00         True  (H)
# FT ATT Avg                      20.00                              20.00         True  (H)
# FT %                            71.00                              70.10         True  (H)
# Seed                              4                                  1          False  (L)
# SAG                             12.00                               1.00        False  (L)
# WLK                             10.00                               1.00        False  (L)
# WOL                             18.00                               1.00        False  (L)
# RTH                             15.00                               1.00        False  (L)
# COL                             14.00                               2.00        False  (L)
# POM                              7.00                               1.00        False  (L)
# DOL                             16.00                               1.00        False  (L)
# RPI                              7.00                               2.00        False  (L)
# MOR                              6.00                               1.00        False  (L)
# Allow PPG                       63.00                              59.00        False  (L)
# Allow Off Rb Avg                12.00                               8.00        False  (L)
# SRS                             20.30                              25.84        False  (H)
# PPG                             74.00                              77.00        False  (H)
# FG %                            45.90                              49.40        False  (H)
# Takeaway Avg                     5.00                               7.00        False  (H)
# Win %                           76.30                              91.90        False  (H)
# Off Rating                      96.81                             104.01        False  (H)
#
#  Kentucky Wins.
#
# Supporting Stat Count= 10  out of 28  stats.
#
#
#
#                                       Hampton                  Manhattan     Stat Supports Winner
# Seed                             16                                 16           True  (L)
# Allow FG %                      41.30                              43.70         True  (L)
# Allow FT ATT Avg                25.00                              26.00         True  (L)
# Turnover Avg                    14.00                              14.00         True  (L)
# Poss Avg                        79.90                              77.59         True  (H)
# Off Rb Avg                      11.00                              10.00         True  (H)
# Def Rb Avg                      25.00                              21.00         True  (H)
# SAG                            266.00                             159.00        False  (L)
# WLK                            249.00                             155.00        False  (L)
# WOL                            252.00                             165.00        False  (L)
# RTH                            290.00                             165.00        False  (L)
# COL                            257.00                             158.00        False  (L)
# POM                            250.00                             146.00        False  (L)
# DOL                            267.00                             154.00        False  (L)
# RPI                            251.00                             168.00        False  (L)
# MOR                            241.00                             100.00        False  (L)
# Allow PPG                       68.00                              67.00        False  (L)
# Allow Off Rb Avg                11.00                              10.00        False  (L)
# Allow Def Rb Avg                25.00                              23.00        False  (L)
# SRS                             -8.25                              -1.34        False  (H)
# SOS                             -7.08                              -3.34        False  (H)
# PPG                             67.00                              69.00        False  (H)
# FG %                            40.60                              43.20        False  (H)
# FT ATT Avg                      24.00                              25.00        False  (H)
# FT %                            65.20                              69.10        False  (H)
# Takeaway Avg                     6.00                               8.00        False  (H)
# Win %                           48.60                              57.60        False  (H)
# Off Rating                      83.85                              88.92        False  (H)
#
#  Hampton Wins.
#
# Supporting Stat Count= 7  out of 28  stats.

# %%
for key,val in result[0:].items():
     print("key={}  value= {}".format(key, val[1][1]))

# %%
correct_predictions = test_games[test_games['game_result'] == 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)

print("Correct predictions= ", correct_predictions.shape[0])

correct_predictions

# %%
result = bdt.decision_function(X_train)
print(result)
