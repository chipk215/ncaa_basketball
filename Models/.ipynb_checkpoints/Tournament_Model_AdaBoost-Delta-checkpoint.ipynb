# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator
import sys

# Non pythonic hack to reuse some utility code
if sys.path[0] != '../py_utils':
    sys.path.insert(0,'../py_utils')

import utils
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
from pathlib import Path
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)
# Out:
# Seaborn version:  0.9.0

# %%
def eliminate_features(classifier, X, y ):
    iteration = 0
    print("Iteration= ", iteration)
    iteration += 1
    model_stats = {}
    drop_list = []
    # get baseline by identifying sorted important features using all of the provided features
    model_stats = utils.save_model_stats(classifier,X,y,model_stats)
    
    important_features = utils.display_important_features(classifier.feature_importances_, X,0)
    # least important feature
    least_important_label = important_features[-1][0]
    print("least_important label= ", least_important_label)
    
    drop_list.append(least_important_label)
    del important_features[-1]
    
    # drop list contains all of the feature labels except for the feature label identified as being most important
    list_count = len(important_features)
    while list_count > 0:
        print("Iteration= ", iteration)
        iteration += 1
        model_stats = utils.save_model_stats(classifier,X.drop(columns=drop_list),y,model_stats)
        least_important_label = important_features[-1][0]
        print("least_important label= ", least_important_label)
        drop_list.append(least_important_label)
        del important_features[-1]
        list_count-=1
    return model_stats

# %% [markdown]
# #### Read in regular season team statistics from SRCBB https://www.sports-reference.com/cbb/

# %%
summary_data = pd.read_csv(Path( '../Data/sr_summaries_kaggle_id.csv'))
print(summary_data.shape)

#display rows with NaNs
summary_data[summary_data.isnull().any(axis=1)]
# Out:
# (2773, 22)
#     season          School team_id  Games    SRS   SOS  win_pct  pts_avg  \
# 38    2009  Centenary (LA)     NaN     29 -17.16 -5.08    0.276       70
#
#     opp_pts_avg  fg_pct  allow_fg_pct  ft_pct  allow_ft_att_avg   poss_avg  \
# 38           80   0.416          0.49   0.733                25  80.641379
#
#     off_rebs_avg  allow_off_rebs_avg  def_rebs_avg  allow_def_rebs_avg  \
# 38             9                  11            20                  27
#
#     to_avg  steal_avg  off_rating  ft_att_avg
# 38      15          7   86.804071          21

# %%
#drop records with NaNs
summary_data.dropna(inplace=True)
print(summary_data.shape)
# Out:
# (2772, 22)

# %%
summary_data.rename(str.lower, axis='columns', inplace=True)
summary_data.head()
# Out:
#    season         school                               team_id  games    srs  \
# 0    2009      Air Force  aa7af640-5762-4686-9181-39f7b8a8186e     31  -4.90
# 1    2009          Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20     35   2.82
# 2    2009        Alabama  c2104cdc-c83d-40d2-a3cd-df986e29f5d3     32  10.34
# 3    2009    Alabama A&M  949c3398-85e4-4c63-ba71-9a82e06ddea4     27 -20.19
# 4    2009  Alabama State  267d417a-8f85-4c87-a15a-068c089a74c6     31 -14.41
#
#      sos  win_pct  pts_avg  opp_pts_avg  fg_pct  allow_fg_pct  ft_pct  \
# 0   3.13    0.323       57           63   0.443         0.451   0.635
# 1  -1.50    0.686       70           65   0.433         0.417   0.657
# 2   6.62    0.531       68           64   0.441         0.424   0.707
# 3 -13.71    0.407       65           69   0.382         0.424   0.635
# 4 -12.02    0.516       64           65   0.404         0.435   0.641
#
#    allow_ft_att_avg   poss_avg  off_rebs_avg  allow_off_rebs_avg  \
# 0                19  65.535484             7                   8
# 1                21  79.485714            13                  11
# 2                19  76.562500            12                  12
# 3                24  85.525926            13                  15
# 4                24  78.954839            12                  10
#
#    def_rebs_avg  allow_def_rebs_avg  to_avg  steal_avg  off_rating  ft_att_avg
# 0            20                  22      12          5   86.975783          16
# 1            22                  22      13          6   88.066139          21
# 2            23                  22      12          7   88.816327          19
# 3            23                  27      16          9   76.000346          27
# 4            22                  23      16          7   81.058997          23

# %% [markdown]
# #### Read table of team names and associated team meta data from the Kaggle data set.
#
# https://console.cloud.google.com/bigquery?project=bigqueryncaa&p=bigquery-public-data&d=ncaa_basketball&page=dataset

# %%
# Read table of team names and associated team meta data
teams = pd.read_csv(Path('../Data/D1_teams.csv'))
teams.drop(columns=['code_ncaa','school_ncaa','turner_name','league_name','league_alias','conf_alias',
                    'conf_id','division_name','division_alias','division_id',
                    'kaggle_team_id','venue_id'], inplace=True)
teams.info()
teams.set_index('id',inplace=True)
teams.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 2 columns):
# id           351 non-null object
# conf_name    351 non-null object
# dtypes: object(2)
# memory usage: 5.6+ KB
#                                      conf_name
# id
# fe406882-9f22-495e-9df6-ef357a6803c6       Ivy
# ca478771-aa3d-4231-81e0-b70f519134fb       Ivy
# 5c7bf63f-bc39-43c5-9907-73b50b7a6b34       Ivy
# d60357bd-1205-42e9-9092-d986a2843a34       Ivy
# 88ff8c00-958e-4ccf-a21d-77fab9e93692       Ivy

# %% [markdown]
# #### Read in the NCAA Men's Tournament results from the the Kaggle data set.

# %%
tourney_data = pd.read_csv(Path('../Data/tournament_results.csv'))
tourney_data.drop(columns=['days_from_epoch','day','num_ot','academic_year','win_region','win_alias','lose_region',
                           'lose_alias','lose_code_ncaa','win_school_ncaa','win_code_ncaa','win_name','lose_name',
                           'win_pts','win_kaggle_team_id','lose_school_ncaa','lose_kaggle_team_id','lose_pts'],inplace=True)



tourney_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2117 entries, 0 to 2116
# Data columns (total 9 columns):
# season          2117 non-null int64
# round           2117 non-null int64
# game_date       2117 non-null object
# win_seed        2117 non-null int64
# win_market      2117 non-null object
# win_team_id     2117 non-null object
# lose_seed       2117 non-null int64
# lose_market     2117 non-null object
# lose_team_id    2117 non-null object
# dtypes: int64(4), object(5)
# memory usage: 148.9+ KB

# %%
game_data = tourney_data.join(teams, on='win_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'win_kaggle_team_id','conf_name':'win_conf_name'}, inplace=True)
game_data = game_data.join(teams,on='lose_team_id',how='left')
game_data.rename(columns={'kaggle_team_id':'lose_kaggle_team_id','conf_name':'lose_conf_name'}, inplace=True)
games_won_conf = game_data.groupby('win_conf_name').size().reset_index(name='count').sort_values(by=['count'], ascending=False)

games_won_conf['percent'] = 100 * games_won_conf['count']/games_won_conf['count'].sum()
games_won_conf['cum_percent'] = games_won_conf['percent'].cumsum()
games_won_conf.head()
# Out:
#      win_conf_name  count    percent  cum_percent
# 3   Atlantic Coast    431  20.358999    20.358999
# 9          Big Ten    313  14.785073    35.144072
# 24    Southeastern    269  12.706660    47.850732
# 5           Big 12    231  10.911667    58.762400
# 22      Pacific 12    197   9.305621    68.068021

# %% [markdown]
# Identify the conferences that have won 70% of all conference games

# %%
top_tournament_conferences_list = games_won_conf[games_won_conf['cum_percent']<= 70]['win_conf_name'].tolist()
top_tournament_conferences_list
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']

# %% [markdown]
# The summary season data in this set goes back to 2010. If more training data is needed we can go back to earlier seasons.
#
# So the intersection of season summary data with tournament data are regular seasons 2010 through 2016.

# %%
tourney_data = tourney_data[tourney_data['season'] >= 2010]
tourney_data.describe()['season']
# Out:
# count     533.000000
# mean     2013.519700
# std         2.284733
# min      2010.000000
# 25%      2012.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2017.000000
# Name: season, dtype: float64

# %%
# recode the tourney data so that the teams are not marked with  win/lose status and the game result is encoded as a binary
tourney_data['game_result'] = 1
tourney_data.game_result = tourney_data.game_result.astype(int)
tourney_data.rename(columns={"win_seed":"team_seed","win_market":"team","win_team_id":"team_id"}, inplace=True)
tourney_data.rename(columns={"lose_seed":"opp_team_seed","lose_market":"opp_team","lose_team_id":"opp_team_id"}, inplace=True)
tourney_data['start_season'] = tourney_data['season'] -1

#create some temporary buffer columns
tourney_data['copy_team'] = tourney_data['team']
tourney_data['copy_team_seed'] = tourney_data['team_seed']
tourney_data['copy_team_id'] = tourney_data['team_id']

#swap the team and opp team data
tourney_data.loc[1::2,'team'] = tourney_data.loc[1::2,'opp_team']
tourney_data.loc[1::2,'opp_team'] = tourney_data.loc[1::2,'copy_team']
tourney_data.loc[1::2,'team_seed'] = tourney_data.loc[1::2,'opp_team_seed']
tourney_data.loc[1::2,'opp_team_seed'] = tourney_data.loc[1::2,'copy_team_seed']
tourney_data.loc[1::2,'team_id'] = tourney_data.loc[1::2,'opp_team_id']
tourney_data.loc[1::2,'opp_team_id'] = tourney_data.loc[1::2,'copy_team_id']

# flip the game result
tourney_data.loc[1::2,'game_result'] = 0

#drop the temporary columns
tourney_data.drop(columns=['copy_team','copy_team_seed','copy_team_id'],inplace=True)
tourney_data.rename(columns={"team_seed":"seed_t","opp_team_seed":"seed_o"}, inplace=True)

tourney_data['Game Result'] = tourney_data.game_result.map({1:'Win', 0:'Lose'})
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','team_id'], 
                                right_on=['season', 'team_id'],how='left',suffixes=('','_y'))

tourney_data.drop(columns=['season_y'],inplace=True)
tourney_data = tourney_data.merge(summary_data, left_on=['start_season','opp_team_id'], 
                                right_on=['season', 'team_id'], how='left',suffixes=('_t','_o'))

tourney_data.drop(columns=['school_t','school_o','games_t','games_o','team_id_o'],inplace=True)

tourney_data = tourney_data.join(teams, on='team_id_t', how='left')
tourney_data = tourney_data.join(teams, on='opp_team_id', how='left', lsuffix='_t', rsuffix='_o')
tourney_data.rename(index=str,columns={'team':'team_t','opp_team':'team_o', 'opp_team_id':'team_id_o'},inplace=True)

tourney_data['game_result'] = tourney_data.game_result.apply(utils.negate_loser)
tourney_data.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   Game Result  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  srs_o  sos_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o
# 0            20     Atlantic Coast  American Athletic
# 1            16  American Athletic            Big Ten
# 2            18       Mid-American        Atlantic 10
# 3            19        Atlantic 10  American Athletic
# 4            20             Big 12        Atlantic 10

# %%
computer_rankings = pd.read_csv(Path( '../Data/massey_seasons_with_id.csv'))
computer_rankings = computer_rankings[computer_rankings['season']>=2010]
computer_rankings[computer_rankings.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [SAG, WLK, WOL, Team, RTH, COL, POM, DOL, RPI, MOR, season, win_pct, kaggle_id]
# Index: []

# %%
temp_merge = tourney_data.merge(computer_rankings, left_on=['season_t','team_id_t'], 
                                right_on=['season', 'kaggle_id'],how='left',suffixes=('','_y'))

temp_merge.drop(columns=['Team','season','win_pct','kaggle_id'],inplace=True)
temp_merge.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   Game Result  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  srs_o  sos_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  SAG   WLK  WOL  RTH  \
# 0            20     Atlantic Coast  American Athletic   25  27.0   36   28
# 1            16  American Athletic            Big Ten   32  30.0   25   32
# 2            18       Mid-American        Atlantic 10   62  55.0   52   59
# 3            19        Atlantic 10  American Athletic   50  43.0   32   54
# 4            20             Big 12        Atlantic 10    2   2.0    3    2
#
#     COL   POM   DOL   RPI  MOR
# 0  32.0  35.0  32.0  33.0   24
# 1  27.0  38.0  25.0  30.0   45
# 2  50.0  54.0  46.0  42.0   60
# 3  35.0  47.0  33.0  38.0   55
# 4   1.0   3.0   2.0   1.0    3

# %%
tourney_comp_ratings = temp_merge.merge(computer_rankings,left_on=['season_t','team_id_o'], 
                                right_on=['season', 'kaggle_id'], how='left',suffixes=('_t','_o'))

tourney_comp_ratings.drop(columns=['Team','season','win_pct','kaggle_id'],inplace=True)

tourney_comp_ratings.rename(str.lower, axis='columns', inplace=True)
tourney_comp_ratings.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   game result  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  srs_o  sos_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  sag_t  wlk_t  wol_t  \
# 0            20     Atlantic Coast  American Athletic     25   27.0     36
# 1            16  American Athletic            Big Ten     32   30.0     25
# 2            18       Mid-American        Atlantic 10     62   55.0     52
# 3            19        Atlantic 10  American Athletic     50   43.0     32
# 4            20             Big 12        Atlantic 10      2    2.0      3
#
#    rth_t  col_t  pom_t  dol_t  rpi_t  mor_t  sag_o  wlk_o  wol_o  rth_o  \
# 0     28   32.0   35.0   32.0   33.0     24     55   58.0     35     47
# 1     32   27.0   38.0   25.0   30.0     45     45   42.0     43     37
# 2     59   50.0   54.0   46.0   42.0     60     26   19.0     27     27
# 3     54   35.0   47.0   33.0   38.0     55     10   10.0     16     16
# 4      2    1.0    3.0    2.0    1.0      3     77   55.0     54     74
#
#    col_o  pom_o  dol_o  rpi_o  mor_o
# 0   40.0   68.0   45.0   41.0     52
# 1   39.0   39.0   39.0   39.0     27
# 2   27.0   21.0   31.0   24.0     16
# 3   11.0   10.0   15.0   12.0     10
# 4   59.0   84.0   72.0   49.0     80

# %% [markdown]
# #### Add a feature
# top_conf = 1 if team is a top conference and opponent is not
# top_conf = -1 if opp_team is a top_conference and team is not
# top_conf = 0 otherwise

# %%
print(top_tournament_conferences_list)
tourney_comp_ratings['top_conf'] = tourney_comp_ratings.apply(lambda row: utils.conf_compare(row.conf_name_t, 
                                                                                             row.conf_name_o,
                                                                                             top_tournament_conferences_list),
                                                              axis=1)

tourney_comp_ratings.head(10)[['game_result','conf_name_t','conf_name_o','top_conf']]
# Out:
# ['Atlantic Coast', 'Big Ten', 'Southeastern', 'Big 12', 'Pacific 12']
#    game_result        conf_name_t        conf_name_o  top_conf
# 0           -1     Atlantic Coast  American Athletic         1
# 1            1  American Athletic            Big Ten        -1
# 2           -1       Mid-American        Atlantic 10         0
# 3            1        Atlantic 10  American Athletic         0
# 4           -1             Big 12        Atlantic 10         1
# 5            1        Atlantic 10     Atlantic Coast        -1
# 6           -1            Big Ten        Atlantic 10         1
# 7            1        Atlantic 10           Big East         0
# 8           -1         Pacific 12        Atlantic 10         1
# 9            1        Atlantic 10         Pacific 12        -1

# %%
# Upsets occur less than 30% of the time when seeding deltas are more than 6
tourney_comp_ratings['upset_seed_threshold'] = tourney_comp_ratings.apply(
    lambda row: abs(row.seed_t - row.seed_o) > 6, axis=1).astype(int)
    
tourney_comp_ratings.head()
# Out:
#    season_t  round   game_date  seed_t                 team_t  \
# 0      2013     64  2013-03-22       8   North Carolina State
# 1      2011     64  2011-03-17       7                 Temple
# 2      2013     64  2013-03-21      12                  Akron
# 3      2012     64  2012-03-15      12  Virginia Commonwealth
# 4      2011      8  2011-03-27       1                 Kansas
#
#                               team_id_t  seed_o                 team_o  \
# 0  52df1e19-b142-4a76-a439-ad68455d0581       9                 Temple
# 1  8598d1b6-106b-4083-a512-2e495729525a      10             Penn State
# 2  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20       5  Virginia Commonwealth
# 3  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       5          Wichita State
# 4  fae4855b-1b64-4b40-a632-9ed345e1e952      11  Virginia Commonwealth
#
#                               team_id_o  game_result  start_season  \
# 0  8598d1b6-106b-4083-a512-2e495729525a           -1          2012
# 1  4aebd148-8119-4875-954c-66779867989b            1          2010
# 2  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2012
# 3  f38b58de-3273-4723-a78b-2f918e9aa2d5            1          2011
# 4  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518           -1          2010
#
#   game result  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0        Lose  14.32   7.17      0.686         77             70     0.496
# 1         Win  12.35   4.23      0.765         70             62     0.447
# 2        Lose   8.11   0.18      0.788         71             62     0.455
# 3         Win   8.79   0.63      0.806         68             59     0.410
# 4        Lose  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  season_o  srs_o  sos_o  win_pct_o  \
# 0            6     98.171354            23      2012   9.52   5.20      0.706
# 1            6     92.484651            19      2010  11.98  11.45      0.559
# 2            7     90.004610            20      2012  16.89   4.47      0.750
# 3           10     89.115399            20      2011  17.42   3.80      0.818
# 4            7    101.090384            22      2010   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o        conf_name_t        conf_name_o  sag_t  wlk_t  wol_t  \
# 0            20     Atlantic Coast  American Athletic     25   27.0     36
# 1            16  American Athletic            Big Ten     32   30.0     25
# 2            18       Mid-American        Atlantic 10     62   55.0     52
# 3            19        Atlantic 10  American Athletic     50   43.0     32
# 4            20             Big 12        Atlantic 10      2    2.0      3
#
#    rth_t  col_t  pom_t  dol_t  rpi_t  mor_t  sag_o  wlk_o  wol_o  rth_o  \
# 0     28   32.0   35.0   32.0   33.0     24     55   58.0     35     47
# 1     32   27.0   38.0   25.0   30.0     45     45   42.0     43     37
# 2     59   50.0   54.0   46.0   42.0     60     26   19.0     27     27
# 3     54   35.0   47.0   33.0   38.0     55     10   10.0     16     16
# 4      2    1.0    3.0    2.0    1.0      3     77   55.0     54     74
#
#    col_o  pom_o  dol_o  rpi_o  mor_o  top_conf  upset_seed_threshold
# 0   40.0   68.0   45.0   41.0     52         1                     0
# 1   39.0   39.0   39.0   39.0     27        -1                     0
# 2   27.0   21.0   31.0   24.0     16         0                     1
# 3   11.0   10.0   15.0   12.0     10         0                     1
# 4   59.0   84.0   72.0   49.0     80         1                     1

# %%
tourney_comp_ratings['margin_victory_avg_t'] = tourney_comp_ratings['pts_avg_t'] - tourney_comp_ratings['opp_pts_avg_t']
tourney_comp_ratings['margin_victory_avg_o'] = tourney_comp_ratings['pts_avg_o'] - tourney_comp_ratings['opp_pts_avg_o']

tourney_comp_ratings['delta_margin_victory_avg'] = tourney_comp_ratings['margin_victory_avg_t'] - \
    tourney_comp_ratings['margin_victory_avg_o']

tourney_comp_ratings['delta_fg_pct'] = tourney_comp_ratings['fg_pct_t'] - tourney_comp_ratings['fg_pct_o']

#tourney_comp_ratings['allow_fg_pct'] = tourney_comp_ratings['allow_fg_pct_t'] - tourney_comp_ratings['allow_fg_pct_o']
tourney_comp_ratings['delta_off_rebs_avg'] = tourney_comp_ratings['off_rebs_avg_t'] - tourney_comp_ratings['off_rebs_avg_o']

tourney_comp_ratings['delta_def_rebs_avg'] = tourney_comp_ratings['def_rebs_avg_t'] - tourney_comp_ratings['def_rebs_avg_o']

tourney_comp_ratings['delta_allow_def_rebs_avg'] = tourney_comp_ratings['allow_def_rebs_avg_t'] - \
    tourney_comp_ratings['allow_def_rebs_avg_o']

tourney_comp_ratings['delta_ft_pct'] = tourney_comp_ratings['ft_pct_t'] - tourney_comp_ratings['ft_pct_o']

tourney_comp_ratings['to_net_avg_t'] = tourney_comp_ratings['to_avg_t'] - tourney_comp_ratings['steal_avg_t']

tourney_comp_ratings['to_net_avg_o'] = tourney_comp_ratings['to_avg_o'] - tourney_comp_ratings['steal_avg_o']

tourney_comp_ratings['delta_to_net_avg'] = tourney_comp_ratings['to_net_avg_t'] - tourney_comp_ratings['to_net_avg_o']

tourney_comp_ratings['delta_win_pct'] = tourney_comp_ratings['win_pct_t'] - tourney_comp_ratings['win_pct_o']

tourney_comp_ratings['delta_off_rating'] = tourney_comp_ratings['off_rating_t'] - tourney_comp_ratings['off_rating_o']

tourney_comp_ratings['delta_allow_off_rebs_avg'] = tourney_comp_ratings['allow_off_rebs_avg_t'] - \
    tourney_comp_ratings['allow_off_rebs_avg_o']

tourney_comp_ratings['delta_ft_att_avg'] = tourney_comp_ratings['ft_att_avg_t'] - tourney_comp_ratings['ft_att_avg_o']

tourney_comp_ratings['delta_allow_ft_att_avg'] = tourney_comp_ratings['allow_ft_att_avg_t'] -  \
    tourney_comp_ratings['allow_ft_att_avg_o']

tourney_comp_ratings['delta_seed'] = tourney_comp_ratings['seed_t'] - tourney_comp_ratings['seed_o']

tourney_comp_ratings['delta_srs'] = tourney_comp_ratings['srs_t'] - tourney_comp_ratings['srs_o']
tourney_comp_ratings['delta_sos'] = tourney_comp_ratings['sos_t'] - tourney_comp_ratings['sos_o']

tourney_comp_ratings['delta_sag'] = tourney_comp_ratings['sag_t'] - tourney_comp_ratings['sag_o']
tourney_comp_ratings['delta_wlk'] = tourney_comp_ratings['wlk_t'] - tourney_comp_ratings['wlk_o']
tourney_comp_ratings['delta_wol'] = tourney_comp_ratings['wol_t'] - tourney_comp_ratings['wol_o']
tourney_comp_ratings['delta_rth'] = tourney_comp_ratings['rth_t'] - tourney_comp_ratings['rth_o']
tourney_comp_ratings['delta_col'] = tourney_comp_ratings['col_t'] - tourney_comp_ratings['col_o']
tourney_comp_ratings['delta_pom'] = tourney_comp_ratings['pom_t'] - tourney_comp_ratings['pom_o']
tourney_comp_ratings['delta_dol'] = tourney_comp_ratings['dol_t'] - tourney_comp_ratings['dol_o']
tourney_comp_ratings['delta_rpi'] = tourney_comp_ratings['rpi_t'] - tourney_comp_ratings['rpi_o']
tourney_comp_ratings['delta_mor'] = tourney_comp_ratings['mor_t'] - tourney_comp_ratings['mor_o']


tourney_comp_ratings.drop(columns=['season_o'], inplace=True)

# %%
feature_data = tourney_comp_ratings.drop(columns=['round','game_date','seed_t','team_t','team_id_t','team_id_o',
                                         'team_o','seed_o','team_id_o','game_result','start_season','game result',
                                         'conf_name_t','conf_name_o']).copy()


feature_data.head()
# Out:
#    season_t  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 0      2013  14.32   7.17      0.686         77             70     0.496
# 1      2011  12.35   4.23      0.765         70             62     0.447
# 2      2013   8.11   0.18      0.788         71             62     0.455
# 3      2012   8.79   0.63      0.806         68             59     0.410
# 4      2011  24.10   7.62      0.921         81             64     0.508
#
#    allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 0           0.419     0.681                  17   78.434286              11
# 1           0.435     0.698                  19   75.688235              11
# 2           0.395     0.643                  19   78.884848              12
# 3           0.424     0.685                  18   76.305556              12
# 4           0.380     0.679                  18   80.126316              11
#
#    allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 0                    12              22                    21        12
# 1                    11              24                    22        10
# 2                    10              21                    21        13
# 3                    10              18                    24        11
# 4                    10              27                    21        13
#
#    steal_avg_t  off_rating_t  ft_att_avg_t  srs_o  sos_o  win_pct_o  \
# 0            6     98.171354            23   9.52   5.20      0.706
# 1            6     92.484651            19  11.98  11.45      0.559
# 2            7     90.004610            20  16.89   4.47      0.750
# 3           10     89.115399            20  17.42   3.80      0.818
# 4            7    101.090384            22   8.56   3.78      0.700
#
#    pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 0         72             67     0.428           0.438     0.723
# 1         63             62     0.439           0.434     0.724
# 2         76             64     0.450           0.444     0.701
# 3         77             62     0.482           0.393     0.748
# 4         71             66     0.434           0.424     0.715
#
#    allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 0                  18   77.494118              11                    10
# 1                  21   68.341176               9                     8
# 2                  20   81.044444              13                    11
# 3                  18   77.496970              10                     9
# 4                  18   75.240000              10                    10
#
#    def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 0              19                    25        10            7     92.910278
# 1              21                    23        10            4     92.184541
# 2              18                    23        11           11     93.775706
# 3              24                    21        12            6     99.358724
# 4              21                    24        11            8     94.364700
#
#    ft_att_avg_o  sag_t  wlk_t  wol_t  rth_t  col_t  pom_t  dol_t  rpi_t  \
# 0            20     25   27.0     36     28   32.0   35.0   32.0   33.0
# 1            16     32   30.0     25     32   27.0   38.0   25.0   30.0
# 2            18     62   55.0     52     59   50.0   54.0   46.0   42.0
# 3            19     50   43.0     32     54   35.0   47.0   33.0   38.0
# 4            20      2    2.0      3      2    1.0    3.0    2.0    1.0
#
#    mor_t  sag_o  wlk_o  wol_o  rth_o  col_o  pom_o  dol_o  rpi_o  mor_o  \
# 0     24     55   58.0     35     47   40.0   68.0   45.0   41.0     52
# 1     45     45   42.0     43     37   39.0   39.0   39.0   39.0     27
# 2     60     26   19.0     27     27   27.0   21.0   31.0   24.0     16
# 3     55     10   10.0     16     16   11.0   10.0   15.0   12.0     10
# 4      3     77   55.0     54     74   59.0   84.0   72.0   49.0     80
#
#    top_conf  upset_seed_threshold  margin_victory_avg_t  margin_victory_avg_o  \
# 0         1                     0                     7                     5
# 1        -1                     0                     8                     1
# 2         0                     1                     9                    12
# 3         0                     1                     9                    15
# 4         1                     1                    17                     5
#
#    delta_margin_victory_avg  delta_fg_pct  delta_off_rebs_avg  \
# 0                         2         0.068                   0
# 1                         7         0.008                   2
# 2                        -3         0.005                  -1
# 3                        -6        -0.072                   2
# 4                        12         0.074                   1
#
#    delta_def_rebs_avg  delta_allow_def_rebs_avg  delta_ft_pct  to_net_avg_t  \
# 0                   3                        -4        -0.042             6
# 1                   3                        -1        -0.026             4
# 2                   3                        -2        -0.058             6
# 3                  -6                         3        -0.063             1
# 4                   6                        -3        -0.036             6
#
#    to_net_avg_o  delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 0             3                 3         -0.020          5.261076
# 1             6                -2          0.206          0.300109
# 2             0                 6          0.038         -3.771096
# 3             6                -5         -0.012        -10.243325
# 4             3                 3          0.221          6.725684
#
#    delta_allow_off_rebs_avg  delta_ft_att_avg  delta_allow_ft_att_avg  \
# 0                         2                 3                      -1
# 1                         3                 3                      -2
# 2                        -1                 2                      -1
# 3                         1                 1                       0
# 4                         0                 2                       0
#
#    delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 0          -1       4.80       1.97        -30      -31.0          1
# 1          -3       0.37      -7.22        -13      -12.0        -18
# 2           7      -8.78      -4.29         36       36.0         25
# 3           7      -8.63      -3.17         40       33.0         16
# 4         -10      15.54       3.84        -75      -53.0        -51
#
#    delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor
# 0        -19       -8.0      -33.0      -13.0       -8.0        -28
# 1         -5      -12.0       -1.0      -14.0       -9.0         18
# 2         32       23.0       33.0       15.0       18.0         44
# 3         38       24.0       37.0       18.0       26.0         45
# 4        -72      -58.0      -81.0      -70.0      -48.0        -77

# %%
feature_data.drop(columns=['pts_avg_t','pts_avg_o', 'opp_pts_avg_t','opp_pts_avg_o',
                                'margin_victory_avg_t', 'margin_victory_avg_o',
                                'poss_avg_t','poss_avg_o',
                                'fg_pct_t','fg_pct_o','allow_fg_pct_t','allow_fg_pct_o',
                                'off_rebs_avg_t','off_rebs_avg_o','def_rebs_avg_t','def_rebs_avg_o',
                                'allow_def_rebs_avg_t','allow_def_rebs_avg_o','ft_pct_t','ft_pct_o',
                                'to_avg_t','to_avg_o','steal_avg_t','steal_avg_o',
                                'to_net_avg_t','to_net_avg_o',
                                'win_pct_t','win_pct_o','off_rating_t','off_rating_o',
                                'allow_off_rebs_avg_t','allow_off_rebs_avg_o',
                                'ft_att_avg_t','ft_att_avg_o','opp_pts_avg_t','opp_pts_avg_o',
                                'srs_t','srs_o','sos_t','sos_o',
                                'allow_ft_att_avg_t','allow_ft_att_avg_o',
                                'sag_t','sag_o','wlk_t','wlk_o','wol_t','wol_o',
                                'rth_t','rth_o','col_t','col_o','pom_t','pom_o',
                                'dol_t','dol_o','rpi_t','rpi_o','mor_t','mor_o'], inplace=True)




feature_data.head()
# Out:
#    season_t  top_conf  upset_seed_threshold  delta_margin_victory_avg  \
# 0      2013         1                     0                         2
# 1      2011        -1                     0                         7
# 2      2013         0                     1                        -3
# 3      2012         0                     1                        -6
# 4      2011         1                     1                        12
#
#    delta_fg_pct  delta_off_rebs_avg  delta_def_rebs_avg  \
# 0         0.068                   0                   3
# 1         0.008                   2                   3
# 2         0.005                  -1                   3
# 3        -0.072                   2                  -6
# 4         0.074                   1                   6
#
#    delta_allow_def_rebs_avg  delta_ft_pct  delta_to_net_avg  delta_win_pct  \
# 0                        -4        -0.042                 3         -0.020
# 1                        -1        -0.026                -2          0.206
# 2                        -2        -0.058                 6          0.038
# 3                         3        -0.063                -5         -0.012
# 4                        -3        -0.036                 3          0.221
#
#    delta_off_rating  delta_allow_off_rebs_avg  delta_ft_att_avg  \
# 0          5.261076                         2                 3
# 1          0.300109                         3                 3
# 2         -3.771096                        -1                 2
# 3        -10.243325                         1                 1
# 4          6.725684                         0                 2
#
#    delta_allow_ft_att_avg  delta_seed  delta_srs  delta_sos  delta_sag  \
# 0                      -1          -1       4.80       1.97        -30
# 1                      -2          -3       0.37      -7.22        -13
# 2                      -1           7      -8.78      -4.29         36
# 3                       0           7      -8.63      -3.17         40
# 4                       0         -10      15.54       3.84        -75
#
#    delta_wlk  delta_wol  delta_rth  delta_col  delta_pom  delta_dol  \
# 0      -31.0          1        -19       -8.0      -33.0      -13.0
# 1      -12.0        -18         -5      -12.0       -1.0      -14.0
# 2       36.0         25         32       23.0       33.0       15.0
# 3       33.0         16         38       24.0       37.0       18.0
# 4      -53.0        -51        -72      -58.0      -81.0      -70.0
#
#    delta_rpi  delta_mor
# 0       -8.0        -28
# 1       -9.0         18
# 2       18.0         44
# 3       26.0         45
# 4      -48.0        -77

# %%
X= feature_data[feature_data['season_t']>=2010]
y=tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']
X= X.drop(columns=['season_t'])

feature_list = list(X)
feature_list
# Out:
# ['top_conf',
#  'upset_seed_threshold',
#  'delta_margin_victory_avg',
#  'delta_fg_pct',
#  'delta_off_rebs_avg',
#  'delta_def_rebs_avg',
#  'delta_allow_def_rebs_avg',
#  'delta_ft_pct',
#  'delta_to_net_avg',
#  'delta_win_pct',
#  'delta_off_rating',
#  'delta_allow_off_rebs_avg',
#  'delta_ft_att_avg',
#  'delta_allow_ft_att_avg',
#  'delta_seed',
#  'delta_srs',
#  'delta_sos',
#  'delta_sag',
#  'delta_wlk',
#  'delta_wol',
#  'delta_rth',
#  'delta_col',
#  'delta_pom',
#  'delta_dol',
#  'delta_rpi',
#  'delta_mor']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
X_train.head()
# Out:
# (426, 26)
# (426,)
# (107, 26)
# (107,)
#      top_conf  upset_seed_threshold  delta_margin_victory_avg  delta_fg_pct  \
# 140         0                     1                         2         0.069
# 293         0                     0                        -3         0.000
# 368        -1                     1                        -4         0.032
# 53          1                     1                         5        -0.006
# 33          0                     0                         1        -0.007
#
#      delta_off_rebs_avg  delta_def_rebs_avg  delta_allow_def_rebs_avg  \
# 140                  -2                  -2                        -6
# 293                   1                   0                        -4
# 368                  -3                   1                        -1
# 53                    7                   3                        -1
# 33                   -1                   0                        -1
#
#      delta_ft_pct  delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 140        -0.008                 2          0.081          5.170601
# 293        -0.044                 3          0.030         -5.202764
# 368         0.016                 2         -0.132          4.187608
# 53         -0.085                 0          0.118         -4.527964
# 33          0.034                -1         -0.015         -0.684009
#
#      delta_allow_off_rebs_avg  delta_ft_att_avg  delta_allow_ft_att_avg  \
# 140                        -1                -4                      -2
# 293                        -4                 0                      -1
# 368                         0                -7                       1
# 53                          1                 5                       5
# 33                         -1                -1                      -3
#
#      delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 140         -11      12.47       9.59       -101      -82.0       -105
# 293           1      -2.42       0.22         10       14.0          5
# 368           9     -14.49      -8.53         82       88.0         90
# 53           -8       9.67       4.01        -56      -71.0        -63
# 33            2      -2.73      -3.85          7        9.0          3
#
#      delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor
# 140       -107      -94.0      -89.0     -110.0      -88.0        -94
# 293          3        3.0       14.0        1.0        4.0          8
# 368        101       92.0       76.0       98.0       67.0         90
# 53         -71      -74.0      -60.0      -68.0      -53.0        -54
# 33           8        5.0        6.0       10.0        6.0         16

# %% [markdown]
# #### Baseline Model

# %%
number_estimators = 201

bdt= AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME.R", n_estimators=number_estimators, 
                        learning_rate = 1.0)
    
bdt.fit(X_train, y_train)
score = bdt.score(X_train, y_train)
print("Training Model Score= ", score)
# Out:
# Training Model Score=  1.0

# %%
important_features = utils.display_important_features( bdt.feature_importances_, X_train)
# Out:
# Coefficient Values
# delta_sos   0.16417910447761194
# delta_win_pct   0.15422885572139303
# delta_fg_pct   0.08955223880597014
# delta_srs   0.05970149253731343
# delta_rth   0.05472636815920398
# delta_dol   0.05472636815920398
# delta_ft_pct   0.04975124378109453
# delta_sag   0.03980099502487562
# delta_mor   0.03980099502487562
# delta_allow_off_rebs_avg   0.029850746268656716
# delta_wlk   0.029850746268656716
# delta_pom   0.029850746268656716
# delta_allow_def_rebs_avg   0.024875621890547265
# delta_seed   0.024875621890547265
# delta_wol   0.024875621890547265
# delta_col   0.024875621890547265
# delta_off_rating   0.01990049751243781
# delta_rpi   0.01990049751243781
# delta_off_rebs_avg   0.014925373134328358
# delta_ft_att_avg   0.014925373134328358
# delta_def_rebs_avg   0.009950248756218905
# delta_to_net_avg   0.009950248756218905
# delta_allow_ft_att_avg   0.009950248756218905
# delta_margin_victory_avg   0.004975124378109453
# top_conf   0.0
# upset_seed_threshold   0.0

# %%
y_pred = bdt.predict(X_test)
print("Ada Boost model accuracy is %2.2f" % metrics.accuracy_score(y_test, y_pred))
# Out:
# Ada Boost model accuracy is 0.71

# %%
utils.display_confusion_matrix(y_test, y_pred)
# Out:
# array([[39, 13],
#        [18, 37]], dtype=int64)

# %% [markdown]
# ##### Baseline Confusion Matrix

# %%
prediction_probabilities = bdt.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.7102803738317757
# Precision: 0.74
# Recall: 0.6727272727272727
# Log loss=  0.6737219426946108

# %%
cross_val_scores = cross_val_score(bdt, X,y, cv=10, scoring='accuracy')
print("Baseline Cross Validation average= ",cross_val_scores.mean())
# Out:
# Baseline Cross Validation average=  0.7565244852980701

# %%
train_sizes, train_scores, test_scores = learning_curve(bdt, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
#                    Baseline Learning Curve

# %% [markdown]
# #### Model Feature Optimization

# %%
X = feature_data[feature_data['season_t']>=2010]
X = X.drop(columns=['season_t'])
y = tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']

model_stats = eliminate_features(bdt, X,y)
# Out:
# Iteration=  0
# least_important label=  upset_seed_threshold
# Iteration=  1
# least_important label=  top_conf
# Iteration=  2
# least_important label=  delta_margin_victory_avg
# Iteration=  3
# least_important label=  delta_allow_ft_att_avg
# Iteration=  4
# least_important label=  delta_to_net_avg
# Iteration=  5
# least_important label=  delta_def_rebs_avg
# Iteration=  6
# least_important label=  delta_ft_att_avg
# Iteration=  7
# least_important label=  delta_off_rebs_avg
# Iteration=  8
# least_important label=  delta_rpi
# Iteration=  9
# least_important label=  delta_off_rating
# Iteration=  10
# least_important label=  delta_col
# Iteration=  11
# least_important label=  delta_wol
# Iteration=  12
# least_important label=  delta_seed
# Iteration=  13
# least_important label=  delta_allow_def_rebs_avg
# Iteration=  14
# least_important label=  delta_pom
# Iteration=  15
# least_important label=  delta_wlk
# Iteration=  16
# least_important label=  delta_allow_off_rebs_avg
# Iteration=  17
# least_important label=  delta_mor
# Iteration=  18
# least_important label=  delta_sag
# Iteration=  19
# least_important label=  delta_ft_pct
# Iteration=  20
# least_important label=  delta_dol
# Iteration=  21
# least_important label=  delta_rth
# Iteration=  22
# least_important label=  delta_srs
# Iteration=  23
# least_important label=  delta_fg_pct
# Iteration=  24
# least_important label=  delta_win_pct
# Iteration=  25
# least_important label=  delta_sos

# %%
max_accuracy = 0
max_cross_val = 0
min_log_loss = 10000
for key, value in model_stats.items():
    accuracy = value['accuracy']
    cross_val = value['cross_validation']
    log_loss_val = value['log_loss']
    print('Accuracy= {0:6.4f} Cross Val= {1:6.4f}  Log Loss= {2:6.4f}'.format(accuracy ,cross_val, log_loss_val ))
    if accuracy > max_accuracy:
        max_accuracy = accuracy
        accuracy_hash = key
    if cross_val > max_cross_val:
        max_cross_val = cross_val
        cross_hash = key
    if log_loss_val < min_log_loss:
        min_log_loss = log_loss_val
        log_hash = key

print("\n")

print('Max Accuracy= {0:6.4f}'.format( model_stats[accuracy_hash]['accuracy']))
print('Max Cross Validation= {0:6.4f}'.format( model_stats[cross_hash]['cross_validation']))
print ("Minimum Log Loss= {0:6.4f}".format(  model_stats[log_hash]['log_loss']))
print('Log Loss at Max Accuracy= {0:6.4f}'.format( model_stats[accuracy_hash]['log_loss'] ))
print('Log Loss at Max Cross Validation= {0:6.4f} '.format( model_stats[cross_hash]['log_loss'] ))
# Out:
# Accuracy= 0.7103 Cross Val= 0.7565  Log Loss= 0.6737
# Accuracy= 0.7103 Cross Val= 0.7565  Log Loss= 0.6737
# Accuracy= 0.7103 Cross Val= 0.7546  Log Loss= 0.6737
# Accuracy= 0.6636 Cross Val= 0.7494  Log Loss= 0.6735
# Accuracy= 0.7009 Cross Val= 0.7565  Log Loss= 0.6769
# Accuracy= 0.7383 Cross Val= 0.7623  Log Loss= 0.6766
# Accuracy= 0.6636 Cross Val= 0.7491  Log Loss= 0.6771
# Accuracy= 0.6916 Cross Val= 0.7527  Log Loss= 0.6773
# Accuracy= 0.6822 Cross Val= 0.7640  Log Loss= 0.6779
# Accuracy= 0.6636 Cross Val= 0.7529  Log Loss= 0.6773
# Accuracy= 0.7103 Cross Val= 0.7884  Log Loss= 0.6759
# Accuracy= 0.7103 Cross Val= 0.7679  Log Loss= 0.6758
# Accuracy= 0.7477 Cross Val= 0.7829  Log Loss= 0.6757
# Accuracy= 0.7196 Cross Val= 0.7813  Log Loss= 0.6758
# Accuracy= 0.7383 Cross Val= 0.7833  Log Loss= 0.6764
# Accuracy= 0.7477 Cross Val= 0.7812  Log Loss= 0.6754
# Accuracy= 0.7196 Cross Val= 0.7791  Log Loss= 0.6771
# Accuracy= 0.6822 Cross Val= 0.7790  Log Loss= 0.6721
# Accuracy= 0.7196 Cross Val= 0.7660  Log Loss= 0.6735
# Accuracy= 0.7477 Cross Val= 0.7848  Log Loss= 0.6730
# Accuracy= 0.7664 Cross Val= 0.7942  Log Loss= 0.6733
# Accuracy= 0.7477 Cross Val= 0.7604  Log Loss= 0.6764
# Accuracy= 0.6729 Cross Val= 0.7089  Log Loss= 0.6786
# Accuracy= 0.6729 Cross Val= 0.6957  Log Loss= 0.6812
# Accuracy= 0.6262 Cross Val= 0.6902  Log Loss= 0.6832
# Accuracy= 0.6168 Cross Val= 0.6374  Log Loss= 0.6881
#
#
# Max Accuracy= 0.7664
# Max Cross Validation= 0.7942
# Minimum Log Loss= 0.6721
# Log Loss at Max Accuracy= 0.6733
# Log Loss at Max Cross Validation= 0.6733

# %%
model_features = model_stats[cross_hash]['labels']
print(model_features)
# Out:
# ['delta_fg_pct', 'delta_win_pct', 'delta_srs', 'delta_sos', 'delta_rth', 'delta_dol']

# %%
X = feature_data[feature_data['season_t']>=2010][model_features]

# %%
y = tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
bdt.fit(X_train, y_train)
y_pred = bdt.predict(X_test)
# save model stats
prediction_probabilities = bdt.predict_proba(X_test)
accuracy = metrics.accuracy_score(y_test, y_pred)
precision = metrics.precision_score(y_test, y_pred)
recall = metrics.recall_score(y_test, y_pred)
log_loss_value = log_loss(y_test, prediction_probabilities)
cross_val_scores = cross_val_score(bdt, X,y, cv=10, scoring='accuracy')
cross_validation_average = cross_val_scores.mean()

train_sizes, train_scores, test_scores = learning_curve(bdt, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))
utils.display_confusion_matrix(y_test, y_pred)
# Out:
# array([[38, 14],
#        [11, 44]], dtype=int64)

# %%
utils.display_important_features( bdt.feature_importances_, X_train)
# Out:
# Coefficient Values
# delta_sos   0.26865671641791045
# delta_win_pct   0.208955223880597
# delta_dol   0.15920398009950248
# delta_rth   0.15422885572139303
# delta_fg_pct   0.10945273631840796
# delta_srs   0.09950248756218906
# [('delta_sos', 0.26865671641791045),
#  ('delta_win_pct', 0.208955223880597),
#  ('delta_dol', 0.15920398009950248),
#  ('delta_rth', 0.15422885572139303),
#  ('delta_fg_pct', 0.10945273631840796),
#  ('delta_srs', 0.09950248756218906)]

# %%
prediction_probabilities = bdt.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.7663551401869159
# Precision: 0.7586206896551724
# Recall: 0.8
# Log loss=  0.673339260571818

# %%
# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
# Retrieve the non-normalized game stats
prediction_probabilities[:,1]
pred_probs = pd.Series(prediction_probabilities[:,1], index=X_test.index)
predictions = pd.Series(y_pred, index=y_test.index)
test_games = tourney_comp_ratings[tourney_comp_ratings.index.isin(X_test.index)].copy()

test_games['predicted_result'] = predictions
test_games['pred_win_prob'] = pred_probs

#test_games['game_result'] = test_games.game_result.apply(negate_loser)

test_games.head()
# Out:
#     season_t  round   game_date  seed_t                 team_t  \
# 7       2011     64  2011-03-18      11  Virginia Commonwealth
# 28      2012     64  2012-03-16       5                 Temple
# 34      2017     32  2017-03-19      11           Rhode Island
# 40      2013     68  2013-03-20      16           LIU Brooklyn
# 43      2017     64  2017-03-16       7           Saint Mary's
#
#                                team_id_t  seed_o                 team_o  \
# 7   c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518       6             Georgetown
# 28  8598d1b6-106b-4083-a512-2e495729525a      12          South Florida
# 34  7e42bca2-3cd7-4aca-aa46-f190fe5d8eb4       3                 Oregon
# 40  82c12e8d-7c6c-47d8-b100-3cbc190d268e      16          James Madison
# 43  b18f34af-a7f1-4659-a2e5-fc11a31cd316      10  Virginia Commonwealth
#
#                                team_id_o  game_result  start_season  \
# 7   8736b67f-5924-400b-bf94-3bd804c36600            1          2010
# 28  55af9c69-3675-4b9b-a882-96640b782fff           -1          2011
# 34  1da70895-f77f-44ef-b216-d63c02e696eb           -1          2016
# 40  524e3eec-7dde-45c7-b3cc-6308cec73350           -1          2012
# 43  c1c1e6df-a383-4fbd-ba7b-32d4f9ef9518            1          2016
#
#    game result  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 7          Win   8.56   3.78      0.700         71             66     0.434
# 28        Lose  10.44   4.94      0.750         75             69     0.469
# 34        Lose  12.88   4.62      0.714         73             65     0.454
# 40        Lose  -3.21  -5.80      0.588         78             76     0.479
# 43         Win  16.75   2.19      0.853         72             57     0.496
#
#     allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 7            0.424     0.715                  18   75.240000              10
# 28           0.435     0.719                  19   77.743750              10
# 34           0.406     0.668                  24   77.840000              11
# 40           0.468     0.691                  19   80.676471              11
# 43           0.412     0.745                  14   69.458824               9
#
#     allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 7                     10              21                    24        11
# 28                    11              21                    22        12
# 34                    10              25                    23        11
# 40                    11              19                    21        14
# 43                     7              25                    19        10
#
#     steal_avg_t  off_rating_t  ft_att_avg_t  srs_o  sos_o  win_pct_o  \
# 7             8     94.364700            20  14.61  10.39      0.656
# 28            7     96.470777            19   9.20   7.29      0.611
# 34            6     93.782117            22  20.80   8.38      0.846
# 40            6     96.682464            25  -1.73  -2.28      0.583
# 43            4    103.658537            14  11.57   3.77      0.743
#
#     pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 7          70             66     0.475           0.387     0.734
# 28         59             56     0.437           0.386     0.705
# 34         78             65     0.481           0.403     0.712
# 40         65             64     0.421           0.428     0.699
# 43         74             66     0.461           0.422     0.705
#
#     allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 7                   19   73.850000              10                    10
# 28                  16   69.133333              10                    10
# 34                  15   77.917949              10                    10
# 40                  20   72.988889              10                    10
# 43                  22   79.537143              11                     9
#
#     def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  off_rating_o  \
# 7               23                    19        13            6     94.786730
# 28              20                    20        13            5     85.342334
# 34              26                    22        11            6    100.105305
# 40              19                    24        11            7     89.054651
# 43              25                    24        12            7     93.038293
#
#     ft_att_avg_o        conf_name_t        conf_name_o  sag_t  wlk_t  wol_t  \
# 7             17        Atlantic 10           Big East     77   55.0     54
# 28            16  American Athletic  American Athletic     36   29.0     28
# 34            20        Atlantic 10         Pacific 12     48   40.0     48
# 40            19          Northeast           Colonial    163  182.0    171
# 43            21         West Coast        Atlantic 10     25   25.0     11
#
#     rth_t  col_t  pom_t  dol_t  rpi_t  mor_t  sag_o  wlk_o  wol_o  rth_o  \
# 7      74   59.0   84.0   72.0   49.0     80     16   19.0     16     17
# 28     35   22.0   34.0   20.0   20.0     42     70   51.0     60     53
# 34     53   43.0   37.0   52.0   31.0     31     13   14.0      8     11
# 40    182  173.0  185.0  193.0  179.0    134    169  183.0    183    184
# 43     20   18.0   14.0   23.0   17.0     26     50   43.0     46     54
#
#     col_o  pom_o  dol_o  rpi_o  mor_o  top_conf  upset_seed_threshold  \
# 7    16.0   31.0   19.0   13.0     42         0                     0
# 28   59.0   66.0   60.0   52.0     47         0                     1
# 34    7.0   16.0   12.0    9.0     24        -1                     1
# 40  179.0  179.0  168.0  182.0    155         0                     0
# 43   30.0   52.0   44.0   22.0     50         0                     0
#
#     margin_victory_avg_t  margin_victory_avg_o  delta_margin_victory_avg  \
# 7                      5                     4                         1
# 28                     6                     3                         3
# 34                     8                    13                        -5
# 40                     2                     1                         1
# 43                    15                     8                         7
#
#     delta_fg_pct  delta_off_rebs_avg  delta_def_rebs_avg  \
# 7         -0.041                   0                  -2
# 28         0.032                   0                   1
# 34        -0.027                   1                  -1
# 40         0.058                   1                   0
# 43         0.035                  -2                   0
#
#     delta_allow_def_rebs_avg  delta_ft_pct  to_net_avg_t  to_net_avg_o  \
# 7                          5        -0.019             3             7
# 28                         2         0.014             5             8
# 34                         1        -0.044             5             5
# 40                        -3        -0.008             8             4
# 43                        -5         0.040             6             5
#
#     delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 7                 -4          0.044         -0.422030
# 28                -3          0.139         11.128444
# 34                 0         -0.132         -6.323188
# 40                 4          0.005          7.627814
# 43                 1          0.110         10.620244
#
#     delta_allow_off_rebs_avg  delta_ft_att_avg  delta_allow_ft_att_avg  \
# 7                          0                 3                      -1
# 28                         1                 3                       3
# 34                         0                 2                       9
# 40                         1                 6                      -1
# 43                        -2                -7                      -8
#
#     delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 7            5      -6.05      -6.61         61       36.0         38
# 28          -7       1.24      -2.35        -34      -22.0        -32
# 34           8      -7.92      -3.76         35       26.0         40
# 40           0      -1.48      -3.52         -6       -1.0        -12
# 43          -3       5.18      -1.58        -25      -18.0        -35
#
#     delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor  \
# 7          57       43.0       53.0       53.0       36.0         38
# 28        -18      -37.0      -32.0      -40.0      -32.0         -5
# 34         42       36.0       21.0       40.0       22.0          7
# 40         -2       -6.0        6.0       25.0       -3.0        -21
# 43        -34      -12.0      -38.0      -21.0       -5.0        -24
#
#     predicted_result  pred_win_prob
# 7                  1       0.504640
# 28                -1       0.495969
# 34                -1       0.493884
# 40                -1       0.493089
# 43                 1       0.500293

# %%
missed_predictions = test_games[test_games['game_result'] != 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)

print("Missed predictions= ", missed_predictions.shape[0])


missed_predictions
# Out:
# Missed predictions=  25
#      season_t  round   game_date  seed_t            team_t  \
# 358      2015     32  2015-03-21       1         Villanova
# 488      2016     64  2016-03-18       3     West Virginia
# 494      2012     64  2012-03-16       7      Saint Mary's
# 454      2016     68  2016-03-16      11             Tulsa
# 50       2013     68  2013-03-19      16           Liberty
# 132      2015      4  2015-04-04       1          Kentucky
# 352      2011     64  2011-03-17      12        Utah State
# 514      2013     16  2013-03-28       2        Miami (FL)
# 292      2010      8  2010-03-28       6         Tennessee
ts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 358         70             65     0.436           0.403     0.686
# 488         80             63     0.478           0.438     0.735
# 494         71             66     0.440           0.442     0.656
# 454         73             67     0.462           0.448     0.738
# 50          62             61     0.403           0.388     0.658
# 132         72             58     0.479           0.428     0.763
# 352         72             66     0.438           0.409     0.655
# 514         68             62     0.457           0.404     0.730
# 292         71             63     0.471           0.406     0.685
# 486         65             63     0.441           0.419     0.750
# 432         69             60     0.455           0.400     0.684
# 506         72             63     0.430           0.417     0.704
# 156         72             64     0.434           0.386     0.763
# 496         79             68     0.479           0.421     0.757
# 319         77             68     0.451           0.394     0.672
# 301         74             67     0.461           0.397     0.656
# 513         72             64     0.461           0.402     0.747
# 99          78             62     0.482           0.390     0.743
# 441         75             65     0.444           0.414     0.768
# 203         73             60     0.475           0.441     0.671
# 51          74             63     0.454           0.393     0.683
# 525         70             57     0.445           0.402     0.701
# 123         80             70     0.452           0.415     0.730
# 517         73             63     0.472           0.385     0.665
# 321         77             59     0.494           0.407     0.701
#
#      allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 358                  19   75.550000              12                    11
# 488                  20   80.100000              11                     9
# 494                  18   74.302857              11                    10
# 454                  14   72.877778               8                     8
# 50                   21   76.070270              10                    12
# 132                  11   67.925000               9                     7
# 352                  22   81.417647              14                    11
# 514                  17   74.771429              11                    11
# 292                  17   78.043243              13                    10
# 486                  15   72.123529              10                     9
# 432                  15   72.694444               9                    10
# 506                  20   78.636842              15                    10
# 156                  15   78.629268              13                    13
# 496                  14   79.171429               9                     8
# 319                  13   85.437838              14                    11
# 301                  21   78.600000              11                     9
# 513                  20   74.637500              10                    11
# 99                   15   77.822222              12                    11
# 441                  18   77.948571              11                    10
# 203                  17   76.029412              14                    10
# 51                   16   78.958824              11                    12
# 525                  18   72.742857              11                     8
# 123                  19   83.111765              12                     9
# 517                  17   77.177143              12                    14
# 321                  15   74.032432              11                     8
#
#      def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  \
# 358              25                    23        10            3
# 488              23                    22        12            9
# 494              18                    24         8            6
# 454              23                    24         9            5
# 50               21                    24        15            7
# 132              23                    20         7            4
# 352              23                    20        14            6
# 514              19                    19        13            6
# 292              25                    19        13            6
# 486              24                    21        12            5
# 432              22                    22        10            6
# 506              23                    21        11            5
# 156              25                    21        11            6
# 496              27                    22        13            5
# 319              28                    23        13            6
# 301              28                    23        12            4
# 513              25                    23        12            5
# 99               23                    19        13            7
# 441              20                    23        11            7
# 203              25                    19        11            4
# 51               26                    23        11            6
# 525              23                    22         9            7
# 123              27                    23        12            7
# 517              25                    21        12            8
# 321              23                    21        10            7
#
#      off_rating_o  ft_att_avg_o        conf_name_t           conf_name_o  \
# 358     92.653872            20           Big East        Atlantic Coast
# 488     99.875156            20             Big 12             Southland
# 494     95.554872            19         West Coast               Big Ten
# 454    100.167709            15  American Athletic               Big Ten
# 50      81.503588            21          Big South  Mid Eastern Athletic
# 132    105.999264            19       Southeastern               Big Ten
# 352     88.432917            24      Mountain West                Big 12
# 514     90.943829            21     Atlantic Coast              Big East
# 292     90.975204            20       Southeastern               Big Ten
# 486     90.123155            21          Northeast          America East
# 432     94.917845            18            Big Ten        Atlantic Coast
# 506     91.560137            22       Southeastern                Big 12
# 156     91.568956            20         Pacific 12     American Athletic
# 496     99.783472            19             Big 12               Big Ten
# 432    9.0      9     11    6.0   14.0   12.0    4.0     14         0
# 506    5.0      4      5    4.0    8.0    5.0    4.0      9         0
# 156   13.0      8     10   11.0   17.0   10.0   14.0     14         1
# 496   11.0     18     14   17.0   15.0   19.0   19.0     13         0
# 319    9.0     13     14    8.0   14.0    9.0    6.0     12         0
# 301   22.0     21     23   21.0   21.0   26.0   16.0     23        -1
# 513   26.0     31     41   22.0   37.0   28.0   22.0     23         0
# 99     2.0      6      2    7.0    3.0    4.0    8.0      2         0
# 441   87.0     71    111   97.0   83.0   83.0   91.0    113         0
# 203    4.0      7      4    5.0    5.0    6.0   10.0      4        -1
# 51   160.0    173    214  178.0  152.0  194.0  202.0    210         0
# 525   21.0     14     21   17.0   14.0   16.0   17.0     19         1
# 123   12.0      3      7    5.0   15.0    8.0    7.0     14         1
# 517   12.0      9     11    9.0   11.0   12.0   18.0      5        -1
# 321    1.0      1      1    2.0    1.0    1.0    2.0      1         0
#
#      upset_seed_threshold  margin_victory_avg_t  margin_victory_avg_o  \
# 358                     1                    16                     5
# 488                     1                    12                    17
# 494                     0                    12                     5
# 454                     0                     4                     6
# 50                      0                     0                     1
# 132                     0                    20                    14
# 352                     1                    14                     6
# 514                     0                     9                     6
# 292                     0                     8                     8
# 486                     0                    -2                     2
# 432                     0                     4                     9
# 506                     0                    15                     9
# 156                     0                     9                     8
# 496                     0                     8                    11
# 319                     0                    11                     9
# 301                     1                    11                     7
# 513                     0                     7                     8
# 99                      0                    12                    16
# 441                     0                     3                    10
# 203                     1                     7                    13
# 51                      0                     1                    11
# 525                     0                    12                    13
# 123                     0                     4                    10
# 517                     1                     7                    10
# 321                     0                    11                    18
#
#      delta_margin_victory_avg  delta_fg_pct  delta_off_rebs_avg  \
# 358                        11         0.034                  -2
# 488                        -5        -0.029                   4
# 494                         7         0.033                   0
# 454                        -2        -0.018                   2
# 50                         -1         0.026                   0
# 132                         6        -0.011                   3
# 352                         8         0.032                  -4
# 514                         3        -0.002                  -2
# 292                         0        -0.015                  -2
# 486                        -4        -0.003                  -1
# 432                        -5        -0.043                   2
# 506                         6         0.048                  -1
# 156                         1         0.035                  -3
# 496                        -3        -0.007                   0
# 319                         2         0.008                  -3
# 301                         4        -0.002                  -1
# 513                        -1         0.004                   2
# 99                         -4        -0.043                   2
# 441                        -7         0.009                  -1
# 203                        -6        -0.042                  -3
# 51                        -10        -0.019                  -1
# 525                        -1         0.064                  -3
# 123                        -6        -0.026                  -1
# 517                        -3        -0.007                   0
# 321                        -7        -0.035                   0
#
#      delta_def_rebs_avg  delta_allow_def_rebs_avg  delta_ft_pct  to_net_avg_t  \
# 358                  -1                        -2         0.045             3
# 488                   0                         0        -0.062             5
# 494                   5                        -4         0.073             5
# 454                   2                         2        -0.061             4
# 50                    1                         0         0.072             8
# 132                   2                        -1        -0.037             4
# 352                   3                         0         0.082             7
# 514                   3                         3        -0.046             4
# 292                  -1                         4        -0.014             6
# 486                  -3                         4        -0.011             4
# 432                  -4                         2         0.042             5
# 506                   4                        -1        -0.036             7
# 156                  -2                         1        -0.017             7
# 496                  -2                         4        -0.057             3
# 319                  -3                        -4         0.038             5
# 301                  -2                         0         0.028             6
# 513                  -2                         0        -0.051             5
# 99                   -3                         3        -0.068             3
# 441                   2                         0        -0.073             6
# 203                  -2                         3         0.055             5
# 51                   -1                         1        -0.009             9
# 525                   1                        -1         0.041             3
# 123                  -4                         0        -0.027             6
# 517                  -2                         2         0.031             5
# 321                   2                        -2         0.009             5
#
#      to_net_avg_o  delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 358             7                -4          0.306         10.241954
# 488             3                 2         -0.081         -8.534150
# 494             2                 3          0.189          3.199576
# 454             4                 0         -0.014         -6.254385
# 50              8                 0         -0.124          9.153346
# 132             3                 1          0.074         -7.675470
# 352             8                -1          0.206          9.659726
# 514             7                -3          0.063          3.974016
# 292             7                -1          0.000         -0.154760
# 486             7                -3         -0.074          5.311410
# 432             4                 1         -0.167         -6.009586
# 506             6                 1          0.105          3.608517
# 156             5                 2          0.009          7.756949
# 496             8                -5         -0.085          0.841843
# 319             7                -2         -0.021          6.687950
# 301             8                -2          0.148          1.462672
# 513             7                -2         -0.155         -1.425497
# 99              6                -3         -0.056        -10.634175
# 441             4                 2         -0.132         -4.965838
# 203             7                -2         -0.087         -1.600580
# 51              5                 4         -0.096         -5.366884
# 525             2                 1         -0.015         11.328333
# 123             5                 1         -0.195         -5.861972
# 517             4                 1         -0.176          0.453166
# 321             3                 2         -0.156         -7.196516
#
#      delta_allow_off_rebs_avg  delta_ft_att_avg  delta_allow_ft_att_avg  \
# 358                        -1                 2                      -3
# 488                        -1                 7                       7
# 494                        -1                 2                      -3
# 454                         2                 7                       5
# 50                          0                 0                       1
# 132                         4                 5                       6
# 352                         0                -2                      -5
# 514                        -1                -3                      -2
# 292                         1                 0                       5
# 486                         1                 0                       5
# 432                         0                -1                       4
# 506                         2                 3                      -2
# 156                        -3                 3                       3
# 496                         3                -2                       1
# 319                         1                -3                       2
# 301                         0                 2                       1
# 513                         2                 2                      -2
# 99                          1                -4                       4
# 441                         1                 1                       2
# 203                        -2                -2                       4
# 51                         -3                 3                       2
# 525                         3                -1                      -4
# 123                        -1                -5                      -2
# 517                        -1                 5                       1
# 321                         4                 0                       0
#
#      delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 358          -7       9.02      -2.17        -26      -29.0        -38
# 488         -11      12.38      15.25        -51      -49.0        -54
# 494          -3      -2.62      -7.27          7        7.0        -19
# 454           0      -3.96      -2.16         29       13.0         29
# 50            0      -2.19       0.50         18       41.0         80
# 132           0       4.11      -1.62         -1       -2.0         -4
# 352           7      -1.36      -7.91         -4      -14.0        -16
# 514          -1       2.95      -0.70         -8      -12.0         -8
# 292           1       0.72      -0.42         -6       -6.0        -13
# 486           0      -3.01       0.78         30       23.0          2
# 432           5      -3.76       2.20         30       34.0         25
# 506          -1       1.97      -3.44         -1       -2.0         -2
# 156           2      -1.41      -2.45          8       10.0         16
# 496           1       0.38       3.15          4        8.0          5
# 319           2       1.43      -1.24         -3        1.0          5
# 301           9      -6.36      -8.91         42       50.0         19
# 513           5       3.01       4.10         -6        7.0          6
# 99            3      -4.60       0.19         11       10.0          8
# 441          -5       5.32      11.36        -37      -34.0        -14
# 203           7      -9.29      -2.83         41       34.0         39
# 51            0      -2.03       7.44         21       55.0         21
# 525          -4       3.67       3.34        -10      -10.0         -6
# 123           5      -5.18       0.97         22       22.0         44
# 517           8      -3.96      -0.28         19       21.0         28
# 321           3      -5.54       0.53         11        9.0         17
#
#      delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor  \
# 358        -30      -38.0      -33.0      -38.0      -37.0        -18
# 488        -93      -72.0      -27.0      -73.0      -52.0        -25
# 494          2      -10.0       20.0       -9.0      -19.0         25
# 454         20       16.0        2.0       25.0        1.0         28
# 50          50       71.0       25.0       57.0       74.0          3
# 132         -2       -2.0       -2.0       -3.0       -3.0         -1
# 352          4      -11.0      -13.0      -10.0       -8.0         13
# 514         -6      -12.0      -11.0       -5.0       -9.0        -11
# 292         -2      -10.0       11.0       -3.0      -14.0          9
# 486          5        9.0       11.0       36.0        4.0         29
# 432         23       32.0       28.0       17.0       36.0         19
# 506         -2       -2.0       -2.0       -3.0       -2.0         -5
# 156         13        8.0        8.0        5.0        5.0         19
# 496          7       10.0        2.0       -4.0        2.0         -2
# 319          1        6.0       -7.0        7.0        1.0         -6
# 301         35       30.0       40.0       26.0       64.0         63
# 513        -19       36.0       -4.0       15.0       42.0         11
# 99          11        9.0       10.0       10.0        6.0         13
# 441        -56      -47.0      -25.0      -31.0      -50.0        -53
# 203         53       36.0       49.0       52.0       23.0         44
# 51         -10       -9.0       66.0      -21.0      -36.0          4
# 525        -13       -8.0       -4.0       -8.0       -1.0        -11
# 123         29       39.0       17.0       34.0       35.0         16
# 517         11       49.0       22.0       31.0       46.0         29
# 321         14       12.0        6.0       15.0        5.0          5
#
#      predicted_result  pred_win_prob
# 358                 1       0.551551
# 488                 1       0.524404
# 494                 1       0.508106
# 454                 1       0.507467
# 50                  1       0.505087
# 132                 1       0.503435
# 352                 1       0.501974
# 514                 1       0.501728
# 292                 1       0.501461
# 486                 1       0.501155
# 432                 1       0.500866
# 506                 1       0.500248
# 156                 1       0.500160
# 496                 1       0.500067
# 319                -1       0.498839
# 301                -1       0.498531
# 513                -1       0.497644
# 99                 -1       0.496394
# 441                -1       0.495860
# 203                -1       0.495231
# 51                 -1       0.495144
# 525                -1       0.494983
# 123                -1       0.494567
# 517                -1       0.493238
# 321                -1       0.488821

# %%
correct_predictions = test_games[test_games['game_result'] == 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)

print("Correct predictions= ",correct_predictions.shape[0])


correct_predictions
# Out:
# Correct predictions=  82
#      season_t  round   game_date  seed_t                 team_t  \
# 343      2017     64  2017-03-16       1              Villanova
# 333      2015     32  2015-03-21       1               Kentucky
# 107      2010     64  2010-03-19       1               Syracuse
# 353      2010     64  2010-03-18       2           Kansas State
# 473      2011     64  2011-03-18       1                   Duke
# 383      2015     64  2015-03-20       2               Virginia
# 329                    12              24                    19        11
# 145                     9              23                    21        11
# 223                    11              27                    22        13
# ..                    ...             ...                   ...       ...
# 304                    12              23                    20        15
# 28                     11              21                    22        12
# 456                    10              23                    22        13
# 302                     7              25                    19        10
# 176                    12              19                    21        12
# 90                      9              25                    21        14
# 430                    11              22                    23        11
# 34                     10              25                    23        11
# 298                     9              20                    19        14
# 40                     11              19                    21        14
# 56                     13              25                    25        10
# 412                    11              24                    22         9
# 366                    10              23                    23        13
# 282                     9              25                    24        11
# 482                     9              24                    20        12
# 336                    11              23                    23        12
# 248                    11              21                    25        12
# 508                    10              24                    24         9
# 250                    11              22                    22        12
# 162                     9              25                    23        11
# 208                    13              26                    20        15
# 436                     9              28                    23        13
# 316                     9              26                    22        11
# 244                    10              19                    21        12
# 300                    13              22                    22        16
# 344                    11              23                    22        14
# 134                     9              26                    21        11
# 278                    10              21                    23         8
# 322                    12              23                    23        14
# 224                    11              22                    24        10
#
#      steal_avg_t  off_rating_t  ft_att_avg_t  srs_o  sos_o  win_pct_o  \
# 343            7    105.704698            18  -4.29  -3.51      0.556
# 333            6     98.323794            24  10.72   4.40      0.676
# 107            9     98.211154            21  -1.26  -6.69      0.714
# 353            7     92.787760            29  -2.49  -4.72      0.727
# 473            7     99.215660            22  -5.20  -8.77      0.727
# 383            5     95.275047            18   0.35  -2.77      0.667
# 163            6     83.851820            24  -1.34  -3.34      0.576
# 375           10     93.582042            23  13.65   5.89      0.743
# 279            7     90.472028            20  18.82   5.63      0.727
# 511            6     89.168207            17  -4.10  -5.34      0.625
# 155            6     91.568956            20  15.41   6.10      0.743
# 317            7     95.168653            25   8.76  -0.91      0.853
# 427            5    100.111235            20   5.44  -1.22      0.765
# 49             6     94.587493            21   9.52   0.87      0.735
# 457            6    101.393511            16  23.86   6.83      0.784
# 199            5     94.414894            21  16.27   7.57      0.784
# 151            7     96.219000            20  18.52   9.88      0.778
# 283            7     90.472028            20  20.19   9.32      0.784
# 75             6     95.566078            22  17.84   8.12      0.714
# 237            6     96.483900            20   7.69   6.57      0.636
# 477            6     96.093059            22  17.52   8.81      0.829
# 149            7     96.219000            20  18.97   7.50      0.853
# 201            6     91.469120            22  16.16   9.07      0.588
# 7              8     94.364700            20  14.61  10.39      0.656
# 111            8     93.289359            24  18.76   9.73      0.657
# 401            7     88.119390            19   8.25   2.84      0.625
# 373           10     93.582042            23  21.28  10.05      0.795
# 329            6    100.384590            23  21.72   9.93      0.821
# 145            7     98.134767            25  15.26   5.28      0.794
# 223            6     96.909691            26  14.64   6.79      0.688
# ..           ...           ...           ...    ...    ...        ...
# 304            8     89.273062            22  16.54   7.99      0.789
# 28             7     96.470777            19   9.20   7.29      0.611
# 456            7     86.792453            22  14.21  10.68      0.600
# 302            4    103.658537            14  18.25   7.63      0.865
# 176            6     91.309213            24  12.93   6.28      0.703
# 90             5     89.838442            23  16.27   7.57      0.784
# 430            8     89.743590            24   0.98  -5.19      0.667
# 34             6     93.782117            22  20.80   8.38      0.846
# 298            6     97.724881            20  18.64  10.55      0.750
# 162         79             69     0.454           0.421     0.720
# 208         68             59     0.442           0.416     0.738
# 436         80             70     0.452           0.415     0.730
# 316         79             68     0.478           0.397     0.690
# 244         73             61     0.472           0.380     0.692
# 300         71             59     0.477           0.379     0.700
# 344         81             72     0.458           0.409     0.755
# 134         72             58     0.479           0.428     0.763
# 278         75             59     0.461           0.390     0.725
# 322         79             64     0.478           0.378     0.668
# 224         77             59     0.497           0.385     0.705
#
#      allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 343                  18   75.138889               7                    11
# 333                  13   70.300000              11                    11
# 107                  19   78.371429              12                    12
# 353                  19   78.830303              11                    11
# 473                  21   77.533333              11                    13
# 383                  16   75.393939               9                    10
# 163                  26   77.593939              10                    10
# 375                  19   76.914286              14                     8
# 279                  17   72.890909              12                     9
# 511                  19   80.893750              12                    10
# 155                  14   75.337143              12                    11
# 317                  19   74.211765              10                     9
# 427                  21   78.300000              11                     9
# 49                   15   77.529412              11                    10
# 457                  15   71.897297              10                     9
# 199                  16   76.556757              12                    10
# 151                  19   81.794444              10                    11
# 283                  15   73.664865              10                     9
# 75                   15   73.891429               9                    10
# 237                  17   77.006061              11                    10
# 477                  19   75.428571              10                    10
# 149                  21   78.005882              11                    10
# 201                  19   74.717647              12                    10
# 7                    19   73.850000              10                    10
# 111                  13   72.194286              11                     9
# 401                  20   75.312500              11                    10
# 373                  12   73.969231              10                    10
# 329                  18   77.441026              11                    10
# 145                  18   75.388235              13                    10
# 223                  19   79.050000              12                    12
# ..                  ...         ...             ...                   ...
# 304                  18   76.515789              10                    10
# 28                   16   69.133333              10                    10
# 456                  15   69.737143               8                     9
# 302                  16   75.486486              10                     9
# 176                  14   77.140541              13                    11
# 90                   16   76.556757              12                    10
# 430                  17   73.461111              11                    10
# 34                   15   77.917949              10                    10
# 298                  17   74.833333              11                     9
# 40                   20   72.988889              10                    10
# 56                   13   72.322222              12                     9
# 412                  18   83.035000              14                    11
# 366                  17   74.055556               9                    10
# 282                  19   79.422222              12                     8
# 482                  18   75.955556               9                    11
# 336                  20   78.510000              14                    10
# 248                  18   78.097297              10                    11
# 508                  22   85.156757              14                    10
# 250                  18   77.441026              11                    10
# 162                  25   84.277778              13                    11
# 208                  17   71.721053               9                     8
# 436                  19   83.111765              12                     9
# 316                  23   79.533333              12                    12
# 244                  18   77.441026              11                    10
# 300                  18   75.394595              11                     9
# 344                  27   83.587879              13                    11
# 134                  11   67.925000               9                     7
# 278                  18   74.511111              11                     9
# 322                  18   83.010526              14                    12
# 224                  16   75.365714              11                    10
#
#      def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  \
# 343              22                    25        13            6
# 333              23                    18        12            6
# 107              24                    21        13            6
# 353              25                    22        14            4
# 473              24                    25        12            7
# 383              23                    22        13            6
# 163              21                    23        14            8
# 375              22                    20        11            4
# 279              19                    18        11            6
# 511              23                    20        16            7
# 155              22                    23        11            7
# 317              23                    20        12            7
# 427              26                    23        11            4
# 49               22                    21        12            7
# 457              21                    20        10            7
# 199              24                    22        12            5
# 151              28                    25        10            5
# 283              22                    22        10            6
# 75               24                    23        11            7
# 237              25                    27         9            5
# 477              23                    24        10            7
# 149              26                    23        11            6
# 201              27                    20        12            3
# 7                23                    19        13            6
# 111              22                    23         9            5
# 401              21                    19        13            5
# 373              21                    21         9            6
# 329              23                    21        12            7
# 145              22                    20        11            7
# 223              25                    20        16            8
# ..              ...                   ...       ...          ...
# 304              23                    22        12            5
# 28               20                    20        13            5
# 456              23                    21        10            4
# 302              26                    20        11            5
# 176              19                    23        10            8
# 90               24                    22        12            5
# 430              21                    21        12            6
# 34               26                    22        11            6
# 298              22                    20        13            8
# 40               19                    24        11            7
# 56               23                    22        11            6
# 412              26                    21        10            6
# 366              23                    22        13            5
# 282              28                    23        11            6
# 482              21                    23        10            6
# 336              26                    19        11            4
# 248              25                    21        13            7
# 508              23                    23        12           10
# 250              23                    21        12            7
# 162              24                    22        12            7
# 208              23                    21        12            7
# 436              27                    23        12            7
# 316              26                    21        10            5
# 244              23                    21        12            7
# 300              23                    20        12            7
# 344              25                    22        13            7
# 134              23                    20         7            4
# 278              26                    21        10            6
# 322              27                    20        14            7
# 224              22                    19        11            7
#
#      off_rating_o  ft_att_avg_o            conf_name_t  \
# 343     89.168207            17               Big East
# 333     88.193457            18           Southeastern
# 107     89.318265            26         Atlantic Coast
# 353     92.603982            27                 Big 12
# 473     85.124678            23         Atlantic Coast
# 383     98.151125            17         Atlantic Coast
# 163     88.924471            25   Mid Eastern Athletic
# 375     93.610698            24         Atlantic Coast
# 279     94.662010            20      American Athletic
# 511     89.005640            23              Northeast
# 155     90.260922            21      American Athletic
# 317    102.409639            15           Southeastern
# 427     97.062580            23                Big Ten
# 49      94.157815            23          Mountain West
# 457     98.751974            16                Big Ten
# 199     94.047871            20               Big East
# 151    101.473884            22      American Athletic
# 283     95.024949            19      American Athletic
# 75      93.380249            22            Atlantic 10
# 237     88.304738            16                Big Ten
# 477     92.803030            21         Atlantic Coast
# 149     98.710504            24      American Athletic
# 201     89.670918            19               Big East
# 7       94.786730            17            Atlantic 10
# 111     88.649675            16           Southeastern
# 401     92.946058            22         Atlantic Coast
# 373    101.393511            16         Atlantic Coast
# 329     94.265280            22           Southeastern
# 145     90.199750            21                    Ivy
# 223     86.021505            20             West Coast
# ..            ...           ...                    ...
# 304     99.325905            23      American Athletic
# 28      85.342334            16      American Athletic
# 456     94.641101            14           Southeastern
# 302    100.680272            22             West Coast
# 176     88.150795            17                 Big 12
# 90      94.047871            20             Pacific 12
# 430     91.204719            19              Southland
# ...
# 40           0.005          7.627814                         1
# 56          -0.114          8.749652                         4
# 412         -0.158          2.392787                         0
# 366          0.076          3.800135                         0
# 282         -0.111         -3.875213                         1
# 482         -0.055          1.776789                        -2
# 336         -0.119         -4.623955                         1
# 248         -0.144         -5.317873                         0
# 508         -0.035          6.628474                         0
# 250         -0.172         -2.832002                         1
# 162          0.135          0.904702                        -2
# 208         -0.011          3.399383                         5
# 436         -0.081          3.168458                         0
# 316          0.038         -3.815673                        -3
# 244         -0.210         -1.720293                         0
# 300         -0.049          1.720158                         4
# 344         -0.101         -9.775579                         0
# 134         -0.194        -13.508842                         2
# 457       10.0       -5.0       13.0          7                 1
# 199       35.0       41.0       25.0         32                 1
# 151        3.0       13.0       15.0         -4                 1
# 283       28.0       28.0       27.0         32                 1
# 75        31.0       37.0       19.0         42                 1
# 237      -66.0      -21.0      -30.0        -55                 1
# 477      -12.0       -3.0      -13.0        -15                 1
# 149       19.0       14.0       17.0         10                 1
# 201        3.0      -10.0      -11.0          5                 1
# 7         53.0       53.0       36.0         38                 1
# 111       25.0       18.0       16.0         20                 1
# 401      -30.0      -54.0      -61.0        -36                 1
# 373       -9.0       -8.0      -17.0        -12                 1
# 329       -3.0       -5.0       -4.0         -5                 1
# 145        9.0       21.0       25.0         12                 1
# 223       37.0        4.0       -6.0         35                 1
# ..         ...        ...        ...        ...               ...
# 304       60.0       31.0        9.0         58                -1
# 28       -32.0      -40.0      -32.0         -5                -1
# 456       15.0       20.0      -18.0         33                -1
# 302       -6.0       18.0       15.0          5                -1
# 176       -3.0        6.0        8.0         22                -1
# 90        34.0       21.0       36.0         34                -1
# 430      -15.0      -17.0      -27.0         -1                -1
# 34        21.0       40.0       22.0          7                -1
# 298       56.0       51.0       49.0         59                -1
# 40         6.0       25.0       -3.0        -21                -1
# 56        15.0       -7.0       18.0         13                -1
# 412       35.0       26.0       27.0         32                -1
# 366      -42.0      -37.0      -44.0        -31                -1
# 282       28.0       18.0       -2.0         36                -1
# 482        9.0       19.0       24.0         13                -1
# 336       26.0       24.0       34.0         27                -1
# 248       20.0       19.0       12.0         13                -1
# 508       20.0       -1.0       -1.0         12                -1
# 250       39.0       42.0       43.0         23                -1
# 162       18.0      -30.0      -31.0         47                -1
# 208      -21.0       -8.0       -7.0        -18                -1
# 436      117.0      107.0      101.0        174                -1
# 316       84.0       73.0       48.0        100                -1
# 244      111.0      118.0      119.0         74                -1
# 300      161.0       95.0       77.0        139                -1
# 344      173.0      149.0      118.0        142                -1
# 134      145.0      143.0      126.0        161                -1
# 278      161.0      194.0      204.0        200                -1
# 322      136.0      161.0      119.0        180                -1
# 224      166.0      182.0      174.0        266                -1
#
#      pred_win_prob
# 343       0.583975
# 333       0.566701
# 107       0.547657
# 353       0.528177
# 473       0.522113
# 383       0.515789
# 163       0.511562
# 375       0.511151
# 279       0.510897
# 511       0.510885
# 155       0.509244
# 317       0.508459
# 427       0.508338
# 49        0.507241
# 457       0.506351
# 199       0.506274
# 151       0.506245
# 283       0.506120
# 75        0.505664
# 237       0.505511
# 477       0.505404
# 149       0.504962
# 201       0.504652
# 7         0.504640
# 111       0.504329
# 401       0.503913
# 373       0.503661
# 329       0.503243
# 145       0.503227
# 223       0.502549
# ..             ...
# 304       0.496266
# 28        0.495969
# 456       0.495956
# 302       0.495895
# 176       0.495594
# 90        0.495360
# 430       0.494837
# 34        0.493884
# 298       0.493192
# 40        0.493089
# 56        0.492427
# 412       0.492371
# 366       0.491450
# 282       0.491103
# 482       0.490402
# 336       0.490063
# 248       0.490034
# 508       0.489254
# 250       0.487852
# 162       0.487742
# 208       0.475806
# 436       0.465666
# 316       0.462002
# 244       0.442550
# 300       0.424266
# 344       0.421907
# 134       0.420161
# 278       0.417378
# 322       0.404264
# 224       0.372503
#
# [82 rows x 100 columns]

# %%
feature_dictionary = utils.Feature_Dictionary()

# %%
missed_predictions.apply(lambda x: feature_dictionary.print_game_info(test_games, 
                                                                      x['season_t'], x['round'], x['team_t'] ), axis=1)
# Out:
#                                     Villanova       North Carolina State     Stat Supports Winner
# Allow FG %                      40.60                              40.30         True  (L)
# SOS                              7.55                               9.72         True  (H)
# Poss Avg                        73.86                              75.55         True  (H)
# Off Rb Avg                      10.00                              12.00         True  (H)
# Def Rb Avg                      24.00                              25.00         True  (H)
# Seed                              1                                  8          False  (L)
# SAG                              6.00                              32.00        False  (L)
# WLK                              4.00                              33.00        False  (L)
# WOL                              2.00                              40.00        False  (L)
# RTH                              2.00                              32.00        False  (L)
# COL                              2.00                              40.00        False  (L)
# POM                              5.00                              38.00        False  (L)
# DOL                              2.00                              40.00        False  (L)
# RPI                              2.00                              39.00        False  (L)
# MOR                              4.00                              22.00        False  (L)
# Allow PPG                       60.00                              65.00        False  (L)
# Allow Off Rb Avg                10.00                              11.00        False  (L)
# Allow Def Rb Avg                21.00                              23.00        False  (L)
# Allow FT ATT Avg                16.00                              19.00        False  (L)
# Turnover Avg                    10.00                              10.00        False  (L)
# Net Turnover Avg                 3.00                               7.00        False  (L)
# SRS                             23.13                              14.11        False  (H)
# PPG                             76.00                              70.00        False  (H)
# FG %                            47.00                              43.60        False  (H)
# FT ATT Avg                      22.00                              20.00        False  (H)
# FT %                            73.10                              68.60        False  (H)
# Takeaway Avg                     7.00                               3.00        False  (H)
# Margin Victory Avg              16.00                               5.00        False  (H)
# Win %                           91.70                              61.10        False  (H)
# Off Rating                     102.90                              92.65        False  (H)
#
#
# Top Conference=  North Carolina State
#
#  North Carolina State Wins.
#
# Supporting Stat Count= 5  out of 30  stats.
#
#
#
#                                 West Virginia          Stephen F. Austin     Stat Supports Winner
# Allow PPG                       66.00                              63.00         True  (L)
# Allow FT ATT Avg                27.00                              20.00         True  (L)
# Turnover Avg                    14.00                              12.00         True  (L)
# Net Turnover Avg                 5.00                               3.00         True  (L)
# PPG                             78.00                              80.00         True  (H)
# FG %                            44.90                              47.80         True  (H)
# FT %                            67.30                              73.50         True  (H)
# Margin Victory Avg              12.00                              17.00         True  (H)
# Win %                           74.30                              82.40         True  (H)
# Off Rating                      91.34                              99.88         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              6.00                              57.00        False  (L)
# WLK                              6.00                              55.00        False  (L)
# WOL                              8.00                              62.00        False  (L)
# RTH                              8.00                             101.00        False  (L)
# COL                             11.00                              83.00        False  (L)
# POM                              6.00                              33.00        False  (L)
# DOL                              7.00                              80.00        False  (L)
# RPI                             10.00                              62.00        False  (L)
# MOR                             11.00                              36.00        False  (L)
# Allow FG %                      42.40                              43.80        False  (L)
# Allow Off Rb Avg                 8.00                               9.00        False  (L)
# Allow Def Rb Avg                22.00                              22.00        False  (L)
# SRS                             21.61                               9.23        False  (H)
# SOS                              9.78                              -5.47        False  (H)
# Poss Avg                        85.39                              80.10        False  (H)
# Off Rb Avg                      15.00                              11.00        False  (H)
# Def Rb Avg                      23.00                              23.00        False  (H)
# FT ATT Avg                      27.00                              20.00        False  (H)
# Takeaway Avg                     9.00                               9.00        False  (H)
#
#
# Top Conference=  West Virginia
#
#  Stephen F. Austin Wins.
#
# Supporting Stat Count= 10  out of 30  stats.
#
#
#
#                                  Saint Mary's                     Purdue     Stat Supports Winner
# SAG                             35.00                              28.00         True  (L)
# WLK                             38.00                              31.00         True  (L)
# RTH                             30.00                              28.00         True  (L)
# POM                             44.00                              24.00         True  (L)
# MOR                             44.00                              19.00         True  (L)
# Turnover Avg                    11.00                               8.00         True  (L)
# Net Turnover Avg                 5.00                               2.00         True  (L)
# SRS                             11.26                              13.88         True  (H)
# SOS                              0.78                               8.05         True  (H)
# Seed                              7                                 10          False  (L)
# WOL                             18.00                              37.00        False  (L)
# COL                             29.00                              39.00        False  (L)
# DOL                             25.00                              34.00        False  (L)
# RPI                             28.00                              47.00        False  (L)
# Allow PPG                       62.00                              66.00        False  (L)
# Allow FG %                      42.80                              44.20        False  (L)
# Allow Off Rb Avg                 9.00                              10.00        False  (L)
# Allow Def Rb Avg                20.00                              24.00        False  (L)
# Allow FT ATT Avg                15.00                              18.00        False  (L)
# PPG                             74.00                              71.00        False  (H)
# Poss Avg                        74.93                              74.30        False  (H)
# FG %                            47.30                              44.00        False  (H)
# Off Rb Avg                      11.00                              11.00        False  (H)
# Def Rb Avg                      23.00                              18.00        False  (H)
# FT ATT Avg                      21.00                              19.00        False  (H)
# FT %                            72.90                              65.60        False  (H)
# Takeaway Avg                     6.00                               6.00        False  (H)
# Margin Victory Avg              12.00                               5.00        False  (H)
# Win %                           81.80                              62.90        False  (H)
# Off Rating                      98.75                              95.55        False  (H)
#
#
# Top Conference=  Purdue
#
#  Purdue Wins.
#
# Supporting Stat Count= 9  out of 30  stats.
#
#
#
#                                         Tulsa                   Michigan     Stat Supports Winner
# SAG                             66.00                              37.00         True  (L)
# WLK                             64.00                              51.00         True  (L)
# WOL                             74.00                              45.00         True  (L)
# RTH                             63.00                              43.00         True  (L)
# COL                             65.00                              49.00         True  (L)
# POM                             58.00                              56.00         True  (L)
# DOL                             60.00                              35.00         True  (L)
# RPI                             58.00                              57.00         True  (L)
# MOR                             71.00                              43.00         True  (L)
# Allow PPG                       69.00                              67.00         True  (L)
# Allow Off Rb Avg                10.00                               8.00         True  (L)
# Allow Def Rb Avg                26.00                              24.00         True  (L)
# Allow FT ATT Avg                19.00                              14.00         True  (L)
# Turnover Avg                    10.00                               9.00         True  (L)
# SRS                              9.79                              13.75         True  (H)
# SOS                              5.76                               7.92         True  (H)
# FG %                            44.40                              46.20         True  (H)
# FT %                            67.70                              73.80         True  (H)
# Margin Victory Avg               4.00                               6.00         True  (H)
# Win %                           62.50                              63.90         True  (H)
# Off Rating                      93.91                             100.17         True  (H)
# Seed                             11                                 11          False  (L)
# Allow FG %                      41.60                              44.80        False  (L)
# Net Turnover Avg                 4.00                               4.00        False  (L)
# PPG                             73.00                              73.00        False  (H)
# Poss Avg                        77.73                              72.88        False  (H)
# Off Rb Avg                      10.00                               8.00        False  (H)
# Def Rb Avg                      25.00                              23.00        False  (H)
# FT ATT Avg                      22.00                              15.00        False  (H)
# Takeaway Avg                     6.00                               5.00        False  (H)
#
#
# Top Conference=  Michigan
#
#  Michigan Wins.
#
# Supporting Stat Count= 21  out of 30  stats.
#
#
#
#                                       Liberty         North Carolina A&T     Stat Supports Winner
# SAG                            260.00                             242.00         True  (L)
# WLK                            264.00                             223.00         True  (L)
# WOL                            299.00                             219.00         True  (L)
# RTH                            296.00                             246.00         True  (L)
# COL                            293.00                             222.00         True  (L)
# POM                            251.00                             226.00         True  (L)
# DOL                            278.00                             221.00         True  (L)
# RPI                            287.00                             213.00         True  (L)
# MOR                            237.00                             234.00         True  (L)
# Allow PPG                       69.00                              61.00         True  (L)
# Allow FG %                      42.20                              38.80         True  (L)
# Allow FT ATT Avg                22.00                              21.00         True  (L)
# SRS                             -9.13                              -6.94         True  (H)
# Takeaway Avg                     5.00                               7.00         True  (H)
# Margin Victory Avg               0.00                               1.00         True  (H)
# Win %                           41.70                              54.10         True  (H)
# Seed                             16                                 16          False  (L)
# Allow Off Rb Avg                12.00                              12.00        False  (L)
# Allow Def Rb Avg                24.00                              24.00        False  (L)
# Turnover Avg                    13.00                              15.00        False  (L)
# Net Turnover Avg                 8.00                               8.00        False  (L)
# SOS                             -5.80                              -6.30        False  (H)
# PPG                             69.00                              62.00        False  (H)
# Poss Avg                        76.11                              76.07        False  (H)
# FG %                            42.90                              40.30        False  (H)
# Off Rb Avg                      10.00                              10.00        False  (H)
# Def Rb Avg                      22.00                              21.00        False  (H)
# FT ATT Avg                      21.00                              21.00        False  (H)
# FT %                            73.00                              65.80        False  (H)
# Off Rating                      90.66                              81.50        False  (H)
#
#  North Carolina A&T Wins.
#
# Supporting Stat Count= 16  out of 30  stats.
#
#
#
#                                      Kentucky                  Wisconsin     Stat Supports Winner
# Allow Off Rb Avg                11.00                               7.00         True  (L)
# Allow FT ATT Avg                17.00                              11.00         True  (L)
# Turnover Avg                    10.00                               7.00         True  (L)
# Net Turnover Avg                 4.00                               3.00         True  (L)
# SOS                              8.67                              10.29         True  (H)
# FG %                            46.80                              47.90         True  (H)
# FT %                            72.60                              76.30         True  (H)
# Off Rating                      98.32                             106.00         True  (H)
# Seed                              1                                  1          False  (L)
# SAG                              1.00                               2.00        False  (L)
# WLK                              1.00                               3.00        False  (L)
# WOL                              1.00                               5.00        False  (L)
# RTH                              1.00                               3.00        False  (L)
# COL                              1.00                               3.00        False  (L)
# POM                              1.00                               3.00        False  (L)
# DOL                              1.00                               4.00        False  (L)
# RPI                              1.00                               4.00        False  (L)
# MOR                              2.00                               3.00        False  (L)
# Allow PPG                       54.00                              58.00        False  (L)
# Allow FG %                      35.40                              42.80        False  (L)
# Allow Def Rb Avg                19.00                              20.00        False  (L)
# SRS                             28.72                              24.61        False  (H)
# PPG                             74.00                              72.00        False  (H)
# Poss Avg                        75.26                              67.92        False  (H)
# Off Rb Avg                      12.00                               9.00        False  (H)
# Def Rb Avg                      25.00                              23.00        False  (H)
# FT ATT Avg                      24.00                              19.00        False  (H)
# Takeaway Avg                     6.00                               4.00        False  (H)
# Margin Victory Avg              20.00                              14.00        False  (H)
# Win %                           97.40                              90.00        False  (H)
#
#  Wisconsin Wins.
#
# Supporting Stat Count= 8  out of 30  stats.
#
#
#
#                                    Utah State               Kansas State     Stat Supports Winner
# Seed                             12                                  5           True  (L)
# RTH                             28.00                              24.00         True  (L)
# MOR                             35.00                              22.00         True  (L)
# Allow FG %                      41.50                              40.90         True  (L)
# SRS                             13.23                              14.59         True  (H)
# SOS                              0.50                               8.41         True  (H)
# Poss Avg                        73.40                              81.42         True  (H)
# Off Rb Avg                      10.00                              14.00         True  (H)
# FT ATT Avg                      22.00                              24.00         True  (H)
# Takeaway Avg                     4.00                               6.00         True  (H)
# SAG                             21.00                              25.00        False  (L)
# WLK                             20.00                              34.00        False  (L)
# WOL                             12.00                              28.00        False  (L)
# COL                             20.00                              31.00        False  (L)
# POM                             16.00                              29.00        False  (L)
# DOL                             14.00                              24.00        False  (L)
# RPI                             15.00                              23.00        False  (L)
# Allow PPG                       58.00                              66.00        False  (L)
# Allow Off Rb Avg                11.00                              11.00        False  (L)
# Allow Def Rb Avg                20.00                              20.00        False  (L)
# Allow FT ATT Avg                17.00                              22.00        False  (L)
# Turnover Avg                    11.00                              14.00        False  (L)
# Net Turnover Avg                 7.00                               8.00        False  (L)
# PPG                             72.00                              72.00        False  (H)
# FG %                            47.00                              43.80        False  (H)
# Def Rb Avg                      26.00                              23.00        False  (H)
# FT %                            73.70                              65.50        False  (H)
# Margin Victory Avg              14.00                               6.00        False  (H)
# Win %                           88.20                              67.60        False  (H)
# Off Rating                      98.09                              88.43        False  (H)
#
#
# Top Conference=  Kansas State
#
#  Kansas State Wins.
#
# Supporting Stat Count= 10  out of 30  stats.
#
#
#
#                                    Miami (FL)                  Marquette     Stat Supports Winner
# Allow Def Rb Avg                22.00                              19.00         True  (L)
# SOS                              7.88                               8.58         True  (H)
# Poss Avg                        72.69                              74.77         True  (H)
# FG %                            45.50                              45.70         True  (H)
# Off Rb Avg                       9.00                              11.00         True  (H)
# FT ATT Avg                      18.00                              21.00         True  (H)
# FT %                            68.40                              73.00         True  (H)
# Seed                              2                                  3          False  (L)
# SAG                             14.00                              22.00        False  (L)
# WLK                              9.00                              21.00        False  (L)
# WOL                              9.00                              17.00        False  (L)
# RTH                             11.00                              17.00        False  (L)
# COL                              6.00                              18.00        False  (L)
# POM                             14.00                              25.00        False  (L)
# DOL                             12.00                              17.00        False  (L)
# RPI                              4.00                              13.00        False  (L)
# MOR                             14.00                              25.00        False  (L)
# Allow PPG                       60.00                              62.00        False  (L)
# Allow FG %                      40.00                              40.40        False  (L)
# Allow Off Rb Avg                10.00                              11.00        False  (L)
# Allow FT ATT Avg                15.00                              17.00        False  (L)
# Turnover Avg                    10.00                              13.00        False  (L)
# Net Turnover Avg                 4.00                               7.00        False  (L)
# SRS                             16.99                              14.04        False  (H)
# PPG                             69.00                              68.00        False  (H)
# Def Rb Avg                      22.00                              19.00        False  (H)
# Takeaway Avg                     6.00                               6.00        False  (H)
# Margin Victory Avg               9.00                               6.00        False  (H)
# Win %                           80.60                              74.30        False  (H)
# Off Rating                      94.92                              90.94        False  (H)
#
#
# Top Conference=  Miami (FL)
#
#  Marquette Wins.
#
# Supporting Stat Count= 7  out of 30  stats.
#
#
#
#                                     Tennessee             Michigan State     Stat Supports Winner
# Seed                              6                                  5           True  (L)
# POM                             35.00                              24.00         True  (L)
# MOR                             27.00                              18.00         True  (L)
# Allow PPG                       65.00                              63.00         True  (L)
# Allow Off Rb Avg                11.00                              10.00         True  (L)
# Allow Def Rb Avg                23.00                              19.00         True  (L)
# Allow FT ATT Avg                22.00                              17.00         True  (L)
# SOS                              7.75                               8.17         True  (H)
# FG %                            45.60                              47.10         True  (H)
# Off Rb Avg                      11.00                              13.00         True  (H)
# Def Rb Avg                      24.00                              25.00         True  (H)
# FT %                            67.10                              68.50         True  (H)
# Off Rating                      90.82                              90.98         True  (H)
# SAG                             19.00                              25.00        False  (L)
# WLK                             22.00                              28.00        False  (L)
# WOL                             17.00                              30.00        False  (L)
# RTH                             20.00                              22.00        False  (L)
# COL                             16.00                              26.00        False  (L)
# DOL                             17.00                              20.00        False  (L)
# RPI                             14.00                              28.00        False  (L)
# Allow FG %                      39.60                              40.60        False  (L)
# Turnover Avg                    13.00                              13.00        False  (L)
# Net Turnover Avg                 6.00                               7.00        False  (L)
# SRS                             16.05                              15.33        False  (H)
# PPG                             73.00                              71.00        False  (H)
# Poss Avg                        80.38                              78.04        False  (H)
# FT ATT Avg                      20.00                              20.00        False  (H)
# Takeaway Avg                     7.00                               6.00        False  (H)
# Margin Victory Avg               8.00                               8.00        False  (H)
# Win %                           75.70                              75.70        False  (H)
#
#  Michigan State Wins.
#
# Supporting Stat Count= 13  out of 30  stats.
#
#
#
#                              Mount St. Mary's                     Albany     Stat Supports Winner
# SAG                            215.00                             185.00         True  (L)
# WLK                            219.00                             196.00         True  (L)
# WOL                            203.00                             201.00         True  (L)
# RTH                            229.00                             224.00         True  (L)
# COL                            220.00                             211.00         True  (L)
# POM                            188.00                             177.00         True  (L)
# DOL                            223.00                             187.00         True  (L)
# RPI                            189.00                             185.00         True  (L)
# MOR                            186.00                             157.00         True  (L)
# Allow PPG                       77.00                              63.00         True  (L)
# Allow FG %                      49.50                              41.90         True  (L)
# Allow Off Rb Avg                10.00                               9.00         True  (L)
# Allow Def Rb Avg                25.00                              21.00         True  (L)
# Allow FT ATT Avg                20.00                              15.00         True  (L)
# SRS                             -6.32                              -3.31         True  (H)
# FG %                            43.80                              44.10         True  (H)
# Off Rb Avg                       9.00                              10.00         True  (H)
# Def Rb Avg                      21.00                              24.00         True  (H)
# FT %                            73.90                              75.00         True  (H)
# Margin Victory Avg              -2.00                               2.00         True  (H)
# Win %                           48.50                              55.90         True  (H)
# Seed                             16                                 16          False  (L)
# Turnover Avg                    11.00                              12.00        False  (L)
# Net Turnover Avg                 4.00                               7.00        False  (L)
# SOS                             -4.44                              -5.22        False  (H)
# PPG                             75.00                              65.00        False  (H)
# Poss Avg                        78.59                              72.12        False  (H)
# FT ATT Avg                      21.00                              21.00        False  (H)
# Takeaway Avg                     7.00                               5.00        False  (H)
# Off Rating                      95.43                              90.12        False  (H)
#
#  Albany Wins.
#
# Supporting Stat Count= 21  out of 30  stats.
#
#
#
#                                      Illinois                 Miami (FL)     Stat Supports Winner
# Seed                              7                                  2           True  (L)
# SAG                             44.00                              14.00         True  (L)
# WLK                             43.00                               9.00         True  (L)
# WOL                             34.00                               9.00         True  (L)
# RTH                             34.00                              11.00         True  (L)
# COL                             38.00                               6.00         True  (L)
# POM                             42.00                              14.00         True  (L)
# DOL                             29.00                              12.00         True  (L)
# RPI                             40.00                               4.00         True  (L)
# MOR                             33.00                              14.00         True  (L)
# Allow PPG                       64.00                              60.00         True  (L)
# Allow FG %                      42.40                              40.00         True  (L)
# Allow Def Rb Avg                24.00                              22.00         True  (L)
# Allow FT ATT Avg                19.00                              15.00         True  (L)
# Turnover Avg                    11.00                              10.00         True  (L)
# Net Turnover Avg                 5.00                               4.00         True  (L)
# SRS                             13.23                              16.99         True  (H)
# PPG                             68.00                              69.00         True  (H)
# FG %                            41.20                              45.50         True  (H)
# Def Rb Avg                      18.00                              22.00         True  (H)
# FT ATT Avg                      17.00                              18.00         True  (H)
# Margin Victory Avg               4.00                               9.00         True  (H)
# Win %                           63.90                              80.60         True  (H)
# Off Rating                      88.91                              94.92         True  (H)
# Allow Off Rb Avg                10.00                              10.00        False  (L)
# SOS                             10.08                               7.88        False  (H)
# Poss Avg                        76.48                              72.69        False  (H)
# Off Rb Avg                      11.00                               9.00        False  (H)
# FT %                            72.60                              68.40        False  (H)
# Takeaway Avg                     6.00                               6.00        False  (H)
#
#  Miami (FL) Wins.
#
# Supporting Stat Count= 24  out of 30  stats.
#
#
#
#                                      Kentucky              West Virginia     Stat Supports Winner
# Allow PPG                       64.00                              63.00         True  (L)
# Allow Off Rb Avg                12.00                              10.00         True  (L)
# Turnover Avg                    14.00                              11.00         True  (L)
# Net Turnover Avg                 7.00                               6.00         True  (L)
# SOS                              6.82                              10.26         True  (H)
# Off Rb Avg                      14.00                              15.00         True  (H)
# FT %                            66.80                              70.40         True  (H)
# Seed                              1                                  2          False  (L)
# SAG                              4.00                               5.00        False  (L)
# WLK                              3.00                               5.00        False  (L)
# WOL                              2.00                               4.00        False  (L)
# RTH                              3.00                               5.00        False  (L)
# COL                              2.00                               4.00        False  (L)
# POM                              6.00                               8.00        False  (L)
# DOL                              2.00                               5.00        False  (L)
# RPI                              2.00                               4.00        False  (L)
# MOR                              4.00                               9.00        False  (L)
# Allow FG %                      37.80                              41.70        False  (L)
# Allow Def Rb Avg                20.00                              21.00        False  (L)
# Allow FT ATT Avg                18.00                              20.00        False  (L)
# SRS                             21.13                              19.16        False  (H)
# PPG                             79.00                              72.00        False  (H)
# Poss Avg                        83.01                              78.64        False  (H)
# FG %                            47.80                              43.00        False  (H)
# Def Rb Avg                      27.00                              23.00        False  (H)
# FT ATT Avg                      25.00                              22.00        False  (H)
# Takeaway Avg                     7.00                               5.00        False  (H)
# Margin Victory Avg              15.00                               9.00        False  (H)
# Win %                           92.10                              81.60        False  (H)
# Off Rating                      95.17                              91.56        False  (H)
#
#  West Virginia Wins.
#
# Supporting Stat Count= 7  out of 30  stats.
#
#
#
#                                       Arizona                Connecticut     Stat Supports Winner
# Seed                              5                                  3           True  (L)
# SAG                             22.00                              14.00         True  (L)
# WLK                             23.00                              13.00         True  (L)
# WOL                             24.00                               8.00         True  (L)
# RTH                             23.00                              10.00         True  (L)
# COL                             19.00                              11.00         True  (L)
# POM                             25.00                              17.00         True  (L)
# DOL                             15.00                              10.00         True  (L)
# RPI                             19.00                              14.00         True  (L)
# MOR                             33.00                              14.00         True  (L)
# Allow PPG                       67.00                              64.00         True  (L)
# Allow FG %                      40.60                              38.60         True  (L)
# Allow Def Rb Avg                22.00                              21.00         True  (L)
# Allow FT ATT Avg                18.00                              15.00         True  (L)
# Turnover Avg                    12.00                              11.00         True  (L)
# Net Turnover Avg                 7.00                               5.00         True  (L)
# SRS                             16.54                              17.95         True  (H)
# SOS                              7.99                              10.44         True  (H)
# Poss Avg                        76.52                              78.63         True  (H)
# Off Rb Avg                      10.00                              13.00         True  (H)
# Def Rb Avg                      23.00                              25.00         True  (H)
# FT %                            74.60                              76.30         True  (H)
# Takeaway Avg                     5.00                               6.00         True  (H)
# Allow Off Rb Avg                10.00                              13.00        False  (L)
# PPG                             76.00                              72.00        False  (H)
# FG %                            46.90                              43.40        False  (H)
# FT ATT Avg                      23.00                              20.00        False  (H)
# Margin Victory Avg               9.00                               8.00        False  (H)
# Win %                           78.90                              78.00        False  (H)
# Off Rating                      99.33                              91.57        False  (H)
#
#
# Top Conference=  Arizona
#
#  Connecticut Wins.
#
# Supporting Stat Count= 23  out of 30  stats.
#
#
#
#                                    Iowa State                     Purdue     Stat Supports Winner
# Seed                              5                                  4           True  (L)
# SAG                             16.00                              12.00         True  (L)
# WLK                             19.00                              11.00         True  (L)
# WOL                             23.00                              18.00         True  (L)
# RTH                             21.00                              14.00         True  (L)
# COL                             27.00                              17.00         True  (L)
# POM                             17.00                              15.00         True  (L)
# RPI                             21.00                              19.00         True  (L)
# Allow PPG                       72.00                              68.00         True  (L)
# Allow FG %                      42.80                              42.10         True  (L)
# Allow Off Rb Avg                11.00                               8.00         True  (L)
# Allow Def Rb Avg                26.00                              22.00         True  (L)
# Allow FT ATT Avg                15.00                              14.00         True  (L)
# FG %                            47.20                              47.90         True  (H)
# Def Rb Avg                      25.00                              27.00         True  (H)
# FT ATT Avg                      17.00                              19.00         True  (H)
# FT %                            70.00                              75.70         True  (H)
# Margin Victory Avg               8.00                              11.00         True  (H)
# Win %                           68.60                              77.10         True  (H)
# DOL                             15.00                              19.00        False  (L)
# MOR                             11.00                              13.00        False  (L)
# Turnover Avg                    10.00                              13.00        False  (L)
# Net Turnover Avg                 3.00                               8.00        False  (L)
# SRS                             20.51                              20.13        False  (H)
# SOS                             11.94                               8.79        False  (H)
# PPG                             80.00                              79.00        False  (H)
# Poss Avg                        79.50                              79.17        False  (H)
# Off Rb Avg                       9.00                               9.00        False  (H)
# Takeaway Avg                     7.00                               5.00        False  (H)
# Off Rating                     100.63                              99.78        False  (H)
#
#  Purdue Wins.
#
# Supporting Stat Count= 19  out of 30  stats.
#
#
#
#                                      Kentucky             North Carolina     Stat Supports Winner
# SAG                             12.00                              15.00         True  (L)
# POM                              7.00                              14.00         True  (L)
# MOR                              6.00                              12.00         True  (L)
# Allow PPG                       63.00                              68.00         True  (L)
# Allow FG %                      37.40                              39.40         True  (L)
# Allow Def Rb Avg                19.00                              23.00         True  (L)
# Turnover Avg                    10.00                              13.00         True  (L)
# Net Turnover Avg                 5.00                               7.00         True  (L)
# SRS                             20.30                              18.87         True  (H)
# FG %                            45.90                              45.10         True  (H)
# FT %                            71.00                              67.20         True  (H)
# Margin Victory Avg              11.00                               9.00         True  (H)
# Off Rating                      96.81                              90.12         True  (H)
# Seed                              4                                  2          False  (L)
# WLK                             10.00                               9.00        False  (L)
# WOL                             18.00                              13.00        False  (L)
# RTH                             15.00                              14.00        False  (L)
# COL                             14.00                               8.00        False  (L)
# DOL                             16.00                               9.00        False  (L)
# RPI                              7.00                               6.00        False  (L)
# Allow Off Rb Avg                12.00                              11.00        False  (L)
# Allow FT ATT Avg                15.00                              13.00        False  (L)
# SOS                              8.91                              10.15        False  (H)
# PPG                             74.00                              77.00        False  (H)
# Poss Avg                        76.44                              85.44        False  (H)
# Off Rb Avg                      11.00                              14.00        False  (H)
# Def Rb Avg                      25.00                              28.00        False  (H)
# FT ATT Avg                      20.00                              23.00        False  (H)
# Takeaway Avg                     5.00                               6.00        False  (H)
# Win %                           76.30                              78.40        False  (H)
#
#  Kentucky Wins.
#
# Supporting Stat Count= 13  out of 30  stats.
#
#
#
#                                        Hawaii                 California     Stat Supports Winner
# Allow PPG                       66.00                              67.00         True  (L)
# Net Turnover Avg                 6.00                               8.00         True  (L)
# PPG                             77.00                              74.00         True  (H)
# Poss Avg                        80.54                              78.60         True  (H)
# FT ATT Avg                      25.00                              23.00         True  (H)
# FT %                            68.40                              65.60         True  (H)
# Takeaway Avg                     7.00                               4.00         True  (H)
# Margin Victory Avg              11.00                               7.00         True  (H)
# Win %                           82.40                              67.60         True  (H)
# Off Rating                      95.61                              94.15         True  (H)
# Seed                             13                                  4          False  (L)
# SAG                             69.00                              27.00        False  (L)
# WLK                             72.00                              22.00        False  (L)
# WOL                             40.00                              21.00        False  (L)
# RTH                             58.00                              23.00        False  (L)
# COL                             51.00                              21.00        False  (L)
# POM                             61.00                              21.00        False  (L)
# DOL                             52.00                              26.00        False  (L)
# RPI                             80.00                              16.00        False  (L)
# MOR                             86.00                              23.00        False  (L)
# Allow FG %                      40.00                              39.70        False  (L)
# Allow Off Rb Avg                 9.00                               9.00        False  (L)
# Allow Def Rb Avg                23.00                              23.00        False  (L)
# Allow FT ATT Avg                22.00                              21.00        False  (L)
# Turnover Avg                    13.00                              12.00        False  (L)
# SRS                              9.03                              15.39        False  (H)
# SOS                             -1.04                               7.87        False  (H)
# FG %                            45.90                              46.10        False  (H)
# Off Rb Avg                      10.00                              11.00        False  (H)
# Def Rb Avg                      26.00                              28.00        False  (H)
#
#
# Top Conference=  California
#
#  Hawaii Wins.
#
# Supporting Stat Count= 10  out of 30  stats.
#
#
#
#                                     Marquette                     Xavier     Stat Supports Winner
# SAG                             29.00                              35.00         True  (L)
# RTH                             22.00                              41.00         True  (L)
# POM                             33.00                              37.00         True  (L)
# Allow FT ATT Avg                18.00                              20.00         True  (L)
# Net Turnover Avg                 5.00                               7.00         True  (L)
# SRS                             14.89                              11.88         True  (H)
# SOS                              8.51                               4.41         True  (H)
# PPG                             75.00                              72.00         True  (H)
# Poss Avg                        78.91                              74.64         True  (H)
# FG %                            46.50                              46.10         True  (H)
# Off Rb Avg                      12.00                              10.00         True  (H)
# FT ATT Avg                      25.00                              23.00         True  (H)
# Takeaway Avg                     7.00                               5.00         True  (H)
# Seed                             11                                  6          False  (L)
# ...
#
#
#
#                                      UC Davis     North Carolina Central     Stat Supports Winner
# RTH                            204.00                             214.00         True  (L)
# COL                            169.00                             178.00         True  (L)
# DOL                            173.00                             194.00         True  (L)
# RPI                            166.00                             202.00         True  (L)
# Allow Off Rb Avg                 9.00                              12.00         True  (L)
# SOS                             -4.68                             -12.12         True  (H)
# Poss Avg                        79.23                              78.96         True  (H)
# FT ATT Avg                      23.00                              20.00         True  (H)
# Seed                             16                                 16          False  (L)
# SAG                            200.00                             179.00        False  (L)
# WLK                            215.00                             160.00        False  (L)
# WOL                            194.00                             173.00        False  (L)
# POM                            218.00                             152.00        False  (L)
# MOR                            214.00                             210.00        False  (L)
# Allow PPG                       69.00                              63.00        False  (L)
# Allow FG %                      42.60                              39.30        False  (L)
# Allow Def Rb Avg                24.00                              23.00        False  (L)
# Allow FT ATT Avg                18.00                              16.00        False  (L)
# Turnover Avg                    14.00                              11.00        False  (L)
# Net Turnover Avg                 9.00                               5.00        False  (L)
# SRS                             -5.21                              -3.18        False  (H)
# PPG                             70.00                              74.00        False  (H)
# FG %                            43.50                              45.40        False  (H)
# Off Rb Avg                      10.00                              11.00        False  (H)
# Def Rb Avg                      25.00                              26.00        False  (H)
# FT %                            67.40                              68.30        False  (H)
# Takeaway Avg                     5.00                               6.00        False  (H)
# Margin Victory Avg               1.00                              11.00        False  (H)
# Win %                           63.90                              73.50        False  (H)
# Off Rating                      88.35                              93.72        False  (H)
#
#  UC Davis Wins.
#
# Supporting Stat Count= 8  out of 30  stats.
#
#
#
#                                    Notre Dame              Wichita State     Stat Supports Winner
# Seed                              3                                  7           True  (L)
# SAG                              8.00                              18.00         True  (L)
# WLK                             11.00                              21.00         True  (L)
# WOL                              8.00                              14.00         True  (L)
# RTH                              8.00                              21.00         True  (L)
# COL                              9.00                              17.00         True  (L)
# POM                             10.00                              14.00         True  (L)
# DOL                              8.00                              16.00         True  (L)
# RPI                             16.00                              17.00         True  (L)
# MOR                              8.00                              19.00         True  (L)
# Allow Def Rb Avg                21.00                              22.00         True  (L)
# Allow FT ATT Avg                14.00                              18.00         True  (L)
# SRS                             19.23                              15.56         True  (H)
# SOS                              7.02                               3.68         True  (H)
# PPG                             77.00                              70.00         True  (H)
# FG %                            50.90                              44.50         True  (H)
# Def Rb Avg                      24.00                              23.00         True  (H)
# FT %                            74.20                              70.10         True  (H)
# Off Rating                     107.56                              96.23         True  (H)
# Allow PPG                       65.00                              57.00        False  (L)
# Allow FG %                      42.70                              40.20        False  (L)
# Allow Off Rb Avg                11.00                               8.00        False  (L)
# Turnover Avg                     9.00                               9.00        False  (L)
# Net Turnover Avg                 3.00                               2.00        False  (L)
# Poss Avg                        71.59                              72.74        False  (H)
# Off Rb Avg                       8.00                              11.00        False  (H)
# FT ATT Avg                      19.00                              20.00        False  (H)
# Takeaway Avg                     6.00                               7.00        False  (H)
# Margin Victory Avg              12.00                              13.00        False  (H)
# Win %                           84.20                              85.70        False  (H)
#
#
# Top Conference=  Notre Dame
#
#  Notre Dame Wins.
#
# Supporting Stat Count= 19  out of 30  stats.
#
#
#
#                                     Wisconsin                     Xavier     Stat Supports Winner
# Allow PPG                       63.00                              70.00         True  (L)
# Allow Off Rb Avg                 8.00                               9.00         True  (L)
# Allow FT ATT Avg                17.00                              19.00         True  (L)
# Turnover Avg                    11.00                              12.00         True  (L)
# SOS                              9.40                               8.43         True  (H)
# Seed                              7                                  2          False  (L)
# SAG                             36.00                              14.00        False  (L)
# WLK                             34.00                              12.00        False  (L)
# WOL                             47.00                               3.00        False  (L)
# RTH                             36.00                               7.00        False  (L)
# COL                             44.00                               5.00        False  (L)
# POM                             32.00                              15.00        False  (L)
# DOL                             42.00                               8.00        False  (L)
# RPI                             42.00                               7.00        False  (L)
# MOR                             30.00                              14.00        False  (L)
# Allow FG %                      42.60                              41.50        False  (L)
# Allow Def Rb Avg                23.00                              23.00        False  (L)
# Net Turnover Avg                 6.00                               5.00        False  (L)
# SRS                             13.40                              18.58        False  (H)
# PPG                             67.00                              80.00        False  (H)
# Poss Avg                        74.12                              83.11        False  (H)
# FG %                            42.60                              45.20        False  (H)
# Off Rb Avg                      11.00                              12.00        False  (H)
# Def Rb Avg                      23.00                              27.00        False  (H)
# FT ATT Avg                      20.00                              25.00        False  (H)
# FT %                            70.30                              73.00        False  (H)
# Takeaway Avg                     5.00                               7.00        False  (H)
# Margin Victory Avg               4.00                              10.00        False  (H)
# Win %                           62.90                              82.40        False  (H)
# Off Rating                      90.39                              96.26        False  (H)
#
#
# Top Conference=  Wisconsin
#
#  Wisconsin Wins.
#
# Supporting Stat Count= 5  out of 30  stats.
#
#
#
#                                     Marquette                   Syracuse     Stat Supports Winner
# Allow Off Rb Avg                13.00                              14.00         True  (L)
# PPG                             75.00                              73.00         True  (H)
# Poss Avg                        78.91                              77.18         True  (H)
# FT ATT Avg                      25.00                              20.00         True  (H)
# FT %                            69.60                              66.50         True  (H)
# Off Rating                      95.04                              94.59         True  (H)
# Seed                             11                                  3          False  (L)
# SAG                             29.00                              10.00        False  (L)
# WLK                             33.00                              12.00        False  (L)
# WOL                             37.00                               9.00        False  (L)
# RTH                             22.00                              11.00        False  (L)
# COL                             58.00                               9.00        False  (L)
# POM                             33.00                              11.00        False  (L)
# DOL                             43.00                              12.00        False  (L)
# RPI                             64.00                              18.00        False  (L)
# MOR                             34.00                               5.00        False  (L)
# Allow PPG                       68.00                              63.00        False  (L)
# Allow FG %                      40.20                              38.50        False  (L)
# Allow Def Rb Avg                23.00                              21.00        False  (L)
# Allow FT ATT Avg                18.00                              17.00        False  (L)
# Turnover Avg                    12.00                              12.00        False  (L)
# Net Turnover Avg                 5.00                               4.00        False  (L)
# SRS                             14.89                              18.85        False  (H)
# SOS                              8.51                               8.79        False  (H)
# FG %                            46.50                              47.20        False  (H)
# Off Rb Avg                      12.00                              12.00        False  (H)
# Def Rb Avg                      23.00                              25.00        False  (H)
# Takeaway Avg                     7.00                               8.00        False  (H)
# Margin Victory Avg               7.00                              10.00        False  (H)
# Win %                           59.50                              77.10        False  (H)
#
#
# Top Conference=  Syracuse
#
#  Marquette Wins.
#
# Supporting Stat Count= 6  out of 30  stats.
#
#
#
#                                      Kentucky                 Ohio State     Stat Supports Winner
# Allow FG %                      37.40                              40.70         True  (L)
# Allow Def Rb Avg                19.00                              21.00         True  (L)
# SOS                              8.91                               8.38         True  (H)
# Poss Avg                        76.44                              74.03         True  (H)
# Def Rb Avg                      25.00                              23.00         True  (H)
# FT %                            71.00                              70.10         True  (H)
# Seed                              4                                  1          False  (L)
# SAG                             12.00                               1.00        False  (L)
# WLK                             10.00                               1.00        False  (L)
# WOL                             18.00                               1.00        False  (L)
# RTH                             15.00                               1.00        False  (L)
# COL                             14.00                               2.00        False  (L)
# POM                              7.00                               1.00        False  (L)
# DOL                             16.00                               1.00        False  (L)
# RPI                              7.00                               2.00        False  (L)
# MOR                              6.00                               1.00        False  (L)
# Allow PPG                       63.00                              59.00        False  (L)
# Allow Off Rb Avg                12.00                               8.00        False  (L)
# Allow FT ATT Avg                15.00                              15.00        False  (L)
# Turnover Avg                    10.00                              10.00        False  (L)
# Net Turnover Avg                 5.00                               3.00        False  (L)
# SRS                             20.30                              25.84        False  (H)
# PPG                             74.00                              77.00        False  (H)
# FG %                            45.90                              49.40        False  (H)
# Off Rb Avg                      11.00                              11.00        False  (H)
# FT ATT Avg                      20.00                              20.00        False  (H)
# Takeaway Avg                     5.00                               7.00        False  (H)
# Margin Victory Avg              11.00                              18.00        False  (H)
# Win %                           76.30                              91.90        False  (H)
# Off Rating                      96.81                             104.01        False  (H)
#
#  Kentucky Wins.
#
# Supporting Stat Count= 6  out of 30  stats.
# 358    [(Allow FG %                      40.60       ...
# 488    [(Allow PPG                       66.00       ...
# 494    [(SAG                             35.00       ...
# 454    [(SAG                             66.00       ...
# 50     [(SAG                            260.00       ...
# 132    [(Allow Off Rb Avg                11.00       ...
# 352    [(Seed                             12         ...
# 514    [(Allow Def Rb Avg                22.00       ...
# 292    [(Seed                              6         ...
# 486    [(SAG                            215.00       ...
# 432    [(Seed                              7         ...
# 506    [(Allow PPG                       64.00       ...
# 156    [(Seed                              5         ...
# 496    [(Seed                              5         ...
# 319    [(SAG                             12.00       ...
# 301    [(Allow PPG                       66.00       ...
# 513    [(SAG                             29.00       ...
# 99     [(Allow PPG                       58.00       ...
# 441    [(Seed                             10         ...
# 203    [(Allow FG %                      41.10       ...
# 51     [(RTH                            204.00       ...
# 525    [(Seed                              3         ...
# 123    [(Allow PPG                       63.00       ...
# 517    [(Allow Off Rb Avg                13.00       ...
# 321    [(Allow FG %                      37.40       ...
# dtype: object

# %%
supporting_features = missed_predictions.apply(lambda row: utils.get_supporting_features(row, feature_dictionary, feature_list),
                                               axis=1)

supporting_model_features = missed_predictions.apply(lambda row: utils.get_supporting_features(row, feature_dictionary, model_features),
                                               axis=1)

# %%
missed_predictions = missed_predictions.merge(supporting_features.to_frame(name='supporting_features'),how='left',
                                              left_index=True, right_index=True)

missed_predictions = missed_predictions.merge(supporting_model_features.to_frame(name='supporting_model_features'),how='left', 
                                              left_index=True, right_index=True)

missed_predictions['features'] = 100 * missed_predictions['supporting_features'].apply(lambda x: len(x)) / len(feature_list)

missed_predictions['model_features'] = 100 * missed_predictions['supporting_model_features'].apply(lambda x: len(x)) / \
    len(model_features)

missed_predictions['game_index'] = missed_predictions.index
missed_predictions.head()
# Out:
#      season_t  round   game_date  seed_t         team_t  \
# 358      2015     32  2015-03-21       1      Villanova
# 488      2016     64  2016-03-18       3  West Virginia
# 494      2012     64  2012-03-16       7   Saint Mary's
# 454      2016     68  2016-03-16      11          Tulsa
# 50       2013     68  2013-03-19      16        Liberty
#
#                                 team_id_t  seed_o                team_o  \
# 358  4383eb6a-7fd8-4ff2-94c5-43c933121e88       8  North Carolina State
# 488  f770d3a2-221c-49ce-9c7a-680f7417fe9e      14     Stephen F. Austin
# 494  b18f34af-a7f1-4659-a2e5-fc11a31cd316      10                Purdue
# 454  2959bd24-7007-41ae-a3a3-abdf26888cfc      11              Michigan
# 50   559db90c-741f-40d1-aa81-3fdd1d4889f3      16    North Carolina A&T
#
#                                 team_id_o  game_result  start_season  \
# 358  52df1e19-b142-4a76-a439-ad68455d0581           -1          2014
# 488  5ef64f01-86ae-4553-9834-c79cc0859eaf           -1          2015
# 494  12d7f888-675b-459f-9099-a38f771d8a95           -1          2011
# 454  bdc2561d-f603-4fab-a262-f1d2af462277           -1          2015
# 50   53aaac6a-796e-41a6-a04e-6ce74c5717f8           -1          2012
#
#     game result  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 358        Lose  23.13   7.55      0.917         76             60     0.470
# 488        Lose  21.61   9.78      0.743         78             66     0.449
# 494        Lose  11.26   0.78      0.818         74             62     0.473
# 454        Lose   9.79   5.76      0.625         73             69     0.444
# 50         Lose  -9.13  -5.80      0.417         69             69     0.429
#
#      allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 358           0.406     0.731                  16   73.861111              10
# 488           0.424     0.673                  27   85.394286              15
# 494           0.428     0.729                  15   74.933333              11
# 454           0.416     0.677                  19   77.731250              10
# 50            0.422     0.730                  22   76.111111              10
#
#      allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 358                    10              24                    21        10
# 488                     8              23                    22        14
# 494                     9              23                    20        11
# 454                    10              25                    26        10
# 50                     12              22                    24        13
#
#      steal_avg_t  off_rating_t  ft_att_avg_t  srs_o  sos_o  win_pct_o  \
# 358            7    102.895826            22  14.11   9.72      0.611
# 488            9     91.341006            27   9.23  -5.47      0.824
# 494            6     98.754448            21  13.88   8.05      0.629
# 454            6     93.913323            22  13.75   7.92      0.639
# 50             5     90.656934            21  -6.94  -6.30      0.541
#
#      pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 358         70             65     0.436           0.403     0.686
# 488         80             63     0.478           0.438     0.735
# 494         71             66     0.440           0.442     0.656
# 454         73             67     0.462           0.448     0.738
# 50          62             61     0.403           0.388     0.658
#
#      allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 358                  19   75.550000              12                    11
# 488                  20   80.100000              11                     9
# 494                  18   74.302857              11                    10
# 454                  14   72.877778               8                     8
# 50                   21   76.070270              10                    12
#
#      def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  \
# 358              25                    23        10            3
# 488              23                    22        12            9
# 494              18                    24         8            6
# 454              23                    24         9            5
# 50               21                    24        15            7
#
#      off_rating_o  ft_att_avg_o        conf_name_t           conf_name_o  \
# 358     92.653872            20           Big East        Atlantic Coast
# 488     99.875156            20             Big 12             Southland
# 494     95.554872            19         West Coast               Big Ten
# 454    100.167709            15  American Athletic               Big Ten
# 50      81.503588            21          Big South  Mid Eastern Athletic
#
#      sag_t  wlk_t  wol_t  rth_t  col_t  pom_t  dol_t  rpi_t  mor_t  sag_o  \
# 358      6    4.0      2      2    2.0    5.0    2.0    2.0      4     32
# 488      6    6.0      8      8   11.0    6.0    7.0   10.0     11     57
# 494     35   38.0     18     30   29.0   44.0   25.0   28.0     44     28
# 454     66   64.0     74     63   65.0   58.0   60.0   58.0     71     37
# 50     260  264.0    299    296  293.0  251.0  278.0  287.0    237    242
#
#      wlk_o  wol_o  rth_o  col_o  pom_o  dol_o  rpi_o  mor_o  top_conf  \
# 358   33.0     40     32   40.0   38.0   40.0   39.0     22        -1
# 488   55.0     62    101   83.0   33.0   80.0   62.0     36         1
# 494   31.0     37     28   39.0   24.0   34.0   47.0     19        -1
# 454   51.0     45     43   49.0   56.0   35.0   57.0     43        -1
# 50   223.0    219    246  222.0  226.0  221.0  213.0    234         0
#
#      upset_seed_threshold  margin_victory_avg_t  margin_victory_avg_o  \
# 358                     1                    16                     5
# 488                     1                    12                    17
# 494                     0                    12                     5
# 454                     0                     4                     6
# 50                      0                     0                     1
#
#      delta_margin_victory_avg  delta_fg_pct  delta_off_rebs_avg  \
# 358                        11         0.034                  -2
# 488                        -5        -0.029                   4
# 494                         7         0.033                   0
# 454                        -2        -0.018                   2
# 50                         -1         0.026                   0
#
#      delta_def_rebs_avg  delta_allow_def_rebs_avg  delta_ft_pct  to_net_avg_t  \
# 358                  -1                        -2         0.045             3
# 488                   0                         0        -0.062             5
# 494                   5                        -4         0.073             5
# 454                   2                         2        -0.061             4
# 50                    1                         0         0.072             8
#
#      to_net_avg_o  delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 358             7                -4          0.306         10.241954
# 488             3                 2         -0.081         -8.534150
# 494             2                 3          0.189          3.199576
# 454             4                 0         -0.014         -6.254385
# 50              8                 0         -0.124          9.153346
#
#      delta_allow_off_rebs_avg  delta_ft_att_avg  delta_allow_ft_att_avg  \
# 358                        -1                 2                      -3
# 488                        -1                 7                       7
# 494                        -1                 2                      -3
# 454                         2                 7                       5
# 50                          0                 0                       1
#
#      delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 358          -7       9.02      -2.17        -26      -29.0        -38
# 488         -11      12.38      15.25        -51      -49.0        -54
# 494          -3      -2.62      -7.27          7        7.0        -19
# 454           0      -3.96      -2.16         29       13.0         29
# 50            0      -2.19       0.50         18       41.0         80
#
#      delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor  \
# 358        -30      -38.0      -33.0      -38.0      -37.0        -18
# 488        -93      -72.0      -27.0      -73.0      -52.0        -25
# 494          2      -10.0       20.0       -9.0      -19.0         25
# 454         20       16.0        2.0       25.0        1.0         28
# 50          50       71.0       25.0       57.0       74.0          3
#
#      predicted_result  pred_win_prob  \
# 358                 1       0.551551
# 488                 1       0.524404
# 494                 1       0.508106
# 454                 1       0.507467
# 50                  1       0.505087
#
#                                    supporting_features  \
# 358                  [off_rebs_avg, def_rebs_avg, sos]
# 488  [margin_victory_avg, fg_pct, ft_pct, to_net_av...
# 494    [to_net_avg, srs, sos, sag, wlk, rth, pom, mor]
# 454  [margin_victory_avg, fg_pct, allow_def_rebs_av...
# 50   [margin_victory_avg, win_pct, allow_ft_att_avg...
#
#                  supporting_model_features   features  model_features  \
# 358                                  [sos]  11.538462       16.666667
# 488                      [fg_pct, win_pct]  26.923077       33.333333
# 494                        [srs, sos, rth]  30.769231       50.000000
# 454  [fg_pct, win_pct, srs, sos, rth, dol]  73.076923      100.000000
# 50                [win_pct, srs, rth, dol]  50.000000       66.666667
#
#      game_index
# 358         358
# 488         488
# 494         494
# 454         454
# 50           50

# %%
plot_missed_predictions_df = missed_predictions[['game_index','features','model_features']]
plot_missed_predictions_df = pd.melt(plot_missed_predictions_df, id_vars='game_index', var_name= 'Features Supporting Outcome')
plot_missed_predictions_df.head()
# Out:
#    game_index Features Supporting Outcome      value
# 0         358                    features  11.538462
# 1         488                    features  26.923077
# 2         494                    features  30.769231
# 3         454                    features  73.076923
# 4          50                    features  50.000000

# %%
m_plot = sns.barplot(x='game_index', y='value', hue='Features Supporting Outcome', data= plot_missed_predictions_df) 
plt.title("Percentage Of Features Consistent With Incorrectly Predicted Game Outcomes")
plt.ylabel('Percentage')
plt.xlabel('Game Index')
m_plot.figure.set_size_inches(20,6)

# %% [markdown]
# #### The bar chart depicts the percentage of features that correctly corresponded to the game outcome but were out weighed by other features in predicting the game incorrectly. Games corresponding to bar heights exceeding 50% should be scrutinized.

# %%
check_index = 454
missed_predictions[missed_predictions['game_index']== check_index]
# Out:
#      season_t  round   game_date  seed_t team_t  \
# 454      2016     68  2016-03-16      11  Tulsa
#
#                                 team_id_t  seed_o    team_o  \
# 454  2959bd24-7007-41ae-a3a3-abdf26888cfc      11  Michigan
#
#                                 team_id_o  game_result  start_season  \
# 454  bdc2561d-f603-4fab-a262-f1d2af462277           -1          2015
#
#     game result  srs_t  sos_t  win_pct_t  pts_avg_t  opp_pts_avg_t  fg_pct_t  \
# 454        Lose   9.79   5.76      0.625         73             69     0.444
#
#      allow_fg_pct_t  ft_pct_t  allow_ft_att_avg_t  poss_avg_t  off_rebs_avg_t  \
# 454           0.416     0.677                  19    77.73125              10
#
#      allow_off_rebs_avg_t  def_rebs_avg_t  allow_def_rebs_avg_t  to_avg_t  \
# 454                    10              25                    26        10
#
#      steal_avg_t  off_rating_t  ft_att_avg_t  srs_o  sos_o  win_pct_o  \
# 454            6     93.913323            22  13.75   7.92      0.639
#
#      pts_avg_o  opp_pts_avg_o  fg_pct_o  allow_fg_pct_o  ft_pct_o  \
# 454         73             67     0.462           0.448     0.738
#
#      allow_ft_att_avg_o  poss_avg_o  off_rebs_avg_o  allow_off_rebs_avg_o  \
# 454                  14   72.877778               8                     8
#
#      def_rebs_avg_o  allow_def_rebs_avg_o  to_avg_o  steal_avg_o  \
# 454              23                    24         9            5
#
#      off_rating_o  ft_att_avg_o        conf_name_t conf_name_o  sag_t  wlk_t  \
# 454    100.167709            15  American Athletic     Big Ten     66   64.0
#
#      wol_t  rth_t  col_t  pom_t  dol_t  rpi_t  mor_t  sag_o  wlk_o  wol_o  \
# 454     74     63   65.0   58.0   60.0   58.0     71     37   51.0     45
#
#      rth_o  col_o  pom_o  dol_o  rpi_o  mor_o  top_conf  upset_seed_threshold  \
# 454     43   49.0   56.0   35.0   57.0     43        -1                     0
#
#      margin_victory_avg_t  margin_victory_avg_o  delta_margin_victory_avg  \
# 454                     4                     6                        -2
#
#      delta_fg_pct  delta_off_rebs_avg  delta_def_rebs_avg  \
# 454        -0.018                   2                   2
#
#      delta_allow_def_rebs_avg  delta_ft_pct  to_net_avg_t  to_net_avg_o  \
# 454                         2        -0.061             4             4
#
#      delta_to_net_avg  delta_win_pct  delta_off_rating  \
# 454                 0         -0.014         -6.254385
#
#      delta_allow_off_rebs_avg  delta_ft_att_avg  delta_allow_ft_att_avg  \
# 454                         2                 7                       5
#
#      delta_seed  delta_srs  delta_sos  delta_sag  delta_wlk  delta_wol  \
# 454           0      -3.96      -2.16         29       13.0         29
#
#      delta_rth  delta_col  delta_pom  delta_dol  delta_rpi  delta_mor  \
# 454         20       16.0        2.0       25.0        1.0         28
#
#      predicted_result  pred_win_prob  \
# 454                 1       0.507467
#
#                                    supporting_features  \
# 454  [margin_victory_avg, fg_pct, allow_def_rebs_av...
#
#                  supporting_model_features   features  model_features  \
# 454  [fg_pct, win_pct, srs, sos, rth, dol]  73.076923           100.0
#
#      game_index
# 454         454

# %%
supporting_model_list = missed_predictions[missed_predictions['game_index']==check_index]['supporting_model_features']

# %%
for item in supporting_model_list:
    print(item)
# Out:
# ['fg_pct', 'win_pct', 'srs', 'sos', 'rth', 'dol']

# %%
#bdt.decision_function(X_test)
#X_test.shape
#estimator_list = bdt.estimators_
#estimator_list
#bdt.get_params(True)

# %%
X_test.loc[check_index].to_frame().transpose()
gen = bdt.staged_decision_function(X_test.loc[check_index].to_frame().transpose())
i=0
for item in gen:
    print(i,' ',item)
    i+= 1
# Out:
# 0   [-1.14334818]
# 1   [-0.34494911]
# 2   [-0.2673347]
# 3   [-0.15702617]
# 4   [0.00309792]
# 5   [-0.05095939]
# 6   [-0.06098506]
# 7   [-0.01381854]
# 8   [-0.00437102]
# 9   [0.01868081]
# 10   [0.04952591]
# 11   [0.05783474]
# 12   [0.03755896]
# 13   [0.04273683]
# 14   [0.03669377]
# 15   [0.03838192]
# 16   [0.02702583]
# 17   [0.01722149]
# 18   [0.02138314]
# 19   [0.01486047]
# 20   [0.02159567]
# 21   [0.01579255]
# 22   [0.0113318]
# 23   [0.01530611]
# 24   [0.00777355]
# 25   [0.01643942]
# 26   [0.02216939]
# 27   [0.02531429]
# 28   [0.01811651]
# 29   [0.02885761]
# 30   [0.02250795]
# 31   [0.02327751]
# 32   [0.02144104]
# 33   [0.02190825]
# 34   [0.01690689]
# 35   [0.02053808]
# 36   [0.01135491]
# 37   [0.0090405]
# 38   [0.01259678]
# 39   [0.01310013]
# 40   [0.02685522]
# 41   [0.02858374]
# 42   [0.0263628]
# 43   [0.031818]
# 44   [0.02631199]
# 45   [0.03096377]
# 46   [0.03422398]
# 47   [0.03147874]
# 48   [0.031925]
# 49   [0.03255743]
# 50   [0.03003131]
# 51   [0.02905374]
# 52   [0.03054879]
# 53   [0.03902759]
# 54   [0.03220818]
# 55   [0.02658025]
# 56   [0.03086921]
# 57   [0.0294223]
# 58   [0.02849606]
# 59   [0.02938279]
# 60   [0.02799749]
# 61   [0.02915031]
# 62   [0.02604064]
# 63   [0.02708912]
# 64   [0.02487525]
# 65   [0.02637471]
# 66   [0.03700693]
# 67   [0.0372146]
# 68   [0.03697272]
# 69   [0.03587396]
# 70   [0.03597389]
# 71   [0.03454306]
# 72   [0.03337107]
# 73   [0.03713137]
# 74   [0.03212422]
# 75   [0.03344144]
# 76   [0.0297709]
# 77   [0.02749212]
# 78   [0.03030528]
# 79   [0.03076107]
# 80   [0.03089431]
# 81   [0.02944829]
# 82   [0.02717608]
# 83   [0.02817499]
# 84   [0.02712958]
# 85   [0.02748053]
# 86   [0.03092861]
# 87   [0.03262246]
# 88   [0.03256087]
# 89   [0.03072684]
# 90   [0.03156682]
# 91   [0.03006261]
# 92   [0.03003817]
# 93   [0.02929104]
# 94   [0.02921285]
# 95   [0.033141]
# 96   [0.0343999]
# 97   [0.03267537]
# 98   [0.03476567]
# 99   [0.03143676]
# 100   [0.03069833]
# 101   [0.0316053]
# 102   [0.0322392]
# 103   [0.03539578]
# 104   [0.03372544]
# 105   [0.0340963]
# 106   [0.03555962]
# 107   [0.03457845]
# 108   [0.03394584]
# 109   [0.03478489]
# 110   [0.03502028]
# 111   [0.0338489]
# 112   [0.03421155]
# 113   [0.03146499]
# 114   [0.0303835]
# 115   [0.02904911]
# 116   [0.02895872]
# 117   [0.02846915]
# 118   [0.02893342]
# 119   [0.02748022]
# 120   [0.02944866]
# 121   [0.029377]
# 122   [0.02960177]
# 123   [0.03413663]
# 124   [0.03223102]
# 125   [0.03096318]
# 126   [0.03106674]
# 127   [0.03117062]
# 128   [0.03000009]
# 129   [0.03048231]
# 130   [0.02991835]
# 131   [0.03028007]
# 132   [0.03345869]
# 133   [0.03453542]
# 134   [0.03399031]
# 135   [0.03386489]
# 136   [0.03400616]
# 137   [0.03583754]
# 138   [0.03323282]
# 139   [0.03240903]
# 140   [0.03246427]
# 141   [0.03201679]
# 142   [0.0320581]
# 143   [0.03244726]
# 144   [0.03145666]
# 145   [0.03253606]
# 146   [0.03036749]
# 147   [0.0299509]
# 148   [0.03096444]
# 149   [0.02962913]
# 150   [0.02971304]
# 151   [0.02887228]
# 152   [0.02911186]
# 153   [0.0285167]
# 154   [0.02882237]
# 155   [0.0326698]
# 156   [0.03305623]
# 157   [0.03301685]
# 158   [0.03236113]
# 159   [0.03198899]
# 160   [0.03073539]
# 161   [0.03161768]
# 162   [0.03289753]
# 163   [0.03311157]
# 164   [0.03271298]
# 165   [0.03286296]
# 166   [0.03222902]
# 167   [0.03157811]
# 168   [0.03193789]
# 169   [0.03090379]
# 170   [0.0311497]
# 171   [0.03001848]
# 172   [0.0302947]
# 173   [0.03127288]
# 174   [0.03073708]
# 175   [0.0306913]
# 176   [0.02968087]
# 177   [0.02941416]
# 178   [0.02939968]
# 179   [0.02970823]
# 180   [0.02887765]
# 181   [0.02928586]
# 182   [0.03200765]
# 183   [0.03216312]
# 184   [0.03143267]
# 185   [0.03113187]
# 186   [0.03120749]
# 187   [0.03237445]
# 188   [0.03045526]
# 189   [0.02982631]
# 190   [0.03007189]
# 191   [0.0296563]
# 192   [0.0302258]
# 193   [0.03033741]
# 194   [0.03006008]
# 195   [0.02971556]
# 196   [0.03016469]
# 197   [0.03104807]
# 198   [0.03003238]
# 199   [0.02889759]
# 200   [0.02986948]

# %% [markdown]
# ## GridSearchCV

# %%
X= feature_data[feature_data['season_t']>=2010]
y=tourney_comp_ratings[tourney_comp_ratings['season_t']>=2010]['game_result']
X= X.drop(columns=['season_t'])

feature_list = list(X)
feature_list

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
X_train.head()

# %%
from sklearn.model_selection import GridSearchCV
from time import time

# %%
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
param_grid ={
    "n_estimators": [21,51,101,201,401],
    "learning_rate": [0.01, .05, .1, .5, 1]
}

grid_search = GridSearchCV( AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME.R"), 
                           param_grid=param_grid, cv=5)

start = time()
grid_search.fit(X, y)

print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(grid_search.cv_results_['params'])))
report(grid_search.cv_results_)

# %% [markdown]
# ### Randomized Search

# %%
from sklearn.model_selection import RandomizedSearchCV

n_iter_search = 20
random_search = RandomizedSearchCV(AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME.R"), 
                                   param_distributions=param_grid,
                                   n_iter=n_iter_search, cv=5)
start = time()
random_search.fit(X, y)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
report(random_search.cv_results_)
