# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import operator
# Non pythonic hack to reuse some utility code
if sys.path[0] != '../py_utils':
    sys.path.insert(0,'../py_utils')

import file_utils    
import utils
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import log_loss
from sklearn.model_selection import learning_curve
from sklearn.model_selection import cross_val_score
from pathlib import Path
# %matplotlib inline
pd.set_option('display.max_columns', 500)
print("Seaborn version: ", sns.__version__)
# Out:
# Seaborn version:  0.9.0

# %%
def get_missed_predictions(tourney_comp_ratings, model_features, numeric_feature_to_scale, prediction_probabilities, X, y, y_pred):
    
    pred_probs = pd.Series(prediction_probabilities[:,1], index=X.index)
    predictions = pd.Series(y_pred, index=y.index)
    test_games = tourney_comp_ratings[tourney_comp_ratings.index.isin(X.index)].copy()
    test_games[numeric_feature_to_scale] = scaler.inverse_transform(test_games[numeric_feature_to_scale])
    test_games['predicted_result'] = predictions
    test_games['pred_win_prob'] = pred_probs
    missed_predictions = test_games[test_games['game_result'] != 
                                test_games['predicted_result']].sort_values(by='pred_win_prob', ascending=False)
   
    missed_predictions.apply(lambda x: feature_dictionary.print_game_info(test_games,x['season_t'], x['round'], x['team_t'] ), axis=1)
    supporting_features = missed_predictions.apply(lambda row: utils.get_supporting_features(row,
                                                                                         feature_dictionary, 
                                                                                         feature_list),axis=1)

    supporting_model_features = missed_predictions.apply(lambda row: utils.get_supporting_features(row, 
                                                                                               feature_dictionary,
                                                                                               model_features),axis=1)
    
    missed_predictions = missed_predictions.merge(supporting_features.to_frame(name='supporting_features'),how='left',
                                              left_index=True, right_index=True)

    missed_predictions = missed_predictions.merge(supporting_model_features.to_frame(name='supporting_model_features'),how='left', 
                                              left_index=True, right_index=True)

    missed_predictions['features'] = 100 * missed_predictions['supporting_features'].apply(lambda x: len(x)) / len(feature_list)

    missed_predictions['model_features'] = 100 * missed_predictions['supporting_model_features'].apply(lambda x: len(x)) / \
        len(model_features)

    missed_predictions['game_index'] = missed_predictions.index
    
    return missed_predictions

# %%
def eliminate_features_logistic_regression(classifier, X, y ):
    iteration = 0
    print("Iteration= ", iteration)
    iteration += 1
    model_stats = {}
    drop_list = []
    # get baseline by identifying sorted important features using all of the provided features
    model_stats = utils.save_model_stats(classifier,X,y,model_stats)
    important_features = utils.display_important_features(classifier.coef_[0], X,0)
    #important_features = display_important_features_regression(classifier, X,0)
    # least important feature
    least_important_label = important_features[-1][0]
    print("least_important label= ", least_important_label)
    
    drop_list.append(least_important_label)
    del important_features[-1]
    
    # drop list contains all of the feature labels except for the feature label identified as being most important
    list_count = len(important_features)
    while list_count > 0:
        print("Iteration= ", iteration)
        iteration += 1
        model_stats = utils.save_model_stats(classifier,X.drop(columns=drop_list),y,model_stats)
        least_important_label = important_features[-1][0]
        print("least_important label= ", least_important_label)
        drop_list.append(least_important_label)
        del important_features[-1]
        list_count-=1
    return model_stats

# %%
summary_team_file = '../Data/sr_summaries_kaggle_id_no_opp_2018.csv'
team_meta_data_file = '../Data/D1_teams.csv'
tournament_data_file = '../Data/tournament_results_2018.csv'
rankings_data_file = '../data/massey_seasons_with_id.csv'

feature_dictionary = utils.Feature_Dictionary()

# %%
# earliest season data starts in 2000 corresponding to tournament season date of 2001
start_tournament = 2003
stop_tournament = 2017

# %% [markdown]
# #### Read in regular season team statistics from SRCBB https://www.sports-reference.com/cbb/
#
# #### Read table of team names and associated team meta data from the Kaggle data set.
# https://console.cloud.google.com/bigquery?project=bigqueryncaa&p=bigquery-public-data&d=ncaa_basketball&page=dataset

# %%
summary_data = file_utils.read_summary_team_data(summary_team_file)
teams = file_utils.read_team_meta_data(team_meta_data_file)
summary_data.head()
# Out:
#    season          school                               team_id  games    srs  \
# 0    2000       Air Force  aa7af640-5762-4686-9181-39f7b8a8186e     29  -3.57
# 1    2000           Akron  56fe0ab2-e4f0-47b9-8726-9ce23ebcde20     28  -3.09
# 2    2000         Alabama  c2104cdc-c83d-40d2-a3cd-df986e29f5d3     36  14.02
# 3    2000     Alabama A&M  949c3398-85e4-4c63-ba71-9a82e06ddea4     28 -13.46
# 4    2000  Alabama State   267d417a-8f85-4c87-a15a-068c089a74c6     31  -8.86
#
#      sos  win_pct  pts_avg  opp_pts_avg  fg_pct  ft_pct   poss_avg  \
# 0   1.99    0.276       57           63   0.435   0.697  63.020690
# 1   1.67    0.429       67           72   0.452   0.725  73.857143
# 2   6.27    0.694       76           68   0.433   0.698  86.200000
# 3 -11.79    0.607       73           74   0.391   0.626  94.264286
# 4 -13.61    0.710       68           63   0.441   0.658  80.690323
#
#    off_rebs_avg  def_rebs_avg  to_avg  steal_avg  off_rating  ft_att_avg
# 0           6.0          16.0      13          7   90.446487          16
# 1           9.0          20.0      15          5   90.715667          23
# 2          16.0          26.0      15          7   88.167053          24
# 3          17.0          22.0      16         12   77.441843          23
# 4          12.0          25.0      16          8   84.272807          22

# %% [markdown]
# #### Read in the NCAA Men's Tournament results from the the Kaggle data set.

# %%
tourney_data = file_utils.read_tournament_results(tournament_data_file,start_tournament)
game_data = utils.compute_game_data(tourney_data, teams)
computer_rankings = pd.read_csv(Path(rankings_data_file))
computer_rankings = computer_rankings[computer_rankings['season'] >= start_tournament]

tourney_data = utils.recode_tourney_data(tourney_data)
tourney_data = file_utils.merge_tourney_summary_data(tourney_data, summary_data)
tourney_data = file_utils.join_tourney_team_data(tourney_data, teams)
tourney_comp_ratings = file_utils.merge_tourney_ranking_data(tourney_data, computer_rankings)
tourney_comp_ratings = utils.implement_top_conference_feature(game_data, tourney_comp_ratings)
tourney_comp_ratings = utils.implement_seed_threshold_feature(tourney_comp_ratings)
tourney_comp_ratings = utils.compute_delta_features(tourney_comp_ratings)

tourney_comp_ratings.dropna(inplace=True)
tourney_comp_ratings[tourney_comp_ratings.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [season_t, round, game_date, seed_t, team_t, team_id_t, win_pts, seed_o, team_o, team_id_o, lose_pts, game_result, start_season, game result, srs_t, sos_t, win_pct_t, pts_avg_t, opp_pts_avg_t, fg_pct_t, ft_pct_t, poss_avg_t, off_rebs_avg_t, def_rebs_avg_t, to_avg_t, steal_avg_t, off_rating_t, ft_att_avg_t, srs_o, sos_o, win_pct_o, pts_avg_o, opp_pts_avg_o, fg_pct_o, ft_pct_o, poss_avg_o, off_rebs_avg_o, def_rebs_avg_o, to_avg_o, steal_avg_o, off_rating_o, ft_att_avg_o, conf_name_t, conf_name_o, sag_t, wlk_t, wol_t, rth_t, col_t, pom_t, dol_t, rpi_t, mor_t, sag_o, wlk_o, wol_o, rth_o, col_o, pom_o, dol_o, rpi_o, mor_o, top_conf_t, top_conf_o, upset_seed_threshold, margin_victory_avg_t, margin_victory_avg_o, delta_margin_victory_avg, delta_fg_pct, delta_off_rebs_avg, delta_def_rebs_avg, delta_ft_pct, to_net_avg_t, to_net_avg_o, delta_to_net_avg, delta_win_pct, delta_off_rating, delta_ft_att_avg, delta_seed, delta_srs, delta_sos, delta_sag, delta_wlk, delta_wol, delta_rth, delta_col, delta_pom, delta_dol, delta_mor]
# Index: []

# %%
numeric_features = ['delta_margin_victory_avg', 'delta_fg_pct', 'delta_off_rebs_avg',
                            'delta_def_rebs_avg', 'delta_ft_pct',
                            'delta_to_net_avg', 'delta_win_pct', 'delta_off_rating',
                            'delta_ft_att_avg',
                            'delta_seed', 'delta_srs', 'delta_sos',
                            'delta_sag', 'delta_wlk', 'delta_wol',
                            'delta_rth', 'delta_col', 'delta_pom',
                            'delta_dol', 'delta_mor']


# Convert types to float to eliminate needless scaler warning 
for item in numeric_features:
    tourney_comp_ratings[item] = tourney_comp_ratings[item].astype(float)

# %%
feature_columns = numeric_features  + ['season_t', 'top_conf_t', 'top_conf_o']
feature_data = tourney_comp_ratings[feature_columns].copy()
feature_data.head()
# Out:
#    delta_margin_victory_avg  delta_fg_pct  delta_off_rebs_avg  \
# 0                       2.0         0.007                 1.0
# 1                       4.0         0.017                -1.0
# 2                       5.0        -0.012                 2.0
# 3                      -6.0         0.022                 1.0
# 4                       0.0        -0.029                 3.0
#
#    delta_def_rebs_avg  delta_ft_pct  delta_to_net_avg  delta_win_pct  \
# 0                 1.0         0.063               0.0         -0.061
# 1                -1.0        -0.002              -1.0         -0.009
# 2                 3.0         0.092               1.0          0.159
# 3                -1.0        -0.026               3.0         -0.120
# 4                -2.0         0.027               1.0         -0.069
#
#    delta_off_rating  delta_ft_att_avg  delta_seed  delta_srs  delta_sos  \
# 0          2.364814               2.0        -1.0       3.05       0.86
# 1          7.042104              -5.0       -13.0      20.19      14.63
# 2          4.598761               6.0        -8.0       4.28      -1.38
# 3         -4.525801               0.0         3.0      -1.93       4.63
# 4         -0.666215               1.0        -2.0      -0.11       0.25
#
#    delta_sag  delta_wlk  delta_wol  delta_rth  delta_col  delta_pom  \
# 0       -8.0       12.0        8.0        2.0       12.0        5.0
# 1     -131.0      -91.0     -104.0     -133.0      -73.0     -128.0
# 2      -34.0      -38.0      -36.0      -33.0      -36.0      -33.0
# 3       23.0       31.0       13.0       12.0       17.0       27.0
# 4       -7.0       -7.0        2.0       -6.0       -5.0       -8.0
#
#    delta_dol  delta_mor  season_t  top_conf_t  top_conf_o
# 0       -4.0      -39.0      2003           0           0
# 1      -85.0     -162.0      2003           1           0
# 2      -39.0      -24.0      2003           0           0
# 3       21.0        6.0      2003           1           0
# 4        2.0       -9.0      2003           0           0

# %%
X= feature_data[feature_data['season_t']<= stop_tournament]
y=tourney_comp_ratings[tourney_comp_ratings['season_t']<= stop_tournament]['game_result']
X= X.drop(columns=['season_t'])

feature_list = list(X)
feature_list
# Out:
# ['delta_margin_victory_avg',
#  'delta_fg_pct',
#  'delta_off_rebs_avg',
#  'delta_def_rebs_avg',
#  'delta_ft_pct',
#  'delta_to_net_avg',
#  'delta_win_pct',
#  'delta_off_rating',
#  'delta_ft_att_avg',
#  'delta_seed',
#  'delta_srs',
#  'delta_sos',
#  'delta_sag',
#  'delta_wlk',
#  'delta_wol',
#  'delta_rth',
#  'delta_col',
#  'delta_pom',
#  'delta_dol',
#  'delta_mor',
#  'top_conf_t',
#  'top_conf_o']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 5)
X_train = X_train.copy()
X_test = X_test.copy()
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
X_train.head()
# Out:
# (782, 22)
# (782,)
# (196, 22)
# (196,)
#      delta_margin_victory_avg  delta_fg_pct  delta_off_rebs_avg  \
# 784                      -3.0        -0.015                 0.0
# 125                       8.0         0.011                -2.0
# 236                       3.0         0.022                -4.0
# 719                       0.0        -0.010                 0.0
# 808                       0.0        -0.046                 5.0
#
#      delta_def_rebs_avg  delta_ft_pct  delta_to_net_avg  delta_win_pct  \
# 784                -1.0         0.062               2.0         -0.055
# 125                 0.0        -0.039              -1.0          0.262
# 236                -3.0         0.071              -3.0          0.139
# 719                -2.0        -0.016               1.0          0.043
# 808                 2.0        -0.051               4.0         -0.008
#
#      delta_off_rating  delta_ft_att_avg  delta_seed  delta_srs  delta_sos  \
# 784         -3.232509              -1.0         3.0     -10.13      -6.65
# 125          8.822234              -1.0        -7.0       5.32      -3.24
# 236         12.896390               4.0        -3.0       4.23       0.00
# 719         -2.544287              -4.0         0.0      -1.24       0.41
# 808         -7.831221               1.0       -11.0      12.38      11.36
#
#      delta_sag  delta_wlk  delta_wol  delta_rth  delta_col  delta_pom  \
# 784       97.0      106.0       98.0       94.0       88.0       80.0
# 125      -24.0      -33.0      -25.0      -25.0      -28.0      -24.0
# 236      -11.0      -11.0      -15.0      -13.0      -14.0      -12.0
# 719        8.0        1.0        3.0        2.0       -4.0      -16.0
# 808      -64.0      -66.0      -58.0      -98.0      -79.0      -56.0
#
#      delta_dol  delta_mor  top_conf_t  top_conf_o
# 784      103.0      102.0           0           1
# 125      -30.0      -19.0           0           1
# 236      -18.0      -14.0           0           0
# 719       12.0       -7.0           0           0
# 808      -78.0      -73.0           1           0

# %%
scaler=StandardScaler(copy=True, with_mean=True, with_std=True)

scaler.fit(X_train[numeric_features])
X_train[numeric_features] = scaler.transform(X_train[numeric_features])
X_test[numeric_features] = scaler.transform(X_test[numeric_features])

# %%
gnb = GaussianNB()

y_pred = gnb.fit(X_train,y_train).predict(X_test)

utils.display_confusion_matrix(y_test, y_pred)
# Out:
# array([[54, 35],
#        [31, 76]], dtype=int64)

# %%
train_sizes, train_scores, test_scores = learning_curve(gnb, 
                                                        X, 
                                                        y,
                                                        # Number of folds in cross-validation
                                                        cv=10,
                                                        # Evaluation metric
                                                        scoring='accuracy',
                                                        # Use all computer cores
                                                        n_jobs=-1, 
                                                        # 50 different sizes of the training set
                                                        train_sizes=np.linspace(0.01, 1.0, 50))

# Create means and standard deviations of training set scores
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)

# Create means and standard deviations of test set scores
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Draw lines
plt.plot(train_sizes, train_mean, '--', color="#111111",  label="Training score")
plt.plot(train_sizes, test_mean, color="#111111", label="Cross-validation score")

# Draw bands
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, color="#DDDDDD")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, color="#DDDDDD")

# Create plot
plt.title("Learning Curve")
plt.xlabel("Training Set Size"), plt.ylabel("Accuracy Score"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
prediction_probabilities = gnb.predict_proba(X_test)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
print("Log loss= ",log_loss(y_test, prediction_probabilities))
# Out:
# Accuracy: 0.6632653061224489
# Precision: 0.6846846846846847
# Recall: 0.7102803738317757
# Log loss=  2.771919836629325

# %%
scores = cross_val_score(gnb, X,y, cv=10, scoring='accuracy')
print(scores.mean())
# Out:
# 0.7300967809804334

# %%
missed_predictions = get_missed_predictions(tourney_comp_ratings, feature_list, numeric_features, 
                                            prediction_probabilities, X_test, y_test, y_pred)
# Out:
#                                        Kansas                   Bucknell     Stat Supports Winner
# Allow PPG                       65.00                              58.00         True  (L)
# FT %                            69.50                              70.10         True  (H)
# Takeaway Avg                     6.00                               7.00         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              9.00                             114.00        False  (L)
# WLK                              7.00                              97.00        False  (L)
# WOL                             10.00                              84.00        False  (L)
# RTH                              7.00                             137.00        False  (L)
# COL                              4.00                             102.00        False  (L)
# POM                             12.00                             110.00        False  (L)
# DOL                              8.00                              87.00        False  (L)
# MOR                             19.00                             151.00        False  (L)
# Turnover Avg                    14.00                              15.00        False  (L)
# Net Turnover Avg                 8.00                               8.00        False  (L)
# SRS                             20.68                               2.12        False  (H)
# SOS                             10.85                              -2.19        False  (H)
# PPG                             75.00                              63.00        False  (H)
# Poss Avg                        79.22                              71.57        False  (H)
# FG %                            47.60                              44.40        False  (H)
# Off Rb Avg                      11.00                               9.00        False  (H)
# Def Rb Avg                      25.00                              22.00        False  (H)
# FT ATT Avg                      21.00                              20.00        False  (H)
# Margin Victory Avg              10.00                               5.00        False  (H)
# Win %                           76.70                              69.70        False  (H)
# Off Rating                      94.67                              88.03        False  (H)
#
#
# Top Conference=  Kansas
#
#  Bucknell Wins.
#
# Supporting Stat Count= 3  out of 25  stats.
#
#
#
#                                    Georgetown         Florida Gulf Coast     Stat Supports Winner
# PPG                             64.00                              72.00         True  (H)
# Poss Avg                        71.05                              79.77         True  (H)
# FG %                            45.30                              46.20         True  (H)
# Off Rb Avg                       9.00                              11.00         True  (H)
# Def Rb Avg                      20.00                              22.00         True  (H)
# FT ATT Avg                      18.00                              19.00         True  (H)
# Takeaway Avg                     7.00                               8.00         True  (H)
# Off Rating                      90.08                              90.26         True  (H)
# Seed                              2                                 15          False  (L)
# SAG                              9.00                             126.00        False  (L)
# WLK                             11.00                             124.00        False  (L)
# WOL                              7.00                             113.00        False  (L)
# RTH                              8.00                             146.00        False  (L)
# COL                              9.00                             115.00        False  (L)
# POM                             12.00                             126.00        False  (L)
# DOL                              9.00                             120.00        False  (L)
# MOR                             11.00                             110.00        False  (L)
# Allow PPG                       56.00                              66.00        False  (L)
# Turnover Avg                    12.00                              14.00        False  (L)
# Net Turnover Avg                 5.00                               6.00        False  (L)
# SRS                             15.84                               2.76        False  (H)
# SOS                              7.59                              -2.07        False  (H)
# FT %                            67.90                              67.50        False  (H)
# Margin Victory Avg               8.00                               6.00        False  (H)
# Win %                           78.10                              70.30        False  (H)
#
#
# Top Conference=  Georgetown
#
#  Florida Gulf Coast Wins.
#
# Supporting Stat Count= 8  out of 25  stats.
#
#
#
#                                          Duke                     Mercer     Stat Supports Winner
# Allow PPG                       67.00                              66.00         True  (L)
# Poss Avg                        76.03                              77.71         True  (H)
# FG %                            46.00                              47.60         True  (H)
# Def Rb Avg                      22.00                              25.00         True  (H)
# FT %                            72.90                              73.60         True  (H)
# Margin Victory Avg              11.00                              12.00         True  (H)
# Win %                           74.30                              75.00         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              7.00                              89.00        False  (L)
# WLK                              8.00                              97.00        False  (L)
# WOL                             15.00                              90.00        False  (L)
# RTH                              9.00                             124.00        False  (L)
# COL                             14.00                              93.00        False  (L)
# POM                              6.00                              95.00        False  (L)
# DOL                             14.00                             100.00        False  (L)
# MOR                              8.00                              94.00        False  (L)
# Turnover Avg                     9.00                              11.00        False  (L)
# Net Turnover Avg                 3.00                               6.00        False  (L)
# SRS                             19.51                               5.33        False  (H)
# SOS                              8.48                              -3.42        False  (H)
# PPG                             78.00                              78.00        False  (H)
# Off Rb Avg                      11.00                              11.00        False  (H)
# FT ATT Avg                      22.00                              21.00        False  (H)
# Takeaway Avg                     6.00                               5.00        False  (H)
# Off Rating                     102.59                             100.38        False  (H)
#
#
# Top Conference=  Duke
#
#  Mercer Wins.
#
# Supporting Stat Count= 7  out of 25  stats.
#
#
#
#                                        Purdue      Virginia Commonwealth     Stat Supports Winner
# Net Turnover Avg                 4.00                               3.00         True  (L)
# FT ATT Avg                      19.00                              20.00         True  (H)
# Takeaway Avg                     6.00                               8.00         True  (H)
# Seed                              3                                 11          False  (L)
# SAG                              9.00                              77.00        False  (L)
# WLK                              8.00                              55.00        False  (L)
# WOL                             10.00                              54.00        False  (L)
# RTH                              9.00                              74.00        False  (L)
# COL                             13.00                              59.00        False  (L)
# POM                              8.00                              84.00        False  (L)
# DOL                              8.00                              72.00        False  (L)
# MOR                             10.00                              80.00        False  (L)
# Allow PPG                       61.00                              66.00        False  (L)
# Turnover Avg                    10.00                              11.00        False  (L)
# SRS                             19.36                               8.56        False  (H)
# SOS                              8.69                               3.78        False  (H)
# PPG                             72.00                              71.00        False  (H)
# Poss Avg                        75.89                              75.24        False  (H)
# FG %                            44.70                              43.40        False  (H)
# Off Rb Avg                      11.00                              10.00        False  (H)
# Def Rb Avg                      24.00                              21.00        False  (H)
# FT %                            71.50                              71.50        False  (H)
# Margin Victory Avg              11.00                               5.00        False  (H)
# Win %                           76.50                              70.00        False  (H)
# Off Rating                      94.88                              94.36        False  (H)
#
#
# Top Conference=  Purdue
#
#  Virginia Commonwealth Wins.
#
# Supporting Stat Count= 3  out of 25  stats.
#
#
#
#                                 West Virginia          Stephen F. Austin     Stat Supports Winner
# Allow PPG                       66.00                              63.00         True  (L)
# Turnover Avg                    14.00                              12.00         True  (L)
# Net Turnover Avg                 5.00                               3.00         True  (L)
# PPG                             78.00                              80.00         True  (H)
# FG %                            44.90                              47.80         True  (H)
# FT %                            67.30                              73.50         True  (H)
# Margin Victory Avg              12.00                              17.00         True  (H)
# Win %                           74.30                              82.40         True  (H)
# Off Rating                      91.34                              99.88         True  (H)
# Seed                              3                                 14          False  (L)
# SAG                              6.00                              57.00        False  (L)
# WLK                              6.00                              55.00        False  (L)
# WOL                              8.00                              62.00        False  (L)
# RTH                              8.00                             101.00        False  (L)
# COL                             11.00                              83.00        False  (L)
# POM                              6.00                              33.00        False  (L)
# DOL                              7.00                              80.00        False  (L)
# MOR                             11.00                              36.00        False  (L)
# SRS                             21.61                               9.23        False  (H)
# SOS                              9.78                              -5.47        False  (H)
# Poss Avg                        85.39                              80.10        False  (H)
# Off Rb Avg                      15.00                              11.00        False  (H)
# Def Rb Avg                      23.00                              23.00        False  (H)
# FT ATT Avg                      27.00                              20.00        False  (H)
# Takeaway Avg                     9.00                               9.00        False  (H)
#
#
# Top Conference=  West Virginia
#
#  Stephen F. Austin Wins.
#
# Supporting Stat Count= 9  out of 25  stats.
#
#
#
#                                   Connecticut               George Mason     Stat Supports Winner
# Allow PPG                       67.00                              60.00         True  (L)
# Turnover Avg                    14.00                              12.00         True  (L)
# Net Turnover Avg                 8.00                               5.00         True  (L)
# FG %                            47.30                              48.10         True  (H)
# Takeaway Avg                     6.00                               7.00         True  (H)
# Seed                              1                                 11          False  (L)
# SAG                              2.00                              38.00        False  (L)
# WLK                              2.00                              25.00        False  (L)
# WOL                              2.00                              37.00        False  (L)
# RTH                              2.00                              53.00        False  (L)
# COL                              3.00                              45.00        False  (L)
# POM                              2.00                              28.00        False  (L)
# DOL                              2.00                              43.00        False  (L)
# MOR                              2.00                              75.00        False  (L)
# SRS                             21.22                              12.11        False  (H)
# SOS                              6.57                               2.77        False  (H)
# PPG                             81.00                              69.00        False  (H)
# Poss Avg                        86.08                              73.44        False  (H)
# Off Rb Avg                      15.00                              10.00        False  (H)
# Def Rb Avg                      28.00                              24.00        False  (H)
# FT ATT Avg                      25.00                              18.00        False  (H)
# FT %                            70.60                              66.40        False  (H)
# Margin Victory Avg              14.00                               9.00        False  (H)
# Win %                           88.20                              77.10        False  (H)
# Off Rating                      94.10                              93.95        False  (H)
#
#
# Top Conference=  Connecticut
#
#  George Mason Wins.
#
# Supporting Stat Count= 5  out of 25  stats.
#
#
#
#                                      Syracuse                     Dayton     Stat Supports Winner
# PPG                             67.00                              72.00         True  (H)
# Poss Avg                        72.50                              75.34         True  (H)
# FG %                            43.70                              46.30         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# FT ATT Avg                      21.00                              22.00         True  (H)
# Off Rating                      92.41                              95.57         True  (H)
# Seed                              3                                 11          False  (L)
# SAG                             19.00                              58.00        False  (L)
# WLK                             18.00                              54.00        False  (L)
# WOL                              5.00                              44.00        False  (L)
# RTH                              5.00                              56.00        False  (L)
# COL                              8.00                              40.00        False  (L)
# POM                             14.00                              51.00        False  (L)
# DOL                              9.00                              56.00        False  (L)
# MOR                             21.00                              56.00        False  (L)
# Allow PPG                       59.00                              66.00        False  (L)
# Turnover Avg                     9.00                              11.00        False  (L)
# Net Turnover Avg                 2.00                               5.00        False  (L)
# SRS                             16.05                              10.55        False  (H)
# SOS                              7.25                               5.34        False  (H)
# Off Rb Avg                      13.00                              11.00        False  (H)
# FT %                            70.80                              68.10        False  (H)
# Takeaway Avg                     7.00                               6.00        False  (H)
# Margin Victory Avg               8.00                               6.00        False  (H)
# Win %                           82.40                              70.30        False  (H)
#
#
# Top Conference=  Syracuse
#
#  Dayton Wins.
#
# Supporting Stat Count= 6  out of 25  stats.
#
#
#
#                                       Alabama                  Milwaukee     Stat Supports Winner
# Allow PPG                       65.00                              64.00         True  (L)
# Net Turnover Avg                 7.00                               5.00         True  (L)
# Poss Avg                        74.90                              80.15         True  (H)
# Off Rb Avg                      10.00                              13.00         True  (H)
# Takeaway Avg                     5.00                               8.00         True  (H)
# Margin Victory Avg              10.00                              11.00         True  (H)
# Win %                           75.00                              81.30         True  (H)
# Seed                              5                                 12          False  (L)
# SAG                             16.00                              36.00        False  (L)
# WLK                             16.00                              38.00        False  (L)
# WOL                             20.00                              40.00        False  (L)
# RTH                             20.00                              60.00        False  (L)
# COL                             20.00                              45.00        False  (L)
# POM                             18.00                              42.00        False  (L)
# DOL                             15.00                              35.00        False  (L)
# MOR                             11.00                              56.00        False  (L)
# Turnover Avg                    12.00                              13.00        False  (L)
# SRS                             16.74                              10.41        False  (H)
# SOS                              6.81                               1.44        False  (H)
# PPG                             75.00                              75.00        False  (H)
# FG %                            48.30                              44.70        False  (H)
# Def Rb Avg                      26.00                              22.00        False  (H)
# FT ATT Avg                      22.00                              21.00        False  (H)
# FT %                            73.60                              70.30        False  (H)
# Off Rating                     100.13                              93.57        False  (H)
#
#
# Top Conference=  Alabama
#
#  Milwaukee Wins.
#
# Supporting Stat Count= 7  out of 25  stats.
#
#
#
#                                     Wisconsin                    Cornell     Stat Supports Winner
# WOL                             28.00                              20.00         True  (L)
# PPG                             67.00                              76.00         True  (H)
# Poss Avg                        68.67                              74.21         True  (H)
# FG %                            44.30                              48.20         True  (H)
# Off Rb Avg                       9.00                              10.00         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# Takeaway Avg                     5.00                               7.00         True  (H)
# Margin Victory Avg              11.00                              12.00         True  (H)
# Win %                           72.70                              85.30         True  (H)
# Off Rating                      97.56                             102.41         True  (H)
# Seed                              4                                 12          False  (L)
# SAG                             14.00                              52.00        False  (L)
# WLK                             17.00                              47.00        False  (L)
# RTH                             13.00                              62.00        False  (L)
# COL                             22.00                              49.00        False  (L)
# POM                              3.00                              66.00        False  (L)
# DOL                             18.00                              37.00        False  (L)
# MOR                              5.00                              70.00        False  (L)
# Allow PPG                       56.00                              64.00        False  (L)
# Turnover Avg                     8.00                              12.00        False  (L)
# Net Turnover Avg                 3.00                               5.00        False  (L)
# SRS                             17.84                               8.76        False  (H)
# SOS                              7.66                              -0.91        False  (H)
# FT ATT Avg                      17.00                              15.00        False  (H)
# FT %                            73.20                              73.00        False  (H)
#
#
# Top Conference=  Wisconsin
#
#  Cornell Wins.
#
# Supporting Stat Count= 10  out of 25  stats.
#
#
#
#                                     Villanova       North Carolina State     Stat Supports Winner
# SOS                              7.55                               9.72         True  (H)
# Poss Avg                        73.86                              75.55         True  (H)
# Off Rb Avg                      10.00                              12.00         True  (H)
# Def Rb Avg                      24.00                              25.00         True  (H)
# Seed                              1                                  8          False  (L)
# SAG                              6.00                              32.00        False  (L)
# WLK                              4.00                              33.00        False  (L)
# WOL                              2.00                              40.00        False  (L)
# RTH                              2.00                              32.00        False  (L)
# COL                              2.00                              40.00        False  (L)
# POM                              5.00                              38.00        False  (L)
# DOL                              2.00                              40.00        False  (L)
# MOR                              4.00                              22.00        False  (L)
# Allow PPG                       60.00                              65.00        False  (L)
# Turnover Avg                    10.00                              10.00        False  (L)
# Net Turnover Avg                 3.00                               7.00        False  (L)
# SRS                             23.13                              14.11        False  (H)
# PPG                             76.00                              70.00        False  (H)
# FG %                            47.00                              43.60        False  (H)
# FT ATT Avg                      22.00                              20.00        False  (H)
# FT %                            73.10                              68.60        False  (H)
# Takeaway Avg                     7.00                               3.00        False  (H)
# Margin Victory Avg              16.00                               5.00        False  (H)
# Win %                           91.70                              61.10        False  (H)
# Off Rating                     102.90                              92.65        False  (H)
#
#  North Carolina State Wins.
#
# Supporting Stat Count= 4  out of 25  stats.
#
#
#
#                                   Wake Forest              West Virginia     Stat Supports Winner
# Allow PPG                       73.00                              67.00         True  (L)
# Turnover Avg                    14.00                              11.00         True  (L)
# Net Turnover Avg                 6.00                               3.00         True  (L)
# FT %                            68.40                              74.20         True  (H)
# Seed                              2                                  7          False  (L)
# SAG                              4.00                              38.00        False  (L)
# WLK                              4.00                              39.00        False  (L)
# WOL                              3.00                              28.00        False  (L)
# RTH                              4.00                              32.00        False  (L)
# COL                              6.00                              34.00        False  (L)
# POM                              5.00                              35.00        False  (L)
# DOL                              3.00                              30.00        False  (L)
# MOR                              5.00                              30.00        False  (L)
# SRS                             20.24                              11.76        False  (H)
# SOS                             10.27                               7.62        False  (H)
# PPG                             84.00                              71.00        False  (H)
# Poss Avg                        85.22                              73.78        False  (H)
# FG %                            49.10                              45.00        False  (H)
# Off Rb Avg                      14.00                               9.00        False  (H)
# Def Rb Avg                      25.00                              20.00        False  (H)
# FT ATT Avg                      27.00                              17.00        False  (H)
# Takeaway Avg                     8.00                               8.00        False  (H)
# Margin Victory Avg              11.00                               4.00        False  (H)
# Win %                           81.80                              68.60        False  (H)
# Off Rating                      98.56                              96.23        False  (H)
#
#  West Virginia Wins.
#
# Supporting Stat Count= 4  out of 25  stats.
#
#
#
#                                 Florida State      Virginia Commonwealth     Stat Supports Winner
# Turnover Avg                    15.00                              11.00         True  (L)
# Net Turnover Avg                 7.00                               3.00         True  (L)
# PPG                             69.00                              71.00         True  (H)
# FT %                            66.50                              71.50         True  (H)
# Win %                           67.60                              70.00         True  (H)
# Off Rating                      85.81                              94.36         True  (H)
# Seed                             10                                 11          False  (L)
# SAG                             44.00                              77.00        False  (L)
# WLK                             39.00                              55.00        False  (L)
# WOL                             49.00                              54.00        False  (L)
# RTH                             42.00                              74.00        False  (L)
# COL                             45.00                              59.00        False  (L)
# POM                             42.00                              84.00        False  (L)
# DOL                             42.00                              72.00        False  (L)
# MOR                             37.00                              80.00        False  (L)
# Allow PPG                       62.00                              66.00        False  (L)
# SRS                             13.48                               8.56        False  (H)
# SOS                              6.45                               3.78        False  (H)
# Poss Avg                        80.41                              75.24        False  (H)
# FG %                            43.50                              43.40        False  (H)
# Off Rb Avg                      12.00                              10.00        False  (H)
# Def Rb Avg                      26.00                              21.00        False  (H)
# FT ATT Avg                      21.00                              20.00        False  (H)
# Takeaway Avg                     8.00                               8.00        False  (H)
# Margin Victory Avg               7.00                               5.00        False  (H)
#
#
# Top Conference=  Florida State
#
#  Virginia Commonwealth Wins.
#
# Supporting Stat Count= 6  out of 25  stats.
#
#
#
#                                    Cincinnati                    Harvard     Stat Supports Winner
# PPG                             68.00                              73.00         True  (H)
# FG %                            42.50                              46.50         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# FT ATT Avg                      21.00                              25.00         True  (H)
# FT %                            70.80                              72.40         True  (H)
# Margin Victory Avg              10.00                              12.00         True  (H)
# Win %                           79.40                              84.40         True  (H)
# Off Rating                      90.20                              98.13         True  (H)
# Seed                              5                                 12          False  (L)
# SAG                             28.00                              35.00        False  (L)
# WLK                             28.00                              39.00        False  (L)
# WOL                             14.00                              34.00        False  (L)
# RTH                             17.00                              62.00        False  (L)
# COL                             19.00                              47.00        False  (L)
# POM                             24.00                              33.00        False  (L)
# DOL                             15.00                              36.00        False  (L)
# MOR                             25.00                              37.00        False  (L)
# Allow PPG                       58.00                              61.00        False  (L)
# Turnover Avg                    11.00                              11.00        False  (L)
# Net Turnover Avg                 4.00                               4.00        False  (L)
# SRS                             15.26                              10.79        False  (H)
# SOS                              5.28                              -0.47        False  (H)
# Poss Avg                        75.39                              74.39        False  (H)
# Off Rb Avg                      13.00                              10.00        False  (H)
# Takeaway Avg                     7.00                               7.00        False  (H)
#
#
# Top Conference=  Cincinnati
#
#  Harvard Wins.
#
# Supporting Stat Count= 8  out of 25  stats.
#
#
#
#                                     Villanova                  Wisconsin     Stat Supports Winner
# SOS                              9.28                               9.40         True  (H)
# Poss Avg                        72.84                              76.41         True  (H)
# Off Rb Avg                       8.00                              12.00         True  (H)
# FT ATT Avg                      18.00                              19.00         True  (H)
# Seed                              1                                  8          False  (L)
# SAG                              2.00                              17.00        False  (L)
# WLK                              1.00                              21.00        False  (L)
# WOL                              2.00                              24.00        False  (L)
# RTH                              2.00                              22.00        False  (L)
# COL                              1.00                              28.00        False  (L)
# POM                              2.00                              23.00        False  (L)
# DOL                              1.00                              24.00        False  (L)
# MOR                              1.00                              18.00        False  (L)
# Allow PPG                       62.00                              62.00        False  (L)
# Turnover Avg                    11.00                              11.00        False  (L)
# Net Turnover Avg                 4.00                               5.00        False  (L)
# SRS                             23.80                              19.40        False  (H)
# PPG                             77.00                              72.00        False  (H)
# FG %                            49.50                              45.50        False  (H)
# Def Rb Avg                      24.00                              24.00        False  (H)
# FT %                            79.00                              64.40        False  (H)
# Takeaway Avg                     7.00                               6.00        False  (H)
# Margin Victory Avg              15.00                              10.00        False  (H)
# Win %                           88.90                              73.00        False  (H)
# Off Rating                     105.70                              94.23        False  (H)
#
#  Wisconsin Wins.
#
# Supporting Stat Count= 4  out of 25  stats.
#
#
#
#                                       Gonzaga              Wichita State     Stat Supports Winner
# SOS                              4.18                               6.09         True  (H)
# Poss Avg                        75.37                              76.27         True  (H)
# Off Rb Avg                      11.00                              13.00         True  (H)
# Seed                              1                                  9          False  (L)
# SAG                              6.00                              42.00        False  (L)
# WLK                              5.00                              31.00        False  (L)
# WOL                              1.00                              38.00        False  (L)
# RTH                              3.00                              43.00        False  (L)
# COL                              5.00                              34.00        False  (L)
# POM                              4.00                              33.00        False  (L)
# DOL                              1.00                              33.00        False  (L)
# MOR                              4.00                              35.00        False  (L)
# Allow PPG                       59.00                              61.00        False  (L)
# Turnover Avg                    11.00                              12.00        False  (L)
# Net Turnover Avg                 4.00                               5.00        False  (L)
# SRS                             20.47                              14.68        False  (H)
# PPG                             77.00                              69.00        False  (H)
# FG %                            49.70                              44.00        False  (H)
# Def Rb Avg                      22.00                              21.00        False  (H)
# FT ATT Avg                      22.00                              20.00        False  (H)
# FT %                            70.50                              69.90        False  (H)
# Takeaway Avg                     7.00                               7.00        False  (H)
# Margin Victory Avg              18.00                               8.00        False  (H)
# Win %                           91.40                              76.90        False  (H)
# Off Rating                     102.17                              90.47        False  (H)
#
#
# Top Conference=  Wichita State
#
#  Wichita State Wins.
#
# Supporting Stat Count= 3  out of 25  stats.
#
#
#
#                                    Ohio State                      Siena     Stat Supports Winner
# Net Turnover Avg                 8.00                               5.00         True  (L)
# PPG                             66.00                              77.00         True  (H)
# Poss Avg                        69.84                              83.62         True  (H)
# Off Rb Avg                       8.00                              12.00         True  (H)
# Def Rb Avg                      22.00                              23.00         True  (H)
# FT ATT Avg                      18.00                              21.00         True  (H)
# Takeaway Avg                     5.00                               8.00         True  (H)
# Margin Victory Avg               4.00                               7.00         True  (H)
# Win %                           66.70                              77.10         True  (H)
# Seed                              8                                  9          False  (L)
# SAG                             25.00                              58.00        False  (L)
# WLK                             28.00                              34.00        False  (L)
# WOL                             22.00                              39.00        False  (L)
# RTH                             23.00                              63.00        False  (L)
# COL                             25.00                              33.00        False  (L)
# POM                             36.00                              65.00        False  (L)
# DOL                             26.00                              45.00        False  (L)
# MOR                             35.00                              62.00        False  (L)
# Allow PPG                       62.00                              70.00        False  (L)
# Turnover Avg                    13.00                              13.00        False  (L)
# SRS                             12.48                               8.05        False  (H)
# SOS                              8.23                               0.99        False  (H)
# FG %                            48.10                              46.70        False  (H)
# FT %                            70.10                              66.40        False  (H)
# Off Rating                      94.51                              92.09        False  (H)
#
#
# Top Conference=  Ohio State
#
#  Siena Wins.
#
# Supporting Stat Count= 9  out of 25  stats.
#
#
#
#                                    Louisville                   Kentucky     Stat Supports Winner
# SOS                              4.80                               9.90         True  (H)
# Off Rb Avg                      13.00                              14.00         True  (H)
# Def Rb Avg                      24.00                              26.00         True  (H)
# FT ATT Avg                      24.00                              28.00         True  (H)
# FT %                            66.10                              68.20         True  (H)
# Seed                              4                                  8          False  (L)
# SAG                              2.00                              18.00        False  (L)
# WLK                              2.00                              16.00        False  (L)
# WOL                             11.00                              33.00        False  (L)
# RTH                              8.00                              19.00        False  (L)
# COL                             16.00                              22.00        False  (L)
# POM                              2.00                              17.00        False  (L)
# DOL                             13.00                              25.00        False  (L)
# MOR                              1.00                              26.00        False  (L)
# Allow PPG                       61.00                              66.00        False  (L)
# Turnover Avg                    10.00                              11.00        False  (L)
# Net Turnover Avg                 0.00                               7.00        False  (L)
# SRS                             24.69                              18.07        False  (H)
# PPG                             81.00                              74.00        False  (H)
# Poss Avg                        80.84                              78.51        False  (H)
# FG %                            47.10                              45.40        False  (H)
# Takeaway Avg                    10.00                               4.00        False  (H)
# Margin Victory Avg              20.00                               8.00        False  (H)
# Win %                           83.80                              72.50        False  (H)
# Off Rating                     100.20                              94.26        False  (H)
#
#  Kentucky Wins.
#
# Supporting Stat Count= 5  out of 25  stats.
#
#
#
#                                    Ohio State                 Georgetown     Stat Supports Winner
# Allow PPG                       63.00                              58.00         True  (L)
# SOS                              5.90                               6.92         True  (H)
# FG %                            46.50                              46.80         True  (H)
# Seed                              2                                  7          False  (L)
# SAG                              8.00                              16.00        False  (L)
# WLK                              6.00                              19.00        False  (L)
# WOL                              7.00                              23.00        False  (L)
# RTH                              6.00                              21.00        False  (L)
# COL                              5.00                              27.00        False  (L)
# POM                              9.00                              17.00        False  (L)
# DOL                              7.00                              21.00        False  (L)
# MOR                             12.00                              20.00        False  (L)
# Turnover Avg                    11.00                              11.00        False  (L)
# Net Turnover Avg                 5.00                               5.00        False  (L)
# SRS                             16.08                              13.98        False  (H)
# PPG                             73.00                              65.00        False  (H)
# Poss Avg                        75.39                              69.04        False  (H)
# Off Rb Avg                      10.00                              10.00        False  (H)
# Def Rb Avg                      23.00                              21.00        False  (H)
# FT ATT Avg                      18.00                              16.00        False  (H)
# FT %                            71.80                              70.60        False  (H)
# Takeaway Avg                     6.00                               6.00        False  (H)
# Margin Victory Avg              10.00                               7.00        False  (H)
# Win %                           81.30                              69.70        False  (H)
# Off Rating                      96.83                              94.15        False  (H)
#
#  Georgetown Wins.
#
# Supporting Stat Count= 3  out of 25  stats.
#
#
#
#                                    Louisville                   Michigan     Stat Supports Winner
# Turnover Avg                    11.00                               9.00         True  (L)
# Net Turnover Avg                 5.00                               4.00         True  (L)
# FG %                            45.70                              48.30         True  (H)
# FT %                            68.60                              77.90         True  (H)
# Off Rating                      95.47                             106.60         True  (H)
# Seed                              2                                  7          False  (L)
# SAG                              7.00                              23.00        False  (L)
# WLK                              6.00                              24.00        False  (L)
# WOL                             13.00                              26.00        False  (L)
# RTH                              9.00                              24.00        False  (L)
# COL                             10.00                              29.00        False  (L)
# POM                              6.00                              21.00        False  (L)
# DOL                             10.00                              26.00        False  (L)
# MOR                              4.00                              15.00        False  (L)
# Allow PPG                       65.00                              66.00        False  (L)
# SRS                             22.47                              18.80        False  (H)
# SOS                             11.15                              10.17        False  (H)
# PPG                             77.00                              75.00        False  (H)
# Poss Avg                        80.65                              70.36        False  (H)
# Off Rb Avg                      13.00                               7.00        False  (H)
# Def Rb Avg                      26.00                              21.00        False  (H)
# FT ATT Avg                      20.00                              16.00        False  (H)
# Takeaway Avg                     6.00                               5.00        False  (H)
# Margin Victory Avg              12.00                               9.00        False  (H)
# Win %                           73.50                              68.40        False  (H)
#
#  Michigan Wins.
#
# Supporting Stat Count= 5  out of 25  stats.
#
#
#
#                                         Texas                        USC     Stat Supports Winner
# Allow PPG                       72.00                              65.00         True  (L)
# SOS                              6.12                               7.87         True  (H)
# FG %                            44.50                              47.60         True  (H)
# Seed                              4                                  5          False  (L)
# SAG                             16.00                              35.00        False  (L)
# WLK                             22.00                              41.00        False  (L)
# WOL                             20.00                              28.00        False  (L)
# RTH                             19.00                              25.00        False  (L)
# COL                             27.00                              30.00        False  (L)
# POM                             16.00                              43.00        False  (L)
# DOL                             16.00                              43.00        False  (L)
# MOR                             12.00                              44.00        False  (L)
# ...
# SOS                              9.00                              11.40        False  (H)
# PPG                             72.00                              78.00        False  (H)
# Poss Avg                        75.27                              79.26        False  (H)
# FG %                            45.90                              49.30        False  (H)
# Off Rb Avg                       9.00                              11.00        False  (H)
# Def Rb Avg                      25.00                              26.00        False  (H)
# FT ATT Avg                      24.00                              26.00        False  (H)
# FT %                            70.20                              71.10        False  (H)
# Takeaway Avg                     5.00                               5.00        False  (H)
# Margin Victory Avg               4.00                               8.00        False  (H)
# Win %                           63.90                              71.40        False  (H)
# Off Rating                      95.65                              98.41        False  (H)
#
#  Stanford Wins.
#
# Supporting Stat Count= 3  out of 25  stats.
#
#
#
#                                  Rhode Island                  Creighton     Stat Supports Winner
# Allow PPG                       65.00                              72.00         True  (L)
# Turnover Avg                    11.00                              12.00         True  (L)
# Net Turnover Avg                 5.00                               6.00         True  (L)
# Off Rb Avg                      11.00                               8.00         True  (H)
# FT ATT Avg                      22.00                              16.00         True  (H)
# Seed                             11                                  6          False  (L)
# SAG                             48.00                              27.00        False  (L)
# WLK                             40.00                              26.00        False  (L)
# WOL                             48.00                              22.00        False  (L)
# RTH                             53.00                              23.00        False  (L)
# COL                             43.00                              22.00        False  (L)
# POM                             37.00                              27.00        False  (L)
# DOL                             52.00                              25.00        False  (L)
# MOR                             31.00                              27.00        False  (L)
# SRS                             12.88                              17.27        False  (H)
# SOS                              4.62                               8.95        False  (H)
# PPG                             73.00                              81.00        False  (H)
# Poss Avg                        77.84                              80.25        False  (H)
# FG %                            45.40                              50.40        False  (H)
# Def Rb Avg                      25.00                              26.00        False  (H)
# FT %                            66.80                              68.20        False  (H)
# Takeaway Avg                     6.00                               6.00        False  (H)
# Margin Victory Avg               8.00                               9.00        False  (H)
# Win %                           71.40                              71.40        False  (H)
# Off Rating                      93.78                             100.93        False  (H)
#
#
# Top Conference=  Creighton
#
#  Rhode Island Wins.
#
# Supporting Stat Count= 5  out of 25  stats.
#
#
#
#                                       Montana                     Nevada     Stat Supports Winner
# Net Turnover Avg                 6.00                               7.00         True  (L)
# PPG                             79.00                              72.00         True  (H)
# Poss Avg                        79.78                              78.78         True  (H)
# FG %                            49.20                              45.60         True  (H)
# FT ATT Avg                      21.00                              20.00         True  (H)
# Takeaway Avg                     7.00                               5.00         True  (H)
# Off Rating                      99.02                              91.39         True  (H)
# Seed                             12                                  5          False  (L)
# SAG                            100.00                              27.00        False  (L)
# WLK                             71.00                              20.00        False  (L)
# WOL                             72.00                              20.00        False  (L)
# RTH                             94.00                              33.00        False  (L)
# COL                             67.00                              20.00        False  (L)
# POM                             90.00                              21.00        False  (L)
# DOL                             66.00                              18.00        False  (L)
# MOR                            115.00                              50.00        False  (L)
# Allow PPG                       71.00                              63.00        False  (L)
# Turnover Avg                    13.00                              12.00        False  (L)
# SRS                              4.86                              10.16        False  (H)
# SOS                             -0.96                               2.26        False  (H)
# Off Rb Avg                      11.00                              12.00        False  (H)
# Def Rb Avg                      24.00                              25.00        False  (H)
# FT %                            71.80                              71.80        False  (H)
# Margin Victory Avg               8.00                               9.00        False  (H)
# Win %                           77.40                              81.80        False  (H)
#
#  Montana Wins.
#
# Supporting Stat Count= 7  out of 25  stats.
#
#
#
#                                      Winthrop                 Notre Dame     Stat Supports Winner
# WOL                             13.00                              23.00         True  (L)
# DOL                             12.00                              18.00         True  (L)
# Allow PPG                       61.00                              68.00         True  (L)
# FG %                            47.70                              45.90         True  (H)
# Win %                           85.30                              75.00         True  (H)
# Seed                             11                                  6          False  (L)
# SAG                             37.00                              14.00        False  (L)
# WLK                             38.00                              18.00        False  (L)
# RTH                             52.00                              16.00        False  (L)
# COL                             68.00                              28.00        False  (L)
# POM                             71.00                              17.00        False  (L)
# MOR                             82.00                              14.00        False  (L)
# Turnover Avg                    13.00                              12.00        False  (L)
# Net Turnover Avg                 6.00                               4.00        False  (L)
# SRS                              9.17                              16.94        False  (H)
# SOS                             -1.20                               4.97        False  (H)
# PPG                             74.00                              81.00        False  (H)
# Poss Avg                        77.94                              81.63        False  (H)
# Off Rb Avg                      12.00                              12.00        False  (H)
# Def Rb Avg                      25.00                              25.00        False  (H)
# FT ATT Avg                      19.00                              23.00        False  (H)
# FT %                            62.40                              74.30        False  (H)
# Takeaway Avg                     7.00                               8.00        False  (H)
# Margin Victory Avg              13.00                              13.00        False  (H)
# Off Rating                      94.94                              99.23        False  (H)
#
#
# Top Conference=  Notre Dame
#
#  Winthrop Wins.
#
# Supporting Stat Count= 5  out of 25  stats.
#
#
#
#                                       Bradley                 Pittsburgh     Stat Supports Winner
# Poss Avg                        81.71                              78.35         True  (H)
# FT %                            71.80                              69.30         True  (H)
# Takeaway Avg                     8.00                               6.00         True  (H)
# Seed                             13                                  5          False  (L)
# SAG                             37.00                              10.00        False  (L)
# WLK                             33.00                              11.00        False  (L)
# WOL                             47.00                              12.00        False  (L)
# RTH                             49.00                               9.00        False  (L)
# COL                             46.00                              10.00        False  (L)
# POM                             32.00                               8.00        False  (L)
# DOL                             51.00                              13.00        False  (L)
# MOR                             47.00                              11.00        False  (L)
# Allow PPG                       65.00                              63.00        False  (L)
# Turnover Avg                    15.00                              13.00        False  (L)
# Net Turnover Avg                 7.00                               7.00        False  (L)
# SRS                             11.78                              16.37        False  (H)
# SOS                              5.38                               7.01        False  (H)
# PPG                             71.00                              72.00        False  (H)
# FG %                            43.90                              45.60        False  (H)
# Off Rb Avg                      12.00                              12.00        False  (H)
# Def Rb Avg                      24.00                              26.00        False  (H)
# FT ATT Avg                      20.00                              22.00        False  (H)
# Margin Victory Avg               6.00                               9.00        False  (H)
# Win %                           66.70                              75.80        False  (H)
# Off Rating                      86.89                              91.89        False  (H)
#
#
# Top Conference=  Pittsburgh
#
#  Bradley Wins.
#
# Supporting Stat Count= 3  out of 25  stats.
#
#
#
#                                        Lehigh                       Duke     Stat Supports Winner
# Allow PPG                       65.00                              68.00         True  (L)
# Turnover Avg                    11.00                              12.00         True  (L)
# Net Turnover Avg                 4.00                               6.00         True  (L)
# FT %                            76.80                              70.10         True  (H)
# Takeaway Avg                     7.00                               6.00         True  (H)
# Margin Victory Avg              10.00                               9.00         True  (H)
# Seed                             15                                  2          False  (L)
# SAG                             92.00                              11.00        False  (L)
# WLK                             87.00                               9.00        False  (L)
# WOL                             71.00                               9.00        False  (L)
# RTH                            111.00                               8.00        False  (L)
# COL                             97.00                               4.00        False  (L)
# POM                             83.00                              17.00        False  (L)
# DOL                             83.00                               8.00        False  (L)
# MOR                            113.00                              14.00        False  (L)
# SRS                              4.27                              17.05        False  (H)
# SOS                             -5.14                               8.40        False  (H)
# PPG                             75.00                              77.00        False  (H)
# Poss Avg                        77.95                              78.69        False  (H)
# FG %                            44.40                              45.60        False  (H)
# Off Rb Avg                      11.00                              11.00        False  (H)
# Def Rb Avg                      20.00                              21.00        False  (H)
# FT ATT Avg                      21.00                              25.00        False  (H)
# Win %                           77.10                              79.40        False  (H)
# Off Rating                      96.22                              97.85        False  (H)
#
#
# Top Conference=  Duke
#
#  Lehigh Wins.
#
# Supporting Stat Count= 6  out of 25  stats.
#
#
#
#                                 Norfolk State                   Missouri     Stat Supports Winner
# Poss Avg                        79.10                              74.14         True  (H)
# Off Rb Avg                      11.00                               9.00         True  (H)
# Def Rb Avg                      21.00                              20.00         True  (H)
# FT ATT Avg                      23.00                              20.00         True  (H)
# Seed                             15                                  2          False  (L)
# SAG                            182.00                               7.00        False  (L)
# WLK                            187.00                               7.00        False  (L)
# WOL                            127.00                               3.00        False  (L)
# RTH                            172.00                               3.00        False  (L)
# COL                            117.00                               7.00        False  (L)
# POM                            214.00                               7.00        False  (L)
# DOL                            126.00                               3.00        False  (L)
# MOR                            236.00                               7.00        False  (L)
# Allow PPG                       67.00                              66.00        False  (L)
# Turnover Avg                    14.00                              10.00        False  (L)
# Net Turnover Avg                 8.00                               2.00        False  (L)
# SRS                             -3.68                              19.77        False  (H)
# SOS                             -5.39                               5.68        False  (H)
# PPG                             68.00                              80.00        False  (H)
# FG %                            44.00                              50.40        False  (H)
# FT %                            65.60                              76.60        False  (H)
# Takeaway Avg                     6.00                               8.00        False  (H)
# Margin Victory Avg               1.00                              14.00        False  (H)
# Win %                           72.20                              85.70        False  (H)
# Off Rating                      85.97                             107.90        False  (H)
#
#
# Top Conference=  Missouri
#
#  Norfolk State Wins.
#
# Supporting Stat Count= 4  out of 25  stats.

# %%
plot_missed_predictions_df = missed_predictions[['game_index','features']]
plot_missed_predictions_df = pd.melt(plot_missed_predictions_df, id_vars='game_index', var_name= 'Features Supporting Outcome')
m_plot = sns.barplot(x='game_index', y='value', hue='Features Supporting Outcome', data= plot_missed_predictions_df) 
plt.title("Percentage Of Features Consistent With Game Outcomes")
plt.ylabel('Percentage')
plt.xlabel('Missed Prediction Game Index')
m_plot.figure.set_size_inches(20,6)

# %% [markdown]
# ##### The bar chart depicts the percentage of features that correctly corresponded to the game outcome but were out weighed by other features in predicting the game incorrectly. Games corresponding to bar heights exceeding 50% should be scrutinized.

# %% [markdown]
# ### Run Model Against 2018 Tournament

# %%
test_year = 2018
feature_copy = feature_data[feature_data['season_t']== test_year].copy()
feature_copy[numeric_features] = scaler.transform(feature_copy[numeric_features])
X_season= feature_copy[feature_list]
y_season = tourney_comp_ratings[tourney_comp_ratings['season_t']== test_year]['game_result']
X_season.shape
# Out:
# (67, 22)

# %%
y_pred_season = gnb.predict(X_season)
utils.display_confusion_matrix(y_season,y_pred_season)
# Out:
# array([[18, 15],
#        [ 9, 25]], dtype=int64)

# %%
prediction_probabilities = gnb.predict_proba(X_season)
print("Accuracy:",metrics.accuracy_score(y_season, y_pred_season))
print("Precision:", metrics.precision_score(y_season,y_pred_season))
print("Recall:",metrics.recall_score(y_season, y_pred_season))
print("Log loss= ",log_loss(y_season, prediction_probabilities))
# Out:
# Accuracy: 0.6417910447761194
# Precision: 0.625
# Recall: 0.7352941176470589
# Log loss=  2.9503248748684547

# %%
missed_predictions = get_missed_predictions(tourney_comp_ratings, feature_list, numeric_feature_to_scale, 
                                            prediction_probabilities,X_season,y_season,y_pred_season)

# %%
plot_missed_predictions_df = missed_predictions[['game_index','features']]
plot_missed_predictions_df = pd.melt(plot_missed_predictions_df, id_vars='game_index', var_name= 'Features Supporting Outcome')
m_plot = sns.barplot(x='game_index', y='value', hue='Features Supporting Outcome', data= plot_missed_predictions_df) 
plt.title("Percentage Of Features Consistent With Game Outcomes")
plt.ylabel('Percentage')
plt.xlabel('MIssed Prediction Game Index')
m_plot.figure.set_size_inches(20,6)
